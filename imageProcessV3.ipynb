# %% [markdown]
# ## Design Overview
#
# This notebook implements an automated Optical Mark Recognition (OMR) workflow for processing scanned answer sheets. The main steps are:
#
# 1. **Preprocessing**: Images are loaded, converted to grayscale, blurred, and binarized to enhance bubble detection.
# 2. **Circle Detection**: Hough Circle Transform is used to detect answer bubbles. Both sequential and parallel approaches are provided for robustness and speed.
# 3. **Pixel Counting**: For each detected bubble, black and white pixel counts are computed to distinguish marked from unmarked bubbles.
# 4. **Row Grouping**: Detected bubbles are grouped by rows using DBSCAN clustering, enabling question-wise analysis.
# 5. **Marked Bubble Identification**: Statistical analysis (mean and standard deviation) of pixel counts is used to identify marked bubbles per question.
# 6. **Scoring**: Student answers are compared to the answer key, and the total score is calculated

# %% [markdown]
# ## Steps

# %% [markdown]
# ### 1. Preprocessing

# %%
import cv2
import numpy as np
import time

def preprocess_image(image_path, blur_ksize=(5, 5)):
    """
    Preprocess the input image by converting it to grayscale and applying Gaussian blur and convert it to binary image.
    
    Args:
        image_path (str): Path to the input image.
        blur_ksize (tuple): Kernel size for the Gaussian blur (default is (5, 5)).
        
    Returns:
        gray_blurred (numpy array): Blurred grayscale version of the image.
        original_img (numpy array): Original color image.
        gray (numpy array): Grayscale version of the image.
        binary_img (numpy array): Binary version of the image
    """
    # Read the image.
    original_img = cv2.imread(image_path, cv2.IMREAD_COLOR)

    if original_img is None:
        raise ValueError(f"Image at {image_path} not found.")
    
    # Convert to grayscale.
    gray = cv2.cvtColor(original_img, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur.
    gray_blurred = cv2.GaussianBlur(gray, blur_ksize, 0)

    # Convert the original image to a binary image
    _, binary_img = cv2.threshold(gray_blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    return gray_blurred, original_img, gray, binary_img

# %%
# Preprocess the images
start_1= time.time()
gray_blurred_s, original_img_s, gray_s, binary_img_s = preprocess_image('./Test/8df22.jpg')
gray_blurred_t, original_img_t, gray_t, binary_img_t = preprocess_image('./Test/9_T.jpg')
gray_blurred_k, original_img_k, gray_k, binary_img_k = preprocess_image('./Test/79109.jpg')
end_1= time.time()
print("Preprocessing time:", end_1-start_1)
questions = 40
options=4
# Out:
# Preprocessing time: 0.05321168899536133

# %% [markdown]
# ### 2.0 Circle Detection

# %%
from collections import Counter
def detect_circles_template(img, gray_blurred, questions, options):
    """
    Detect circles in the preprocessed grayscale image using the Hough Circle Transform.
    
    Args:
        img (numpy array): Original image for visualization.
        gray_blurred (numpy array): Blurred grayscale image.
        num_questions (int): Number of questions in the OMR.
        num_options (int): Number of options per question.
        dp (float): Inverse ratio of the accumulator resolution to the image resolution (default is 1).
        min_dist (int): Minimum distance between the centers of detected circles (default is 1).
        param1 (float): First method-specific parameter (gradient threshold for Canny edge detection).
        param2 (float): Second method-specific parameter (accumulator threshold for circle detection).
        min_radius_range (tuple): Tuple for minimum and maximum radius values for circle detection.
    
    Returns:
        detected_circles (numpy array): Array of detected circles, if found.
    """
    
    for b in range(15,5,-1): 
        for a in range(5,35):  
            detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, a, 
                            param1 = b,param2 = 3*b, minRadius = a//2, maxRadius = a) 
            if detected_circles is not None:
                
                print(f"circles:{detected_circles.shape[1]},a:{a},b:{b}")
                if detected_circles.shape[1]==questions*options:
                    detected_circles=np.uint16(np.around(detected_circles))
                    radii_list = [pt[2] for pt in detected_circles[0, :]]
                    
                    # Find the most common radius
                    most_common_radius = Counter(radii_list).most_common(1)[0][0]
                    print(f"Most common radius: {most_common_radius}")

                    for pt in detected_circles[0, :]: 
                        x, y, r = pt[0], pt[1], pt[2] 

                        # Draw the circumference of the circle. 
                        cv2.circle(img, (x, y), r, (0, 255, 0), 3) 

                        # Draw a small circle (of radius 1) to show the center. 
                        cv2.circle(img, (x, y), 2, (0, 0, 255), 3) 
                    #cv2.imwrite(f'./testoutput/detected_circlesf7.jpg', img)
                    cv2.imshow("Detected Circle", img) 
                    cv2.waitKey(0) 
                    return detected_circles, most_common_radius,a,b

    cv2.destroyAllWindows()
    return None

# %%
import math
def detect_circles(img, gray_blurred, questions, options, mode_radius, a_t, b_t):
    """
    Detect circles in the preprocessed grayscale image using the Hough Circle Transform.
    
    Args:
        img (numpy array): Original image for visualization.
        gray_blurred (numpy array): Blurred grayscale image.
        num_questions (int): Number of questions in the OMR.
        num_options (int): Number of options per question.
        dp (float): Inverse ratio of the accumulator resolution to the image resolution (default is 1).
        min_dist (int): Minimum distance between the centers of detected circles (default is 1).
        param1 (float): First method-specific parameter (gradient threshold for Canny edge detection).
        param2 (float): Second method-specific parameter (accumulator threshold for circle detection).
        min_radius_range (tuple): Tuple for minimum and maximum radius values for circle detection.
    
    Returns:
        detected_circles (numpy array): Array of detected circles, if found.
    """
    #b=b_t
    # a=math.ceil(mode_radius+mode_radius*0.20)

    upper_a = max(a_t, mode_radius)
    lower_a = min(a_t, mode_radius)
    upper_a_threshold = math.ceil(upper_a + upper_a * 0.20)
    lower_a_threshold = math.floor(lower_a - lower_a * 0.20)

    # Ensure b_t and lower bound are not less than 0
    for b in range(max(b_t, 0), max(b_t - 10, 0), -1):
        for a in range(max(upper_a_threshold, 0), max(lower_a_threshold, 0) - 1, -1):
            # Your processing logic here

            detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, a, 
                            param1 = b,param2 = 3*b, minRadius = a//2, maxRadius = a) 
            if detected_circles is not None:
                print(f"detect_circles: {detected_circles.shape[1]}, a: {a}, b: {b}")
                
                if detected_circles.shape[1]==questions*options:
                    detected_circles=np.uint16(np.around(detected_circles))
                    for pt in detected_circles[0, :]: 
                        a, b, r = pt[0], pt[1], pt[2] 
    
                        cv2.circle(img, (a, b), r, (0, 255, 0), 3) 
                        cv2.circle(img, (a, b), 2, (0, 0, 255), 3) 
                    cv2.imshow("Detected Circle", img) 
                    #cv2.imwrite(f'./testoutput/detected_circles{a}b{b}.jpg', img)
                    cv2.waitKey(0) 
                    return detected_circles

    cv2.destroyAllWindows()
    return None

# %%
start_2= time.time()
detected_circles_t,mode_radius,a_t,b_t = detect_circles_template(
    original_img_t, gray_blurred_t, 
    questions, options,
)
end_2= time.time()
print("Detecting circles time template:", end_2-start_2)
# Out:
# circles:1,a:11,b:15
# circles:24,a:12,b:15
# circles:107,a:13,b:15
# circles:87,a:14,b:15
# circles:92,a:15,b:15
# circles:95,a:16,b:15
# circles:94,a:17,b:15
# circles:90,a:18,b:15
# circles:90,a:19,b:15
# circles:79,a:20,b:15
# circles:78,a:21,b:15
# circles:37,a:22,b:15
# circles:37,a:23,b:15
# circles:10,a:24,b:15
# circles:10,a:25,b:15
# circles:1,a:27,b:15
# circles:1,a:10,b:14
# circles:3,a:11,b:14
# circles:44,a:12,b:14
# circles:120,a:13,b:14
# circles:109,a:14,b:14
# circles:111,a:15,b:14
# circles:117,a:16,b:14
# circles:115,a:17,b:14
# circles:115,a:18,b:14
# circles:116,a:19,b:14
# circles:109,a:20,b:14
# circles:109,a:21,b:14
# circles:63,a:22,b:14
# circles:63,a:23,b:14
# circles:26,a:24,b:14
# circles:26,a:25,b:14
# circles:1,a:26,b:14
# circles:1,a:27,b:14
# circles:6,a:10,b:13
# circles:11,a:11,b:13
# circles:70,a:12,b:13
# circles:130,a:13,b:13
# circles:127,a:14,b:13
# circles:122,a:15,b:13
# circles:126,a:16,b:13
# circles:129,a:17,b:13
# circles:129,a:18,b:13
# circles:130,a:19,b:13
# circles:121,a:20,b:13
# circles:120,a:21,b:13
# circles:89,a:22,b:13
# circles:90,a:23,b:13
# circles:38,a:24,b:13
# circles:38,a:25,b:13
# circles:1,a:26,b:13
# circles:2,a:27,b:13
# circles:12,a:10,b:12
# circles:30,a:11,b:12
# circles:98,a:12,b:12
# circles:139,a:13,b:12
# circles:142,a:14,b:12
# circles:140,a:15,b:12
# circles:144,a:16,b:12
# circles:147,a:17,b:12
# circles:153,a:18,b:12
# circles:152,a:19,b:12
# circles:142,a:20,b:12
# circles:142,a:21,b:12
# circles:126,a:22,b:12
# circles:127,a:23,b:12
# circles:63,a:24,b:12
# circles:64,a:25,b:12
# circles:3,a:26,b:12
# circles:3,a:27,b:12
# circles:1,a:33,b:12
# circles:23,a:10,b:11
# circles:70,a:11,b:11
# circles:127,a:12,b:11
# circles:154,a:13,b:11
# circles:155,a:14,b:11
# circles:154,a:15,b:11
# circles:155,a:16,b:11
# circles:155,a:17,b:11
# circles:157,a:18,b:11
# circles:156,a:19,b:11
# circles:157,a:20,b:11
# circles:156,a:21,b:11
# circles:143,a:22,b:11
# circles:146,a:23,b:11
# circles:97,a:24,b:11
# circles:98,a:25,b:11
# circles:9,a:26,b:11
# circles:9,a:27,b:11
# circles:1,a:31,b:11
# circles:1,a:32,b:11
# circles:1,a:33,b:11
# circles:1,a:34,b:11
# circles:1,a:9,b:10
# circles:41,a:10,b:10
# circles:115,a:11,b:10
# circles:149,a:12,b:10
# circles:157,a:13,b:10
# circles:159,a:14,b:10
# circles:158,a:15,b:10
# circles:160,a:16,b:10
# Most common radius: 12
# Detecting circles time template: 11.768578290939331

# %%
start_3= time.time()
detected_circles_s = detect_circles(
    original_img_s, gray_blurred_s, 
    questions, options, mode_radius, a_t, b_t
)

detected_circles_k = detect_circles(
    original_img_k, gray_blurred_k, 
    questions, options, mode_radius, a_t, b_t
)
end_3= time.time()
print("Detecting circles time:", end_3-start_3)
# Out:
# detect_circles: 156, a: 20, b: 10
# detect_circles: 159, a: 19, b: 10
# detect_circles: 158, a: 18, b: 10
# detect_circles: 158, a: 17, b: 10
# detect_circles: 158, a: 16, b: 10
# detect_circles: 153, a: 15, b: 10
# detect_circles: 153, a: 14, b: 10
# detect_circles: 144, a: 13, b: 10
# detect_circles: 153, a: 12, b: 10
# detect_circles: 103, a: 11, b: 10
# detect_circles: 26, a: 10, b: 10
# detect_circles: 12, a: 9, b: 10
# detect_circles: 159, a: 20, b: 9
# detect_circles: 160, a: 19, b: 9
# detect_circles: 155, a: 20, b: 10
# detect_circles: 156, a: 19, b: 10
# detect_circles: 155, a: 18, b: 10
# detect_circles: 156, a: 17, b: 10
# detect_circles: 157, a: 16, b: 10
# detect_circles: 152, a: 15, b: 10
# detect_circles: 149, a: 14, b: 10
# detect_circles: 148, a: 13, b: 10
# detect_circles: 149, a: 12, b: 10
# detect_circles: 135, a: 11, b: 10
# detect_circles: 38, a: 10, b: 10
# detect_circles: 3, a: 9, b: 10
# detect_circles: 159, a: 20, b: 9
# detect_circles: 158, a: 19, b: 9
# detect_circles: 158, a: 18, b: 9
# detect_circles: 159, a: 17, b: 9
# detect_circles: 160, a: 16, b: 9
# Detecting circles time: 4.0238401889801025

# %%
# Draw detected circles on the original images and display them
for title, img, circles in [
    ("Student Sheet", original_img_s, detected_circles_s),
    ("Template",    original_img_t, detected_circles_t),
    ("Answer Key",  original_img_k, detected_circles_k),
]:
    img_drawn = img.copy()
    # circles is of shape (1, N, 3)
    if circles is None:
        print(f"No circles detected in {title}.")
        continue
    for (x, y, r) in circles[0]:
        # outer circle
        cv2.circle(img_drawn, (int(x), int(y)), int(r), (0, 255, 0), 2)
        # center point
        cv2.circle(img_drawn, (int(x), int(y)), 2, (0, 0, 255), 3)
    cv2.imshow(f"Detected Circles - {title}", img_drawn)
    cv2.waitKey(0)

cv2.destroyAllWindows()

# %% [markdown]
# ### 2.1 circle detection using parallel processing

# %%
import concurrent.futures
from collections import Counter

def hough_for_params(params):
    a, b, gray_blurred, questions, options = params
    detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, a,
                                        param1=b, param2=3*b, minRadius=a//2, maxRadius=a)
    if detected_circles is not None and detected_circles.shape[1] == questions * options:
        detected_circles = np.uint16(np.around(detected_circles))
        radii_list = [pt[2] for pt in detected_circles[0, :]]
        most_common_radius = Counter(radii_list).most_common(1)[0][0]
        return detected_circles, most_common_radius, a, b
    return None

def detect_circles_template_parallel(img, gray_blurred, questions, options):
    # Generate all (a,b) pairs, same ranges as before
    param_combinations = [(a, b, gray_blurred, questions, options) 
                          for b in range(15, 5, -1) 
                          for a in range(5, 35)]
    
    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(executor.map(hough_for_params, param_combinations))
        
    # Filter out None results and return the first valid detection
    for result in results:
        if result is not None:
            detected_circles, most_common_radius, a, b = result
            print(f"circles:{detected_circles.shape[1]}, a:{a}, b:{b}")
            print(f"Most common radius: {most_common_radius}")
            return detected_circles, most_common_radius, a, b

    return None
if __name__ == "__main__":
    start_2= time.time()
    detected_circles_t,mode_radius,a_t,b_t = detect_circles_template_parallel(
        original_img_t, gray_blurred_t, 
        questions, options,
    )
    end_2= time.time()
    print("Detecting circles time template:", end_2-start_2)
# Out:
# circles:160, a:16, b:10
# Most common radius: 12
# Detecting circles time template: 2.2580857276916504

# %% [markdown]
# ### 3. Pixel counts

# %%
import cv2
import numpy as np

def count_black_and_white_pixels(img, circles):
    """
    Count black and white pixels in the detected circles.

    Parameters:
    - img: The binary image (where black indicates marked areas).
    - circles: List of detected circles in the format (x, y, r).

    Returns:
    - A list of tuples containing counts of (black_pixels, white_pixels) for each circle.
    """
    counts = []

    for (x, y, r) in circles:
        # Create a mask for the current circle
        mask = np.zeros_like(img, dtype=np.uint8)
        cv2.circle(mask, (x, y), r, (255), thickness=-1)  # Fill the circle in the mask

        # Apply the mask to get the pixel values within the circle
        masked_area = cv2.bitwise_and(img, mask)

        # Count black and white pixels
        black_pixels = np.sum(masked_area == 0)   # Count of black pixels (0)
        white_pixels = np.sum(masked_area == 255) # Count of white pixels (255)

        counts.append((x,y,r,black_pixels, white_pixels))

    return counts

# %%
circles_s = detected_circles_s[0, :]
circles_t = detected_circles_t[0, :]  
circles_k = detected_circles_k[0, :]
start = time.time()
# Count black and white pixels in the detected circles
pixel_counts_s = count_black_and_white_pixels(binary_img_s, circles_s)
pixel_counts_t = count_black_and_white_pixels(binary_img_t, circles_t)
pixel_counts_k = count_black_and_white_pixels(binary_img_k, circles_k)
end = time.time()
print("Counting pixels time:", end-start)
# Print the results
print("students answer sheet")
for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_s, start=1):
    print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")

print("template")
for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_t, start=1):
    print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")

print("key")
for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_k, start=1):
    print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")

# Display the binary image
#cv2.imshow("Binary Image", binary_img)

# Draw the circles on the binary image for visualization
for (x, y, r) in circles_s:
    cv2.circle(binary_img_s, (x, y), r, (127), 2)  # Draw circles in a different color (grey)
cv2.imshow("Detected Circles in Binary Image student", binary_img_s)
cv2.waitKey(0)


for (x, y, r) in circles_t:
    cv2.circle(binary_img_t, (x, y), r, (127), 2)  
cv2.imshow("Detected Circles in Binary Image template", binary_img_t)
cv2.waitKey(0)

for (x, y, r) in circles_k:
    cv2.circle(binary_img_k, (x, y), r, (127), 2)
cv2.imshow("Detected Circles in Binary Image key(scheme)", binary_img_k)
cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# Counting pixels time: 1.6478755474090576
# students answer sheet
# Circle 1: Coordinates = (762, 554), Black Pixels = 1228645, White Pixels = 155
# Circle 2: Coordinates = (594, 516), Black Pixels = 1228657, White Pixels = 143
# Circle 3: Coordinates = (594, 234), Black Pixels = 1228594, White Pixels = 206
# Circle 4: Coordinates = (760, 512), Black Pixels = 1228644, White Pixels = 156
# Circle 5: Coordinates = (634, 516), Black Pixels = 1228665, White Pixels = 135
# Circle 6: Coordinates = (800, 512), Black Pixels = 1228793, White Pixels = 7
# Circle 7: Coordinates = (838, 432), Black Pixels = 1228677, White Pixels = 123
# Circle 8: Coordinates = (876, 236), Black Pixels = 1228646, White Pixels = 154
# Circle 9: Coordinates = (384, 606), Black Pixels = 1228639, White Pixels = 161
# Circle 10: Coordinates = (556, 474), Black Pixels = 1228776, White Pixels = 24
# Circle 11: Coordinates = (838, 472), Black Pixels = 1228782, White Pixels = 18
# Circle 12: Coordinates = (876, 354), Black Pixels = 1228684, White Pixels = 116
# Circle 13: Coordinates = (634, 558), Black Pixels = 1228652, White Pixels = 148
# Circle 14: Coordinates = (262, 228), Black Pixels = 1228589, White Pixels = 211
# Circle 15: Coordinates = (838, 276), Black Pixels = 1228663, White Pixels = 137
# Circle 16: Coordinates = (262, 270), Black Pixels = 1228601, White Pixels = 199
# Circle 17: Coordinates = (798, 432), Black Pixels = 1228778, White Pixels = 22
# Circle 18: Coordinates = (838, 316), Black Pixels = 1228668, White Pixels = 132
# Circle 19: Coordinates = (252, 520), Black Pixels = 1228618, White Pixels = 182
# Circle 20: Coordinates = (798, 316), Black Pixels = 1228786, White Pixels = 14
# Circle 21: Coordinates = (634, 274), Black Pixels = 1228642, White Pixels = 158
# Circle 22: Coordinates = (1106, 316), Black Pixels = 1228669, White Pixels = 131
# Circle 23: Coordinates = (338, 606), Black Pixels = 1228653, White Pixels = 147
# Circle 24: Coordinates = (514, 476), Black Pixels = 1228615, White Pixels = 185
# Circle 25: Coordinates = (760, 434), Black Pixels = 1228626, White Pixels = 174
# Circle 26: Coordinates = (798, 394), Black Pixels = 1228775, White Pixels = 25
# Circle 27: Coordinates = (876, 316), Black Pixels = 1228651, White Pixels = 149
# Circle 28: Coordinates = (878, 472), Black Pixels = 1228688, White Pixels = 112
# Circle 29: Coordinates = (1082, 592), Black Pixels = 1228670, White Pixels = 130
# Circle 30: Coordinates = (758, 316), Black Pixels = 1228608, White Pixels = 192
# Circle 31: Coordinates = (1112, 470), Black Pixels = 1228658, White Pixels = 142
# Circle 32: Coordinates = (634, 314), Black Pixels = 1228634, White Pixels = 166
# Circle 33: Coordinates = (1032, 354), Black Pixels = 1228663, White Pixels = 137
# Circle 34: Coordinates = (876, 276), Black Pixels = 1228655, White Pixels = 145
# Circle 35: Coordinates = (800, 234), Black Pixels = 1228798, White Pixels = 2
# Circle 36: Coordinates = (338, 562), Black Pixels = 1228797, White Pixels = 3
# Circle 37: Coordinates = (302, 228), Black Pixels = 1228634, White Pixels = 166
# Circle 38: Coordinates = (798, 472), Black Pixels = 1228671, White Pixels = 129
# Circle 39: Coordinates = (342, 312), Black Pixels = 1228797, White Pixels = 3
# Circle 40: Coordinates = (634, 600), Black Pixels = 1228656, White Pixels = 144
# Circle 41: Coordinates = (1110, 430), Black Pixels = 1228639, White Pixels = 161
# Circle 42: Coordinates = (1030, 238), Black Pixels = 1228773, White Pixels = 27
# Circle 43: Coordinates = (594, 434), Black Pixels = 1228648, White Pixels = 152
# Circle 44: Coordinates = (760, 474), Black Pixels = 1228663, White Pixels = 137
# Circle 45: Coordinates = (384, 562), Black Pixels = 1228646, White Pixels = 154
# Circle 46: Coordinates = (762, 596), Black Pixels = 1228631, White Pixels = 169
# Circle 47: Coordinates = (882, 594), Black Pixels = 1228672, White Pixels = 128
# Circle 48: Coordinates = (800, 552), Black Pixels = 1228696, White Pixels = 104
# Circle 49: Coordinates = (556, 434), Black Pixels = 1228667, White Pixels = 133
# Circle 50: Coordinates = (760, 274), Black Pixels = 1228799, White Pixels = 1
# Circle 51: Coordinates = (1070, 316), Black Pixels = 1228798, White Pixels = 2
# Circle 52: Coordinates = (758, 354), Black Pixels = 1228613, White Pixels = 187
# Circle 53: Coordinates = (758, 394), Black Pixels = 1228635, White Pixels = 165
# Circle 54: Coordinates = (1076, 510), Black Pixels = 1228676, White Pixels = 124
# Circle 55: Coordinates = (514, 394), Black Pixels = 1228623, White Pixels = 177
# Circle 56: Coordinates = (292, 608), Black Pixels = 1228799, White Pixels = 1
# Circle 57: Coordinates = (300, 312), Black Pixels = 1228652, White Pixels = 148
# Circle 58: Coordinates = (340, 520), Black Pixels = 1228656, White Pixels = 144
# Circle 59: Coordinates = (514, 516), Black Pixels = 1228779, White Pixels = 21
# Circle 60: Coordinates = (256, 394), Black Pixels = 1228618, White Pixels = 182
# Circle 61: Coordinates = (382, 394), Black Pixels = 1228630, White Pixels = 170
# Circle 62: Coordinates = (634, 394), Black Pixels = 1228672, White Pixels = 128
# Circle 63: Coordinates = (386, 478), Black Pixels = 1228652, White Pixels = 148
# Circle 64: Coordinates = (876, 394), Black Pixels = 1228679, White Pixels = 121
# Circle 65: Coordinates = (250, 608), Black Pixels = 1228618, White Pixels = 182
# Circle 66: Coordinates = (594, 356), Black Pixels = 1228604, White Pixels = 196
# Circle 67: Coordinates = (296, 394), Black Pixels = 1228652, White Pixels = 148
# Circle 68: Coordinates = (876, 432), Black Pixels = 1228649, White Pixels = 151
# Circle 69: Coordinates = (1122, 592), Black Pixels = 1228672, White Pixels = 128
# Circle 70: Coordinates = (554, 556), Black Pixels = 1228785, White Pixels = 15
# Circle 71: Coordinates = (840, 552), Black Pixels = 1228789, White Pixels = 11
# Circle 72: Coordinates = (1034, 432), Black Pixels = 1228688, White Pixels = 112
# Circle 73: Coordinates = (836, 394), Black Pixels = 1228679, White Pixels = 121
# Circle 74: Coordinates = (1074, 472), Black Pixels = 1228663, White Pixels = 137
# Circle 75: Coordinates = (514, 434), Black Pixels = 1228790, White Pixels = 10
# Circle 76: Coordinates = (514, 232), Black Pixels = 1228800, White Pixels = 0
# Circle 77: Coordinates = (386, 272), Black Pixels = 1228642, White Pixels = 158
# Circle 78: Coordinates = (554, 356), Black Pixels = 1228672, White Pixels = 128
# Circle 79: Coordinates = (634, 476), Black Pixels = 1228666, White Pixels = 134
# Circle 80: Coordinates = (798, 276), Black Pixels = 1228689, White Pixels = 111
# Circle 81: Coordinates = (798, 354), Black Pixels = 1228693, White Pixels = 107
# Circle 82: Coordinates = (1038, 510), Black Pixels = 1228700, White Pixels = 100
# Circle 83: Coordinates = (842, 594), Black Pixels = 1228682, White Pixels = 118
# Circle 84: Coordinates = (1072, 432), Black Pixels = 1228653, White Pixels = 147
# Circle 85: Coordinates = (514, 354), Black Pixels = 1228779, White Pixels = 21
# Circle 86: Coordinates = (882, 552), Black Pixels = 1228657, White Pixels = 143
# Circle 87: Coordinates = (1106, 278), Black Pixels = 1228646, White Pixels = 154
# Circle 88: Coordinates = (256, 354), Black Pixels = 1228800, White Pixels = 0
# Circle 89: Coordinates = (340, 436), Black Pixels = 1228649, White Pixels = 151
# Circle 90: Coordinates = (556, 276), Black Pixels = 1228674, White Pixels = 126
# Circle 91: Coordinates = (1042, 594), Black Pixels = 1228687, White Pixels = 113
# Circle 92: Coordinates = (1080, 550), Black Pixels = 1228799, White Pixels = 1
# Circle 93: Coordinates = (250, 564), Black Pixels = 1228610, White Pixels = 190
# Circle 94: Coordinates = (384, 352), Black Pixels = 1228503, White Pixels = 297
# Circle 95: Coordinates = (344, 228), Black Pixels = 1228795, White Pixels = 5
# Circle 96: Coordinates = (992, 238), Black Pixels = 1228616, White Pixels = 184
# Circle 97: Coordinates = (760, 232), Black Pixels = 1228629, White Pixels = 171
# Circle 98: Coordinates = (838, 234), Black Pixels = 1228668, White Pixels = 132
# Circle 99: Coordinates = (340, 478), Black Pixels = 1228622, White Pixels = 178
# Circle 100: Coordinates = (514, 272), Black Pixels = 1228596, White Pixels = 204
# Circle 101: Coordinates = (254, 480), Black Pixels = 1228788, White Pixels = 12
# Circle 102: Coordinates = (258, 312), Black Pixels = 1228592, White Pixels = 208
# Circle 103: Coordinates = (342, 394), Black Pixels = 1228782, White Pixels = 18
# Circle 104: Coordinates = (594, 556), Black Pixels = 1228631, White Pixels = 169
# Circle 105: Coordinates = (1036, 472), Black Pixels = 1228772, White Pixels = 28
# Circle 106: Coordinates = (1072, 392), Black Pixels = 1228666, White Pixels = 134
# Circle 107: Coordinates = (1070, 354), Black Pixels = 1228651, White Pixels = 149
# Circle 108: Coordinates = (384, 436), Black Pixels = 1228626, White Pixels = 174
# Circle 109: Coordinates = (594, 314), Black Pixels = 1228641, White Pixels = 159
# Circle 110: Coordinates = (594, 476), Black Pixels = 1228670, White Pixels = 130
# Circle 111: Coordinates = (386, 518), Black Pixels = 1228637, White Pixels = 163
# Circle 112: Coordinates = (556, 514), Black Pixels = 1228652, White Pixels = 148
# Circle 113: Coordinates = (1032, 316), Black Pixels = 1228654, White Pixels = 146
# Circle 114: Coordinates = (802, 596), Black Pixels = 1228786, White Pixels = 14
# Circle 115: Coordinates = (516, 316), Black Pixels = 1228613, White Pixels = 187
# Circle 116: Coordinates = (998, 472), Black Pixels = 1228662, White Pixels = 138
# Circle 117: Coordinates = (994, 392), Black Pixels = 1228673, White Pixels = 127
# Circle 118: Coordinates = (1108, 354), Black Pixels = 1228685, White Pixels = 115
# Circle 119: Coordinates = (388, 230), Black Pixels = 1228632, White Pixels = 168
# Circle 120: Coordinates = (1002, 594), Black Pixels = 1228765, White Pixels = 35
# Circle 121: Coordinates = (302, 272), Black Pixels = 1228760, White Pixels = 40
# Circle 122: Coordinates = (298, 436), Black Pixels = 1228797, White Pixels = 3
# Circle 123: Coordinates = (254, 436), Black Pixels = 1228619, White Pixels = 181
# Circle 124: Coordinates = (556, 234), Black Pixels = 1228662, White Pixels = 138
# Circle 125: Coordinates = (556, 394), Black Pixels = 1228674, White Pixels = 126
# Circle 126: Coordinates = (838, 356), Black Pixels = 1228788, White Pixels = 12
# Circle 127: Coordinates = (1002, 552), Black Pixels = 1228655, White Pixels = 145
# Circle 128: Coordinates = (992, 278), Black Pixels = 1228778, White Pixels = 22
# Circle 129: Coordinates = (1068, 278), Black Pixels = 1228685, White Pixels = 115
# Circle 130: Coordinates = (594, 600), Black Pixels = 1228661, White Pixels = 139
# Circle 131: Coordinates = (1120, 550), Black Pixels = 1228681, White Pixels = 119
# Circle 132: Coordinates = (294, 564), Black Pixels = 1228654, White Pixels = 146
# Circle 133: Coordinates = (1110, 392), Black Pixels = 1228657, White Pixels = 143
# Circle 134: Coordinates = (1040, 550), Black Pixels = 1228673, White Pixels = 127
# Circle 135: Coordinates = (554, 600), Black Pixels = 1228792, White Pixels = 8
# Circle 136: Coordinates = (384, 312), Black Pixels = 1228628, White Pixels = 172
# Circle 137: Coordinates = (1000, 510), Black Pixels = 1228649, White Pixels = 151
# Circle 138: Coordinates = (1032, 392), Black Pixels = 1228787, White Pixels = 13
# Circle 139: Coordinates = (1068, 238), Black Pixels = 1228696, White Pixels = 104
# Circle 140: Coordinates = (514, 556), Black Pixels = 1228618, White Pixels = 182
# Circle 141: Coordinates = (1116, 510), Black Pixels = 1228785, White Pixels = 15
# Circle 142: Coordinates = (994, 354), Black Pixels = 1228800, White Pixels = 0
# Circle 143: Coordinates = (634, 434), Black Pixels = 1228650, White Pixels = 150
# Circle 144: Coordinates = (294, 520), Black Pixels = 1228800, White Pixels = 0
# Circle 145: Coordinates = (992, 316), Black Pixels = 1228635, White Pixels = 165
# Circle 146: Coordinates = (1030, 278), Black Pixels = 1228675, White Pixels = 125
# Circle 147: Coordinates = (340, 354), Black Pixels = 1228652, White Pixels = 148
# Circle 148: Coordinates = (880, 512), Black Pixels = 1228681, White Pixels = 119
# Circle 149: Coordinates = (296, 480), Black Pixels = 1228670, White Pixels = 130
# Circle 150: Coordinates = (1106, 238), Black Pixels = 1228671, White Pixels = 129
# Circle 151: Coordinates = (996, 432), Black Pixels = 1228800, White Pixels = 0
# Circle 152: Coordinates = (514, 598), Black Pixels = 1228645, White Pixels = 155
# Circle 153: Coordinates = (556, 314), Black Pixels = 1228748, White Pixels = 52
# Circle 154: Coordinates = (634, 234), Black Pixels = 1228605, White Pixels = 195
# Circle 155: Coordinates = (632, 356), Black Pixels = 1228644, White Pixels = 156
# Circle 156: Coordinates = (838, 512), Black Pixels = 1228695, White Pixels = 105
# Circle 157: Coordinates = (298, 354), Black Pixels = 1228653, White Pixels = 147
# Circle 158: Coordinates = (594, 394), Black Pixels = 1228797, White Pixels = 3
# Circle 159: Coordinates = (344, 272), Black Pixels = 1228638, White Pixels = 162
# Circle 160: Coordinates = (596, 274), Black Pixels = 1228767, White Pixels = 33
# template
# Circle 1: Coordinates = (772, 520), Black Pixels = 1228646, White Pixels = 154
# Circle 2: Coordinates = (218, 334), Black Pixels = 1228556, White Pixels = 244
# Circle 3: Coordinates = (854, 522), Black Pixels = 1228644, White Pixels = 156
# Circle 4: Coordinates = (526, 300), Black Pixels = 1228650, White Pixels = 150
# Circle 5: Coordinates = (350, 384), Black Pixels = 1228578, White Pixels = 222
# Circle 6: Coordinates = (854, 392), Black Pixels = 1228644, White Pixels = 156
# Circle 7: Coordinates = (204, 612), Black Pixels = 1228536, White Pixels = 264
# Circle 8: Coordinates = (602, 610), Black Pixels = 1228624, White Pixels = 176
# Circle 9: Coordinates = (602, 566), Black Pixels = 1228631, White Pixels = 169
# Circle 10: Coordinates = (214, 380), Black Pixels = 1228554, White Pixels = 246
# Circle 11: Coordinates = (204, 660), Black Pixels = 1228547, White Pixels = 253
# Circle 12: Coordinates = (264, 246), Black Pixels = 1228566, White Pixels = 234
# Circle 13: Coordinates = (1018, 568), Black Pixels = 1228662, White Pixels = 138
# Circle 14: Coordinates = (734, 346), Black Pixels = 1228615, White Pixels = 185
# Circle 15: Coordinates = (974, 264), Black Pixels = 1228631, White Pixels = 169
# Circle 16: Coordinates = (250, 612), Black Pixels = 1228589, White Pixels = 211
# Circle 17: Coordinates = (604, 476), Black Pixels = 1228626, White Pixels = 174
# Circle 18: Coordinates = (256, 426), Black Pixels = 1228613, White Pixels = 187
# Circle 19: Coordinates = (302, 474), Black Pixels = 1228621, White Pixels = 179
# Circle 20: Coordinates = (558, 658), Black Pixels = 1228605, White Pixels = 195
# Circle 21: Coordinates = (222, 244), Black Pixels = 1228580, White Pixels = 220
# Circle 22: Coordinates = (346, 566), Black Pixels = 1228588, White Pixels = 212
# Circle 23: Coordinates = (1064, 658), Black Pixels = 1228639, White Pixels = 161
# Circle 24: Coordinates = (606, 256), Black Pixels = 1228624, White Pixels = 176
# Circle 25: Coordinates = (208, 518), Black Pixels = 1228537, White Pixels = 263
# Circle 26: Coordinates = (256, 472), Black Pixels = 1228603, White Pixels = 197
# Circle 27: Coordinates = (302, 428), Black Pixels = 1228611, White Pixels = 189
# Circle 28: Coordinates = (604, 388), Black Pixels = 1228586, White Pixels = 214
# Circle 29: Coordinates = (732, 432), Black Pixels = 1228603, White Pixels = 197
# Circle 30: Coordinates = (478, 564), Black Pixels = 1228589, White Pixels = 211
# Circle 31: Coordinates = (484, 254), Black Pixels = 1228560, White Pixels = 240
# Circle 32: Coordinates = (1058, 568), Black Pixels = 1228646, White Pixels = 154
# Circle 33: Coordinates = (206, 566), Black Pixels = 1228546, White Pixels = 254
# Circle 34: Coordinates = (600, 658), Black Pixels = 1228593, White Pixels = 207
# Circle 35: Coordinates = (732, 520), Black Pixels = 1228613, White Pixels = 187
# Circle 36: Coordinates = (814, 434), Black Pixels = 1228668, White Pixels = 132
# Circle 37: Coordinates = (978, 478), Black Pixels = 1228617, White Pixels = 183
# Circle 38: Coordinates = (1056, 394), Black Pixels = 1228662, White Pixels = 138
# Circle 39: Coordinates = (1104, 612), Black Pixels = 1228641, White Pixels = 159
# Circle 40: Coordinates = (250, 660), Black Pixels = 1228600, White Pixels = 200
# Circle 41: Coordinates = (814, 390), Black Pixels = 1228614, White Pixels = 186
# Circle 42: Coordinates = (1018, 524), Black Pixels = 1228603, White Pixels = 197
# Circle 43: Coordinates = (220, 290), Black Pixels = 1228570, White Pixels = 230
# Circle 44: Coordinates = (732, 476), Black Pixels = 1228617, White Pixels = 183
# Circle 45: Coordinates = (856, 304), Black Pixels = 1228647, White Pixels = 153
# Circle 46: Coordinates = (774, 390), Black Pixels = 1228654, White Pixels = 146
# Circle 47: Coordinates = (564, 386), Black Pixels = 1228613, White Pixels = 187
# Circle 48: Coordinates = (606, 300), Black Pixels = 1228633, White Pixels = 167
# Circle 49: Coordinates = (298, 612), Black Pixels = 1228585, White Pixels = 215
# Circle 50: Coordinates = (342, 612), Black Pixels = 1228590, White Pixels = 210
# Circle 51: Coordinates = (524, 386), Black Pixels = 1228601, White Pixels = 199
# Circle 52: Coordinates = (306, 336), Black Pixels = 1228578, White Pixels = 222
# Circle 53: Coordinates = (1014, 264), Black Pixels = 1228671, White Pixels = 129
# Circle 54: Coordinates = (1016, 392), Black Pixels = 1228663, White Pixels = 137
# Circle 55: Coordinates = (564, 432), Black Pixels = 1228616, White Pixels = 184
# Circle 56: Coordinates = (814, 348), Black Pixels = 1228644, White Pixels = 156
# Circle 57: Coordinates = (604, 432), Black Pixels = 1228648, White Pixels = 152
# Circle 58: Coordinates = (346, 520), Black Pixels = 1228598, White Pixels = 202
# Circle 59: Coordinates = (478, 610), Black Pixels = 1228587, White Pixels = 213
# Circle 60: Coordinates = (854, 566), Black Pixels = 1228643, White Pixels = 157
# Circle 61: Coordinates = (560, 610), Black Pixels = 1228580, White Pixels = 220
# Circle 62: Coordinates = (814, 654), Black Pixels = 1228626, White Pixels = 174
# Circle 63: Coordinates = (482, 430), Black Pixels = 1228557, White Pixels = 243
# Circle 64: Coordinates = (304, 382), Black Pixels = 1228604, White Pixels = 196
# Circle 65: Coordinates = (300, 566), Black Pixels = 1228615, White Pixels = 185
# Circle 66: Coordinates = (1022, 658), Black Pixels = 1228641, White Pixels = 159
# Circle 67: Coordinates = (774, 656), Black Pixels = 1228632, White Pixels = 168
# Circle 68: Coordinates = (1054, 264), Black Pixels = 1228679, White Pixels = 121
# Circle 69: Coordinates = (1056, 350), Black Pixels = 1228677, White Pixels = 123
# Circle 70: Coordinates = (308, 246), Black Pixels = 1228618, White Pixels = 182
# Circle 71: Coordinates = (772, 564), Black Pixels = 1228653, White Pixels = 147
# Circle 72: Coordinates = (258, 380), Black Pixels = 1228559, White Pixels = 241
# Circle 73: Coordinates = (522, 518), Black Pixels = 1228591, White Pixels = 209
# Circle 74: Coordinates = (562, 518), Black Pixels = 1228598, White Pixels = 202
# Circle 75: Coordinates = (482, 298), Black Pixels = 1228602, White Pixels = 198
# Circle 76: Coordinates = (482, 342), Black Pixels = 1228603, White Pixels = 197
# Circle 77: Coordinates = (524, 430), Black Pixels = 1228657, White Pixels = 143
# Circle 78: Coordinates = (602, 520), Black Pixels = 1228623, White Pixels = 177
# Circle 79: Coordinates = (518, 654), Black Pixels = 1228599, White Pixels = 201
# Circle 80: Coordinates = (812, 478), Black Pixels = 1228645, White Pixels = 155
# Circle 81: Coordinates = (526, 256), Black Pixels = 1228634, White Pixels = 166
# Circle 82: Coordinates = (772, 476), Black Pixels = 1228655, White Pixels = 145
# Circle 83: Coordinates = (774, 346), Black Pixels = 1228660, White Pixels = 140
# Circle 84: Coordinates = (854, 478), Black Pixels = 1228649, White Pixels = 151
# Circle 85: Coordinates = (348, 474), Black Pixels = 1228583, White Pixels = 217
# Circle 86: Coordinates = (346, 428), Black Pixels = 1228592, White Pixels = 208
# Circle 87: Coordinates = (1016, 436), Black Pixels = 1228668, White Pixels = 132
# Circle 88: Coordinates = (976, 306), Black Pixels = 1228637, White Pixels = 163
# Circle 89: Coordinates = (1018, 350), Black Pixels = 1228659, White Pixels = 141
# Circle 90: Coordinates = (606, 344), Black Pixels = 1228635, White Pixels = 165
# Circle 91: Coordinates = (772, 608), Black Pixels = 1228659, White Pixels = 141
# Circle 92: Coordinates = (854, 434), Black Pixels = 1228655, White Pixels = 145
# Circle 93: Coordinates = (856, 348), Black Pixels = 1228650, White Pixels = 150
# Circle 94: Coordinates = (978, 568), Black Pixels = 1228615, White Pixels = 185
# Circle 95: Coordinates = (482, 386), Black Pixels = 1228569, White Pixels = 231
# Circle 96: Coordinates = (526, 342), Black Pixels = 1228634, White Pixels = 166
# Circle 97: Coordinates = (1054, 308), Black Pixels = 1228654, White Pixels = 146
# Circle 98: Coordinates = (566, 300), Black Pixels = 1228626, White Pixels = 174
# Circle 99: Coordinates = (214, 426), Black Pixels = 1228575, White Pixels = 225
# Circle 100: Coordinates = (524, 474), Black Pixels = 1228634, White Pixels = 166
# Circle 101: Coordinates = (1094, 266), Black Pixels = 1228671, White Pixels = 129
# Circle 102: Coordinates = (976, 436), Black Pixels = 1228648, White Pixels = 152
# Circle 103: Coordinates = (520, 608), Black Pixels = 1228605, White Pixels = 195
# Circle 104: Coordinates = (300, 520), Black Pixels = 1228615, White Pixels = 185
# Circle 105: Coordinates = (1096, 394), Black Pixels = 1228654, White Pixels = 146
# Circle 106: Coordinates = (1100, 568), Black Pixels = 1228645, White Pixels = 155
# Circle 107: Coordinates = (256, 520), Black Pixels = 1228604, White Pixels = 196
# Circle 108: Coordinates = (980, 612), Black Pixels = 1228620, White Pixels = 180
# Circle 109: Coordinates = (564, 476), Black Pixels = 1228590, White Pixels = 210
# Circle 110: Coordinates = (812, 520), Black Pixels = 1228650, White Pixels = 150
# Circle 111: Coordinates = (736, 258), Black Pixels = 1228597, White Pixels = 203
# Circle 112: Coordinates = (816, 304), Black Pixels = 1228658, White Pixels = 142
# Circle 113: Coordinates = (1016, 480), Black Pixels = 1228666, White Pixels = 134
# Circle 114: Coordinates = (814, 564), Black Pixels = 1228672, White Pixels = 128
# Circle 115: Coordinates = (1098, 524), Black Pixels = 1228648, White Pixels = 152
# Circle 116: Coordinates = (210, 472), Black Pixels = 1228610, White Pixels = 190
# Circle 117: Coordinates = (732, 564), Black Pixels = 1228608, White Pixels = 192
# Circle 118: Coordinates = (772, 434), Black Pixels = 1228667, White Pixels = 133
# Circle 119: Coordinates = (856, 656), Black Pixels = 1228658, White Pixels = 142
# Circle 120: Coordinates = (260, 336), Black Pixels = 1228600, White Pixels = 200
# Circle 121: Coordinates = (480, 518), Black Pixels = 1228571, White Pixels = 229
# Circle 122: Coordinates = (342, 660), Black Pixels = 1228612, White Pixels = 188
# Circle 123: Coordinates = (562, 564), Black Pixels = 1228622, White Pixels = 178
# Circle 124: Coordinates = (732, 390), Black Pixels = 1228642, White Pixels = 158
# Circle 125: Coordinates = (478, 656), Black Pixels = 1228553, White Pixels = 247
# Circle 126: Coordinates = (732, 608), Black Pixels = 1228605, White Pixels = 195
# Circle 127: Coordinates = (732, 654), Black Pixels = 1228612, White Pixels = 188
# Circle 128: Coordinates = (522, 564), Black Pixels = 1228654, White Pixels = 146
# Circle 129: Coordinates = (352, 248), Black Pixels = 1228596, White Pixels = 204
# Circle 130: Coordinates = (1058, 524), Black Pixels = 1228662, White Pixels = 138
# Circle 131: Coordinates = (294, 660), Black Pixels = 1228615, White Pixels = 185
# Circle 132: Coordinates = (480, 474), Black Pixels = 1228588, White Pixels = 212
# Circle 133: Coordinates = (1096, 350), Black Pixels = 1228672, White Pixels = 128
# Circle 134: Coordinates = (350, 338), Black Pixels = 1228604, White Pixels = 196
# Circle 135: Coordinates = (566, 344), Black Pixels = 1228637, White Pixels = 163
# Circle 136: Coordinates = (816, 260), Black Pixels = 1228652, White Pixels = 148
# Circle 137: Coordinates = (856, 610), Black Pixels = 1228664, White Pixels = 136
# Circle 138: Coordinates = (856, 260), Black Pixels = 1228666, White Pixels = 134
# Circle 139: Coordinates = (1020, 612), Black Pixels = 1228664, White Pixels = 136
# Circle 140: Coordinates = (1060, 612), Black Pixels = 1228668, White Pixels = 132
# Circle 141: Coordinates = (776, 258), Black Pixels = 1228649, White Pixels = 151
# Circle 142: Coordinates = (566, 256), Black Pixels = 1228606, White Pixels = 194
# Circle 143: Coordinates = (978, 524), Black Pixels = 1228617, White Pixels = 183
# Circle 144: Coordinates = (1104, 658), Black Pixels = 1228661, White Pixels = 139
# Circle 145: Coordinates = (976, 392), Black Pixels = 1228628, White Pixels = 172
# Circle 146: Coordinates = (1094, 308), Black Pixels = 1228675, White Pixels = 125
# Circle 147: Coordinates = (1056, 436), Black Pixels = 1228666, White Pixels = 134
# Circle 148: Coordinates = (350, 294), Black Pixels = 1228609, White Pixels = 191
# Circle 149: Coordinates = (736, 302), Black Pixels = 1228625, White Pixels = 175
# Circle 150: Coordinates = (980, 658), Black Pixels = 1228624, White Pixels = 176
# Circle 151: Coordinates = (1096, 436), Black Pixels = 1228677, White Pixels = 123
# Circle 152: Coordinates = (774, 304), Black Pixels = 1228675, White Pixels = 125
# Circle 153: Coordinates = (1016, 308), Black Pixels = 1228671, White Pixels = 129
# Circle 154: Coordinates = (306, 292), Black Pixels = 1228637, White Pixels = 163
# Circle 155: Coordinates = (976, 350), Black Pixels = 1228664, White Pixels = 136
# Circle 156: Coordinates = (1098, 480), Black Pixels = 1228651, White Pixels = 149
# Circle 157: Coordinates = (252, 566), Black Pixels = 1228657, White Pixels = 143
# Circle 158: Coordinates = (1058, 480), Black Pixels = 1228679, White Pixels = 121
# Circle 159: Coordinates = (814, 610), Black Pixels = 1228665, White Pixels = 135
# Circle 160: Coordinates = (264, 290), Black Pixels = 1228648, White Pixels = 152
# key
# Circle 1: Coordinates = (226, 510), Black Pixels = 1228628, White Pixels = 172
# Circle 2: Coordinates = (224, 590), Black Pixels = 1228793, White Pixels = 7
# Circle 3: Coordinates = (222, 632), Black Pixels = 1228630, White Pixels = 170
# Circle 4: Coordinates = (746, 280), Black Pixels = 1228800, White Pixels = 0
# Circle 5: Coordinates = (590, 316), Black Pixels = 1228800, White Pixels = 0
# Circle 6: Coordinates = (552, 354), Black Pixels = 1228660, White Pixels = 140
# Circle 7: Coordinates = (552, 392), Black Pixels = 1228787, White Pixels = 13
# Circle 8: Coordinates = (266, 510), Black Pixels = 1228678, White Pixels = 122
# Circle 9: Coordinates = (964, 322), Black Pixels = 1228795, White Pixels = 5
# Circle 10: Coordinates = (590, 624), Black Pixels = 1228677, White Pixels = 123
# Circle 11: Coordinates = (306, 590), Black Pixels = 1228652, White Pixels = 148
# Circle 12: Coordinates = (234, 272), Black Pixels = 1228593, White Pixels = 207
# Circle 13: Coordinates = (514, 392), Black Pixels = 1228649, White Pixels = 151
# Circle 14: Coordinates = (266, 470), Black Pixels = 1228652, White Pixels = 148
# Circle 15: Coordinates = (352, 468), Black Pixels = 1228619, White Pixels = 181
# Circle 16: Coordinates = (552, 316), Black Pixels = 1228658, White Pixels = 142
# Circle 17: Coordinates = (710, 504), Black Pixels = 1228797, White Pixels = 3
# Circle 18: Coordinates = (818, 356), Black Pixels = 1228705, White Pixels = 95
# Circle 19: Coordinates = (268, 390), Black Pixels = 1228654, White Pixels = 146
# Circle 20: Coordinates = (820, 282), Black Pixels = 1228677, White Pixels = 123
# Circle 21: Coordinates = (514, 544), Black Pixels = 1228799, White Pixels = 1
# Circle 22: Coordinates = (818, 466), Black Pixels = 1228797, White Pixels = 3
# Circle 23: Coordinates = (1038, 358), Black Pixels = 1228699, White Pixels = 101
# Circle 24: Coordinates = (308, 508), Black Pixels = 1228659, White Pixels = 141
# Circle 25: Coordinates = (514, 354), Black Pixels = 1228795, White Pixels = 5
# Circle 26: Coordinates = (970, 542), Black Pixels = 1228709, White Pixels = 91
# Circle 27: Coordinates = (938, 620), Black Pixels = 1228680, White Pixels = 120
# Circle 28: Coordinates = (744, 356), Black Pixels = 1228711, White Pixels = 89
# Circle 29: Coordinates = (354, 310), Black Pixels = 1228658, White Pixels = 142
# Circle 30: Coordinates = (308, 390), Black Pixels = 1228658, White Pixels = 142
# Circle 31: Coordinates = (476, 584), Black Pixels = 1228606, White Pixels = 194
# Circle 32: Coordinates = (744, 466), Black Pixels = 1228797, White Pixels = 3
# Circle 33: Coordinates = (782, 356), Black Pixels = 1228705, White Pixels = 95
# Circle 34: Coordinates = (784, 282), Black Pixels = 1228691, White Pixels = 109
# Circle 35: Coordinates = (550, 584), Black Pixels = 1228651, White Pixels = 149
# Circle 36: Coordinates = (928, 356), Black Pixels = 1228652, White Pixels = 148
# Circle 37: Coordinates = (928, 284), Black Pixels = 1228780, White Pixels = 20
# Circle 38: Coordinates = (818, 394), Black Pixels = 1228704, White Pixels = 96
# Circle 39: Coordinates = (1038, 466), Black Pixels = 1228692, White Pixels = 108
# Circle 40: Coordinates = (1002, 394), Black Pixels = 1228713, White Pixels = 87
# Circle 41: Coordinates = (1038, 322), Black Pixels = 1228698, White Pixels = 102
# Circle 42: Coordinates = (352, 546), Black Pixels = 1228668, White Pixels = 132
# Circle 43: Coordinates = (226, 468), Black Pixels = 1228629, White Pixels = 171
# Circle 44: Coordinates = (590, 584), Black Pixels = 1228800, White Pixels = 0
# Circle 45: Coordinates = (1002, 466), Black Pixels = 1228703, White Pixels = 97
# Circle 46: Coordinates = (972, 578), Black Pixels = 1228709, White Pixels = 91
# Circle 47: Coordinates = (552, 430), Black Pixels = 1228684, White Pixels = 116
# Circle 48: Coordinates = (552, 468), Black Pixels = 1228662, White Pixels = 138
# Circle 49: Coordinates = (746, 542), Black Pixels = 1228711, White Pixels = 89
# Circle 50: Coordinates = (818, 430), Black Pixels = 1228709, White Pixels = 91
# Circle 51: Coordinates = (822, 542), Black Pixels = 1228800, White Pixels = 0
# Circle 52: Coordinates = (350, 588), Black Pixels = 1228652, White Pixels = 148
# Circle 53: Coordinates = (474, 506), Black Pixels = 1228644, White Pixels = 156
# Circle 54: Coordinates = (310, 548), Black Pixels = 1228680, White Pixels = 120
# Circle 55: Coordinates = (306, 430), Black Pixels = 1228661, White Pixels = 139
# Circle 56: Coordinates = (550, 544), Black Pixels = 1228688, White Pixels = 112
# Circle 57: Coordinates = (552, 278), Black Pixels = 1228660, White Pixels = 140
# Circle 58: Coordinates = (708, 466), Black Pixels = 1228666, White Pixels = 134
# Circle 59: Coordinates = (966, 358), Black Pixels = 1228697, White Pixels = 103
# Circle 60: Coordinates = (264, 590), Black Pixels = 1228663, White Pixels = 137
# Circle 61: Coordinates = (476, 428), Black Pixels = 1228641, White Pixels = 159
# Circle 62: Coordinates = (710, 580), Black Pixels = 1228667, White Pixels = 133
# Circle 63: Coordinates = (476, 276), Black Pixels = 1228766, White Pixels = 34
# Circle 64: Coordinates = (226, 550), Black Pixels = 1228640, White Pixels = 160
# Circle 65: Coordinates = (1040, 504), Black Pixels = 1228699, White Pixels = 101
# Circle 66: Coordinates = (818, 320), Black Pixels = 1228775, White Pixels = 25
# Circle 67: Coordinates = (966, 466), Black Pixels = 1228782, White Pixels = 18
# Circle 68: Coordinates = (1004, 504), Black Pixels = 1228763, White Pixels = 37
# Circle 69: Coordinates = (350, 508), Black Pixels = 1228789, White Pixels = 11
# Circle 70: Coordinates = (514, 624), Black Pixels = 1228652, White Pixels = 148
# Circle 71: Coordinates = (514, 316), Black Pixels = 1228685, White Pixels = 115
# Circle 72: Coordinates = (516, 278), Black Pixels = 1228669, White Pixels = 131
# Circle 73: Coordinates = (708, 318), Black Pixels = 1228670, White Pixels = 130
# Circle 74: Coordinates = (782, 466), Black Pixels = 1228705, White Pixels = 95
# Circle 75: Coordinates = (820, 504), Black Pixels = 1228712, White Pixels = 88
# Circle 76: Coordinates = (968, 504), Black Pixels = 1228720, White Pixels = 80
# Circle 77: Coordinates = (974, 618), Black Pixels = 1228800, White Pixels = 0
# Circle 78: Coordinates = (476, 468), Black Pixels = 1228766, White Pixels = 34
# Circle 79: Coordinates = (230, 348), Black Pixels = 1228570, White Pixels = 230
# Circle 80: Coordinates = (712, 620), Black Pixels = 1228765, White Pixels = 35
# Circle 81: Coordinates = (782, 430), Black Pixels = 1228775, White Pixels = 25
# Circle 82: Coordinates = (928, 320), Black Pixels = 1228654, White Pixels = 146
# Circle 83: Coordinates = (514, 506), Black Pixels = 1228684, White Pixels = 116
# Circle 84: Coordinates = (746, 504), Black Pixels = 1228720, White Pixels = 80
# Circle 85: Coordinates = (782, 320), Black Pixels = 1228692, White Pixels = 108
# Circle 86: Coordinates = (1038, 394), Black Pixels = 1228697, White Pixels = 103
# Circle 87: Coordinates = (708, 430), Black Pixels = 1228690, White Pixels = 110
# Circle 88: Coordinates = (350, 630), Black Pixels = 1228791, White Pixels = 9
# Circle 89: Coordinates = (786, 618), Black Pixels = 1228649, White Pixels = 151
# Circle 90: Coordinates = (228, 390), Black Pixels = 1228607, White Pixels = 193
# Circle 91: Coordinates = (708, 356), Black Pixels = 1228792, White Pixels = 8
# Circle 92: Coordinates = (1000, 284), Black Pixels = 1228696, White Pixels = 104
# Circle 93: Coordinates = (1008, 578), Black Pixels = 1228702, White Pixels = 98
# Circle 94: Coordinates = (272, 272), Black Pixels = 1228679, White Pixels = 121
# Circle 95: Coordinates = (590, 278), Black Pixels = 1228666, White Pixels = 134
# Circle 96: Coordinates = (936, 580), Black Pixels = 1228681, White Pixels = 119
# Circle 97: Coordinates = (784, 540), Black Pixels = 1228654, White Pixels = 146
# Circle 98: Coordinates = (268, 350), Black Pixels = 1228790, White Pixels = 10
# Circle 99: Coordinates = (310, 468), Black Pixels = 1228796, White Pixels = 4
# Circle 100: Coordinates = (588, 506), Black Pixels = 1228670, White Pixels = 130
# Circle 101: Coordinates = (1006, 540), Black Pixels = 1228695, White Pixels = 105
# Circle 102: Coordinates = (350, 352), Black Pixels = 1228638, White Pixels = 162
# Circle 103: Coordinates = (588, 468), Black Pixels = 1228651, White Pixels = 149
# Circle 104: Coordinates = (964, 394), Black Pixels = 1228710, White Pixels = 90
# Circle 105: Coordinates = (1010, 618), Black Pixels = 1228698, White Pixels = 102
# Circle 106: Coordinates = (744, 394), Black Pixels = 1228799, White Pixels = 1
# Circle 107: Coordinates = (588, 392), Black Pixels = 1228669, White Pixels = 131
# Circle 108: Coordinates = (232, 310), Black Pixels = 1228763, White Pixels = 37
# Circle 109: Coordinates = (1046, 578), Black Pixels = 1228771, White Pixels = 29
# Circle 110: Coordinates = (312, 312), Black Pixels = 1228618, White Pixels = 182
# Circle 111: Coordinates = (786, 580), Black Pixels = 1228765, White Pixels = 35
# Circle 112: Coordinates = (932, 466), Black Pixels = 1228648, White Pixels = 152
# Circle 113: Coordinates = (348, 430), Black Pixels = 1228636, White Pixels = 164
# Circle 114: Coordinates = (476, 354), Black Pixels = 1228633, White Pixels = 167
# Circle 115: Coordinates = (710, 280), Black Pixels = 1228644, White Pixels = 156
# Circle 116: Coordinates = (1036, 284), Black Pixels = 1228665, White Pixels = 135
# Circle 117: Coordinates = (1000, 320), Black Pixels = 1228707, White Pixels = 93
# Circle 118: Coordinates = (746, 318), Black Pixels = 1228711, White Pixels = 89
# Circle 119: Coordinates = (228, 428), Black Pixels = 1228788, White Pixels = 12
# Circle 120: Coordinates = (356, 272), Black Pixels = 1228661, White Pixels = 139
# Circle 121: Coordinates = (476, 314), Black Pixels = 1228602, White Pixels = 198
# Circle 122: Coordinates = (966, 430), Black Pixels = 1228696, White Pixels = 104
# Circle 123: Coordinates = (268, 430), Black Pixels = 1228654, White Pixels = 146
# Circle 124: Coordinates = (514, 582), Black Pixels = 1228669, White Pixels = 131
# Circle 125: Coordinates = (748, 580), Black Pixels = 1228704, White Pixels = 96
# Circle 126: Coordinates = (824, 618), Black Pixels = 1228684, White Pixels = 116
# Circle 127: Coordinates = (1042, 540), Black Pixels = 1228704, White Pixels = 96
# Circle 128: Coordinates = (306, 632), Black Pixels = 1228678, White Pixels = 122
# Circle 129: Coordinates = (550, 624), Black Pixels = 1228800, White Pixels = 0
# Circle 130: Coordinates = (934, 542), Black Pixels = 1228785, White Pixels = 15
# Circle 131: Coordinates = (964, 284), Black Pixels = 1228695, White Pixels = 105
# Circle 132: Coordinates = (1048, 618), Black Pixels = 1228692, White Pixels = 108
# Circle 133: Coordinates = (552, 506), Black Pixels = 1228795, White Pixels = 5
# Circle 134: Coordinates = (708, 394), Black Pixels = 1228664, White Pixels = 136
# Circle 135: Coordinates = (590, 354), Black Pixels = 1228673, White Pixels = 127
# Circle 136: Coordinates = (824, 580), Black Pixels = 1228692, White Pixels = 108
# Circle 137: Coordinates = (710, 542), Black Pixels = 1228677, White Pixels = 123
# Circle 138: Coordinates = (928, 394), Black Pixels = 1228799, White Pixels = 1
# Circle 139: Coordinates = (264, 632), Black Pixels = 1228662, White Pixels = 138
# Circle 140: Coordinates = (314, 272), Black Pixels = 1228800, White Pixels = 0
# Circle 141: Coordinates = (932, 504), Black Pixels = 1228670, White Pixels = 130
# Circle 142: Coordinates = (274, 310), Black Pixels = 1228640, White Pixels = 160
# Circle 143: Coordinates = (514, 430), Black Pixels = 1228687, White Pixels = 113
# Circle 144: Coordinates = (590, 430), Black Pixels = 1228779, White Pixels = 21
# Circle 145: Coordinates = (514, 468), Black Pixels = 1228681, White Pixels = 119
# Circle 146: Coordinates = (744, 430), Black Pixels = 1228717, White Pixels = 83
# Circle 147: Coordinates = (266, 548), Black Pixels = 1228800, White Pixels = 0
# Circle 148: Coordinates = (310, 350), Black Pixels = 1228675, White Pixels = 125
# Circle 149: Coordinates = (748, 620), Black Pixels = 1228702, White Pixels = 98
# Circle 150: Coordinates = (782, 394), Black Pixels = 1228661, White Pixels = 139
# Circle 151: Coordinates = (474, 544), Black Pixels = 1228625, White Pixels = 175
# Circle 152: Coordinates = (476, 624), Black Pixels = 1228646, White Pixels = 154
# Circle 153: Coordinates = (1038, 430), Black Pixels = 1228800, White Pixels = 0
# Circle 154: Coordinates = (930, 430), Black Pixels = 1228690, White Pixels = 110
# Circle 155: Coordinates = (590, 546), Black Pixels = 1228696, White Pixels = 104
# Circle 156: Coordinates = (782, 504), Black Pixels = 1228716, White Pixels = 84
# Circle 157: Coordinates = (476, 392), Black Pixels = 1228659, White Pixels = 141
# Circle 158: Coordinates = (350, 390), Black Pixels = 1228781, White Pixels = 19
# Circle 159: Coordinates = (1000, 358), Black Pixels = 1228796, White Pixels = 4
# Circle 160: Coordinates = (1002, 430), Black Pixels = 1228721, White Pixels = 79

# %% [markdown]
# ### 4. Divide the circles by rows

# %% [markdown]
# #### Using clustering method DBSCAN

# %%
import numpy as np
from sklearn.cluster import DBSCAN
from collections import defaultdict

def group_by_row_dbscan(pixel_counts, eps=20, fallback_eps=10):
    # Extract y-coordinates
    y_coords = np.array([[y] for x, y, r, bc, wc in pixel_counts])

    def _cluster(eps_val):
        labels = DBSCAN(eps=eps_val, min_samples=1).fit(y_coords).labels_
        groups = defaultdict(list)
        for lbl, data in zip(labels, pixel_counts):
            groups[lbl].append(data)
        # Sort rows by mean y and then sort circles in each row by x
        sorted_rows = sorted(groups.values(), key=lambda row: np.mean([c[1] for c in row]))
        return [sorted(row, key=lambda c: c[0]) for row in sorted_rows]

    rows = _cluster(eps)
    if len({len(r) for r in rows}) != 1:
        print(f"Warning: inconsistent row lengths, retrying with eps={fallback_eps}")
        rows = _cluster(fallback_eps)
    return rows

# %%
# Group the circles by rows using the group_by_row_dbscan function
start = time.time()
grouped_rows_s = group_by_row_dbscan(pixel_counts_s, eps=10)
end = time.time()
print("Grouping by row time:", end-start)
# Print the grouped results
for row_idx, row in enumerate(grouped_rows_s, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, black_count, white_count) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")
# Out:
# Grouping by row time: 0.002513885498046875
# Row 1:
#   Circle 1: Coordinates = (262, 228), Black Pixels = 1228589, White Pixels = 211
#   Circle 2: Coordinates = (302, 228), Black Pixels = 1228634, White Pixels = 166
#   Circle 3: Coordinates = (344, 228), Black Pixels = 1228795, White Pixels = 5
#   Circle 4: Coordinates = (388, 230), Black Pixels = 1228632, White Pixels = 168
#   Circle 5: Coordinates = (514, 232), Black Pixels = 1228800, White Pixels = 0
#   Circle 6: Coordinates = (556, 234), Black Pixels = 1228662, White Pixels = 138
#   Circle 7: Coordinates = (594, 234), Black Pixels = 1228594, White Pixels = 206
#   Circle 8: Coordinates = (634, 234), Black Pixels = 1228605, White Pixels = 195
#   Circle 9: Coordinates = (760, 232), Black Pixels = 1228629, White Pixels = 171
#   Circle 10: Coordinates = (800, 234), Black Pixels = 1228798, White Pixels = 2
#   Circle 11: Coordinates = (838, 234), Black Pixels = 1228668, White Pixels = 132
#   Circle 12: Coordinates = (876, 236), Black Pixels = 1228646, White Pixels = 154
#   Circle 13: Coordinates = (992, 238), Black Pixels = 1228616, White Pixels = 184
#   Circle 14: Coordinates = (1030, 238), Black Pixels = 1228773, White Pixels = 27
#   Circle 15: Coordinates = (1068, 238), Black Pixels = 1228696, White Pixels = 104
#   Circle 16: Coordinates = (1106, 238), Black Pixels = 1228671, White Pixels = 129
# Row 2:
#   Circle 1: Coordinates = (262, 270), Black Pixels = 1228601, White Pixels = 199
#   Circle 2: Coordinates = (302, 272), Black Pixels = 1228760, White Pixels = 40
#   Circle 3: Coordinates = (344, 272), Black Pixels = 1228638, White Pixels = 162
#   Circle 4: Coordinates = (386, 272), Black Pixels = 1228642, White Pixels = 158
#   Circle 5: Coordinates = (514, 272), Black Pixels = 1228596, White Pixels = 204
#   Circle 6: Coordinates = (556, 276), Black Pixels = 1228674, White Pixels = 126
#   Circle 7: Coordinates = (596, 274), Black Pixels = 1228767, White Pixels = 33
#   Circle 8: Coordinates = (634, 274), Black Pixels = 1228642, White Pixels = 158
#   Circle 9: Coordinates = (760, 274), Black Pixels = 1228799, White Pixels = 1
#   Circle 10: Coordinates = (798, 276), Black Pixels = 1228689, White Pixels = 111
#   Circle 11: Coordinates = (838, 276), Black Pixels = 1228663, White Pixels = 137
#   Circle 12: Coordinates = (876, 276), Black Pixels = 1228655, White Pixels = 145
#   Circle 13: Coordinates = (992, 278), Black Pixels = 1228778, White Pixels = 22
#   Circle 14: Coordinates = (1030, 278), Black Pixels = 1228675, White Pixels = 125
#   Circle 15: Coordinates = (1068, 278), Black Pixels = 1228685, White Pixels = 115
#   Circle 16: Coordinates = (1106, 278), Black Pixels = 1228646, White Pixels = 154
# Row 3:
#   Circle 1: Coordinates = (258, 312), Black Pixels = 1228592, White Pixels = 208
#   Circle 2: Coordinates = (300, 312), Black Pixels = 1228652, White Pixels = 148
#   Circle 3: Coordinates = (342, 312), Black Pixels = 1228797, White Pixels = 3
#   Circle 4: Coordinates = (384, 312), Black Pixels = 1228628, White Pixels = 172
#   Circle 5: Coordinates = (516, 316), Black Pixels = 1228613, White Pixels = 187
#   Circle 6: Coordinates = (556, 314), Black Pixels = 1228748, White Pixels = 52
#   Circle 7: Coordinates = (594, 314), Black Pixels = 1228641, White Pixels = 159
#   Circle 8: Coordinates = (634, 314), Black Pixels = 1228634, White Pixels = 166
#   Circle 9: Coordinates = (758, 316), Black Pixels = 1228608, White Pixels = 192
#   Circle 10: Coordinates = (798, 316), Black Pixels = 1228786, White Pixels = 14
#   Circle 11: Coordinates = (838, 316), Black Pixels = 1228668, White Pixels = 132
#   Circle 12: Coordinates = (876, 316), Black Pixels = 1228651, White Pixels = 149
#   Circle 13: Coordinates = (992, 316), Black Pixels = 1228635, White Pixels = 165
#   Circle 14: Coordinates = (1032, 316), Black Pixels = 1228654, White Pixels = 146
#   Circle 15: Coordinates = (1070, 316), Black Pixels = 1228798, White Pixels = 2
#   Circle 16: Coordinates = (1106, 316), Black Pixels = 1228669, White Pixels = 131
# Row 4:
#   Circle 1: Coordinates = (256, 354), Black Pixels = 1228800, White Pixels = 0
#   Circle 2: Coordinates = (298, 354), Black Pixels = 1228653, White Pixels = 147
#   Circle 3: Coordinates = (340, 354), Black Pixels = 1228652, White Pixels = 148
#   Circle 4: Coordinates = (384, 352), Black Pixels = 1228503, White Pixels = 297
#   Circle 5: Coordinates = (514, 354), Black Pixels = 1228779, White Pixels = 21
#   Circle 6: Coordinates = (554, 356), Black Pixels = 1228672, White Pixels = 128
#   Circle 7: Coordinates = (594, 356), Black Pixels = 1228604, White Pixels = 196
#   Circle 8: Coordinates = (632, 356), Black Pixels = 1228644, White Pixels = 156
#   Circle 9: Coordinates = (758, 354), Black Pixels = 1228613, White Pixels = 187
#   Circle 10: Coordinates = (798, 354), Black Pixels = 1228693, White Pixels = 107
#   Circle 11: Coordinates = (838, 356), Black Pixels = 1228788, White Pixels = 12
#   Circle 12: Coordinates = (876, 354), Black Pixels = 1228684, White Pixels = 116
#   Circle 13: Coordinates = (994, 354), Black Pixels = 1228800, White Pixels = 0
#   Circle 14: Coordinates = (1032, 354), Black Pixels = 1228663, White Pixels = 137
#   Circle 15: Coordinates = (1070, 354), Black Pixels = 1228651, White Pixels = 149
#   Circle 16: Coordinates = (1108, 354), Black Pixels = 1228685, White Pixels = 115
# Row 5:
#   Circle 1: Coordinates = (256, 394), Black Pixels = 1228618, White Pixels = 182
#   Circle 2: Coordinates = (296, 394), Black Pixels = 1228652, White Pixels = 148
#   Circle 3: Coordinates = (342, 394), Black Pixels = 1228782, White Pixels = 18
#   Circle 4: Coordinates = (382, 394), Black Pixels = 1228630, White Pixels = 170
#   Circle 5: Coordinates = (514, 394), Black Pixels = 1228623, White Pixels = 177
#   Circle 6: Coordinates = (556, 394), Black Pixels = 1228674, White Pixels = 126
#   Circle 7: Coordinates = (594, 394), Black Pixels = 1228797, White Pixels = 3
#   Circle 8: Coordinates = (634, 394), Black Pixels = 1228672, White Pixels = 128
#   Circle 9: Coordinates = (758, 394), Black Pixels = 1228635, White Pixels = 165
#   Circle 10: Coordinates = (798, 394), Black Pixels = 1228775, White Pixels = 25
#   Circle 11: Coordinates = (836, 394), Black Pixels = 1228679, White Pixels = 121
#   Circle 12: Coordinates = (876, 394), Black Pixels = 1228679, White Pixels = 121
#   Circle 13: Coordinates = (994, 392), Black Pixels = 1228673, White Pixels = 127
#   Circle 14: Coordinates = (1032, 392), Black Pixels = 1228787, White Pixels = 13
#   Circle 15: Coordinates = (1072, 392), Black Pixels = 1228666, White Pixels = 134
#   Circle 16: Coordinates = (1110, 392), Black Pixels = 1228657, White Pixels = 143
# Row 6:
#   Circle 1: Coordinates = (254, 436), Black Pixels = 1228619, White Pixels = 181
#   Circle 2: Coordinates = (298, 436), Black Pixels = 1228797, White Pixels = 3
#   Circle 3: Coordinates = (340, 436), Black Pixels = 1228649, White Pixels = 151
#   Circle 4: Coordinates = (384, 436), Black Pixels = 1228626, White Pixels = 174
#   Circle 5: Coordinates = (514, 434), Black Pixels = 1228790, White Pixels = 10
#   Circle 6: Coordinates = (556, 434), Black Pixels = 1228667, White Pixels = 133
#   Circle 7: Coordinates = (594, 434), Black Pixels = 1228648, White Pixels = 152
#   Circle 8: Coordinates = (634, 434), Black Pixels = 1228650, White Pixels = 150
#   Circle 9: Coordinates = (760, 434), Black Pixels = 1228626, White Pixels = 174
#   Circle 10: Coordinates = (798, 432), Black Pixels = 1228778, White Pixels = 22
#   Circle 11: Coordinates = (838, 432), Black Pixels = 1228677, White Pixels = 123
#   Circle 12: Coordinates = (876, 432), Black Pixels = 1228649, White Pixels = 151
#   Circle 13: Coordinates = (996, 432), Black Pixels = 1228800, White Pixels = 0
#   Circle 14: Coordinates = (1034, 432), Black Pixels = 1228688, White Pixels = 112
#   Circle 15: Coordinates = (1072, 432), Black Pixels = 1228653, White Pixels = 147
#   Circle 16: Coordinates = (1110, 430), Black Pixels = 1228639, White Pixels = 161
# Row 7:
#   Circle 1: Coordinates = (254, 480), Black Pixels = 1228788, White Pixels = 12
#   Circle 2: Coordinates = (296, 480), Black Pixels = 1228670, White Pixels = 130
#   Circle 3: Coordinates = (340, 478), Black Pixels = 1228622, White Pixels = 178
#   Circle 4: Coordinates = (386, 478), Black Pixels = 1228652, White Pixels = 148
#   Circle 5: Coordinates = (514, 476), Black Pixels = 1228615, White Pixels = 185
#   Circle 6: Coordinates = (556, 474), Black Pixels = 1228776, White Pixels = 24
#   Circle 7: Coordinates = (594, 476), Black Pixels = 1228670, White Pixels = 130
#   Circle 8: Coordinates = (634, 476), Black Pixels = 1228666, White Pixels = 134
#   Circle 9: Coordinates = (760, 474), Black Pixels = 1228663, White Pixels = 137
#   Circle 10: Coordinates = (798, 472), Black Pixels = 1228671, White Pixels = 129
#   Circle 11: Coordinates = (838, 472), Black Pixels = 1228782, White Pixels = 18
#   Circle 12: Coordinates = (878, 472), Black Pixels = 1228688, White Pixels = 112
#   Circle 13: Coordinates = (998, 472), Black Pixels = 1228662, White Pixels = 138
#   Circle 14: Coordinates = (1036, 472), Black Pixels = 1228772, White Pixels = 28
#   Circle 15: Coordinates = (1074, 472), Black Pixels = 1228663, White Pixels = 137
#   Circle 16: Coordinates = (1112, 470), Black Pixels = 1228658, White Pixels = 142
# Row 8:
#   Circle 1: Coordinates = (252, 520), Black Pixels = 1228618, White Pixels = 182
#   Circle 2: Coordinates = (294, 520), Black Pixels = 1228800, White Pixels = 0
#   Circle 3: Coordinates = (340, 520), Black Pixels = 1228656, White Pixels = 144
#   Circle 4: Coordinates = (386, 518), Black Pixels = 1228637, White Pixels = 163
#   Circle 5: Coordinates = (514, 516), Black Pixels = 1228779, White Pixels = 21
#   Circle 6: Coordinates = (556, 514), Black Pixels = 1228652, White Pixels = 148
#   Circle 7: Coordinates = (594, 516), Black Pixels = 1228657, White Pixels = 143
#   Circle 8: Coordinates = (634, 516), Black Pixels = 1228665, White Pixels = 135
#   Circle 9: Coordinates = (760, 512), Black Pixels = 1228644, White Pixels = 156
#   Circle 10: Coordinates = (800, 512), Black Pixels = 1228793, White Pixels = 7
#   Circle 11: Coordinates = (838, 512), Black Pixels = 1228695, White Pixels = 105
#   Circle 12: Coordinates = (880, 512), Black Pixels = 1228681, White Pixels = 119
#   Circle 13: Coordinates = (1000, 510), Black Pixels = 1228649, White Pixels = 151
#   Circle 14: Coordinates = (1038, 510), Black Pixels = 1228700, White Pixels = 100
#   Circle 15: Coordinates = (1076, 510), Black Pixels = 1228676, White Pixels = 124
#   Circle 16: Coordinates = (1116, 510), Black Pixels = 1228785, White Pixels = 15
# Row 9:
#   Circle 1: Coordinates = (250, 564), Black Pixels = 1228610, White Pixels = 190
#   Circle 2: Coordinates = (294, 564), Black Pixels = 1228654, White Pixels = 146
#   Circle 3: Coordinates = (338, 562), Black Pixels = 1228797, White Pixels = 3
#   Circle 4: Coordinates = (384, 562), Black Pixels = 1228646, White Pixels = 154
#   Circle 5: Coordinates = (514, 556), Black Pixels = 1228618, White Pixels = 182
#   Circle 6: Coordinates = (554, 556), Black Pixels = 1228785, White Pixels = 15
#   Circle 7: Coordinates = (594, 556), Black Pixels = 1228631, White Pixels = 169
#   Circle 8: Coordinates = (634, 558), Black Pixels = 1228652, White Pixels = 148
#   Circle 9: Coordinates = (762, 554), Black Pixels = 1228645, White Pixels = 155
#   Circle 10: Coordinates = (800, 552), Black Pixels = 1228696, White Pixels = 104
#   Circle 11: Coordinates = (840, 552), Black Pixels = 1228789, White Pixels = 11
#   Circle 12: Coordinates = (882, 552), Black Pixels = 1228657, White Pixels = 143
#   Circle 13: Coordinates = (1002, 552), Black Pixels = 1228655, White Pixels = 145
#   Circle 14: Coordinates = (1040, 550), Black Pixels = 1228673, White Pixels = 127
#   Circle 15: Coordinates = (1080, 550), Black Pixels = 1228799, White Pixels = 1
#   Circle 16: Coordinates = (1120, 550), Black Pixels = 1228681, White Pixels = 119
# Row 10:
#   Circle 1: Coordinates = (250, 608), Black Pixels = 1228618, White Pixels = 182
#   Circle 2: Coordinates = (292, 608), Black Pixels = 1228799, White Pixels = 1
#   Circle 3: Coordinates = (338, 606), Black Pixels = 1228653, White Pixels = 147
#   Circle 4: Coordinates = (384, 606), Black Pixels = 1228639, White Pixels = 161
#   Circle 5: Coordinates = (514, 598), Black Pixels = 1228645, White Pixels = 155
#   Circle 6: Coordinates = (554, 600), Black Pixels = 1228792, White Pixels = 8
#   Circle 7: Coordinates = (594, 600), Black Pixels = 1228661, White Pixels = 139
#   Circle 8: Coordinates = (634, 600), Black Pixels = 1228656, White Pixels = 144
#   Circle 9: Coordinates = (762, 596), Black Pixels = 1228631, White Pixels = 169
#   Circle 10: Coordinates = (802, 596), Black Pixels = 1228786, White Pixels = 14
#   Circle 11: Coordinates = (842, 594), Black Pixels = 1228682, White Pixels = 118
#   Circle 12: Coordinates = (882, 594), Black Pixels = 1228672, White Pixels = 128
#   Circle 13: Coordinates = (1002, 594), Black Pixels = 1228765, White Pixels = 35
#   Circle 14: Coordinates = (1042, 594), Black Pixels = 1228687, White Pixels = 113
#   Circle 15: Coordinates = (1082, 592), Black Pixels = 1228670, White Pixels = 130
#   Circle 16: Coordinates = (1122, 592), Black Pixels = 1228672, White Pixels = 128

# %%
start_2= time.time()
grouped_rows_t = group_by_row_dbscan(pixel_counts_t, eps=10)
end_2= time.time()
print("Grouping by row time:", end_2-start_2)
# Print the grouped results
for row_idx, row in enumerate(grouped_rows_t, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, black_count, white_count) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")
# Out:
# Grouping by row time: 0.0021054744720458984
# Row 1:
#   Circle 1: Coordinates = (222, 244), Black Pixels = 1228580, White Pixels = 220
#   Circle 2: Coordinates = (264, 246), Black Pixels = 1228566, White Pixels = 234
#   Circle 3: Coordinates = (308, 246), Black Pixels = 1228618, White Pixels = 182
#   Circle 4: Coordinates = (352, 248), Black Pixels = 1228596, White Pixels = 204
#   Circle 5: Coordinates = (484, 254), Black Pixels = 1228560, White Pixels = 240
#   Circle 6: Coordinates = (526, 256), Black Pixels = 1228634, White Pixels = 166
#   Circle 7: Coordinates = (566, 256), Black Pixels = 1228606, White Pixels = 194
#   Circle 8: Coordinates = (606, 256), Black Pixels = 1228624, White Pixels = 176
#   Circle 9: Coordinates = (736, 258), Black Pixels = 1228597, White Pixels = 203
#   Circle 10: Coordinates = (776, 258), Black Pixels = 1228649, White Pixels = 151
#   Circle 11: Coordinates = (816, 260), Black Pixels = 1228652, White Pixels = 148
#   Circle 12: Coordinates = (856, 260), Black Pixels = 1228666, White Pixels = 134
#   Circle 13: Coordinates = (974, 264), Black Pixels = 1228631, White Pixels = 169
#   Circle 14: Coordinates = (1014, 264), Black Pixels = 1228671, White Pixels = 129
#   Circle 15: Coordinates = (1054, 264), Black Pixels = 1228679, White Pixels = 121
#   Circle 16: Coordinates = (1094, 266), Black Pixels = 1228671, White Pixels = 129
# Row 2:
#   Circle 1: Coordinates = (220, 290), Black Pixels = 1228570, White Pixels = 230
#   Circle 2: Coordinates = (264, 290), Black Pixels = 1228648, White Pixels = 152
#   Circle 3: Coordinates = (306, 292), Black Pixels = 1228637, White Pixels = 163
#   Circle 4: Coordinates = (350, 294), Black Pixels = 1228609, White Pixels = 191
#   Circle 5: Coordinates = (482, 298), Black Pixels = 1228602, White Pixels = 198
#   Circle 6: Coordinates = (526, 300), Black Pixels = 1228650, White Pixels = 150
#   Circle 7: Coordinates = (566, 300), Black Pixels = 1228626, White Pixels = 174
#   Circle 8: Coordinates = (606, 300), Black Pixels = 1228633, White Pixels = 167
#   Circle 9: Coordinates = (736, 302), Black Pixels = 1228625, White Pixels = 175
#   Circle 10: Coordinates = (774, 304), Black Pixels = 1228675, White Pixels = 125
#   Circle 11: Coordinates = (816, 304), Black Pixels = 1228658, White Pixels = 142
#   Circle 12: Coordinates = (856, 304), Black Pixels = 1228647, White Pixels = 153
#   Circle 13: Coordinates = (976, 306), Black Pixels = 1228637, White Pixels = 163
#   Circle 14: Coordinates = (1016, 308), Black Pixels = 1228671, White Pixels = 129
#   Circle 15: Coordinates = (1054, 308), Black Pixels = 1228654, White Pixels = 146
#   Circle 16: Coordinates = (1094, 308), Black Pixels = 1228675, White Pixels = 125
# Row 3:
#   Circle 1: Coordinates = (218, 334), Black Pixels = 1228556, White Pixels = 244
#   Circle 2: Coordinates = (260, 336), Black Pixels = 1228600, White Pixels = 200
#   Circle 3: Coordinates = (306, 336), Black Pixels = 1228578, White Pixels = 222
#   Circle 4: Coordinates = (350, 338), Black Pixels = 1228604, White Pixels = 196
#   Circle 5: Coordinates = (482, 342), Black Pixels = 1228603, White Pixels = 197
#   Circle 6: Coordinates = (526, 342), Black Pixels = 1228634, White Pixels = 166
#   Circle 7: Coordinates = (566, 344), Black Pixels = 1228637, White Pixels = 163
#   Circle 8: Coordinates = (606, 344), Black Pixels = 1228635, White Pixels = 165
#   Circle 9: Coordinates = (734, 346), Black Pixels = 1228615, White Pixels = 185
#   Circle 10: Coordinates = (774, 346), Black Pixels = 1228660, White Pixels = 140
#   Circle 11: Coordinates = (814, 348), Black Pixels = 1228644, White Pixels = 156
#   Circle 12: Coordinates = (856, 348), Black Pixels = 1228650, White Pixels = 150
#   Circle 13: Coordinates = (976, 350), Black Pixels = 1228664, White Pixels = 136
#   Circle 14: Coordinates = (1018, 350), Black Pixels = 1228659, White Pixels = 141
#   Circle 15: Coordinates = (1056, 350), Black Pixels = 1228677, White Pixels = 123
#   Circle 16: Coordinates = (1096, 350), Black Pixels = 1228672, White Pixels = 128
# Row 4:
#   Circle 1: Coordinates = (214, 380), Black Pixels = 1228554, White Pixels = 246
#   Circle 2: Coordinates = (258, 380), Black Pixels = 1228559, White Pixels = 241
#   Circle 3: Coordinates = (304, 382), Black Pixels = 1228604, White Pixels = 196
#   Circle 4: Coordinates = (350, 384), Black Pixels = 1228578, White Pixels = 222
#   Circle 5: Coordinates = (482, 386), Black Pixels = 1228569, White Pixels = 231
#   Circle 6: Coordinates = (524, 386), Black Pixels = 1228601, White Pixels = 199
#   Circle 7: Coordinates = (564, 386), Black Pixels = 1228613, White Pixels = 187
#   Circle 8: Coordinates = (604, 388), Black Pixels = 1228586, White Pixels = 214
#   Circle 9: Coordinates = (732, 390), Black Pixels = 1228642, White Pixels = 158
#   Circle 10: Coordinates = (774, 390), Black Pixels = 1228654, White Pixels = 146
#   Circle 11: Coordinates = (814, 390), Black Pixels = 1228614, White Pixels = 186
#   Circle 12: Coordinates = (854, 392), Black Pixels = 1228644, White Pixels = 156
#   Circle 13: Coordinates = (976, 392), Black Pixels = 1228628, White Pixels = 172
#   Circle 14: Coordinates = (1016, 392), Black Pixels = 1228663, White Pixels = 137
#   Circle 15: Coordinates = (1056, 394), Black Pixels = 1228662, White Pixels = 138
#   Circle 16: Coordinates = (1096, 394), Black Pixels = 1228654, White Pixels = 146
# Row 5:
#   Circle 1: Coordinates = (214, 426), Black Pixels = 1228575, White Pixels = 225
#   Circle 2: Coordinates = (256, 426), Black Pixels = 1228613, White Pixels = 187
#   Circle 3: Coordinates = (302, 428), Black Pixels = 1228611, White Pixels = 189
#   Circle 4: Coordinates = (346, 428), Black Pixels = 1228592, White Pixels = 208
#   Circle 5: Coordinates = (482, 430), Black Pixels = 1228557, White Pixels = 243
#   Circle 6: Coordinates = (524, 430), Black Pixels = 1228657, White Pixels = 143
#   Circle 7: Coordinates = (564, 432), Black Pixels = 1228616, White Pixels = 184
#   Circle 8: Coordinates = (604, 432), Black Pixels = 1228648, White Pixels = 152
#   Circle 9: Coordinates = (732, 432), Black Pixels = 1228603, White Pixels = 197
#   Circle 10: Coordinates = (772, 434), Black Pixels = 1228667, White Pixels = 133
#   Circle 11: Coordinates = (814, 434), Black Pixels = 1228668, White Pixels = 132
#   Circle 12: Coordinates = (854, 434), Black Pixels = 1228655, White Pixels = 145
#   Circle 13: Coordinates = (976, 436), Black Pixels = 1228648, White Pixels = 152
#   Circle 14: Coordinates = (1016, 436), Black Pixels = 1228668, White Pixels = 132
#   Circle 15: Coordinates = (1056, 436), Black Pixels = 1228666, White Pixels = 134
#   Circle 16: Coordinates = (1096, 436), Black Pixels = 1228677, White Pixels = 123
# Row 6:
#   Circle 1: Coordinates = (210, 472), Black Pixels = 1228610, White Pixels = 190
#   Circle 2: Coordinates = (256, 472), Black Pixels = 1228603, White Pixels = 197
#   Circle 3: Coordinates = (302, 474), Black Pixels = 1228621, White Pixels = 179
#   Circle 4: Coordinates = (348, 474), Black Pixels = 1228583, White Pixels = 217
#   Circle 5: Coordinates = (480, 474), Black Pixels = 1228588, White Pixels = 212
#   Circle 6: Coordinates = (524, 474), Black Pixels = 1228634, White Pixels = 166
#   Circle 7: Coordinates = (564, 476), Black Pixels = 1228590, White Pixels = 210
#   Circle 8: Coordinates = (604, 476), Black Pixels = 1228626, White Pixels = 174
#   Circle 9: Coordinates = (732, 476), Black Pixels = 1228617, White Pixels = 183
#   Circle 10: Coordinates = (772, 476), Black Pixels = 1228655, White Pixels = 145
#   Circle 11: Coordinates = (812, 478), Black Pixels = 1228645, White Pixels = 155
#   Circle 12: Coordinates = (854, 478), Black Pixels = 1228649, White Pixels = 151
#   Circle 13: Coordinates = (978, 478), Black Pixels = 1228617, White Pixels = 183
#   Circle 14: Coordinates = (1016, 480), Black Pixels = 1228666, White Pixels = 134
#   Circle 15: Coordinates = (1058, 480), Black Pixels = 1228679, White Pixels = 121
#   Circle 16: Coordinates = (1098, 480), Black Pixels = 1228651, White Pixels = 149
# Row 7:
#   Circle 1: Coordinates = (208, 518), Black Pixels = 1228537, White Pixels = 263
#   Circle 2: Coordinates = (256, 520), Black Pixels = 1228604, White Pixels = 196
#   Circle 3: Coordinates = (300, 520), Black Pixels = 1228615, White Pixels = 185
#   Circle 4: Coordinates = (346, 520), Black Pixels = 1228598, White Pixels = 202
#   Circle 5: Coordinates = (480, 518), Black Pixels = 1228571, White Pixels = 229
#   Circle 6: Coordinates = (522, 518), Black Pixels = 1228591, White Pixels = 209
#   Circle 7: Coordinates = (562, 518), Black Pixels = 1228598, White Pixels = 202
#   Circle 8: Coordinates = (602, 520), Black Pixels = 1228623, White Pixels = 177
#   Circle 9: Coordinates = (732, 520), Black Pixels = 1228613, White Pixels = 187
#   Circle 10: Coordinates = (772, 520), Black Pixels = 1228646, White Pixels = 154
#   Circle 11: Coordinates = (812, 520), Black Pixels = 1228650, White Pixels = 150
#   Circle 12: Coordinates = (854, 522), Black Pixels = 1228644, White Pixels = 156
#   Circle 13: Coordinates = (978, 524), Black Pixels = 1228617, White Pixels = 183
#   Circle 14: Coordinates = (1018, 524), Black Pixels = 1228603, White Pixels = 197
#   Circle 15: Coordinates = (1058, 524), Black Pixels = 1228662, White Pixels = 138
#   Circle 16: Coordinates = (1098, 524), Black Pixels = 1228648, White Pixels = 152
# Row 8:
#   Circle 1: Coordinates = (206, 566), Black Pixels = 1228546, White Pixels = 254
#   Circle 2: Coordinates = (252, 566), Black Pixels = 1228657, White Pixels = 143
#   Circle 3: Coordinates = (300, 566), Black Pixels = 1228615, White Pixels = 185
#   Circle 4: Coordinates = (346, 566), Black Pixels = 1228588, White Pixels = 212
#   Circle 5: Coordinates = (478, 564), Black Pixels = 1228589, White Pixels = 211
#   Circle 6: Coordinates = (522, 564), Black Pixels = 1228654, White Pixels = 146
#   Circle 7: Coordinates = (562, 564), Black Pixels = 1228622, White Pixels = 178
#   Circle 8: Coordinates = (602, 566), Black Pixels = 1228631, White Pixels = 169
#   Circle 9: Coordinates = (732, 564), Black Pixels = 1228608, White Pixels = 192
#   Circle 10: Coordinates = (772, 564), Black Pixels = 1228653, White Pixels = 147
#   Circle 11: Coordinates = (814, 564), Black Pixels = 1228672, White Pixels = 128
#   Circle 12: Coordinates = (854, 566), Black Pixels = 1228643, White Pixels = 157
#   Circle 13: Coordinates = (978, 568), Black Pixels = 1228615, White Pixels = 185
#   Circle 14: Coordinates = (1018, 568), Black Pixels = 1228662, White Pixels = 138
#   Circle 15: Coordinates = (1058, 568), Black Pixels = 1228646, White Pixels = 154
#   Circle 16: Coordinates = (1100, 568), Black Pixels = 1228645, White Pixels = 155
# Row 9:
#   Circle 1: Coordinates = (204, 612), Black Pixels = 1228536, White Pixels = 264
#   Circle 2: Coordinates = (250, 612), Black Pixels = 1228589, White Pixels = 211
#   Circle 3: Coordinates = (298, 612), Black Pixels = 1228585, White Pixels = 215
#   Circle 4: Coordinates = (342, 612), Black Pixels = 1228590, White Pixels = 210
#   Circle 5: Coordinates = (478, 610), Black Pixels = 1228587, White Pixels = 213
#   Circle 6: Coordinates = (520, 608), Black Pixels = 1228605, White Pixels = 195
#   Circle 7: Coordinates = (560, 610), Black Pixels = 1228580, White Pixels = 220
#   Circle 8: Coordinates = (602, 610), Black Pixels = 1228624, White Pixels = 176
#   Circle 9: Coordinates = (732, 608), Black Pixels = 1228605, White Pixels = 195
#   Circle 10: Coordinates = (772, 608), Black Pixels = 1228659, White Pixels = 141
#   Circle 11: Coordinates = (814, 610), Black Pixels = 1228665, White Pixels = 135
#   Circle 12: Coordinates = (856, 610), Black Pixels = 1228664, White Pixels = 136
#   Circle 13: Coordinates = (980, 612), Black Pixels = 1228620, White Pixels = 180
#   Circle 14: Coordinates = (1020, 612), Black Pixels = 1228664, White Pixels = 136
#   Circle 15: Coordinates = (1060, 612), Black Pixels = 1228668, White Pixels = 132
#   Circle 16: Coordinates = (1104, 612), Black Pixels = 1228641, White Pixels = 159
# Row 10:
#   Circle 1: Coordinates = (204, 660), Black Pixels = 1228547, White Pixels = 253
#   Circle 2: Coordinates = (250, 660), Black Pixels = 1228600, White Pixels = 200
#   Circle 3: Coordinates = (294, 660), Black Pixels = 1228615, White Pixels = 185
#   Circle 4: Coordinates = (342, 660), Black Pixels = 1228612, White Pixels = 188
#   Circle 5: Coordinates = (478, 656), Black Pixels = 1228553, White Pixels = 247
#   Circle 6: Coordinates = (518, 654), Black Pixels = 1228599, White Pixels = 201
#   Circle 7: Coordinates = (558, 658), Black Pixels = 1228605, White Pixels = 195
#   Circle 8: Coordinates = (600, 658), Black Pixels = 1228593, White Pixels = 207
#   Circle 9: Coordinates = (732, 654), Black Pixels = 1228612, White Pixels = 188
#   Circle 10: Coordinates = (774, 656), Black Pixels = 1228632, White Pixels = 168
#   Circle 11: Coordinates = (814, 654), Black Pixels = 1228626, White Pixels = 174
#   Circle 12: Coordinates = (856, 656), Black Pixels = 1228658, White Pixels = 142
#   Circle 13: Coordinates = (980, 658), Black Pixels = 1228624, White Pixels = 176
#   Circle 14: Coordinates = (1022, 658), Black Pixels = 1228641, White Pixels = 159
#   Circle 15: Coordinates = (1064, 658), Black Pixels = 1228639, White Pixels = 161
#   Circle 16: Coordinates = (1104, 658), Black Pixels = 1228661, White Pixels = 139

# %%
start = time.time()
grouped_rows_k = group_by_row_dbscan(pixel_counts_k, eps=10)
end = time.time()
print("Grouping by row time:", end-start)
# Print the grouped results
for row_idx, row in enumerate(grouped_rows_k, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, black_count, white_count) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")
# Out:
# Grouping by row time: 0.003481626510620117
# Row 1:
#   Circle 1: Coordinates = (234, 272), Black Pixels = 1228593, White Pixels = 207
#   Circle 2: Coordinates = (272, 272), Black Pixels = 1228679, White Pixels = 121
#   Circle 3: Coordinates = (314, 272), Black Pixels = 1228800, White Pixels = 0
#   Circle 4: Coordinates = (356, 272), Black Pixels = 1228661, White Pixels = 139
#   Circle 5: Coordinates = (476, 276), Black Pixels = 1228766, White Pixels = 34
#   Circle 6: Coordinates = (516, 278), Black Pixels = 1228669, White Pixels = 131
#   Circle 7: Coordinates = (552, 278), Black Pixels = 1228660, White Pixels = 140
#   Circle 8: Coordinates = (590, 278), Black Pixels = 1228666, White Pixels = 134
#   Circle 9: Coordinates = (710, 280), Black Pixels = 1228644, White Pixels = 156
#   Circle 10: Coordinates = (746, 280), Black Pixels = 1228800, White Pixels = 0
#   Circle 11: Coordinates = (784, 282), Black Pixels = 1228691, White Pixels = 109
#   Circle 12: Coordinates = (820, 282), Black Pixels = 1228677, White Pixels = 123
#   Circle 13: Coordinates = (928, 284), Black Pixels = 1228780, White Pixels = 20
#   Circle 14: Coordinates = (964, 284), Black Pixels = 1228695, White Pixels = 105
#   Circle 15: Coordinates = (1000, 284), Black Pixels = 1228696, White Pixels = 104
#   Circle 16: Coordinates = (1036, 284), Black Pixels = 1228665, White Pixels = 135
# Row 2:
#   Circle 1: Coordinates = (232, 310), Black Pixels = 1228763, White Pixels = 37
#   Circle 2: Coordinates = (274, 310), Black Pixels = 1228640, White Pixels = 160
#   Circle 3: Coordinates = (312, 312), Black Pixels = 1228618, White Pixels = 182
#   Circle 4: Coordinates = (354, 310), Black Pixels = 1228658, White Pixels = 142
#   Circle 5: Coordinates = (476, 314), Black Pixels = 1228602, White Pixels = 198
#   Circle 6: Coordinates = (514, 316), Black Pixels = 1228685, White Pixels = 115
#   Circle 7: Coordinates = (552, 316), Black Pixels = 1228658, White Pixels = 142
#   Circle 8: Coordinates = (590, 316), Black Pixels = 1228800, White Pixels = 0
#   Circle 9: Coordinates = (708, 318), Black Pixels = 1228670, White Pixels = 130
#   Circle 10: Coordinates = (746, 318), Black Pixels = 1228711, White Pixels = 89
#   Circle 11: Coordinates = (782, 320), Black Pixels = 1228692, White Pixels = 108
#   Circle 12: Coordinates = (818, 320), Black Pixels = 1228775, White Pixels = 25
#   Circle 13: Coordinates = (928, 320), Black Pixels = 1228654, White Pixels = 146
#   Circle 14: Coordinates = (964, 322), Black Pixels = 1228795, White Pixels = 5
#   Circle 15: Coordinates = (1000, 320), Black Pixels = 1228707, White Pixels = 93
#   Circle 16: Coordinates = (1038, 322), Black Pixels = 1228698, White Pixels = 102
# Row 3:
#   Circle 1: Coordinates = (230, 348), Black Pixels = 1228570, White Pixels = 230
#   Circle 2: Coordinates = (268, 350), Black Pixels = 1228790, White Pixels = 10
#   Circle 3: Coordinates = (310, 350), Black Pixels = 1228675, White Pixels = 125
#   Circle 4: Coordinates = (350, 352), Black Pixels = 1228638, White Pixels = 162
#   Circle 5: Coordinates = (476, 354), Black Pixels = 1228633, White Pixels = 167
#   Circle 6: Coordinates = (514, 354), Black Pixels = 1228795, White Pixels = 5
#   Circle 7: Coordinates = (552, 354), Black Pixels = 1228660, White Pixels = 140
#   Circle 8: Coordinates = (590, 354), Black Pixels = 1228673, White Pixels = 127
#   Circle 9: Coordinates = (708, 356), Black Pixels = 1228792, White Pixels = 8
#   Circle 10: Coordinates = (744, 356), Black Pixels = 1228711, White Pixels = 89
#   Circle 11: Coordinates = (782, 356), Black Pixels = 1228705, White Pixels = 95
#   Circle 12: Coordinates = (818, 356), Black Pixels = 1228705, White Pixels = 95
#   Circle 13: Coordinates = (928, 356), Black Pixels = 1228652, White Pixels = 148
#   Circle 14: Coordinates = (966, 358), Black Pixels = 1228697, White Pixels = 103
#   Circle 15: Coordinates = (1000, 358), Black Pixels = 1228796, White Pixels = 4
#   Circle 16: Coordinates = (1038, 358), Black Pixels = 1228699, White Pixels = 101
# Row 4:
#   Circle 1: Coordinates = (228, 390), Black Pixels = 1228607, White Pixels = 193
#   Circle 2: Coordinates = (268, 390), Black Pixels = 1228654, White Pixels = 146
#   Circle 3: Coordinates = (308, 390), Black Pixels = 1228658, White Pixels = 142
#   Circle 4: Coordinates = (350, 390), Black Pixels = 1228781, White Pixels = 19
#   Circle 5: Coordinates = (476, 392), Black Pixels = 1228659, White Pixels = 141
#   Circle 6: Coordinates = (514, 392), Black Pixels = 1228649, White Pixels = 151
#   Circle 7: Coordinates = (552, 392), Black Pixels = 1228787, White Pixels = 13
#   Circle 8: Coordinates = (588, 392), Black Pixels = 1228669, White Pixels = 131
#   Circle 9: Coordinates = (708, 394), Black Pixels = 1228664, White Pixels = 136
#   Circle 10: Coordinates = (744, 394), Black Pixels = 1228799, White Pixels = 1
#   Circle 11: Coordinates = (782, 394), Black Pixels = 1228661, White Pixels = 139
#   Circle 12: Coordinates = (818, 394), Black Pixels = 1228704, White Pixels = 96
#   Circle 13: Coordinates = (928, 394), Black Pixels = 1228799, White Pixels = 1
#   Circle 14: Coordinates = (964, 394), Black Pixels = 1228710, White Pixels = 90
#   Circle 15: Coordinates = (1002, 394), Black Pixels = 1228713, White Pixels = 87
#   Circle 16: Coordinates = (1038, 394), Black Pixels = 1228697, White Pixels = 103
# Row 5:
#   Circle 1: Coordinates = (228, 428), Black Pixels = 1228788, White Pixels = 12
#   Circle 2: Coordinates = (268, 430), Black Pixels = 1228654, White Pixels = 146
#   Circle 3: Coordinates = (306, 430), Black Pixels = 1228661, White Pixels = 139
#   Circle 4: Coordinates = (348, 430), Black Pixels = 1228636, White Pixels = 164
#   Circle 5: Coordinates = (476, 428), Black Pixels = 1228641, White Pixels = 159
#   Circle 6: Coordinates = (514, 430), Black Pixels = 1228687, White Pixels = 113
#   Circle 7: Coordinates = (552, 430), Black Pixels = 1228684, White Pixels = 116
#   Circle 8: Coordinates = (590, 430), Black Pixels = 1228779, White Pixels = 21
#   Circle 9: Coordinates = (708, 430), Black Pixels = 1228690, White Pixels = 110
#   Circle 10: Coordinates = (744, 430), Black Pixels = 1228717, White Pixels = 83
#   Circle 11: Coordinates = (782, 430), Black Pixels = 1228775, White Pixels = 25
#   Circle 12: Coordinates = (818, 430), Black Pixels = 1228709, White Pixels = 91
#   Circle 13: Coordinates = (930, 430), Black Pixels = 1228690, White Pixels = 110
#   Circle 14: Coordinates = (966, 430), Black Pixels = 1228696, White Pixels = 104
#   Circle 15: Coordinates = (1002, 430), Black Pixels = 1228721, White Pixels = 79
#   Circle 16: Coordinates = (1038, 430), Black Pixels = 1228800, White Pixels = 0
# Row 6:
#   Circle 1: Coordinates = (226, 468), Black Pixels = 1228629, White Pixels = 171
#   Circle 2: Coordinates = (266, 470), Black Pixels = 1228652, White Pixels = 148
#   Circle 3: Coordinates = (310, 468), Black Pixels = 1228796, White Pixels = 4
#   Circle 4: Coordinates = (352, 468), Black Pixels = 1228619, White Pixels = 181
#   Circle 5: Coordinates = (476, 468), Black Pixels = 1228766, White Pixels = 34
#   Circle 6: Coordinates = (514, 468), Black Pixels = 1228681, White Pixels = 119
#   Circle 7: Coordinates = (552, 468), Black Pixels = 1228662, White Pixels = 138
#   Circle 8: Coordinates = (588, 468), Black Pixels = 1228651, White Pixels = 149
#   Circle 9: Coordinates = (708, 466), Black Pixels = 1228666, White Pixels = 134
#   Circle 10: Coordinates = (744, 466), Black Pixels = 1228797, White Pixels = 3
#   Circle 11: Coordinates = (782, 466), Black Pixels = 1228705, White Pixels = 95
#   Circle 12: Coordinates = (818, 466), Black Pixels = 1228797, White Pixels = 3
#   Circle 13: Coordinates = (932, 466), Black Pixels = 1228648, White Pixels = 152
#   Circle 14: Coordinates = (966, 466), Black Pixels = 1228782, White Pixels = 18
#   Circle 15: Coordinates = (1002, 466), Black Pixels = 1228703, White Pixels = 97
#   Circle 16: Coordinates = (1038, 466), Black Pixels = 1228692, White Pixels = 108
# Row 7:
#   Circle 1: Coordinates = (226, 510), Black Pixels = 1228628, White Pixels = 172
#   Circle 2: Coordinates = (266, 510), Black Pixels = 1228678, White Pixels = 122
#   Circle 3: Coordinates = (308, 508), Black Pixels = 1228659, White Pixels = 141
#   Circle 4: Coordinates = (350, 508), Black Pixels = 1228789, White Pixels = 11
#   Circle 5: Coordinates = (474, 506), Black Pixels = 1228644, White Pixels = 156
#   Circle 6: Coordinates = (514, 506), Black Pixels = 1228684, White Pixels = 116
#   Circle 7: Coordinates = (552, 506), Black Pixels = 1228795, White Pixels = 5
#   Circle 8: Coordinates = (588, 506), Black Pixels = 1228670, White Pixels = 130
#   Circle 9: Coordinates = (710, 504), Black Pixels = 1228797, White Pixels = 3
#   Circle 10: Coordinates = (746, 504), Black Pixels = 1228720, White Pixels = 80
#   Circle 11: Coordinates = (782, 504), Black Pixels = 1228716, White Pixels = 84
#   Circle 12: Coordinates = (820, 504), Black Pixels = 1228712, White Pixels = 88
#   Circle 13: Coordinates = (932, 504), Black Pixels = 1228670, White Pixels = 130
#   Circle 14: Coordinates = (968, 504), Black Pixels = 1228720, White Pixels = 80
#   Circle 15: Coordinates = (1004, 504), Black Pixels = 1228763, White Pixels = 37
#   Circle 16: Coordinates = (1040, 504), Black Pixels = 1228699, White Pixels = 101
# Row 8:
#   Circle 1: Coordinates = (226, 550), Black Pixels = 1228640, White Pixels = 160
#   Circle 2: Coordinates = (266, 548), Black Pixels = 1228800, White Pixels = 0
#   Circle 3: Coordinates = (310, 548), Black Pixels = 1228680, White Pixels = 120
#   Circle 4: Coordinates = (352, 546), Black Pixels = 1228668, White Pixels = 132
#   Circle 5: Coordinates = (474, 544), Black Pixels = 1228625, White Pixels = 175
#   Circle 6: Coordinates = (514, 544), Black Pixels = 1228799, White Pixels = 1
#   Circle 7: Coordinates = (550, 544), Black Pixels = 1228688, White Pixels = 112
#   Circle 8: Coordinates = (590, 546), Black Pixels = 1228696, White Pixels = 104
#   Circle 9: Coordinates = (710, 542), Black Pixels = 1228677, White Pixels = 123
#   Circle 10: Coordinates = (746, 542), Black Pixels = 1228711, White Pixels = 89
#   Circle 11: Coordinates = (784, 540), Black Pixels = 1228654, White Pixels = 146
#   Circle 12: Coordinates = (822, 542), Black Pixels = 1228800, White Pixels = 0
#   Circle 13: Coordinates = (934, 542), Black Pixels = 1228785, White Pixels = 15
#   Circle 14: Coordinates = (970, 542), Black Pixels = 1228709, White Pixels = 91
#   Circle 15: Coordinates = (1006, 540), Black Pixels = 1228695, White Pixels = 105
#   Circle 16: Coordinates = (1042, 540), Black Pixels = 1228704, White Pixels = 96
# Row 9:
#   Circle 1: Coordinates = (224, 590), Black Pixels = 1228793, White Pixels = 7
#   Circle 2: Coordinates = (264, 590), Black Pixels = 1228663, White Pixels = 137
#   Circle 3: Coordinates = (306, 590), Black Pixels = 1228652, White Pixels = 148
#   Circle 4: Coordinates = (350, 588), Black Pixels = 1228652, White Pixels = 148
#   Circle 5: Coordinates = (476, 584), Black Pixels = 1228606, White Pixels = 194
#   Circle 6: Coordinates = (514, 582), Black Pixels = 1228669, White Pixels = 131
#   Circle 7: Coordinates = (550, 584), Black Pixels = 1228651, White Pixels = 149
#   Circle 8: Coordinates = (590, 584), Black Pixels = 1228800, White Pixels = 0
#   Circle 9: Coordinates = (710, 580), Black Pixels = 1228667, White Pixels = 133
#   Circle 10: Coordinates = (748, 580), Black Pixels = 1228704, White Pixels = 96
#   Circle 11: Coordinates = (786, 580), Black Pixels = 1228765, White Pixels = 35
#   Circle 12: Coordinates = (824, 580), Black Pixels = 1228692, White Pixels = 108
#   Circle 13: Coordinates = (936, 580), Black Pixels = 1228681, White Pixels = 119
#   Circle 14: Coordinates = (972, 578), Black Pixels = 1228709, White Pixels = 91
#   Circle 15: Coordinates = (1008, 578), Black Pixels = 1228702, White Pixels = 98
#   Circle 16: Coordinates = (1046, 578), Black Pixels = 1228771, White Pixels = 29
# Row 10:
#   Circle 1: Coordinates = (222, 632), Black Pixels = 1228630, White Pixels = 170
#   Circle 2: Coordinates = (264, 632), Black Pixels = 1228662, White Pixels = 138
#   Circle 3: Coordinates = (306, 632), Black Pixels = 1228678, White Pixels = 122
#   Circle 4: Coordinates = (350, 630), Black Pixels = 1228791, White Pixels = 9
#   Circle 5: Coordinates = (476, 624), Black Pixels = 1228646, White Pixels = 154
#   Circle 6: Coordinates = (514, 624), Black Pixels = 1228652, White Pixels = 148
#   Circle 7: Coordinates = (550, 624), Black Pixels = 1228800, White Pixels = 0
#   Circle 8: Coordinates = (590, 624), Black Pixels = 1228677, White Pixels = 123
#   Circle 9: Coordinates = (712, 620), Black Pixels = 1228765, White Pixels = 35
#   Circle 10: Coordinates = (748, 620), Black Pixels = 1228702, White Pixels = 98
#   Circle 11: Coordinates = (786, 618), Black Pixels = 1228649, White Pixels = 151
#   Circle 12: Coordinates = (824, 618), Black Pixels = 1228684, White Pixels = 116
#   Circle 13: Coordinates = (938, 620), Black Pixels = 1228680, White Pixels = 120
#   Circle 14: Coordinates = (974, 618), Black Pixels = 1228800, White Pixels = 0
#   Circle 15: Coordinates = (1010, 618), Black Pixels = 1228698, White Pixels = 102
#   Circle 16: Coordinates = (1048, 618), Black Pixels = 1228692, White Pixels = 108

# %% [markdown]
# ### 5. Idendifying Marked and unmarked bubbles

# %%
def mean_sd(grouped_rows, num_options):

    temp=[]
    for row in grouped_rows:
        for question_start in range(0, len(row), num_options):
            question_group = row[question_start:question_start + num_options]

            # Extract white pixel values for the current question
            white_pixel_values = [white for (_, _, _, _, white) in question_group]

            # Calculate the mean and standard deviation of the white pixel values
            mean_white = np.mean(white_pixel_values)
            std_dev_white = np.std(white_pixel_values)
            print(f"Mean: {mean_white}, Standard Deviation: {std_dev_white}")
            temp.append((mean_white,std_dev_white))

    return temp

start = time.time()
stat_template = mean_sd(grouped_rows_t, options)
end = time.time()
print("Mean and SD time:", end-start)
# Out:
# Mean: 210.0, Standard Deviation: 19.339079605813716
# Mean: 194.0, Standard Deviation: 28.39013913315678
# Mean: 159.0, Standard Deviation: 26.201145013147805
# Mean: 137.0, Standard Deviation: 18.76166303929372
# Mean: 184.0, Standard Deviation: 30.124740662784138
# Mean: 172.25, Standard Deviation: 17.239127008059313
# Mean: 148.75, Standard Deviation: 18.14352501582865
# Mean: 140.75, Standard Deviation: 15.07274029498286
# Mean: 215.5, Standard Deviation: 19.20286436967152
# Mean: 172.75, Standard Deviation: 14.042346669983617
# Mean: 157.75, Standard Deviation: 16.7388022271607
# Mean: 132.0, Standard Deviation: 6.96419413859206
# Mean: 226.25, Standard Deviation: 19.62619423117992
# Mean: 207.75, Standard Deviation: 16.48294573187693
# Mean: 161.5, Standard Deviation: 14.857657958103626
# Mean: 148.25, Standard Deviation: 14.148763196831021
# Mean: 202.25, Standard Deviation: 15.481844205391036
# Mean: 180.5, Standard Deviation: 39.16950344336777
# Mean: 151.75, Standard Deviation: 26.621185172715357
# Mean: 135.25, Standard Deviation: 10.520812706250407
# Mean: 195.75, Standard Deviation: 13.845125496000389
# Mean: 190.5, Standard Deviation: 20.706279240848655
# Mean: 158.5, Standard Deviation: 14.585952145814822
# Mean: 146.75, Standard Deviation: 23.155722834755128
# Mean: 211.5, Standard Deviation: 30.35210042155238
# Mean: 204.25, Standard Deviation: 18.59267328815305
# Mean: 161.75, Standard Deviation: 14.737282653189496
# Mean: 167.5, Standard Deviation: 23.56374333589636
# Mean: 198.5, Standard Deviation: 40.38873605350878
# Mean: 176.0, Standard Deviation: 23.33452377915607
# Mean: 156.0, Standard Deviation: 23.24865587512534
# Mean: 158.0, Standard Deviation: 16.98528775146303
# Mean: 225.0, Standard Deviation: 22.594247055390007
# Mean: 201.0, Standard Deviation: 17.073371078963874
# Mean: 151.75, Standard Deviation: 25.073641538476217
# Mean: 151.75, Standard Deviation: 19.292161620720474
# Mean: 206.5, Standard Deviation: 27.427176303804956
# Mean: 212.5, Standard Deviation: 20.3654118544163
# Mean: 168.0, Standard Deviation: 16.673332000533065
# Mean: 158.75, Standard Deviation: 13.160072188251856
# Mean and SD time: 0.004000186920166016

# %%
max_tuple = max(stat_template, key=lambda x: x[1])
max_sd = max_tuple[1]
print("Maximum Standard Deviation:", max_sd)
# Out:
# Maximum Standard Deviation: 40.38873605350878

# %%
start = time.time()
mean_sd(grouped_rows_s, options)
end = time.time()
print("Mean and SD time:", end-start)
# Out:
# Mean: 137.5, Standard Deviation: 78.58275892331599
# Mean: 134.75, Standard Deviation: 81.96760030646256
# Mean: 114.75, Standard Deviation: 66.54838465357368
# Mean: 111.0, Standard Deviation: 56.47565847336355
# Mean: 139.75, Standard Deviation: 59.767779781417346
# Mean: 130.25, Standard Deviation: 62.61938597591005
# Mean: 98.5, Standard Deviation: 57.67798540171111
# Mean: 104.0, Standard Deviation: 49.462106708064915
# Mean: 132.75, Standard Deviation: 77.89536250637775
# Mean: 141.0, Standard Deviation: 52.407060593015515
# Mean: 121.75, Standard Deviation: 65.94078783272157
# Mean: 111.0, Standard Deviation: 64.07417576528005
# Mean: 148.0, Standard Deviation: 105.00714261420507
# Mean: 125.25, Standard Deviation: 64.85898164479612
# Mean: 105.5, Standard Deviation: 62.2434735534578
# Mean: 100.25, Standard Deviation: 59.14970414127192
# Mean: 129.5, Standard Deviation: 65.5190811901388
# Mean: 108.5, Standard Deviation: 64.24367673164419
# Mean: 108.0, Standard Deviation: 51.176166327695945
# Mean: 104.25, Standard Deviation: 52.98761647781489
# Mean: 127.25, Standard Deviation: 72.58916930231396
# Mean: 111.25, Standard Deviation: 58.921027655668055
# Mean: 117.5, Standard Deviation: 58.01939330947886
# Mean: 105.0, Standard Deviation: 63.194145298437256
# Mean: 117.0, Standard Deviation: 63.0
# Mean: 118.25, Standard Deviation: 58.576339079870806
# Mean: 99.0, Standard Deviation: 47.62877281643944
# Mean: 111.25, Standard Deviation: 48.100805606559234
# Mean: 122.25, Standard Deviation: 71.84836462996218
# Mean: 111.75, Standard Deviation: 52.59931083198714
# Mean: 96.75, Standard Deviation: 55.065302142093074
# Mean: 97.5, Standard Deviation: 50.93378053904893
# Mean: 123.25, Standard Deviation: 71.37707965446612
# Mean: 128.5, Standard Deviation: 66.6427040267725
# Mean: 103.25, Standard Deviation: 56.499446899947614
# Mean: 98.0, Standard Deviation: 56.789083458002736
# Mean: 122.75, Standard Deviation: 71.38758645590983
# Mean: 111.5, Standard Deviation: 60.035406219996545
# Mean: 107.25, Standard Deviation: 57.12869244083922
# Mean: 101.5, Standard Deviation: 38.95189340712464
# Mean and SD time: 0.00452423095703125

# %%
start = time.time()
mean_sd(grouped_rows_k, options)
end = time.time()
print("Mean and SD time:", end-start)
# Out:
# Mean: 116.75, Standard Deviation: 74.6470863463538
# Mean: 109.75, Standard Deviation: 43.85416171813115
# Mean: 97.0, Standard Deviation: 58.54485459884583
# Mean: 91.0, Standard Deviation: 42.84273567362383
# Mean: 130.25, Standard Deviation: 55.670346684747706
# Mean: 113.75, Standard Deviation: 72.17470124635086
# Mean: 88.0, Standard Deviation: 39.15992849840255
# Mean: 86.5, Standard Deviation: 51.14929129518805
# Mean: 131.75, Standard Deviation: 79.74451391788654
# Mean: 109.75, Standard Deviation: 62.174653195655225
# Mean: 71.75, Standard Deviation: 36.88749788207381
# Mean: 89.0, Standard Deviation: 52.54997621312497
# Mean: 125.0, Standard Deviation: 64.40108694734896
# Mean: 109.0, Standard Deviation: 55.87486017879597
# Mean: 93.0, Standard Deviation: 55.76289088632332
# Mean: 70.25, Standard Deviation: 40.43126883984721
# Mean: 115.25, Standard Deviation: 60.30495419117736
# Mean: 102.25, Standard Deviation: 50.3158772158451
# Mean: 77.25, Standard Deviation: 31.72045869781835
# Mean: 73.25, Standard Deviation: 43.859862060886606
# Mean: 126.0, Standard Deviation: 71.44578364046404
# Mean: 110.0, Standard Deviation: 45.17189391646093
# Mean: 58.75, Standard Deviation: 57.42984851103127
# Mean: 93.75, Standard Deviation: 48.334123556758534
# Mean: 111.5, Standard Deviation: 60.70625997374571
# Mean: 101.75, Standard Deviation: 57.67310898503739
# Mean: 63.75, Standard Deviation: 35.187888541371734
# Mean: 87.0, Standard Deviation: 33.88952640566109
# Mean: 103.0, Standard Deviation: 61.212743771211564
# Mean: 98.0, Standard Deviation: 62.38990302925627
# Mean: 89.5, Standard Deviation: 55.509008277936296
# Mean: 76.75, Standard Deviation: 36.00260407248342
# Mean: 110.0, Standard Deviation: 59.63639828158639
# Mean: 118.5, Standard Deviation: 72.16127770487438
# Mean: 93.0, Standard Deviation: 36.04857833535187
# Mean: 84.25, Standard Deviation: 33.521448357730605
# Mean: 109.75, Standard Deviation: 60.68103080864728
# Mean: 106.25, Standard Deviation: 62.4354666836086
# Mean: 100.0, Standard Deviation: 42.089191011469914
# Mean: 82.5, Standard Deviation: 48.0702610768862
# Mean and SD time: 0.0037355422973632812

# %%
def detect_marked_and_unmarked_bubbles(subtracted_grouped_rows, num_options, deviation_threshold=50):
    """
    Detect marked and unmarked bubbles based on white pixel values and a deviation threshold.

    Args:
        subtracted_grouped_rows (list): List of grouped circles with subtracted pixel counts.
        num_options (int): The number of options per question.
        deviation_threshold (float): The threshold below which a question is considered unmarked.

    Returns:
        list: A 2D array where each element is:
              - 1 for the most deviated (marked) bubble.
              - 0 for unmarked bubbles.
    """
    marked_bubbles = []

    for row in subtracted_grouped_rows:
        for question_start in range(0, len(row), num_options):
            question_group = row[question_start:question_start + num_options]

            # Extract white pixel values for the current question
            white_pixel_values = [subtracted_white for (_, _, _, _, subtracted_white) in question_group]

            # Calculate the mean and standard deviation of the white pixel values
            mean_white = np.mean(white_pixel_values)
            std_dev_white = np.std(white_pixel_values)
            print(f"Mean: {mean_white}, Standard Deviation: {std_dev_white}")
            # If the standard deviation is less than the threshold, consider the question unmarked
            if std_dev_white < deviation_threshold:
                marked_bubbles.append([0] * num_options)  
            else:

                # Create a 1D array for the question (options), initialized to zeros
                marked_question = np.zeros(num_options, dtype=int)

                min_white_index = np.argmin(white_pixel_values)

                # Mark the option with the highest deviation as 1 (marked bubble)
                marked_question[min_white_index] = 1

                marked_bubbles.append(marked_question)

    return np.array(marked_bubbles)
start = time.time()
answer_student = detect_marked_and_unmarked_bubbles(grouped_rows_s, options, deviation_threshold=max_sd)
end = time.time()
print("Detecting marked and unmarked bubbles time:", end-start)
# Print the marked bubbles in a readable format
for row_idx, row in enumerate(answer_student, start=1):
    print(f"Question {row_idx}: Marked Bubble = {row.tolist()}")
# Out:
# Mean: 137.5, Standard Deviation: 78.58275892331599
# Mean: 134.75, Standard Deviation: 81.96760030646256
# Mean: 114.75, Standard Deviation: 66.54838465357368
# Mean: 111.0, Standard Deviation: 56.47565847336355
# Mean: 139.75, Standard Deviation: 59.767779781417346
# Mean: 130.25, Standard Deviation: 62.61938597591005
# Mean: 98.5, Standard Deviation: 57.67798540171111
# Mean: 104.0, Standard Deviation: 49.462106708064915
# Mean: 132.75, Standard Deviation: 77.89536250637775
# Mean: 141.0, Standard Deviation: 52.407060593015515
# Mean: 121.75, Standard Deviation: 65.94078783272157
# Mean: 111.0, Standard Deviation: 64.07417576528005
# Mean: 148.0, Standard Deviation: 105.00714261420507
# Mean: 125.25, Standard Deviation: 64.85898164479612
# Mean: 105.5, Standard Deviation: 62.2434735534578
# Mean: 100.25, Standard Deviation: 59.14970414127192
# Mean: 129.5, Standard Deviation: 65.5190811901388
# Mean: 108.5, Standard Deviation: 64.24367673164419
# Mean: 108.0, Standard Deviation: 51.176166327695945
# Mean: 104.25, Standard Deviation: 52.98761647781489
# Mean: 127.25, Standard Deviation: 72.58916930231396
# Mean: 111.25, Standard Deviation: 58.921027655668055
# Mean: 117.5, Standard Deviation: 58.01939330947886
# Mean: 105.0, Standard Deviation: 63.194145298437256
# Mean: 117.0, Standard Deviation: 63.0
# Mean: 118.25, Standard Deviation: 58.576339079870806
# Mean: 99.0, Standard Deviation: 47.62877281643944
# Mean: 111.25, Standard Deviation: 48.100805606559234
# Mean: 122.25, Standard Deviation: 71.84836462996218
# Mean: 111.75, Standard Deviation: 52.59931083198714
# Mean: 96.75, Standard Deviation: 55.065302142093074
# Mean: 97.5, Standard Deviation: 50.93378053904893
# Mean: 123.25, Standard Deviation: 71.37707965446612
# Mean: 128.5, Standard Deviation: 66.6427040267725
# Mean: 103.25, Standard Deviation: 56.499446899947614
# Mean: 98.0, Standard Deviation: 56.789083458002736
# Mean: 122.75, Standard Deviation: 71.38758645590983
# Mean: 111.5, Standard Deviation: 60.035406219996545
# Mean: 107.25, Standard Deviation: 57.12869244083922
# Mean: 101.5, Standard Deviation: 38.95189340712464
# Detecting marked and unmarked bubbles time: 0.00448918342590332
# Question 1: Marked Bubble = [0, 0, 1, 0]
# Question 2: Marked Bubble = [1, 0, 0, 0]
# Question 3: Marked Bubble = [0, 1, 0, 0]
# Question 4: Marked Bubble = [0, 1, 0, 0]
# Question 5: Marked Bubble = [0, 1, 0, 0]
# Question 6: Marked Bubble = [0, 0, 1, 0]
# Question 7: Marked Bubble = [1, 0, 0, 0]
# Question 8: Marked Bubble = [1, 0, 0, 0]
# Question 9: Marked Bubble = [0, 0, 1, 0]
# Question 10: Marked Bubble = [0, 1, 0, 0]
# Question 11: Marked Bubble = [0, 1, 0, 0]
# Question 12: Marked Bubble = [0, 0, 1, 0]
# Question 13: Marked Bubble = [1, 0, 0, 0]
# Question 14: Marked Bubble = [1, 0, 0, 0]
# Question 15: Marked Bubble = [0, 0, 1, 0]
# Question 16: Marked Bubble = [1, 0, 0, 0]
# Question 17: Marked Bubble = [0, 0, 1, 0]
# Question 18: Marked Bubble = [0, 0, 1, 0]
# Question 19: Marked Bubble = [0, 1, 0, 0]
# Question 20: Marked Bubble = [0, 1, 0, 0]
# Question 21: Marked Bubble = [0, 1, 0, 0]
# Question 22: Marked Bubble = [1, 0, 0, 0]
# Question 23: Marked Bubble = [0, 1, 0, 0]
# Question 24: Marked Bubble = [1, 0, 0, 0]
# Question 25: Marked Bubble = [1, 0, 0, 0]
# Question 26: Marked Bubble = [0, 1, 0, 0]
# Question 27: Marked Bubble = [0, 0, 1, 0]
# Question 28: Marked Bubble = [0, 1, 0, 0]
# Question 29: Marked Bubble = [0, 1, 0, 0]
# Question 30: Marked Bubble = [1, 0, 0, 0]
# Question 31: Marked Bubble = [0, 1, 0, 0]
# Question 32: Marked Bubble = [0, 0, 0, 1]
# Question 33: Marked Bubble = [0, 0, 1, 0]
# Question 34: Marked Bubble = [0, 1, 0, 0]
# Question 35: Marked Bubble = [0, 0, 1, 0]
# Question 36: Marked Bubble = [0, 0, 1, 0]
# Question 37: Marked Bubble = [0, 1, 0, 0]
# Question 38: Marked Bubble = [0, 1, 0, 0]
# Question 39: Marked Bubble = [0, 1, 0, 0]
# Question 40: Marked Bubble = [0, 0, 0, 0]

# %%
start = time.time()
answer_key = detect_marked_and_unmarked_bubbles(grouped_rows_k, options, deviation_threshold=max_sd)
end = time.time()
print("Detecting marked and unmarked bubbles time:", end-start)
for row_idx, row in enumerate(answer_key, start=1):
    print(f"Question {row_idx}: Marked Bubble = {row.tolist()}")
# Out:
# Mean: 116.75, Standard Deviation: 74.6470863463538
# Mean: 109.75, Standard Deviation: 43.85416171813115
# Mean: 97.0, Standard Deviation: 58.54485459884583
# Mean: 91.0, Standard Deviation: 42.84273567362383
# Mean: 130.25, Standard Deviation: 55.670346684747706
# Mean: 113.75, Standard Deviation: 72.17470124635086
# Mean: 88.0, Standard Deviation: 39.15992849840255
# Mean: 86.5, Standard Deviation: 51.14929129518805
# Mean: 131.75, Standard Deviation: 79.74451391788654
# Mean: 109.75, Standard Deviation: 62.174653195655225
# Mean: 71.75, Standard Deviation: 36.88749788207381
# Mean: 89.0, Standard Deviation: 52.54997621312497
# Mean: 125.0, Standard Deviation: 64.40108694734896
# Mean: 109.0, Standard Deviation: 55.87486017879597
# Mean: 93.0, Standard Deviation: 55.76289088632332
# Mean: 70.25, Standard Deviation: 40.43126883984721
# Mean: 115.25, Standard Deviation: 60.30495419117736
# Mean: 102.25, Standard Deviation: 50.3158772158451
# Mean: 77.25, Standard Deviation: 31.72045869781835
# Mean: 73.25, Standard Deviation: 43.859862060886606
# Mean: 126.0, Standard Deviation: 71.44578364046404
# Mean: 110.0, Standard Deviation: 45.17189391646093
# Mean: 58.75, Standard Deviation: 57.42984851103127
# Mean: 93.75, Standard Deviation: 48.334123556758534
# Mean: 111.5, Standard Deviation: 60.70625997374571
# Mean: 101.75, Standard Deviation: 57.67310898503739
# Mean: 63.75, Standard Deviation: 35.187888541371734
# Mean: 87.0, Standard Deviation: 33.88952640566109
# Mean: 103.0, Standard Deviation: 61.212743771211564
# Mean: 98.0, Standard Deviation: 62.38990302925627
# Mean: 89.5, Standard Deviation: 55.509008277936296
# Mean: 76.75, Standard Deviation: 36.00260407248342
# Mean: 110.0, Standard Deviation: 59.63639828158639
# Mean: 118.5, Standard Deviation: 72.16127770487438
# Mean: 93.0, Standard Deviation: 36.04857833535187
# Mean: 84.25, Standard Deviation: 33.521448357730605
# Mean: 109.75, Standard Deviation: 60.68103080864728
# Mean: 106.25, Standard Deviation: 62.4354666836086
# Mean: 100.0, Standard Deviation: 42.089191011469914
# Mean: 82.5, Standard Deviation: 48.0702610768862
# Detecting marked and unmarked bubbles time: 0.004007816314697266
# Question 1: Marked Bubble = [0, 0, 1, 0]
# Question 2: Marked Bubble = [1, 0, 0, 0]
# Question 3: Marked Bubble = [0, 1, 0, 0]
# Question 4: Marked Bubble = [1, 0, 0, 0]
# Question 5: Marked Bubble = [1, 0, 0, 0]
# Question 6: Marked Bubble = [0, 0, 0, 1]
# Question 7: Marked Bubble = [0, 0, 0, 0]
# Question 8: Marked Bubble = [0, 1, 0, 0]
# Question 9: Marked Bubble = [0, 1, 0, 0]
# Question 10: Marked Bubble = [0, 1, 0, 0]
# Question 11: Marked Bubble = [0, 0, 0, 0]
# Question 12: Marked Bubble = [0, 0, 1, 0]
# Question 13: Marked Bubble = [0, 0, 0, 1]
# Question 14: Marked Bubble = [0, 0, 1, 0]
# Question 15: Marked Bubble = [0, 1, 0, 0]
# Question 16: Marked Bubble = [1, 0, 0, 0]
# Question 17: Marked Bubble = [1, 0, 0, 0]
# Question 18: Marked Bubble = [0, 0, 0, 1]
# Question 19: Marked Bubble = [0, 0, 0, 0]
# Question 20: Marked Bubble = [0, 0, 0, 1]
# Question 21: Marked Bubble = [0, 0, 1, 0]
# Question 22: Marked Bubble = [1, 0, 0, 0]
# Question 23: Marked Bubble = [0, 1, 0, 0]
# Question 24: Marked Bubble = [0, 1, 0, 0]
# Question 25: Marked Bubble = [0, 0, 0, 1]
# Question 26: Marked Bubble = [0, 0, 1, 0]
# Question 27: Marked Bubble = [0, 0, 0, 0]
# Question 28: Marked Bubble = [0, 0, 0, 0]
# Question 29: Marked Bubble = [0, 1, 0, 0]
# Question 30: Marked Bubble = [0, 1, 0, 0]
# Question 31: Marked Bubble = [0, 0, 0, 1]
# Question 32: Marked Bubble = [0, 0, 0, 0]
# Question 33: Marked Bubble = [1, 0, 0, 0]
# Question 34: Marked Bubble = [0, 0, 0, 1]
# Question 35: Marked Bubble = [0, 0, 0, 0]
# Question 36: Marked Bubble = [0, 0, 0, 0]
# Question 37: Marked Bubble = [0, 0, 0, 1]
# Question 38: Marked Bubble = [0, 0, 1, 0]
# Question 39: Marked Bubble = [1, 0, 0, 0]
# Question 40: Marked Bubble = [0, 1, 0, 0]

# %% [markdown]
# ### 6. Calculating score

# %%
def calculate_score(answer_key, answer_student):
    """
    Compare the student's answers with the answer key and calculate the score.

    Args:
        answer_key (np.ndarray): The correct answer key with marked bubbles (1 for correct option, 0 for others).
        answer_student (np.ndarray): The student's marked answers with bubbles (1 for marked option, 0 for others).

    Returns:
        int: The total score of the student.
        list: A list indicating correctness for each question (1 for correct, 0 for incorrect).
    """
    total_score = 0
    result_per_question = []

    for key, student in zip(answer_key, answer_student):
        if np.array_equal(key, student):
            total_score += 1
            result_per_question.append(1)  # Correct answer
        else:
            result_per_question.append(0)  # Incorrect answer

    return total_score, result_per_question

start = time.time()
total_score, result_per_question = calculate_score(answer_key, answer_student)
end = time.time()
print("Calculating score time:", end-start)
# Print the final score and results
print(f"Total Score: {total_score}")
for idx, result in enumerate(result_per_question, start=1):
    status = "Correct" if result == 1 else "Incorrect"
    print(f"Question {idx}: {status}")
# Out:
# Calculating score time: 0.0010046958923339844
# Total Score: 9
# Question 1: Correct
# Question 2: Correct
# Question 3: Correct
# Question 4: Incorrect
# Question 5: Incorrect
# Question 6: Incorrect
# Question 7: Incorrect
# Question 8: Incorrect
# Question 9: Incorrect
# Question 10: Correct
# Question 11: Incorrect
# Question 12: Correct
# Question 13: Incorrect
# Question 14: Incorrect
# Question 15: Incorrect
# Question 16: Correct
# Question 17: Incorrect
# Question 18: Incorrect
# Question 19: Incorrect
# Question 20: Incorrect
# Question 21: Incorrect
# Question 22: Correct
# Question 23: Correct
# Question 24: Incorrect
# Question 25: Incorrect
# Question 26: Incorrect
# Question 27: Incorrect
# Question 28: Incorrect
# Question 29: Correct
# Question 30: Incorrect
# Question 31: Incorrect
# Question 32: Incorrect
# Question 33: Incorrect
# Question 34: Incorrect
# Question 35: Incorrect
# Question 36: Incorrect
# Question 37: Incorrect
# Question 38: Incorrect
# Question 39: Incorrect
# Question 40: Incorrect

# %% [markdown]
# ## extra verification step

# %% [markdown]
# ### Group Circle by radius

# %% [markdown]
# this can be used to verify that the detected circles are answer circles. Now we are not using this. we will use this after we finish the core of the function.

# %%
import cv2
import numpy as np
from collections import defaultdict

def group_circles_by_radius(circles, img, tolerance_percentage=20):
    """
    Groups circles based on their radius with a given tolerance percentage of the y-coordinate.
    
    Args:
        circles (array): List of detected circles [(x, y, r)].
        img (numpy array): The original image.
        tolerance_percentage (float): Tolerance as a percentage of the y-coordinate (default is 20%).
        
    Returns:
        dict: Groups of circles based on their radius.
    """
    radius_groups = defaultdict(list)
    
    # Iterate over the detected circles and group them by radius
    for circle in circles:
        x, y, r = circle[0], circle[1], circle[2]

        if not radius_groups:
            # If no groups exist yet, start a new group with the first circle
            radius_groups[r].append((x, y, r))
        else:
            matched_group = None
            for existing_radius in radius_groups.keys():
                diff = abs(int(r) - int(existing_radius))
                
                # Calculate tolerance based on the radius
                tol = (tolerance_percentage / 100.0) * existing_radius

                if diff <= tol:
                    matched_group = existing_radius
                    break

            if matched_group is not None:
                radius_groups[matched_group].append((x, y, r))
            else:
                radius_groups[r].append((x, y, r))

    # Print the radius groups for debugging
    for radius, grouped_circles in radius_groups.items():
        print(f"Radius: {radius}, Circles: {grouped_circles}")
        
    # Visualize each group of circles in separate images
    for radius, grouped_circles in radius_groups.items():
        img_copy = img.copy()  # Create a copy of the original image to visualize each group
        
        for x, y, r in grouped_circles:
            cv2.circle(img_copy, (x, y), r, (0, 255, 0), 2)  # Draw outer circle
            cv2.circle(img_copy, (x, y), 2, (0, 0, 255), 3)  # Draw center

        # Display the grouped circles in a separate window
        cv2.imshow(f'Circles with radius ~ {radius}', img_copy)
        cv2.waitKey(0)
    
    return radius_groups



# if detected_circles is not None:
#     detected_circles = np.uint16(np.around(detected_circles))

#     # Call the function with the detected circles and image
#     group_circles_by_radius(detected_circles[0, :], img, tolerance_percentage=20)

cv2.destroyAllWindows()
