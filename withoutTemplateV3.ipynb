# %% [markdown]
# ## OMR without Template Image

# %% [markdown]
# ### 1. preprocessing

# %%
import cv2
import numpy as np


def preprocess_image(image_path, blur_ksize=(5, 5)):
    """
    Preprocess the input image by converting it to grayscale and applying Gaussian blur and convert it to binary image.
    
    Args:
        image_path (str): Path to the input image.
        blur_ksize (tuple): Kernel size for the Gaussian blur (default is (5, 5)).
        
    Returns:
        gray_blurred (numpy array): Blurred grayscale version of the image.
        original_img (numpy array): Original color image.
        gray (numpy array): Grayscale version of the image.
        binary_img (numpy array): Binary version of the image
    """
    # Read the image.
    original_img = cv2.imread(image_path, cv2.IMREAD_COLOR)

    if original_img is None:
        raise ValueError(f"Image at {image_path} not found.")
    
    # Convert to grayscale.
    gray = cv2.cvtColor(original_img, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur.
    gray_blurred = cv2.GaussianBlur(gray, blur_ksize, 0)

    # Convert the original image to a binary image
    _, binary_img = cv2.threshold(gray_blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    return gray_blurred, original_img, gray, binary_img

# %% [markdown]
# ###

# %%
# Preprocess the images
gray_blurred_s, original_img_s, gray_s, binary_img_s = preprocess_image('./Test/5_S.jpg')
#gray_blurred_t, original_img_t, gray_t, binary_img_t = preprocess_image('./Test/7_T.jpg')
gray_blurred_k, original_img_k, gray_k, binary_img_k = preprocess_image('./Test/5_K.jpg')

questions = 50
options=5

# %% [markdown]
# ### 2. circle detection

# %%
from collections import Counter
def detect_circles(img, gray_blurred, questions, options):
    """
    Detect circles in the preprocessed grayscale image using the Hough Circle Transform.
    
    Args:
        img (numpy array): Original image for visualization.
        gray_blurred (numpy array): Blurred grayscale image.
        num_questions (int): Number of questions in the OMR.
        num_options (int): Number of options per question.
        dp (float): Inverse ratio of the accumulator resolution to the image resolution (default is 1).
        min_dist (int): Minimum distance between the centers of detected circles (default is 1).
        param1 (float): First method-specific parameter (gradient threshold for Canny edge detection).
        param2 (float): Second method-specific parameter (accumulator threshold for circle detection).
        min_radius_range (tuple): Tuple for minimum and maximum radius values for circle detection.
    
    Returns:
        detected_circles (numpy array): Array of detected circles, if found.
    """
    
    for b in range(15,5,-1): 
        for a in range(5,35):  
            detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, a, 
                            param1 = b,param2 = 3*b, minRadius = a//2, maxRadius = a) 
            if detected_circles is not None:
                detected_circles=np.uint16(np.around(detected_circles))
                print(f"circles:{detected_circles.shape[1]},a:{a},b:{b}")
                if detected_circles.shape[1]==questions*options:

                    radii_list = [pt[2] for pt in detected_circles[0, :]]
                    
                    # Find the most common radius
                    most_common_radius = Counter(radii_list).most_common(1)[0][0]
                    print(f"Most common radius: {most_common_radius}")



                    for pt in detected_circles[0, :]: 
                        x, y, r = pt[0], pt[1], pt[2] 

                        # Draw the circumference of the circle. 
                        cv2.circle(img, (x, y), r, (0, 255, 0), 3) 

                        # Draw a small circle (of radius 1) to show the center. 
                        cv2.circle(img, (x, y), 2, (0, 0, 255), 3) 
                    #cv2.imwrite(f'./testoutput/detected_circlesf7.jpg', img)
                    cv2.imshow("Detected Circle", img) 
                    cv2.waitKey(0) 
                    return detected_circles

    cv2.destroyAllWindows()
    return None

# %%
# Detect circles in the preprocessed image
detected_circles_s = detect_circles(
    original_img_s, gray_blurred_s, 
    questions, options
)

detected_circles_k = detect_circles(
    original_img_k, gray_blurred_k, 
    questions, options
)
# Out:
# circles:32,a:16,b:15
# circles:145,a:17,b:15
# circles:152,a:18,b:15
# circles:165,a:19,b:15
# circles:223,a:20,b:15
# circles:235,a:21,b:15
# circles:235,a:22,b:15
# circles:238,a:23,b:15
# circles:238,a:24,b:15
# circles:240,a:25,b:15
# circles:240,a:26,b:15
# circles:238,a:27,b:15
# circles:238,a:28,b:15
# circles:239,a:29,b:15
# circles:241,a:30,b:15
# circles:242,a:31,b:15
# circles:241,a:32,b:15
# circles:243,a:33,b:15
# circles:241,a:34,b:15
# circles:1,a:15,b:14
# circles:47,a:16,b:14
# circles:162,a:17,b:14
# circles:172,a:18,b:14
# circles:180,a:19,b:14
# circles:230,a:20,b:14
# circles:242,a:21,b:14
# circles:239,a:22,b:14
# circles:241,a:23,b:14
# circles:243,a:24,b:14
# circles:245,a:25,b:14
# circles:244,a:26,b:14
# circles:243,a:27,b:14
# circles:242,a:28,b:14
# circles:244,a:29,b:14
# circles:244,a:30,b:14
# circles:245,a:31,b:14
# circles:246,a:32,b:14
# circles:247,a:33,b:14
# circles:247,a:34,b:14
# circles:1,a:15,b:13
# circles:61,a:16,b:13
# circles:173,a:17,b:13
# circles:187,a:18,b:13
# circles:197,a:19,b:13
# circles:236,a:20,b:13
# circles:246,a:21,b:13
# circles:247,a:22,b:13
# circles:246,a:23,b:13
# circles:246,a:24,b:13
# circles:248,a:25,b:13
# circles:247,a:26,b:13
# circles:247,a:27,b:13
# circles:247,a:28,b:13
# circles:247,a:29,b:13
# circles:247,a:30,b:13
# circles:249,a:31,b:13
# circles:247,a:32,b:13
# circles:247,a:33,b:13
# circles:248,a:34,b:13
# circles:1,a:13,b:12
# circles:4,a:15,b:12
# circles:81,a:16,b:12
# circles:189,a:17,b:12
# circles:201,a:18,b:12
# circles:213,a:19,b:12
# circles:241,a:20,b:12
# circles:249,a:21,b:12
# circles:250,a:22,b:12
# Most common radius: 20
# circles:17,a:15,b:15
# circles:152,a:16,b:15
# circles:153,a:17,b:15
# circles:176,a:18,b:15
# circles:193,a:19,b:15
# circles:213,a:20,b:15
# circles:209,a:21,b:15
# circles:213,a:22,b:15
# circles:215,a:23,b:15
# circles:219,a:24,b:15
# circles:221,a:25,b:15
# circles:219,a:26,b:15
# circles:222,a:27,b:15
# circles:221,a:28,b:15
# circles:224,a:29,b:15
# circles:224,a:30,b:15
# circles:223,a:31,b:15
# circles:224,a:32,b:15
# circles:227,a:33,b:15
# circles:221,a:34,b:15
# circles:23,a:15,b:14
# circles:168,a:16,b:14
# circles:177,a:17,b:14
# circles:197,a:18,b:14
# circles:199,a:19,b:14
# circles:225,a:20,b:14
# circles:222,a:21,b:14
# circles:220,a:22,b:14
# circles:221,a:23,b:14
# circles:226,a:24,b:14
# circles:229,a:25,b:14
# circles:231,a:26,b:14
# circles:232,a:27,b:14
# circles:231,a:28,b:14
# circles:233,a:29,b:14
# circles:232,a:30,b:14
# circles:234,a:31,b:14
# circles:234,a:32,b:14
# circles:234,a:33,b:14
# circles:230,a:34,b:14
# circles:33,a:15,b:13
# circles:179,a:16,b:13
# circles:190,a:17,b:13
# circles:199,a:18,b:13
# circles:211,a:19,b:13
# circles:235,a:20,b:13
# circles:232,a:21,b:13
# circles:230,a:22,b:13
# circles:232,a:23,b:13
# circles:235,a:24,b:13
# circles:237,a:25,b:13
# circles:237,a:26,b:13
# circles:236,a:27,b:13
# circles:240,a:28,b:13
# circles:241,a:29,b:13
# circles:242,a:30,b:13
# circles:244,a:31,b:13
# circles:241,a:32,b:13
# circles:243,a:33,b:13
# circles:241,a:34,b:13
# circles:1,a:9,b:12
# circles:1,a:10,b:12
# circles:1,a:11,b:12
# circles:1,a:12,b:12
# circles:1,a:13,b:12
# circles:1,a:14,b:12
# circles:53,a:15,b:12
# circles:190,a:16,b:12
# circles:198,a:17,b:12
# circles:200,a:18,b:12
# circles:219,a:19,b:12
# circles:243,a:20,b:12
# circles:240,a:21,b:12
# circles:241,a:22,b:12
# circles:243,a:23,b:12
# circles:242,a:24,b:12
# circles:244,a:25,b:12
# circles:246,a:26,b:12
# circles:245,a:27,b:12
# circles:247,a:28,b:12
# circles:247,a:29,b:12
# circles:247,a:30,b:12
# circles:247,a:31,b:12
# circles:246,a:32,b:12
# circles:249,a:33,b:12
# circles:246,a:34,b:12
# circles:1,a:7,b:11
# circles:1,a:9,b:11
# circles:3,a:10,b:11
# circles:2,a:11,b:11
# circles:5,a:12,b:11
# circles:6,a:13,b:11
# circles:4,a:14,b:11
# circles:78,a:15,b:11
# circles:195,a:16,b:11
# circles:199,a:17,b:11
# circles:204,a:18,b:11
# circles:229,a:19,b:11
# circles:247,a:20,b:11
# circles:246,a:21,b:11
# circles:247,a:22,b:11
# circles:248,a:23,b:11
# circles:247,a:24,b:11
# circles:248,a:25,b:11
# circles:249,a:26,b:11
# circles:248,a:27,b:11
# circles:248,a:28,b:11
# circles:250,a:29,b:11
# Most common radius: 19

# %% [markdown]
# ### 3.pixelcount

# %%
import cv2
import numpy as np

def count_black_and_white_pixels(img, circles):
    """
    Count black and white pixels in the detected circles.

    Parameters:
    - img: The binary image (where black indicates marked areas).
    - circles: List of detected circles in the format (x, y, r).

    Returns:
    - A list of tuples containing counts of (black_pixels, white_pixels) for each circle.
    """
    counts = []

    for (x, y, r) in circles:
        # Create a mask for the current circle
        mask = np.zeros_like(img, dtype=np.uint8)
        cv2.circle(mask, (x, y), r, (255), thickness=-1)  # Fill the circle in the mask

        # Apply the mask to get the pixel values within the circle
        masked_area = cv2.bitwise_and(img, mask)

        # Count black and white pixels
        black_pixels = np.sum(masked_area == 0)   # Count of black pixels (0)
        white_pixels = np.sum(masked_area == 255) # Count of white pixels (255)

        counts.append((x,y,r,black_pixels, white_pixels))

    return counts

# %%
circles_s = detected_circles_s[0, :]
circles_k = detected_circles_k[0, :]

# Count black and white pixels in the detected circles
pixel_counts_s = count_black_and_white_pixels(binary_img_s, circles_s)
#pixel_counts_t = count_black_and_white_pixels(binary_img_t, circles_t)
pixel_counts_k = count_black_and_white_pixels(binary_img_k, circles_k)

# Print the results
print("students answer sheet")
for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_s, start=1):
    print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")

# print("template")
# for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_t, start=1):
#     print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")

print("key")
for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_k, start=1):
    print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")



# Draw the circles on the binary image for visualization
for (x, y, r) in circles_s:
    cv2.circle(binary_img_s, (x, y), r, (127), 2)  # Draw circles in a different color (grey)
cv2.imshow("Detected Circles in Binary Image student", binary_img_s)
cv2.waitKey(0)


# for (x, y, r) in circles_t:
#     cv2.circle(binary_img_t, (x, y), r, (127), 2)  
# cv2.imshow("Detected Circles in Binary Image template", binary_img_t)
# cv2.waitKey(0)

for (x, y, r) in circles_k:
    cv2.circle(binary_img_k, (x, y), r, (127), 2)
cv2.imshow("Detected Circles in Binary Image key(scheme)", binary_img_k)
cv2.waitKey(0)




cv2.destroyAllWindows()
# Out:
# students answer sheet
# Circle 1: Coordinates = (938, 1336), Black Pixels = 2061503, White Pixels = 585
# Circle 2: Coordinates = (498, 1446), Black Pixels = 2061503, White Pixels = 585
# Circle 3: Coordinates = (500, 1010), Black Pixels = 2061463, White Pixels = 625
# Circle 4: Coordinates = (500, 1118), Black Pixels = 2061538, White Pixels = 550
# Circle 5: Coordinates = (1042, 254), Black Pixels = 2061459, White Pixels = 629
# Circle 6: Coordinates = (1110, 574), Black Pixels = 2061481, White Pixels = 607
# Circle 7: Coordinates = (492, 374), Black Pixels = 2061411, White Pixels = 677
# Circle 8: Coordinates = (440, 748), Black Pixels = 2061452, White Pixels = 636
# Circle 9: Coordinates = (1052, 738), Black Pixels = 2061461, White Pixels = 627
# Circle 10: Coordinates = (1054, 1116), Black Pixels = 2061466, White Pixels = 622
# Circle 11: Coordinates = (864, 152), Black Pixels = 2061447, White Pixels = 641
# Circle 12: Coordinates = (258, 1174), Black Pixels = 2061488, White Pixels = 600
# Circle 13: Coordinates = (1096, 148), Black Pixels = 2061467, White Pixels = 621
# Circle 14: Coordinates = (322, 956), Black Pixels = 2061515, White Pixels = 573
# Circle 15: Coordinates = (320, 1066), Black Pixels = 2062072, White Pixels = 16
# Circle 16: Coordinates = (380, 1390), Black Pixels = 2061456, White Pixels = 632
# Circle 17: Coordinates = (1110, 628), Black Pixels = 2061428, White Pixels = 660
# Circle 18: Coordinates = (248, 262), Black Pixels = 2061369, White Pixels = 719
# Circle 19: Coordinates = (320, 1336), Black Pixels = 2061545, White Pixels = 543
# Circle 20: Coordinates = (1052, 1008), Black Pixels = 2061484, White Pixels = 604
# Circle 21: Coordinates = (938, 1282), Black Pixels = 2061517, White Pixels = 571
# Circle 22: Coordinates = (380, 694), Black Pixels = 2061408, White Pixels = 680
# Circle 23: Coordinates = (936, 1062), Black Pixels = 2061545, White Pixels = 543
# Circle 225: Coordinates = (942, 440), Black Pixels = 2043958, White Pixels = 519
# Circle 226: Coordinates = (360, 1384), Black Pixels = 2043928, White Pixels = 549
# Circle 227: Coordinates = (358, 758), Black Pixels = 2043959, White Pixels = 518
# Circle 228: Coordinates = (298, 398), Black Pixels = 2043995, White Pixels = 482
# Circle 229: Coordinates = (466, 500), Black Pixels = 2044257, White Pixels = 220
# Circle 230: Coordinates = (1046, 290), Black Pixels = 2043855, White Pixels = 622
# Circle 231: Coordinates = (242, 1230), Black Pixels = 2044439, White Pixels = 38
# Circle 232: Coordinates = (898, 1328), Black Pixels = 2044448, White Pixels = 29
# Circle 233: Coordinates = (892, 1006), Black Pixels = 2044473, White Pixels = 4
# Circle 234: Coordinates = (1008, 1166), Black Pixels = 2043956, White Pixels = 521
# Circle 235: Coordinates = (878, 242), Black Pixels = 2043968, White Pixels = 509
# Circle 236: Coordinates = (826, 546), Black Pixels = 2044380, White Pixels = 97
# Circle 237: Coordinates = (886, 852), Black Pixels = 2044030, White Pixels = 447
# Circle 238: Coordinates = (298, 1066), Black Pixels = 2043522, White Pixels = 955
# Circle 239: Coordinates = (822, 292), Black Pixels = 2043935, White Pixels = 542
# Circle 240: Coordinates = (828, 804), Black Pixels = 2044467, White Pixels = 10
# Circle 241: Coordinates = (1042, 240), Black Pixels = 2043916, White Pixels = 561
# Circle 242: Coordinates = (878, 290), Black Pixels = 2044051, White Pixels = 426
# Circle 243: Coordinates = (302, 1176), Black Pixels = 2043981, White Pixels = 496
# Circle 244: Coordinates = (298, 348), Black Pixels = 2044393, White Pixels = 84
# Circle 245: Coordinates = (474, 1276), Black Pixels = 2043962, White Pixels = 515
# Circle 246: Coordinates = (408, 296), Black Pixels = 2044450, White Pixels = 27
# Circle 247: Coordinates = (302, 758), Black Pixels = 2043989, White Pixels = 488
# Circle 248: Coordinates = (244, 810), Black Pixels = 2043903, White Pixels = 574
# Circle 249: Coordinates = (348, 196), Black Pixels = 2043719, White Pixels = 758
# Circle 250: Coordinates = (898, 1272), Black Pixels = 2044010, White Pixels = 467

# %% [markdown]
# ### 4. sorting the bubbles

# %%
import numpy as np
from sklearn.cluster import DBSCAN


# Function to group circles by rows using DBSCAN (y-coordinate clustering)
def group_by_row_dbscan(pixel_counts, eps=10):
    # Extract the y-coordinates of circles from the pixel_counts
    y_coords = np.array([[y] for (x, y, r, black_count, white_count) in pixel_counts])
    
    # Apply DBSCAN clustering based on y-coordinates
    clustering = DBSCAN(eps=eps, min_samples=1).fit(y_coords)
    
    # Get cluster labels
    labels = clustering.labels_

    # Group circles by the row labels
    rows = {}
    for label, circle_data in zip(labels, pixel_counts):
        if label not in rows:
            rows[label] = []
        rows[label].append(circle_data)

    sorted_rows = sorted(rows.values(), key=lambda row: np.mean([c[1] for c in row]))
    sorted_rows = [sorted(row, key=lambda c: c[0]) for row in sorted_rows]
    
    return sorted_rows

# %%
# Group the circles by rows using the group_by_row_dbscan function
grouped_rows_s = group_by_row_dbscan(pixel_counts_s, eps=20)

# Print the grouped results
for row_idx, row in enumerate(grouped_rows_s, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, black_count, white_count) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")
# Out:
# Row 1:
#   Circle 1: Coordinates =
#   Circle 8: Coordinates = (986, 308), Black Pixels = 2061519, White Pixels = 569
#   Circle 9: Coordinates = (1044, 306), Black Pixels = 2061447, White Pixels = 641
#   Circle 10: Coordinates = (1102, 306), Black Pixels = 2061455, White Pixels = 633
# Row 5:
#   Circle 1: Coordinates = (254, 374), Black Pixels = 2061361, White Pixels = 727
#   Circle 2: Coordinates = (314, 374), Black Pixels = 2061461, White Pixels = 627
#   Circle 3: Coordinates = (372, 374), Black Pixels = 2061304, White Pixels = 784
#   Circle 4: Coordinates = (434, 374), Black Pixels = 2062004, White Pixels = 84
#   Circle 5: Coordinates = (492, 374), Black Pixels = 2061411, White Pixels = 677
#   Circle 6: Coordinates = (870, 364), Black Pixels = 2061408, White Pixels = 680
#   Circle 7: Coordinates = (928, 362), Black Pixels = 2061504, White Pixels = 584
#   Circle 8: Coordinates = (988, 362), Black Pixels = 2061408, White Pixels = 680
#   Circle 9: Coordinates = (1046, 362), Black Pixels = 2062060, White Pixels = 28
#   Circle 10: Coordinates = (1104, 360), Black Pixels = 2061495, White Pixels = 593
# Row 6:
#   Circle 1: Coordinates = (254, 424), Black Pixels = 2061421, White Pixels = 667
#   Circle 2: Coordinates = (314, 424), Black Pixels = 2061948, White Pixels = 140
#   Circle 3: Coordinates = (374, 424), Black Pixels = 2061576, White Pixels = 512
#   Circle 4: Coordinates = (436, 422), Black Pixels = 2061310, White Pixels = 778
#   Circle 5: Coordinates = (494, 424), Black Pixels = 2061442, White Pixels = 646
#   Circle 6: Coordinates = (872, 416), Black Pixels = 2061467, White Pixels = 621
#   Circle 7: Coordinates = (930, 418), Black Pixels = 2061553, White Pixels = 535
#   Circle 8: Coordinates = (988, 416), Black Pixels = 2061496, White Pixels = 592
#   Circle 9: Coordinates = (1046, 414), Black Pixels = 2061421, White Pixels = 667
#   Circle 10: Coordinates = (1106, 414), Black Pixels = 2062077, White Pixels = 11
# Row 7:
#   Circle 1: Coordinates = (254, 478), Black Pixels = 2061386, White Pixels = 702
#   Circle 2: Coordinates = (316, 478), Black Pixels = 2061520, White Pixels = 568
#   Circle 3: Coordinates = (374, 478), Black Pixels = 2061940, White Pixels = 148
#   Circle 4: Coordinates = (434, 478), Black Pixels = 2061424, White Pixels = 664
#   Circle 5: Coordinates = (496, 478), Black Pixels = 2061500, White Pixels = 588
#   Circle 6: Coordinates = (872, 472), Black Pixels = 2061424, White Pixels = 664
#   Circle 7: Coordinates = (930, 470), Black Pixels = 2061470, White Pixels = 618
#   Circle 8: Coordinates = (988, 470), Black Pixels = 2061488, White Pixels = 600
#   Circle 9: Coordinates = (1048, 468), Black Pixels = 2062065, White Pixels = 23
#   Circle 10: Coordinates = (1108, 466), Black Pixels = 2061437, White Pixels = 651
# Row 8:
#   Circle 1: Coordinates = (256, 532), Black Pixels = 2062088, White Pixels = 0
#   Circle 2: Coordinates = (316, 534), Black Pixels = 2061468, White Pixels = 620
#   Circle 3: Coordinates = (378, 532), Black Pixels = 2061315, White Pixels = 773
#   Circle 7: Coordinates = (934, 900), Black Pixels = 2061558, White Pixels = 530
#   Circle 8: Coordinates = (992, 900), Black Pixels = 2062035, White Pixels = 53
#   Circle 9: Coordinates = (1052, 900), Black Pixels = 2061517, White Pixels = 571
#   Circle 10: Coordinates = (1112, 898), Black Pixels = 2061440, White Pixels = 648
# Row 16:
#   Circle 1: Coordinates = (260, 956), Black Pixels = 2061453, White Pixels = 635
#   Circle 2: Coordinates = (322, 956), Black Pixels = 2061515, White Pixels = 573
#   Circle 3: Coordinates = (380, 956), Black Pixels = 2062080, White Pixels = 8
#   Circle 4: Coordinates = (442, 956), Black Pixels = 2061582, White Pixels = 506
#   Circle 5: Coordinates = (500, 956), Black Pixels = 2061586, White Pixels = 502
#   Circle 6: Coordinates = (874, 954), Black Pixels = 2061452, White Pixels = 636
#   Circle 7: Coordinates = (934, 956), Black Pixels = 2061499, White Pixels = 589
#   Circle 8: Coordinates = (994, 952), Black Pixels = 2061506, White Pixels = 582
#   Circle 9: Coordinates = (1052, 954), Black Pixels = 2061546, White Pixels = 542
#   Circle 10: Coordinates = (1112, 952), Black Pixels = 2062040, White Pixels = 48
# Row 17:
#   Circle 1: Coordinates = (260, 1012), Black Pixels = 2061497, White Pixels = 591
#   Circle 2: Coordinates = (320, 1012), Black Pixels = 2061459, White Pixels = 629
#   Circle 3: Coordinates = (382, 1010), Black Pixels = 2062081, White Pixels = 7
#   Circle 4: Coordinates = (442, 1010), Black Pixels = 2061479, White Pixels = 609
#   Circle 5: Coordinates = (500, 1010), Black Pixels = 2061463, White Pixels = 625
#   Circle 6: Coordinates = (876, 1008), Black Pixels = 2061449, White Pixels = 639
#   Circle 7: Coordinates = (934, 1008), Black Pixels = 2061562, White Pixels = 526
#   Circle 8: Coordinates = (994, 1008), Black Pixels = 2061465, White Pixels = 623
#   Circle 9: Coordinates = (1052, 1008), Black Pixels = 2061484, White Pixels = 604
#   Circle 10: Coordinates = (1112, 1006), Black Pixels = 2062027, White Pixels = 61
# Row 18:
#   Circle 1: Coordinates = (260, 1066), Black Pixels = 2061498, White Pixels = 590
#   Circle 2: Coordinates = (320, 1066), Black Pixels = 2062072, White Pixels = 16
#   Circle 3: Coordinates = (380, 1064), Black Pixels = 2061495, White Pixels = 593
#   Circle 4: Coordinates = (440, 1064), Black Pixels = 2061537, White Pixels = 551
#   Circle 5: Coordinates = (500, 1064), Black Pixels = 2061495, White Pixels = 593
#   Circle 6: Coordinates = (876, 1060), Black Pixels = 2061962, White Pixels = 126
#   Circle 7: Coordinates = (936, 1062), Black Pixels = 2061545, White Pixels = 543
#   Circle 8: Coordinates = (994, 1062), Black Pixels = 2061481, White Pixels = 607
#   Circle 9: Coordinates = (1054, 1062), Black Pixels = 2061527, White Pixels = 561
#   Circle 10: Coordinates = (1114, 1062), Black Pixels = 2061457, White Pixels = 631
# Row 19:
#   Circle 1: Coordinates = (258, 1120), Black Pixels = 2061526, White Pixels = 562
#   Circle 2: Coordinates = (320, 1120), Black Pixels = 2061516, White Pixels = 572
#   Circle 9: Coordinates = (1058, 1282), Black Pixels = 2061541, White Pixels = 547
#   Circle 10: Coordinates = (1118, 1282), Black Pixels = 2061513, White Pixels = 575
# Row 23:
#   Circle 1: Coordinates = (260, 1336), Black Pixels = 2061496, White Pixels = 592
#   Circle 2: Coordinates = (320, 1336), Black Pixels = 2061545, White Pixels = 543
#   Circle 3: Coordinates = (380, 1334), Black Pixels = 2062047, White Pixels = 41
#   Circle 4: Coordinates = (438, 1336), Black Pixels = 2061533, White Pixels = 555
#   Circle 5: Coordinates = (500, 1334), Black Pixels = 2061506, White Pixels = 582
#   Circle 6: Coordinates = (878, 1336), Black Pixels = 2061494, White Pixels = 594
#   Circle 7: Coordinates = (938, 1336), Black Pixels = 2061503, White Pixels = 585
#   Circle 8: Coordinates = (996, 1336), Black Pixels = 2061473, White Pixels = 615
#   Circle 9: Coordinates = (1058, 1336), Black Pixels = 2062079, White Pixels = 9
#   Circle 10: Coordinates = (1116, 1334), Black Pixels = 2061415, White Pixels = 673
# Row 24:
#   Circle 1: Coordinates = (260, 1392), Black Pixels = 2061494, White Pixels = 594
#   Circle 2: Coordinates = (320, 1390), Black Pixels = 2061521, White Pixels = 567
#   Circle 3: Coordinates = (380, 1390), Black Pixels = 2061456, White Pixels = 632
#   Circle 4: Coordinates = (440, 1390), Black Pixels = 2062088, White Pixels = 0
#   Circle 5: Coordinates = (498, 1390), Black Pixels = 2061505, White Pixels = 583
#   Circle 6: Coordinates = (880, 1392), Black Pixels = 2061523, White Pixels = 565
#   Circle 7: Coordinates = (938, 1392), Black Pixels = 2061587, White Pixels = 501
#   Circle 8: Coordinates = (998, 1392), Black Pixels = 2061536, White Pixels = 552
#   Circle 9: Coordinates = (1058, 1392), Black Pixels = 2061567, White Pixels = 521
#   Circle 10: Coordinates = (1116, 1388), Black Pixels = 2062081, White Pixels = 7
# Row 25:
#   Circle 1: Coordinates = (260, 1444), Black Pixels = 2062072, White Pixels = 16
#   Circle 2: Coordinates = (320, 1446), Black Pixels = 2061565, White Pixels = 523
#   Circle 3: Coordinates = (378, 1446), Black Pixels = 2061469, White Pixels = 619
#   Circle 4: Coordinates = (438, 1446), Black Pixels = 2061532, White Pixels = 556
#   Circle 5: Coordinates = (498, 1446), Black Pixels = 2061503, White Pixels = 585
#   Circle 6: Coordinates = (878, 1450), Black Pixels = 2062043, White Pixels = 45
#   Circle 7: Coordinates = (940, 1448), Black Pixels = 2061524, White Pixels = 564
#   Circle 8: Coordinates = (996, 1446), Black Pixels = 2061497, White Pixels = 591
#   Circle 9: Coordinates = (1056, 1444), Black Pixels = 2061559, White Pixels = 529
#   Circle 10: Coordinates = (1114, 1442), Black Pixels = 2061561, White Pixels = 527

# %%
grouped_rows_k = group_by_row_dbscan(pixel_counts_k, eps=10)

# Print the grouped results
for row_idx, row in enumerate(grouped_rows_k, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, black_count, white_count) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")
# Out:
# Row 1:
#   Circle 1: Coordinates = (238, 132), Black Pixels = 2042816, White Pixels = 1661
#   Circle 2: Coordinates = (294, 136), Black Pixels = 2043335, White Pixels = 1142
#   Circle 3: Coordinates = (352, 140), Black Pixels = 2043794, White Pixels = 683
#   Circle 4: Coordinates = (408, 142), Black Pixels = 2043929, White Pixels = 548
#   Circle 5: Coordinates = (464, 142), Black Pixels = 2043945, White Pixels = 532
#   Circle 6: Coordinates = (820, 142), Black Pixels = 2044391, White Pixels = 86
#   Circle 7: Coordinates = (876, 142), Black Pixels = 2043950, White Pixels = 527
#   Circle 8: Coordinates = (932, 142), Black Pixels = 2043889, White Pixels = 588
#   Circle 9: Coordinates = (986, 140), Black Pixels = 2044043, White Pixels = 434
#   Circle 10: Coordinates = (1042, 142), Black Pixels = 2044035, White Pixels = 442
# Row 2:
#   Circle 1: Coordinates = (238, 190), Black Pixels = 2043853, White Pixels = 624
#   Circle 2: Coordinates = (296, 190), Black Pixels = 2043949, White Pixels = 528
#   Circle 3: Coordinates = (348, 196), Black Pixels = 2043719, White Pixels = 758
#   Circle 4: Coordinates = (408, 194), Black Pixels = 2044350, White Pixels = 127
#   Circle 5: Coordinates = (466, 194), Black Pixels = 2043903, White Pixels = 574
#   Circle 6: Coordinates = (822, 192), Black Pixels = 2043844, White Pixels = 633
#   Circle 7: Coordinates = (876, 194), Black Pixels = 2043935, White Pixels = 542
#   Circle 8: Coordinates = (932, 192), Black Pixels = 2043924, White Pixels = 553
#   Circle 9: Coordinates = (986, 192), Black Pixels = 2043938, White Pixels = 539
#   Circle 10: Coordinates = (1042, 192), Black Pixels = 2044398, White Pixels = 79
# Row 3:
#   Circle 1: Coordinates = (240, 240), Black Pixels = 2043901, White Pixels = 576
#   Circle 2: Coordinates = (296, 244), Black Pixels = 2043996, White Pixels = 481
#   Circle 3: Coordinates = (354, 244), Black Pixels = 2043619, White Pixels = 858
#   Circle 4: Coordinates = (410, 244), Black Pixels = 2043925, White Pixels = 552
#   Circle 5: Coordinates = (466, 244), Black Pixels = 2043918, White Pixels = 559
#   Circle 6: Coordinates = (822, 242), Black Pixels = 2044413, White Pixels = 64
#   Circle 7: Coordinates = (878, 242), Black Pixels = 2043968, White Pixels = 509
#   Circle 8: Coordinates = (932, 242), Black Pixels = 2043990, White Pixels = 487
#   Circle 9: Coordinates = (988, 242), Black Pixels = 2044022, White Pixels = 455
#   Circle 10: Coordinates = (1042, 240), Black Pixels = 2043916, White Pixels = 561
# Row 4:
#   Circle 1: Coordinates = (240, 296), Black Pixels = 2043900, White Pixels = 577
#   Circle 2: Coordinates = (298, 296), Black Pixels = 2043955, White Pixels = 522
#   Circle 3: Coordinates = (354, 296), Black Pixels = 2043899, White Pixels = 578
#   Circle 4: Coordinates = (408, 296), Black Pixels = 2044450, White Pixels = 27
#   Circle 5: Coordinates = (466, 294), Black Pixels = 2044025, White Pixels = 452
#   Circle 6: Coordinates = (822, 292), Black Pixels = 2043935, White Pixels = 542
#   Circle 7: Coordinates = (878, 290), Black Pixels = 2044051, White Pixels = 426
#   Circle 8: Coordinates = (934, 290), Black Pixels = 2043914, White Pixels = 563
#   Circle 9: Coordinates = (1046, 290), Black Pixels = 2043855, White Pixels = 622
# Row 5:
#   Circle 1: Coordinates = (242, 348), Black Pixels = 2043885, White Pixels = 592
#   Circle 2: Coordinates = (298, 348), Black Pixels = 2044393, White Pixels = 84
#   Circle 3: Coordinates = (354, 346), Black Pixels = 2043888, White Pixels = 589
#   Circle 4: Coordinates = (410, 346), Black Pixels = 2043915, White Pixels = 562
#   Circle 5: Coordinates = (466, 344), Black Pixels = 2043854, White Pixels = 623
#   Circle 6: Coordinates = (824, 342), Black Pixels = 2043926, White Pixels = 551
#   Circle 7: Coordinates = (882, 342), Black Pixels = 2043291, White Pixels = 1186
#   Circle 8: Coordinates = (936, 340), Black Pixels = 2043913, White Pixels = 564
#   Circle 9: Coordinates = (992, 340), Black Pixels = 2043939, White Pixels = 538
#   Circle 10: Coordinates = (1048, 340), Black Pixels = 2043923, White Pixels = 554
# Row 6:
#   Circle 1: Coordinates = (240, 400), Black Pixels = 2042586, White Pixels = 1891
#   Circle 2: Coordinates = (298, 398), Black Pixels = 2043995, White Pixels = 482
#   Circle 3: Coordinates = (354, 398), Black Pixels = 2043861, White Pixels = 616
#   Circle 4: Coordinates = (412, 396), Black Pixels = 2043056, White Pixels = 1421
#   Circle 5: Coordinates = (466, 396), Black Pixels = 2043923, White Pixels = 554
#   Circle 6: Coordinates = (826, 392), Black Pixels = 2043890, White Pixels = 587
#   Circle 7: Coordinates = (882, 392), Black Pixels = 2043977, White Pixels = 500
#   Circle 8: Coordinates = (936, 392), Black Pixels = 2043906, White Pixels = 571
#   Circle 9: Coordinates = (994, 392), Black Pixels = 2043187, White Pixels = 1290
#   Circle 10: Coordinates = (1048, 390), Black Pixels = 2043941, White Pixels = 536
# Row 7:
#   Circle 1: Coordinates = (240, 448), Black Pixels = 2043901, White Pixels = 576
#   Circle 2: Coordinates = (298, 448), Black Pixels = 2043948, White Pixels = 529
#   Circle 3: Coordinates = (354, 446), Black Pixels = 2044441, White Pixels = 36
#   Circle 4: Coordinates = (410, 446), Black Pixels = 2043899, White Pixels = 578
#   Circle 5: Coordinates = (468, 446), Black Pixels = 2043878, White Pixels = 599
#   Circle 6: Coordinates = (822, 446), Black Pixels = 2042607, White Pixels = 1870
#   Circle 7: Coordinates = (882, 442), Black Pixels = 2043952, White Pixels = 525
#   Circle 8: Coordinates = (942, 440), Black Pixels = 2043958, White Pixels = 519
#   Circle 9: Coordinates = (994, 440), Black Pixels = 2043883, White Pixels = 594
#   Circle 10: Coordinates = (1050, 440), Black Pixels = 2043921, White Pixels = 556
# Row 8:
#   Circle 1: Coordinates = (240, 500), Black Pixels = 2043892, White Pixels = 585
#   Circle 2: Coordinates = (298, 500), Black Pixels = 2043943, White Pixels = 534
#   Circle 3: Coordinates = (354, 498), Black Pixels = 2043926, White Pixels = 551
#   Circle 10: Coordinates = (1052, 646), Black Pixels = 2043926, White Pixels = 551
# Row 12:
#   Circle 1: Coordinates = (244, 708), Black Pixels = 2043924, White Pixels = 553
#   Circle 2: Coordinates = (302, 708), Black Pixels = 2043992, White Pixels = 485
#   Circle 3: Coordinates = (358, 706), Black Pixels = 2043212, White Pixels = 1265
#   Circle 4: Coordinates = (414, 706), Black Pixels = 2043962, White Pixels = 515
#   Circle 5: Coordinates = (470, 706), Black Pixels = 2043975, White Pixels = 502
#   Circle 6: Coordinates = (828, 702), Black Pixels = 2043912, White Pixels = 565
#   Circle 7: Coordinates = (888, 700), Black Pixels = 2042673, White Pixels = 1804
#   Circle 8: Coordinates = (940, 700), Black Pixels = 2044467, White Pixels = 10
#   Circle 9: Coordinates = (996, 698), Black Pixels = 2043977, White Pixels = 500
#   Circle 10: Coordinates = (1054, 698), Black Pixels = 2043926, White Pixels = 551
# Row 13:
#   Circle 1: Coordinates = (244, 756), Black Pixels = 2042654, White Pixels = 1823
#   Circle 2: Coordinates = (302, 758), Black Pixels = 2043989, White Pixels = 488
#   Circle 3: Coordinates = (358, 758), Black Pixels = 2043959, White Pixels = 518
#   Circle 4: Coordinates = (416, 756), Black Pixels = 2044412, White Pixels = 65
#   Circle 5: Coordinates = (472, 756), Black Pixels = 2043948, White Pixels = 529
#   Circle 6: Coordinates = (828, 752), Black Pixels = 2043934, White Pixels = 543
#   Circle 7: Coordinates = (884, 752), Black Pixels = 2043976, White Pixels = 501
#   Circle 8: Coordinates = (940, 750), Black Pixels = 2043918, White Pixels = 559
#   Circle 9: Coordinates = (998, 748), Black Pixels = 2043913, White Pixels = 564
#   Circle 10: Coordinates = (1054, 748), Black Pixels = 2044455, White Pixels = 22
# Row 14:
#   Circle 1: Coordinates = (244, 810), Black Pixels = 2043903, White Pixels = 574
#   Circle 2: Coordinates = (302, 810), Black Pixels = 2043957, White Pixels = 520
#   Circle 3: Coordinates = (360, 810), Black Pixels = 2043944, White Pixels = 533
#   Circle 4: Coordinates = (416, 808), Black Pixels = 2043905, White Pixels = 572
#   Circle 5: Coordinates = (472, 808), Black Pixels = 2044407, White Pixels = 70
#   Circle 6: Coordinates = (828, 804), Black Pixels = 2044467, White Pixels = 10
#   Circle 7: Coordinates = (886, 802), Black Pixels = 2042827, White Pixels = 1650
#   Circle 8: Coordinates = (942, 802), Black Pixels = 2043926, White Pixels = 551
#   Circle 9: Coordinates = (998, 802), Black Pixels = 2043922, White Pixels = 555
#   Circle 10: Coordinates = (1054, 800), Black Pixels = 2043900, White Pixels = 577
# Row 15:
#   Circle 1: Coordinates = (244, 862), Black Pixels = 2043936, White Pixels = 541
#   Circle 2: Coordinates = (300, 862), Black Pixels = 2043956, White Pixels = 521
#   Circle 3: Coordinates = (358, 862), Black Pixels = 2043309, White Pixels = 1168
#   Circle 4: Coordinates = (416, 860), Black Pixels = 2043944, White Pixels = 533
#   Circle 5: Coordinates = (472, 858), Black Pixels = 2043907, White Pixels = 570
#   Circle 6: Coordinates = (674, 872), Black Pixels = 2042356, White Pixels = 2121
#   Circle 7: Coordinates = (830, 854), Black Pixels = 2043924, White Pixels = 553
#   Circle 8: Coordinates = (886, 852), Black Pixels = 2044030, White Pixels = 447
#   Circle 9: Coordinates = (944, 852), Black Pixels = 2043901, White Pixels = 576
#   Circle 10: Coordinates = (1000, 852), Black Pixels = 2043945, White Pixels = 532
#   Circle 11: Coordinates = (1054, 852), Black Pixels = 2043185, White Pixels = 1292
# Row 16:
#   Circle 1: Coordinates = (244, 914), Black Pixels = 2043910, White Pixels = 567
#   Circle 2: Coordinates = (302, 912), Black Pixels = 2044436, White Pixels = 41
#   Circle 3: Coordinates = (358, 912), Black Pixels = 2043919, White Pixels = 558
#   Circle 4: Coordinates = (416, 910), Black Pixels = 2043932, White Pixels = 545
#   Circle 5: Coordinates = (472, 910), Black Pixels = 2043962, White Pixels = 515
#   Circle 6: Coordinates = (830, 906), Black Pixels = 2044456, White Pixels = 21
#   Circle 7: Coordinates = (888, 906), Black Pixels = 2043955, White Pixels = 522
#   Circle 8: Coordinates = (944, 904), Black Pixels = 2043913, White Pixels = 564
#   Circle 9: Coordinates = (1002, 904), Black Pixels = 2043945, White Pixels = 532
#   Circle 10: Coordinates = (1060, 900), Black Pixels = 2042809, White Pixels = 1668
# Row 17:
#   Circle 1: Coordinates = (244, 966), Black Pixels = 2043964, White Pixels = 513
#   Circle 2: Coordinates = (300, 966), Black Pixels = 2044017, White Pixels = 460
#   Circle 3: Coordinates = (358, 964), Black Pixels = 2043900, White Pixels = 577
#   Circle 4: Coordinates = (416, 964), Black Pixels = 2044001, White Pixels = 476
#   Circle 5: Coordinates = (472, 962), Black Pixels = 2044455, White Pixels = 22
#   Circle 6: Coordinates = (832, 958), Black Pixels = 2043951, White Pixels = 526
#   Circle 7: Coordinates = (890, 956), Black Pixels = 2043945, White Pixels = 532
#   Circle 8: Coordinates = (944, 956), Black Pixels = 2043715, White Pixels = 762
#   Circle 9: Coordinates = (1002, 954), Black Pixels = 2043878, White Pixels = 599
#   Circle 10: Coordinates = (1058, 954), Black Pixels = 2043944, White Pixels = 533
# Row 18:
#   Circle 1: Coordinates = (242, 1018), Black Pixels = 2043958, White Pixels = 519
#   Circle 2: Coordinates = (300, 1018), Black Pixels = 2043977, White Pixels = 500
#   Circle 3: Coordinates = (360, 1020), Black Pixels = 2043460, White Pixels = 1017
#   Circle 4: Coordinates = (416, 1014), Black Pixels = 2043938, White Pixels = 539
#   Circle 5: Coordinates = (472, 1014), Black Pixels = 2044421, White Pixels = 56
#   Circle 6: Coordinates = (834, 1008), Black Pixels = 2043964, White Pixels = 513
#   Circle 7: Coordinates = (892, 1006), Black Pixels = 2044473, White Pixels = 4
#   Circle 8: Coordinates = (948, 1008), Black Pixels = 2043919, White Pixels = 558
#   Circle 9: Coordinates = (1004, 1008), Black Pixels = 2043973, White Pixels = 504
#   Circle 10: Coordinates = (1060, 1006), Black Pixels = 2043914, White Pixels = 563
# Row 19:
#   Circle 1: Coordinates = (244, 1070), Black Pixels = 2044465, White Pixels = 12
#   Circle 2: Coordinates = (298, 1066), Black Pixels = 2043522, White Pixels = 955
#   Circle 3: Coordinates = (358, 1068), Black Pixels = 2043917, White Pixels = 560
#   Circle 4: Coordinates = (418, 1070), Black Pixels = 2042888, White Pixels = 1589
#   Circle 5: Coordinates = (474, 1066), Black Pixels = 2043934, White Pixels = 543
#   Circle 6: Coordinates = (834, 1062), Black Pixels = 2043945, White Pixels = 532
#   Circle 7: Coordinates = (892, 1062), Black Pixels = 2043987, White Pixels = 490
#   Circle 8: Coordinates = (948, 1060), Black Pixels = 2043935, White Pixels = 542
#   Circle 9: Coordinates = (1004, 1060), Black Pixels = 2044462, White Pixels = 15
#   Circle 10: Coordinates = (1062, 1060), Black Pixels = 2043964, White Pixels = 513
# Row 20:
#   Circle 1: Coordinates = (244, 1124), Black Pixels = 2043900, White Pixels = 577
#   Circle 2: Coordinates = (300, 1122), Black Pixels = 2043990, White Pixels = 487
#   Circle 3: Coordinates = (358, 1122), Black Pixels = 2043920, White Pixels = 557
#   Circle 4: Coordinates = (416, 1118), Black Pixels = 2043398, White Pixels = 1079
#   Circle 5: Coordinates = (472, 1118), Black Pixels = 2043927, White Pixels = 550
#   Circle 6: Coordinates = (836, 1114), Black Pixels = 2043921, White Pixels = 556
#   Circle 7: Coordinates = (892, 1114), Black Pixels = 2043991, White Pixels = 486
#   Circle 8: Coordinates = (952, 1110), Black Pixels = 2042818, White Pixels = 1659
#   Circle 9: Coordinates = (1006, 1112), Black Pixels = 2043960, White Pixels = 517
#   Circle 10: Coordinates = (1064, 1112), Black Pixels = 2044470, White Pixels = 7
# Row 21:
#   Circle 1: Coordinates = (244, 1176), Black Pixels = 2043844, White Pixels = 633
#   Circle 2: Coordinates = (302, 1176), Black Pixels = 2043981, White Pixels = 496
#   Circle 3: Coordinates = (358, 1174), Black Pixels = 2043894, White Pixels = 583
#   Circle 4: Coordinates = (416, 1172), Black Pixels = 2044432, White Pixels = 45
#   Circle 5: Coordinates = (474, 1172), Black Pixels = 2043882, White Pixels = 595
#   Circle 6: Coordinates = (838, 1168), Black Pixels = 2043901, White Pixels = 576
#   Circle 7: Coordinates = (894, 1166), Black Pixels = 2044461, White Pixels = 16
#   Circle 8: Coordinates = (956, 1164), Black Pixels = 2042666, White Pixels = 1811
#   Circle 9: Coordinates = (1008, 1166), Black Pixels = 2043956, White Pixels = 521
#   Circle 10: Coordinates = (1066, 1164), Black Pixels = 2043862, White Pixels = 615
# Row 22:
#   Circle 1: Coordinates = (242, 1230), Black Pixels = 2044439, White Pixels = 38
#   Circle 2: Coordinates = (300, 1228), Black Pixels = 2043988, White Pixels = 489
#   Circle 3: Coordinates = (360, 1228), Black Pixels = 2043910, White Pixels = 567
#   Circle 4: Coordinates = (416, 1226), Black Pixels = 2043954, White Pixels = 523
#   Circle 5: Coordinates = (472, 1226), Black Pixels = 2043923, White Pixels = 554
#   Circle 6: Coordinates = (838, 1222), Black Pixels = 2043925, White Pixels = 552
#   Circle 7: Coordinates = (896, 1220), Black Pixels = 2044015, White Pixels = 462
#   Circle 8: Coordinates = (952, 1220), Black Pixels = 2043869, White Pixels = 608
#   Circle 9: Coordinates = (1008, 1218), Black Pixels = 2044453, White Pixels = 24
#   Circle 10: Coordinates = (1068, 1214), Black Pixels = 2042873, White Pixels = 1604
# Row 23:
#   Circle 1: Coordinates = (244, 1282), Black Pixels = 2043937, White Pixels = 540
#   Circle 2: Coordinates = (304, 1282), Black Pixels = 2042963, White Pixels = 1514
#   Circle 3: Coordinates = (358, 1280), Black Pixels = 2044448, White Pixels = 29
#   Circle 4: Coordinates = (418, 1282), Black Pixels = 2042785, White Pixels = 1692
#   Circle 5: Coordinates = (474, 1276), Black Pixels = 2043962, White Pixels = 515
#   Circle 6: Coordinates = (838, 1272), Black Pixels = 2044458, White Pixels = 19
#   Circle 7: Coordinates = (898, 1272), Black Pixels = 2044010, White Pixels = 467
#   Circle 8: Coordinates = (954, 1272), Black Pixels = 2043867, White Pixels = 610
#   Circle 9: Coordinates = (1010, 1270), Black Pixels = 2043979, White Pixels = 498
#   Circle 10: Coordinates = (1068, 1270), Black Pixels = 2043935, White Pixels = 542
# Row 24:
#   Circle 1: Coordinates = (244, 1334), Black Pixels = 2043935, White Pixels = 542
#   Circle 2: Coordinates = (302, 1334), Black Pixels = 2044034, White Pixels = 443
#   Circle 3: Coordinates = (360, 1332), Black Pixels = 2043963, White Pixels = 514
#   Circle 4: Coordinates = (416, 1332), Black Pixels = 2043973, White Pixels = 504
#   Circle 5: Coordinates = (474, 1330), Black Pixels = 2044473, White Pixels = 4
#   Circle 6: Coordinates = (836, 1328), Black Pixels = 2043515, White Pixels = 962
#   Circle 7: Coordinates = (898, 1328), Black Pixels = 2044448, White Pixels = 29
#   Circle 8: Coordinates = (954, 1324), Black Pixels = 2043964, White Pixels = 513
#   Circle 9: Coordinates = (1010, 1320), Black Pixels = 2042914, White Pixels = 1563
#   Circle 10: Coordinates = (1070, 1324), Black Pixels = 2043876, White Pixels = 601
# Row 25:
#   Circle 1: Coordinates = (246, 1386), Black Pixels = 2043948, White Pixels = 529
#   Circle 2: Coordinates = (302, 1384), Black Pixels = 2043442, White Pixels = 1035
#   Circle 3: Coordinates = (360, 1384), Black Pixels = 2043928, White Pixels = 549
#   Circle 4: Coordinates = (414, 1386), Black Pixels = 2042916, White Pixels = 1561
#   Circle 5: Coordinates = (474, 1384), Black Pixels = 2043926, White Pixels = 551
#   Circle 6: Coordinates = (840, 1380), Black Pixels = 2043962, White Pixels = 515
#   Circle 7: Coordinates = (898, 1380), Black Pixels = 2043978, White Pixels = 499
#   Circle 8: Coordinates = (956, 1378), Black Pixels = 2043890, White Pixels = 587
#   Circle 9: Coordinates = (1014, 1378), Black Pixels = 2044475, White Pixels = 2
#   Circle 10: Coordinates = (1070, 1378), Black Pixels = 2043879, White Pixels = 598

# %% [markdown]
# ### 5. detecting marked and unmarked bubble

# %%
def detect_marked_and_unmarked_bubbles(subtracted_grouped_rows, num_options, deviation_threshold=50):
    """
    Detect marked and unmarked bubbles based on white pixel values and a deviation threshold.

    Args:
        subtracted_grouped_rows (list): List of grouped circles with subtracted pixel counts.
        num_options (int): The number of options per question.
        deviation_threshold (float): The threshold below which a question is considered unmarked.

    Returns:
        list: A 2D array where each element is:
              - 1 for the most deviated (marked) bubble.
              - 0 for unmarked bubbles.
    """
    marked_bubbles = []

    for row in subtracted_grouped_rows:
        for question_start in range(0, len(row), num_options):
            question_group = row[question_start:question_start + num_options]

            # Extract white pixel values for the current question
            white_pixel_values = [subtracted_white for (_, _, _, _, subtracted_white) in question_group]

            # Calculate the mean and standard deviation of the white pixel values
            mean_white = np.mean(white_pixel_values)
            std_dev_white = np.std(white_pixel_values)
            print(f"Mean: {mean_white}, Standard Deviation: {std_dev_white}")
            # If the standard deviation is less than the threshold, consider the question unmarked
            if std_dev_white < deviation_threshold:
                marked_bubbles.append([0] * num_options)  
            else:
                # Calculate absolute deviations from the mean
                deviations = [abs(white_value - mean_white) for white_value in white_pixel_values]

                # Create a 1D array for the question (options), initialized to zeros
                marked_question = np.zeros(num_options, dtype=int)

                # Find the index of the maximum deviation
                max_deviation_index = np.argmax(deviations)

                # Mark the option with the highest deviation as 1 (marked bubble)
                marked_question[max_deviation_index] = 1

                marked_bubbles.append(marked_question)

    return np.array(marked_bubbles)


  
answer_student = detect_marked_and_unmarked_bubbles(grouped_rows_s, options)

# Print the marked bubbles in a readable format
for row_idx, row in enumerate(answer_student, start=1):
    print(f"Question {row_idx}: Marked Bubble = {row.tolist()}")
# Out:
# Mean: 557.6, Standard Deviation: 262.47483688917686
# Mean: 510.0, Standard Deviation: 226.45264405610283
# Mean: 556.0, Standard Deviation: 265.7404748998541
# Mean: 516.4, Standard Deviation: 200.47204293866017
# Mean: 523.4, Standard Deviation: 232.13926854369123
# Mean: 519.4, Standard Deviation: 193.75819982648477
# Mean: 506.2, Standard Deviation: 221.31642505697585
# Mean: 512.2, Standard Deviation: 231.25691341017247
# Mean: 579.8, Standard Deviation: 253.3214558619147
# Mean: 513.0, Standard Deviation: 245.9447092335999
# Mean: 548.6, Standard Deviation: 221.09871098674455
# Mean: 485.2, Standard Deviation: 240.9335178010731
# Mean: 534.0, Standard Deviation: 199.09394767295163
# Mean: 511.2, Standard Deviation: 245.1623135802075
# Mean: 506.4, Standard Deviation: 263.9868178527102
# Mean: 524.6, Standard Deviation: 233.81411420185907
# Mean: 561.2, Standard Deviation: 297.8720530697702
# Mean: 557.8, Standard Deviation: 193.72495967221158
# Mean: 503.6, Standard Deviation: 248.02790165624512
# Mean: 515.0, Standard Deviation: 226.42438031272164
# Mean: 529.6, Standard Deviation: 224.39126542715516
# Mean: 515.2, Standard Deviation: 244.30423655761686
# Mean: 491.8, Standard Deviation: 216.23450233484942
# Mean: 521.0, Standard Deviation: 214.35297991863794
# Mean: 512.6, Standard Deviation: 240.57979965076038
# Mean: 484.2, Standard Deviation: 225.68952124544904
# Mean: 493.8, Standard Deviation: 239.28175860269835
# Mean: 499.2, Standard Deviation: 239.85445586855374
# Mean: 497.8, Standard Deviation: 229.15531850690263
# Mean: 501.4, Standard Deviation: 232.23660348876962
# Mean: 444.8, Standard Deviation: 223.79579978185473
# Mean: 479.4, Standard Deviation: 217.7554591738173
# Mean: 492.2, Standard Deviation: 242.97028624916257
# Mean: 490.6, Standard Deviation: 218.2756055998929
# Mean: 468.6, Standard Deviation: 226.85907519867922
# Mean: 493.6, Standard Deviation: 186.46779882864496
# Mean: 467.4, Standard Deviation: 194.38683082966293
# Mean: 468.0, Standard Deviation: 210.9284238788125
# Mean: 462.0, Standard Deviation: 220.13722992715248
# Mean: 482.2, Standard Deviation: 235.34434346293517
# Mean: 474.2, Standard Deviation: 220.64034082642277
# Mean: 487.4, Standard Deviation: 225.07030012864868
# Mean: 490.2, Standard Deviation: 245.5617234016735
# Mean: 455.4, Standard Deviation: 226.49467984921853
# Mean: 462.6, Standard Deviation: 211.54157983715638
# Mean: 495.2, Standard Deviation: 245.02277445168238
# Mean: 475.2, Standard Deviation: 238.56353451439304
# Mean: 429.2, Standard Deviation: 212.30016486098168
# Mean: 459.8, Standard Deviation: 224.15476796178126
# Mean: 451.2, Standard Deviation: 204.4821752622952
# Question 1: Marked Bubble = [0, 0, 0, 0, 1]
# Question 2: Marked Bubble = [0, 0, 1, 0, 0]
# Question 3: Marked Bubble = [0, 1, 0, 0, 0]
# Question 4: Marked Bubble = [0, 1, 0, 0, 0]
# Question 5: Marked Bubble = [0, 0, 1, 0, 0]
# Question 6: Marked Bubble = [1, 0, 0, 0, 0]
# Question 7: Marked Bubble = [0, 0, 0, 0, 1]
# Question 8: Marked Bubble = [0, 1, 0, 0, 0]
# Question 9: Marked Bubble = [0, 0, 0, 1, 0]
# Question 10: Marked Bubble = [0, 0, 0, 1, 0]
# Question 11: Marked Bubble = [0, 1, 0, 0, 0]
# Question 12: Marked Bubble = [0, 0, 0, 0, 1]
# Question 13: Marked Bubble = [0, 0, 1, 0, 0]
# Question 14: Marked Bubble = [0, 0, 0, 1, 0]
# Question 15: Marked Bubble = [1, 0, 0, 0, 0]
# Question 16: Marked Bubble = [0, 0, 1, 0, 0]
# Question 17: Marked Bubble = [0, 1, 0, 0, 0]
# Question 18: Marked Bubble = [0, 1, 0, 0, 0]
# Question 19: Marked Bubble = [0, 0, 1, 0, 0]
# Question 20: Marked Bubble = [1, 0, 0, 0, 0]
# Question 21: Marked Bubble = [0, 0, 0, 1, 0]
# Question 22: Marked Bubble = [1, 0, 0, 0, 0]
# Question 23: Marked Bubble = [1, 0, 0, 0, 0]
# Question 24: Marked Bubble = [0, 1, 0, 0, 0]
# Question 25: Marked Bubble = [0, 1, 0, 0, 0]
# Question 26: Marked Bubble = [0, 0, 1, 0, 0]
# Question 27: Marked Bubble = [0, 1, 0, 0, 0]
# Question 28: Marked Bubble = [0, 1, 0, 0, 0]
# Question 29: Marked Bubble = [1, 0, 0, 0, 0]
# Question 30: Marked Bubble = [0, 0, 1, 0, 0]
# Question 31: Marked Bubble = [0, 0, 1, 0, 0]
# Question 32: Marked Bubble = [0, 0, 0, 0, 1]
# Question 33: Marked Bubble = [0, 0, 1, 0, 0]
# Question 34: Marked Bubble = [0, 0, 0, 0, 1]
# Question 35: Marked Bubble = [0, 1, 0, 0, 0]
# Question 36: Marked Bubble = [1, 0, 0, 0, 0]
# Question 37: Marked Bubble = [0, 0, 0, 1, 0]
# Question 38: Marked Bubble = [1, 0, 0, 0, 0]
# Question 39: Marked Bubble = [0, 0, 0, 0, 1]
# Question 40: Marked Bubble = [0, 0, 1, 0, 0]
# Question 41: Marked Bubble = [0, 0, 0, 0, 1]
# Question 42: Marked Bubble = [0, 0, 0, 1, 0]
# Question 43: Marked Bubble = [0, 1, 0, 0, 0]
# Question 44: Marked Bubble = [0, 0, 1, 0, 0]
# Question 45: Marked Bubble = [0, 0, 1, 0, 0]
# Question 46: Marked Bubble = [0, 0, 0, 1, 0]
# Question 47: Marked Bubble = [0, 0, 0, 1, 0]
# Question 48: Marked Bubble = [0, 0, 0, 0, 1]
# Question 49: Marked Bubble = [1, 0, 0, 0, 0]
# Question 50: Marked Bubble = [1, 0, 0, 0, 0]

# %%
answer_key = detect_marked_and_unmarked_bubbles(grouped_rows_k, options)
for row_idx, row in enumerate(answer_key, start=1):
    print(f"Question {row_idx}: Marked Bubble = {row.tolist()}")
# Out:
# Mean: 913.2, Standard Deviation: 434.3341570726392
# Mean: 415.4, Standard Deviation: 174.24304864183247
# Mean: 522.2, Standard Deviation: 212.06829088762893
# Mean: 469.2, Standard Deviation: 198.13167338918834
# Mean: 605.2, Standard Deviation: 130.4996551719582
# Mean: 415.2, Standard Deviation: 178.961895385582
# Mean: 431.2, Standard Deviation: 207.29823925928557
# Mean: 538.25, Standard Deviation: 71.13499490405549
# Mean: 490.0, Standard Deviation: 203.9186112153572
# Mean: 678.6, Standard Deviation: 253.83585247163174
# Mean: 992.8, Standard Deviation: 563.1267708074266
# Mean: 696.8, Standard Deviation: 298.1123278229198
# Mean: 463.6, Standard Deviation: 215.02241743595016
# Mean: 812.8, Standard Deviation: 529.270970297824
# Mean: 486.2, Standard Deviation: 134.2466386916261
# Mean: 672.8, Standard Deviation: 230.93583524433794
# Mean: 440.6, Standard Deviation: 207.5115418476765
# Mean: 526.4, Standard Deviation: 264.6330289287412
# Mean: 663.2, Standard Deviation: 520.165896613763
# Mean: 443.4, Standard Deviation: 204.947407887975
# Mean: 423.2, Standard Deviation: 200.5376772579158
# Mean: 651.4, Standard Deviation: 241.49086939261284
# Mean: 664.0, Standard Deviation: 301.3330383479382
# Mean: 686.0, Standard Deviation: 595.7116752255239
# Mean: 684.6, Standard Deviation: 595.0591903331971
# Mean: 437.8, Standard Deviation: 209.07740193526416
# Mean: 453.8, Standard Deviation: 193.06827807798982
# Mean: 668.6, Standard Deviation: 535.1682352307544
# Mean: 666.6, Standard Deviation: 251.2199036700715
# Mean: 845.8, Standard Deviation: 639.088538467089
# Mean: 1292.0, Standard Deviation: 0.0
# Mean: 445.2, Standard Deviation: 202.8638952598515
# Mean: 661.4, Standard Deviation: 542.0367515215181
# Mean: 409.6, Standard Deviation: 197.93797008153842
# Mean: 590.4, Standard Deviation: 89.85900066214847
# Mean: 526.2, Standard Deviation: 304.261335039469
# Mean: 428.4, Standard Deviation: 213.49529268815274
# Mean: 731.8, Standard Deviation: 523.0454664749518
# Mean: 418.4, Standard Deviation: 202.47923350309284
# Mean: 650.0, Standard Deviation: 216.60470909008419
# Mean: 645.0, Standard Deviation: 544.9451348530418
# Mean: 470.4, Standard Deviation: 217.37672368494287
# Mean: 707.8, Standard Deviation: 592.7081575278005
# Mean: 434.2, Standard Deviation: 199.92538608190807
# Mean: 650.0, Standard Deviation: 519.3657670659475
# Mean: 858.0, Standard Deviation: 637.4803526384167
# Mean: 427.2, Standard Deviation: 209.67536812892448
# Mean: 401.4, Standard Deviation: 201.311301222758
# Mean: 733.6, Standard Deviation: 510.4467063269191
# Mean: 845.0, Standard Deviation: 405.6264291192081
# Mean: 440.2, Standard Deviation: 222.49620221477937
# Question 1: Marked Bubble = [1, 0, 0, 0, 0]
# Question 2: Marked Bubble = [1, 0, 0, 0, 0]
# Question 3: Marked Bubble = [0, 0, 0, 1, 0]
# Question 4: Marked Bubble = [0, 0, 0, 0, 1]
# Question 5: Marked Bubble = [0, 0, 1, 0, 0]
# Question 6: Marked Bubble = [1, 0, 0, 0, 0]
# Question 7: Marked Bubble = [0, 0, 0, 1, 0]
# Question 8: Marked Bubble = [0, 1, 0, 0, 0]
# Question 9: Marked Bubble = [0, 1, 0, 0, 0]
# Question 10: Marked Bubble = [0, 1, 0, 0, 0]
# Question 11: Marked Bubble = [1, 0, 0, 0, 0]
# Question 12: Marked Bubble = [0, 0, 0, 1, 0]
# Question 13: Marked Bubble = [0, 0, 1, 0, 0]
# Question 14: Marked Bubble = [1, 0, 0, 0, 0]
# Question 15: Marked Bubble = [0, 0, 0, 0, 1]
# Question 16: Marked Bubble = [0, 0, 0, 1, 0]
# Question 17: Marked Bubble = [0, 0, 0, 0, 1]
# Question 18: Marked Bubble = [1, 0, 0, 0, 0]
# Question 19: Marked Bubble = [0, 1, 0, 0, 0]
# Question 20: Marked Bubble = [0, 0, 1, 0, 0]
# Question 21: Marked Bubble = [1, 0, 0, 0, 0]
# Question 22: Marked Bubble = [1, 0, 0, 0, 0]
# Question 23: Marked Bubble = [0, 0, 1, 0, 0]
# Question 24: Marked Bubble = [0, 1, 0, 0, 0]
# Question 25: Marked Bubble = [1, 0, 0, 0, 0]
# Question 26: Marked Bubble = [0, 0, 0, 0, 1]
# Question 27: Marked Bubble = [0, 0, 0, 0, 1]
# Question 28: Marked Bubble = [0, 1, 0, 0, 0]
# Question 29: Marked Bubble = [0, 0, 1, 0, 0]
# Question 30: Marked Bubble = [1, 0, 0, 0, 0]
# Question 31: Marked Bubble = [0, 0, 0, 0, 0]
# Question 32: Marked Bubble = [0, 1, 0, 0, 0]
# Question 33: Marked Bubble = [0, 0, 0, 0, 1]
# Question 34: Marked Bubble = [0, 0, 0, 0, 1]
# Question 35: Marked Bubble = [0, 0, 1, 0, 0]
# Question 36: Marked Bubble = [0, 0, 1, 0, 0]
# Question 37: Marked Bubble = [0, 1, 0, 0, 0]
# Question 38: Marked Bubble = [0, 0, 0, 1, 0]
# Question 39: Marked Bubble = [0, 0, 0, 1, 0]
# Question 40: Marked Bubble = [0, 0, 0, 1, 0]
# Question 41: Marked Bubble = [0, 0, 1, 0, 0]
# Question 42: Marked Bubble = [0, 0, 0, 1, 0]
# Question 43: Marked Bubble = [0, 0, 1, 0, 0]
# Question 44: Marked Bubble = [1, 0, 0, 0, 0]
# Question 45: Marked Bubble = [0, 0, 0, 0, 1]
# Question 46: Marked Bubble = [0, 0, 0, 1, 0]
# Question 47: Marked Bubble = [1, 0, 0, 0, 0]
# Question 48: Marked Bubble = [0, 0, 0, 0, 1]
# Question 49: Marked Bubble = [0, 0, 0, 1, 0]
# Question 50: Marked Bubble = [0, 0, 0, 1, 0]
# Question 51: Marked Bubble = [0, 0, 0, 1, 0]

# %% [markdown]
# ### 6. calculate score

# %%
def calculate_score(answer_key, answer_student):
    """
    Compare the student's answers with the answer key and calculate the score.

    Args:
        answer_key (np.ndarray): The correct answer key with marked bubbles (1 for correct option, 0 for others).
        answer_student (np.ndarray): The student's marked answers with bubbles (1 for marked option, 0 for others).

    Returns:
        int: The total score of the student.
        list: A list indicating correctness for each question (1 for correct, 0 for incorrect).
    """
    total_score = 0
    result_per_question = []

    for key, student in zip(answer_key, answer_student):
        if np.array_equal(key, student):
            total_score += 1
            result_per_question.append(1)  # Correct answer
        else:
            result_per_question.append(0)  # Incorrect answer

    return total_score, result_per_question


total_score, result_per_question = calculate_score(answer_key, answer_student)

# Print the final score and results
print(f"Total Score: {total_score}")
for idx, result in enumerate(result_per_question, start=1):
    status = "Correct" if result == 1 else "Incorrect"
    print(f"Question {idx}: {status}")
# Out:
# Total Score: 11
# Question 1: Incorrect
# Question 2: Incorrect
# Question 3: Incorrect
# Question 4: Incorrect
# Question 5: Correct
# Question 6: Correct
# Question 7: Incorrect
# Question 8: Correct
# Question 9: Incorrect
# Question 10: Incorrect
# Question 11: Incorrect
# Question 12: Incorrect
# Question 13: Correct
# Question 14: Incorrect
# Question 15: Incorrect
# Question 16: Incorrect
# Question 17: Incorrect
# Question 18: Incorrect
# Question 19: Incorrect
# Question 20: Incorrect
# Question 21: Incorrect
# Question 22: Correct
# Question 23: Incorrect
# Question 24: Correct
# Question 25: Incorrect
# Question 26: Incorrect
# Question 27: Incorrect
# Question 28: Correct
# Question 29: Incorrect
# Question 30: Incorrect
# Question 31: Incorrect
# Question 32: Incorrect
# Question 33: Incorrect
# Question 34: Correct
# Question 35: Incorrect
# Question 36: Incorrect
# Question 37: Incorrect
# Question 38: Incorrect
# Question 39: Incorrect
# Question 40: Incorrect
# Question 41: Incorrect
# Question 42: Correct
# Question 43: Incorrect
# Question 44: Incorrect
# Question 45: Incorrect
# Question 46: Correct
# Question 47: Incorrect
# Question 48: Correct
# Question 49: Incorrect
# Question 50: Incorrect
