# %% [markdown]
# # Hough Circles

# %%
# this is the basic idea of the cicle detection in the OMR sheet
import cv2 
import numpy as np 

# Read image. 
img = cv2.imread('./Test/5_T.jpg',cv2.IMREAD_COLOR) 

# Convert to grayscale. 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

 
gray_blurred = cv2.GaussianBlur(gray, (5, 5), 0)
options =25
questions =4
b=10
a=10
# Apply Hough transform on the blurred image. 
detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, a, 
					param1 = b,param2 = 3*b, minRadius = a//2, maxRadius = a)  
if detected_circles is not None:
	detected_circles = np.uint16(np.around(detected_circles))
	print(f"a:{a} b:{b} detected circles:{detected_circles.shape[1]}")
	if detected_circles.shape[1]==options*questions:
		for pt in detected_circles[0, :]: 
			a, b, r = pt[0], pt[1], pt[2] 

			# Draw the circumference of the circle. 
			cv2.circle(img, (a, b), r, (0, 255, 0), 3) 

			# Draw a small circle (of radius 1) to show the center. 
			cv2.circle(img, (a, b), 2, (0, 0, 255), 3) 
		cv2.imshow("Detected Circle", img) 
		cv2.imwrite(f'./camera/detected_circles{a}b{b}.jpg', img)
		cv2.waitKey(0)
# Out:
# a:10 b:10 detected circles:2

# %%
import cv2
import numpy as np

# Function to resize the image within max width and height while maintaining aspect ratio
def resize_image(image, max_width=None, max_height=None):
    (h, w) = image.shape[:2]

    if max_width is not None and max_height is not None:
        # Calculate aspect ratio to fit both width and height constraints
        if w > h:
            ratio = max_width / float(w)
            new_width = max_width
            new_height = int(h * ratio)
        else:
            ratio = max_height / float(h)
            new_height = max_height
            new_width = int(w * ratio)
    elif max_width is not None:
        ratio = max_width / float(w)
        new_width = max_width
        new_height = int(h * ratio)
    elif max_height is not None:
        ratio = max_height / float(h)
        new_height = max_height
        new_width = int(w * ratio)
    else:
        return image  # If no resizing dimensions are provided, return original image

    return cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)

# Read image
img = cv2.imread('./Test/7_S.jpg', cv2.IMREAD_COLOR)

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur
gray_blurred = cv2.GaussianBlur(gray, (5, 5), 0)

a = 22
b = 10

# Apply Hough transform on the blurred image
detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, a, 
                                    param1=b, param2=3*b, 
                                    minRadius=a//2, maxRadius=a)

# Draw circles that are detected
if detected_circles is not None:
    detected_circles = np.uint16(np.around(detected_circles))

    for pt in detected_circles[0, :]:
        a, b, r = pt[0], pt[1], pt[2]

        # Draw the circumference of the circle
        cv2.circle(img, (a, b), r, (0, 255, 0), 3)

        # Draw a small circle to show the center
        cv2.circle(img, (a, b), 2, (0, 0, 255), 3)

        print(f"Circle found at: ({a}, {b}), radius={r}")

# Resize the image to fit within the given max width and height
resized_img = resize_image(img, max_width=800, max_height=600)  # Change width/height as needed

# Display the resized image
cv2.imshow("Detected Circles", resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Circle found at: (1108, 738), radius=17
# Circle found at: (1046, 804), radius=17
# Circle found at: (984, 544), radius=18
# Circle found at: (230, 274), radius=18
# Circle found at: (1340, 228), radius=17
# Circle found at: (168, 206), radius=18
# Circle found at: (1108, 804), radius=17
# Circle found at: (730, 608), radius=17
# Circle found at: (348, 610), radius=18
# Circle found at: (612, 412), radius=18
# Circle found at: (550, 346), radius=18
# Circle found at: (730, 542), radius=17
# Circle found at: (166, 340), radius=18
# Circle found at: (1346, 544), radius=17
# Circle found at: (1342, 290), radius=17
# Circle found at: (1460, 418), radius=17
# Circle found at: (292, 274), radius=15
# Circle found at: (222, 542), radius=18
# Circle found at: (156, 812), radius=17
# Circle found at: (1458, 354), radius=17
# Circle found at: (350, 542), radius=15
# Circle found at: (732, 412), radius=15
# Circle found at: (280, 816), radius=18
# Circle found at: (542, 808), radius=18
# Circle found at: (924, 738), radius=17
# Circle found at: (928, 214), radius=17
# Circle found at: (1400, 354), radius=17
# Circle found at: (666, 742), radius=17
# Circle found at: (924, 806), radius=17
# Circle found at: (162, 474), radius=14
# Circle found at: (158, 676), radius=18
# Circle found at: (730, 676), radius=18
# Circle found at: (1044, 672), radius=17
# Circle found at: (1458, 228), radius=17
# Circle found at: (164, 406), radius=14
# Circle found at: (282, 678), radius=18
# Circle found at: (1344, 354), radius=17
# Circle found at: (1458, 292), radius=14
# Circle found at: (730, 742), radius=17
# Circle found at: (1284, 352), radius=17
# Circle found at: (1398, 228), radius=17
# Circle found at: (1286, 478), radius=16
# Circle found at: (232, 208), radius=17
# Circle found at: (614, 284), radius=17
# Circle found at: (924, 544), radius=17
# Circle found at: (672, 412), radius=17
# Circle found at: (608, 674), radius=15
# Circle found at: (552, 216), radius=18
# Circle found at: (926, 282), radius=18
# Circle found at: (346, 746), radius=18
# Circle found at: (728, 810), radius=17
# Circle found at: (986, 284), radius=17
# Circle found at: (1350, 738), radius=17
# Circle found at: (924, 478), radius=17
# Circle found at: (986, 804), radius=15
# Circle found at: (294, 208), radius=15
# Circle found at: (984, 478), radius=15
# Circle found at: (550, 280), radius=18
# Circle found at: (286, 474), radius=18
# Circle found at: (1048, 218), radius=17
# Circle found at: (674, 282), radius=17
# Circle found at: (1292, 804), radius=17
# Circle found at: (280, 746), radius=16
# Circle found at: (1044, 544), radius=15
# Circle found at: (288, 406), radius=14
# Circle found at: (550, 412), radius=14
# Circle found at: (548, 476), radius=14
# Circle found at: (1106, 608), radius=18
# Circle found at: (666, 810), radius=17
# Circle found at: (1290, 610), radius=17
# Circle found at: (1108, 674), radius=15
# Circle found at: (1046, 738), radius=18
# Circle found at: (226, 408), radius=18
# Circle found at: (670, 542), radius=17
# Circle found at: (1286, 418), radius=16
# Circle found at: (610, 608), radius=15
# Circle found at: (546, 674), radius=18
# Circle found at: (346, 678), radius=16
# Circle found at: (358, 274), radius=16
# Circle found at: (1106, 414), radius=15
# Circle found at: (984, 608), radius=14
# Circle found at: (352, 474), radius=18
# Circle found at: (1106, 544), radius=18
# Circle found at: (674, 216), radius=17
# Circle found at: (1346, 608), radius=17
# Circle found at: (218, 678), radius=14
# Circle found at: (1400, 292), radius=14
# Circle found at: (290, 340), radius=18
# Circle found at: (1408, 738), radius=17
# Circle found at: (672, 348), radius=16
# Circle found at: (732, 478), radius=15
# Circle found at: (610, 542), radius=14
# Circle found at: (614, 478), radius=16
# Circle found at: (354, 406), radius=20
# Circle found at: (358, 210), radius=18
# Circle found at: (284, 610), radius=18
# Circle found at: (986, 738), radius=15
# Circle found at: (158, 610), radius=14
# Circle found at: (668, 676), radius=14
# Circle found at: (1046, 414), radius=14
# Circle found at: (1046, 284), radius=17
# Circle found at: (160, 542), radius=15
# Circle found at: (218, 746), radius=15
# Circle found at: (732, 346), radius=15
# Circle found at: (986, 348), radius=15
# Circle found at: (220, 610), radius=14
# Circle found at: (546, 608), radius=14
# Circle found at: (732, 280), radius=14
# Circle found at: (924, 414), radius=17
# Circle found at: (1348, 674), radius=17
# Circle found at: (224, 474), radius=15
# Circle found at: (168, 274), radius=14
# Circle found at: (1046, 348), radius=14
# Circle found at: (1106, 284), radius=14
# Circle found at: (1106, 220), radius=14
# Circle found at: (156, 744), radius=14
# Circle found at: (668, 610), radius=14
# Circle found at: (924, 608), radius=14
# Circle found at: (544, 740), radius=18
# Circle found at: (228, 340), radius=17
# Circle found at: (614, 218), radius=15
# Circle found at: (734, 214), radius=15
# Circle found at: (218, 814), radius=14
# Circle found at: (984, 672), radius=14
# Circle found at: (1352, 804), radius=14
# Circle found at: (1290, 674), radius=14
# Circle found at: (1292, 738), radius=14
# Circle found at: (1406, 672), radius=16
# Circle found at: (924, 674), radius=15
# Circle found at: (548, 542), radius=14
# Circle found at: (986, 414), radius=14
# Circle found at: (1106, 478), radius=14
# Circle found at: (1404, 546), radius=17
# Circle found at: (1282, 226), radius=17
# Circle found at: (926, 348), radius=15
# Circle found at: (614, 346), radius=16
# Circle found at: (1044, 478), radius=15
# Circle found at: (1462, 672), radius=14
# Circle found at: (1282, 288), radius=16
# Circle found at: (1462, 546), radius=14
# Circle found at: (1468, 802), radius=17
# Circle found at: (1344, 416), radius=17
# Circle found at: (1344, 480), radius=16
# Circle found at: (1404, 608), radius=16
# Circle found at: (988, 214), radius=15
# Circle found at: (1462, 608), radius=14
# Circle found at: (344, 814), radius=16
# Circle found at: (1046, 610), radius=16
# Circle found at: (1412, 802), radius=15
# Circle found at: (352, 340), radius=16
# Circle found at: (1108, 350), radius=12
# Circle found at: (608, 808), radius=17
# Circle found at: (1464, 734), radius=16
# Circle found at: (1288, 544), radius=14
# Circle found at: (610, 738), radius=18
# Circle found at: (1402, 416), radius=14
# Circle found at: (670, 476), radius=16
# Circle found at: (1462, 480), radius=15
# Circle found at: (284, 542), radius=18
# Circle found at: (1404, 480), radius=13

# %% [markdown]
# #### this to classify those clusters

# %%
import cv2
import numpy as np
from sklearn.cluster import DBSCAN
import random

def detect_circles(img, gray_blurred, questions, options):
    for b in range(15, 5, -1):
        for a in range(1, 30):
            detected_circles = cv2.HoughCircles(
                gray_blurred, cv2.HOUGH_GRADIENT, 1, a,
                param1=b, param2=3*b, minRadius=a//2, maxRadius=a
            )

            if detected_circles is not None:
                detected_circles = np.uint16(np.around(detected_circles))
                
                if detected_circles.shape[1] == questions * options:
                    pixel_counts = [(x, y, r, 0, 0) for (x, y, r) in detected_circles[0]]

                    # Group circles by rows using DBSCAN
                    rows = group_by_row_dbscan(pixel_counts)

                    # Validate if each row has clusters with 'options' circles
                    valid_rows = all(
                        len(cluster_questions_in_row(row, options)) == len(row) // options
                        for row in rows
                    )

                    if valid_rows:
                        visualize_clusters(img, rows)
                        return detected_circles[0], (a, b)

    return None, (None, None)

# Function to group circles by rows
def group_by_row_dbscan(pixel_counts, eps=10):
    y_coords = np.array([[y] for (x, y, r, black_count, white_count) in pixel_counts])
    clustering = DBSCAN(eps=eps, min_samples=1).fit(y_coords)
    labels = clustering.labels_
    rows = {}
    for label, circle_data in zip(labels, pixel_counts):
        if label not in rows:
            rows[label] = []
        rows[label].append(circle_data)
    sorted_rows = sorted(rows.values(), key=lambda row: np.mean([c[1] for c in row]))
    sorted_rows = [sorted(row, key=lambda c: c[0]) for row in sorted_rows]
    return sorted_rows

# Function to cluster questions within each row
def cluster_questions_in_row(row, options, eps=80):
    x_coords = np.array([[x] for (x, y, r, black_count, white_count) in row])
    clustering = DBSCAN(eps=eps, min_samples=1).fit(x_coords)
    labels = clustering.labels_
    questions = {}
    for label, circle_data in zip(labels, row):
        if label not in questions:
            questions[label] = []
        questions[label].append(circle_data)
    return [q for q in questions.values() if len(q) == options]

# Visualization function to display clusters with unique colors
def visualize_clusters(img, rows):
    # Assign a random color to each cluster (question) for visualization
    for row in rows:
        question_clusters = cluster_questions_in_row(row, options=4)  # Assuming options=4; adjust as needed

        # Assign a unique color for each question cluster
        for cluster in question_clusters:
            color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
            for (x, y, r, _, _) in cluster:
                # Draw each circle with a unique color per cluster
                cv2.circle(img, (x, y), r, color, 2)
                cv2.circle(img, (x, y), 2, (0, 0, 255), 3)  # Mark the center

    cv2.imshow("Detected Circles with Clusters", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
detected = detect_circles(original_img_t, gray_blurred_t, 50, 4)

# %% [markdown]
# ## Steps

# %% [markdown]
# ### 1. Preprocessing

# %%
import cv2
import numpy as np


def preprocess_image(image_path, blur_ksize=(5, 5)):
    """
    Preprocess the input image by converting it to grayscale and applying Gaussian blur and convert it to binary image.
    
    Args:
        image_path (str): Path to the input image.
        blur_ksize (tuple): Kernel size for the Gaussian blur (default is (5, 5)).
        
    Returns:
        gray_blurred (numpy array): Blurred grayscale version of the image.
        original_img (numpy array): Original color image.
        gray (numpy array): Grayscale version of the image.
        binary_img (numpy array): Binary version of the image
    """
    # Read the image.
    original_img = cv2.imread(image_path, cv2.IMREAD_COLOR)

    if original_img is None:
        raise ValueError(f"Image at {image_path} not found.")
    
    # Convert to grayscale.
    gray = cv2.cvtColor(original_img, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur.
    gray_blurred = cv2.GaussianBlur(gray, blur_ksize, 0)

    # Convert the original image to a binary image
    _, binary_img = cv2.threshold(gray_blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    return gray_blurred, original_img, gray, binary_img

# %%
# Preprocess the images
gray_blurred_s, original_img_s, gray_s, binary_img_s = preprocess_image('./Test/1_S.jpg')
gray_blurred_t, original_img_t, gray_t, binary_img_t = preprocess_image('./Test/1_T.jpg')
gray_blurred_k, original_img_k, gray_k, binary_img_k = preprocess_image('./Test/1_K.jpg')

questions = 50
options=4

# %% [markdown]
# ### 2. Circle Detection

# %%
def detect_circles(img, gray_blurred, questions, options):
    """
    Detect circles in the preprocessed grayscale image using the Hough Circle Transform.
    
    Args:
        img (numpy array): Original image for visualization.
        gray_blurred (numpy array): Blurred grayscale image.
        num_questions (int): Number of questions in the OMR.
        num_options (int): Number of options per question.
        dp (float): Inverse ratio of the accumulator resolution to the image resolution (default is 1).
        min_dist (int): Minimum distance between the centers of detected circles (default is 1).
        param1 (float): First method-specific parameter (gradient threshold for Canny edge detection).
        param2 (float): Second method-specific parameter (accumulator threshold for circle detection).
        min_radius_range (tuple): Tuple for minimum and maximum radius values for circle detection.
    
    Returns:
        detected_circles (numpy array): Array of detected circles, if found.
    """
    
    for b in range(20,10,-1): 
        for a in range(5,35):  
            detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, a, 
                            param1 = b,param2 = 3*b, minRadius = a//2, maxRadius = a) 
            if detected_circles is not None:
                detected_circles=np.uint16(np.around(detected_circles))
                print(f"circles:{detected_circles.shape[1]},a:{a},b:{b}")
                if detected_circles.shape[1]==questions*options:
                    for pt in detected_circles[0, :]: 
                        a, b, r = pt[0], pt[1], pt[2] 

                        # Draw the circumference of the circle. 
                        cv2.circle(img, (a, b), r, (0, 255, 0), 3) 

                        # Draw a small circle (of radius 1) to show the center. 
                        cv2.circle(img, (a, b), 2, (0, 0, 255), 3) 
                    cv2.imshow("Detected Circle", img) 
                    cv2.imwrite(f'./camera/detected_circles{a}b{b}.jpg', img)
                    cv2.waitKey(0) 
                    return detected_circles

    cv2.destroyAllWindows()
    return None

# %%
# Detect circles in the preprocessed image
detected_circles_s = detect_circles(
    original_img_s, gray_blurred_s, 
    questions, options, 
)
detected_circles_t = detect_circles(
    original_img_t, gray_blurred_t, 
    questions, options,
)

detected_circles_k = detect_circles(
    original_img_k, gray_blurred_k, 
    questions, options,
)
# Out:
# circles:1,a:25,b:14
# circles:1,a:26,b:14
# circles:1,a:27,b:14
# circles:1,a:29,b:14
# circles:1,a:8,b:13
# circles:1,a:17,b:13
# circles:1,a:23,b:13
# circles:1,a:25,b:13
# circles:1,a:26,b:13
# circles:1,a:27,b:13
# circles:3,a:28,b:13
# circles:4,a:29,b:13
# circles:1,a:8,b:12
# circles:2,a:17,b:12
# circles:1,a:19,b:12
# circles:1,a:22,b:12
# circles:3,a:23,b:12
# circles:5,a:24,b:12
# circles:6,a:25,b:12
# circles:6,a:26,b:12
# circles:8,a:27,b:12
# circles:9,a:28,b:12
# circles:14,a:29,b:12
# circles:1,a:8,b:11
# circles:3,a:15,b:11
# circles:2,a:16,b:11
# circles:10,a:17,b:11
# circles:8,a:18,b:11
# circles:11,a:19,b:11
# circles:8,a:20,b:11
# circles:9,a:21,b:11
# circles:7,a:22,b:11
# circles:17,a:23,b:11
# circles:12,a:24,b:11
# circles:17,a:25,b:11
# circles:20,a:26,b:11
# circles:37,a:27,b:11
# circles:39,a:28,b:11
# circles:66,a:29,b:11
# circles:1,a:8,b:10
# circles:4,a:9,b:10
# circles:1,a:10,b:10
# circles:1,a:12,b:10
# circles:5,a:14,b:10
# circles:16,a:15,b:10
# circles:20,a:16,b:10
# circles:43,a:17,b:10
# circles:38,a:18,b:10
# circles:49,a:19,b:10
# circles:34,a:20,b:10
# circles:52,a:21,b:10
# circles:49,a:22,b:10
# circles:77,a:23,b:10
# circles:67,a:24,b:10
# circles:94,a:25,b:10
# circles:81,a:26,b:10
# circles:104,a:27,b:10
# circles:112,a:28,b:10
# circles:131,a:29,b:10
# circles:2,a:8,b:9
# circles:8,a:9,b:9
# circles:4,a:10,b:9
# circles:8,a:11,b:9
# circles:3,a:12,b:9
# circles:10,a:13,b:9
# circles:22,a:14,b:9
# circles:55,a:15,b:9
# circles:70,a:16,b:9
# circles:98,a:17,b:9
# circles:96,a:18,b:9
# circles:105,a:19,b:9
# circles:97,a:20,b:9
# circles:120,a:21,b:9
# circles:121,a:22,b:9
# circles:137,a:23,b:9
# circles:139,a:24,b:9
# circles:161,a:25,b:9
# circles:158,a:26,b:9
# circles:172,a:27,b:9
# circles:178,a:28,b:9
# circles:187,a:29,b:9
# circles:1,a:7,b:8
# circles:7,a:8,b:8
# circles:11,a:9,b:8
# circles:14,a:10,b:8
# circles:23,a:11,b:8
# circles:18,a:12,b:8
# circles:44,a:13,b:8
# circles:87,a:14,b:8
# circles:133,a:15,b:8
# circles:138,a:16,b:8
# circles:159,a:17,b:8
# circles:151,a:18,b:8
# circles:170,a:19,b:8
# circles:159,a:20,b:8
# circles:177,a:21,b:8
# circles:175,a:22,b:8
# circles:194,a:23,b:8
# circles:188,a:24,b:8
# circles:201,a:25,b:8
# circles:200,a:26,b:8
# circles:1,a:28,b:14
# circles:3,a:29,b:14
# circles:1,a:24,b:13
# circles:3,a:25,b:13
# circles:4,a:26,b:13
# circles:4,a:27,b:13
# circles:4,a:28,b:13
# circles:4,a:29,b:13
# circles:1,a:12,b:12
# circles:1,a:13,b:12
# circles:1,a:17,b:12
# circles:1,a:19,b:12
# circles:1,a:20,b:12
# circles:3,a:21,b:12
# circles:3,a:23,b:12
# circles:7,a:24,b:12
# circles:7,a:25,b:12
# circles:9,a:26,b:12
# circles:13,a:27,b:12
# circles:13,a:28,b:12
# circles:21,a:29,b:12
# circles:1,a:12,b:11
# circles:2,a:13,b:11
# circles:1,a:14,b:11
# circles:1,a:15,b:11
# circles:2,a:16,b:11
# circles:7,a:17,b:11
# circles:6,a:18,b:11
# circles:14,a:19,b:11
# circles:9,a:20,b:11
# circles:15,a:21,b:11
# circles:16,a:22,b:11
# circles:28,a:23,b:11
# circles:26,a:24,b:11
# circles:38,a:25,b:11
# circles:40,a:26,b:11
# circles:51,a:27,b:11
# circles:48,a:28,b:11
# circles:66,a:29,b:11
# circles:2,a:8,b:10
# circles:4,a:10,b:10
# circles:3,a:11,b:10
# circles:2,a:12,b:10
# circles:3,a:13,b:10
# circles:4,a:14,b:10
# circles:10,a:15,b:10
# circles:12,a:16,b:10
# circles:33,a:17,b:10
# circles:35,a:18,b:10
# circles:51,a:19,b:10
# circles:42,a:20,b:10
# circles:61,a:21,b:10
# circles:57,a:22,b:10
# circles:77,a:23,b:10
# circles:74,a:24,b:10
# circles:97,a:25,b:10
# circles:95,a:26,b:10
# circles:123,a:27,b:10
# circles:130,a:28,b:10
# circles:152,a:29,b:10
# circles:3,a:8,b:9
# circles:1,a:9,b:9
# circles:8,a:10,b:9
# circles:8,a:11,b:9
# circles:7,a:12,b:9
# circles:14,a:13,b:9
# circles:26,a:14,b:9
# circles:56,a:15,b:9
# circles:78,a:16,b:9
# circles:112,a:17,b:9
# circles:102,a:18,b:9
# circles:127,a:19,b:9
# circles:115,a:20,b:9
# circles:146,a:21,b:9
# circles:128,a:22,b:9
# circles:161,a:23,b:9
# circles:155,a:24,b:9
# circles:185,a:25,b:9
# circles:179,a:26,b:9
# circles:194,a:27,b:9
# circles:193,a:28,b:9
# circles:205,a:29,b:9
# circles:2,a:7,b:8
# circles:5,a:8,b:8
# circles:6,a:9,b:8
# circles:16,a:10,b:8
# circles:25,a:11,b:8
# circles:27,a:12,b:8
# circles:66,a:13,b:8
# circles:106,a:14,b:8
# circles:161,a:15,b:8
# circles:169,a:16,b:8
# circles:204,a:17,b:8
# circles:193,a:18,b:8
# circles:206,a:19,b:8
# circles:196,a:20,b:8
# circles:214,a:21,b:8
# circles:202,a:22,b:8
# circles:222,a:23,b:8
# circles:216,a:24,b:8
# circles:235,a:25,b:8
# circles:223,a:26,b:8
# circles:245,a:27,b:8
# circles:240,a:28,b:8
# circles:275,a:29,b:8
# circles:5,a:7,b:7
# circles:22,a:8,b:7
# circles:30,a:9,b:7
# circles:49,a:10,b:7
# circles:82,a:11,b:7
# circles:112,a:12,b:7
# circles:195,a:13,b:7
# circles:221,a:14,b:7
# circles:249,a:15,b:7
# circles:237,a:16,b:7
# circles:246,a:17,b:7
# circles:237,a:18,b:7
# circles:258,a:19,b:7
# circles:249,a:20,b:7
# circles:290,a:21,b:7
# circles:285,a:22,b:7
# circles:318,a:23,b:7
# circles:309,a:24,b:7
# circles:360,a:25,b:7
# circles:353,a:26,b:7
# circles:418,a:27,b:7
# circles:402,a:28,b:7
# circles:453,a:29,b:7
# circles:14,a:7,b:6
# circles:50,a:8,b:6
# circles:84,a:9,b:6
# circles:136,a:10,b:6
# circles:206,a:11,b:6
# circles:266,a:12,b:6
# circles:356,a:13,b:6
# circles:323,a:14,b:6
# circles:357,a:15,b:6
# circles:328,a:16,b:6
# circles:382,a:17,b:6
# circles:371,a:18,b:6
# circles:492,a:19,b:6
# circles:465,a:20,b:6
# circles:586,a:21,b:6
# circles:530,a:22,b:6
# circles:621,a:23,b:6
# circles:596,a:24,b:6
# circles:665,a:25,b:6
# circles:637,a:26,b:6
# circles:668,a:27,b:6
# circles:639,a:28,b:6
# circles:650,a:29,b:6
# circles:1,a:23,b:14
# circles:1,a:24,b:14
# circles:1,a:25,b:14
# circles:1,a:19,b:13
# circles:2,a:22,b:13
# circles:2,a:23,b:13
# circles:1,a:24,b:13
# circles:2,a:25,b:13
# circles:1,a:26,b:13
# circles:2,a:27,b:13
# circles:1,a:28,b:13
# circles:4,a:29,b:13
# circles:1,a:15,b:12
# circles:1,a:16,b:12
# circles:2,a:17,b:12
# circles:2,a:19,b:12
# circles:1,a:20,b:12
# circles:3,a:22,b:12
# circles:4,a:23,b:12
# circles:3,a:24,b:12
# circles:6,a:25,b:12
# circles:5,a:26,b:12
# circles:5,a:27,b:12
# circles:10,a:28,b:12
# circles:13,a:29,b:12
# circles:1,a:13,b:11
# circles:2,a:14,b:11
# circles:4,a:15,b:11
# circles:4,a:16,b:11
# circles:9,a:17,b:11
# circles:7,a:18,b:11
# circles:10,a:19,b:11
# circles:9,a:20,b:11
# circles:14,a:21,b:11
# circles:10,a:22,b:11
# circles:17,a:23,b:11
# circles:16,a:24,b:11
# circles:23,a:25,b:11
# circles:19,a:26,b:11
# circles:31,a:27,b:11
# circles:29,a:28,b:11
# circles:39,a:29,b:11
# circles:2,a:10,b:10
# circles:2,a:11,b:10
# circles:1,a:12,b:10
# circles:2,a:13,b:10
# circles:4,a:14,b:10
# circles:12,a:15,b:10
# circles:17,a:16,b:10
# circles:38,a:17,b:10
# circles:33,a:18,b:10
# circles:44,a:19,b:10
# circles:38,a:20,b:10
# circles:51,a:21,b:10
# circles:41,a:22,b:10
# circles:57,a:23,b:10
# circles:50,a:24,b:10
# circles:70,a:25,b:10
# circles:67,a:26,b:10
# circles:95,a:27,b:10
# circles:97,a:28,b:10
# circles:118,a:29,b:10
# circles:1,a:8,b:9
# circles:2,a:9,b:9
# circles:4,a:10,b:9
# circles:5,a:11,b:9
# circles:6,a:12,b:9
# circles:10,a:13,b:9
# circles:21,a:14,b:9
# circles:51,a:15,b:9
# circles:72,a:16,b:9
# circles:93,a:17,b:9
# circles:97,a:18,b:9
# circles:106,a:19,b:9
# circles:90,a:20,b:9
# circles:110,a:21,b:9
# circles:98,a:22,b:9
# circles:131,a:23,b:9
# circles:120,a:24,b:9
# circles:144,a:25,b:9
# circles:145,a:26,b:9
# circles:160,a:27,b:9
# circles:164,a:28,b:9
# circles:186,a:29,b:9
# circles:2,a:7,b:8
# circles:5,a:8,b:8
# circles:8,a:9,b:8
# circles:15,a:10,b:8
# circles:26,a:11,b:8
# circles:22,a:12,b:8
# circles:49,a:13,b:8
# circles:71,a:14,b:8
# circles:124,a:15,b:8
# circles:137,a:16,b:8
# circles:159,a:17,b:8
# circles:146,a:18,b:8
# circles:170,a:19,b:8
# circles:160,a:20,b:8
# circles:172,a:21,b:8
# circles:168,a:22,b:8
# circles:188,a:23,b:8
# circles:182,a:24,b:8
# circles:200,a:25,b:8

# %% [markdown]
# ### 3. Pixel counts

# %%
import cv2
import numpy as np

def count_black_and_white_pixels(img, circles):
    """
    Count black and white pixels in the detected circles.

    Parameters:
    - img: The binary image (where black indicates marked areas).
    - circles: List of detected circles in the format (x, y, r).

    Returns:
    - A list of tuples containing counts of (black_pixels, white_pixels) for each circle.
    """
    counts = []

    for (x, y, r) in circles:
        # Create a mask for the current circle
        mask = np.zeros_like(img, dtype=np.uint8)
        cv2.circle(mask, (x, y), r, (255), thickness=-1)  # Fill the circle in the mask

        # Apply the mask to get the pixel values within the circle
        masked_area = cv2.bitwise_and(img, mask)

        # Count black and white pixels
        black_pixels = np.sum(masked_area == 0)   # Count of black pixels (0)
        white_pixels = np.sum(masked_area == 255) # Count of white pixels (255)

        counts.append((x,y,r,black_pixels, white_pixels))

    return counts

# %%
circles_s = detected_circles_s[0, :]
circles_t = detected_circles_t[0, :]  
circles_k = detected_circles_k[0, :]

# Count black and white pixels in the detected circles
pixel_counts_s = count_black_and_white_pixels(binary_img_s, circles_s)
pixel_counts_t = count_black_and_white_pixels(binary_img_t, circles_t)
pixel_counts_k = count_black_and_white_pixels(binary_img_k, circles_k)

# Print the results
# print("students answer sheet")
# for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_s, start=1):
#     print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")

# print("template")
# for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_t, start=1):
#     print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")

# print("key")
# for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_k, start=1):
#     print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")

# Display the binary image
#cv2.imshow("Binary Image", binary_img)

# Draw the circles on the binary image for visualization
for (x, y, r) in circles_s:
    cv2.circle(binary_img_s, (x, y), r, (127), 2)  # Draw circles in a different color (grey)
cv2.imshow("Detected Circles in Binary Image student", binary_img_s)
cv2.waitKey(0)


for (x, y, r) in circles_t:
    cv2.circle(binary_img_t, (x, y), r, (127), 2)  
cv2.imshow("Detected Circles in Binary Image template", binary_img_t)
cv2.waitKey(0)

for (x, y, r) in circles_k:
    cv2.circle(binary_img_k, (x, y), r, (127), 2)
cv2.imshow("Detected Circles in Binary Image key(scheme)", binary_img_k)
cv2.waitKey(0)




cv2.destroyAllWindows()

# %% [markdown]
# ### 4. Divide the circles by rows

# %% [markdown]
# #### method using tolerance

# %%
from collections import defaultdict
import numpy as np

def group_circles_by_rows(circles, percentage=0.5):
    # Sort circles by y-coordinate (vertical position)
    sorted_circles = sorted(circles, key=lambda x: x[1])

    # Calculate the average vertical distance between consecutive circles
    y_distances = [sorted_circles[i+1][1] - sorted_circles[i][1] for i in range(len(sorted_circles) - 1)]
    avg_distance = np.mean(y_distances)
    print(f"Average distance between circles: {avg_distance}")
    # Set the tolerance as a percentage of the average distance
    tolerance = percentage * avg_distance

    # Group circles into rows based on y-coordinate proximity
    grouped_by_rows = defaultdict(list)
    for circle in sorted_circles:
        x, y, r = circle[0], circle[1], circle[2]

        # Find the row where this circle belongs based on y-coordinate
        assigned = False
        for row_y in grouped_by_rows:
            if abs(row_y - y) < tolerance:
                grouped_by_rows[row_y].append((x, y, r))
                assigned = True
                break
        
        # If not assigned to any existing row, create a new row
        if not assigned:
            grouped_by_rows[y].append((x, y, r))

    # For each row, sort circles by x-coordinate (left to right)
    grouped_circles = []
    for row_y in sorted(grouped_by_rows.keys()):
        grouped_by_rows[row_y].sort(key=lambda c: c[0])  # Sort by x (horizontal position)
        grouped_circles.append(grouped_by_rows[row_y])

    return grouped_circles

# Example usage:
if pixel_counts is not None:
    #circles = detected_circles[0, :]  # Extract the circles from detected_circles
    
    # Group the circles by rows with a 50% tolerance of average row distance
    grouped_circles = group_circles_by_rows(pixel_counts, percentage=0.5)

    # For visualization
    question_num = 1
    for group in grouped_circles:
        print(f"Row No {question_num}:")
        for idx, (x, y, r) in enumerate(group, 1):
            print(f"circle {idx}: (x={x}, y={y}, r={r})")
            cv2.circle(original_img, (x, y), r, (0, 255, 0), 2)   # Draw the circle
            cv2.circle(original_img, (x, y), 2, (0, 0, 255), 3)   # Draw the center
        question_num += 1

    # Display the result
    cv2.imshow("Detected Circles", original_img)
    cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# Average distance between circles: 4.257028112449799
# Row No 1:
# circle 1: (x=642, y=286, r=11)
# circle 2: (x=704, y=286, r=11)
# circle 3: (x=764, y=286, r=14)
# Row No 2:
# circle 1: (x=466, y=288, r=11)
# circle 2: (x=822, y=288, r=14)
# Row No 3:
# circle 1: (x=226, y=290, r=14)
# circle 2: (x=286, y=290, r=11)
# circle 3: (x=340, y=290, r=14)
# circle 4: (x=408, y=290, r=13)
# circle 5: (x=882, y=290, r=14)
# Row No 4:
# circle 1: (x=642, y=328, r=14)
# circle 2: (x=704, y=328, r=14)
# circle 3: (x=764, y=328, r=14)
# circle 4: (x=824, y=328, r=14)
# Row No 5:
# circle 1: (x=224, y=330, r=14)
# circle 2: (x=346, y=330, r=11)
# circle 3: (x=406, y=330, r=14)
# circle 4: (x=468, y=330, r=14)
# circle 5: (x=884, y=330, r=14)
# Row No 6:
# circle 1: (x=286, y=332, r=14)
# Row No 7:
# circle 1: (x=704, y=368, r=14)
# circle 2: (x=766, y=368, r=14)
# circle 3: (x=826, y=368, r=12)
# Row No 8:
# circle 1: (x=468, y=370, r=14)
# circle 2: (x=644, y=370, r=14)
# circle 3: (x=886, y=370, r=14)
# Row No 9:
# circle 1: (x=226, y=372, r=13)
# circle 2: (x=284, y=372, r=14)
# circle 3: (x=346, y=372, r=14)
# circle 4: (x=406, y=372, r=14)
# Row No 10:
# circle 1: (x=706, y=410, r=14)
# circle 2: (x=766, y=410, r=14)
# circle 3: (x=828, y=410, r=14)
# Row No 11:
# circle 1: (x=406, y=412, r=14)
# circle 2: (x=466, y=412, r=14)
# circle 3: (x=644, y=412, r=12)
# circle 4: (x=888, y=412, r=12)
# Row No 12:
# circle 1: (x=220, y=414, r=13)
# circle 2: (x=282, y=414, r=14)
# circle 3: (x=344, y=414, r=14)
# Row No 13:
# circle 1: (x=768, y=452, r=14)
# circle 2: (x=828, y=452, r=14)
# Row No 14:
# circle 1: (x=406, y=454, r=14)
# circle 2: (x=466, y=454, r=14)
# circle 3: (x=644, y=454, r=14)
# circle 4: (x=706, y=454, r=14)
# circle 5: (x=890, y=454, r=14)
# Row No 15:
# circle 1: (x=220, y=456, r=14)
# circle 2: (x=282, y=456, r=14)
# circle 3: (x=344, y=456, r=14)
# Row No 16:
# circle 1: (x=706, y=494, r=11)
# circle 2: (x=768, y=494, r=14)
# circle 3: (x=830, y=494, r=14)
# Row No 17:
# circle 1: (x=220, y=496, r=14)
# circle 2: (x=282, y=496, r=14)
# circle 3: (x=466, y=496, r=14)
# circle 4: (x=644, y=496, r=14)
# circle 5: (x=890, y=496, r=14)
# Row No 18:
# circle 1: (x=342, y=498, r=13)
# circle 2: (x=404, y=498, r=14)
# Row No 19:
# circle 1: (x=708, y=536, r=14)
# circle 2: (x=770, y=536, r=14)
# circle 3: (x=830, y=536, r=14)
# Row No 20:
# circle 1: (x=218, y=538, r=14)
# circle 2: (x=466, y=538, r=14)
# circle 3: (x=646, y=538, r=14)
# circle 4: (x=892, y=538, r=14)
# Row No 21:
# circle 1: (x=282, y=540, r=14)
# circle 2: (x=344, y=540, r=14)
# circle 3: (x=406, y=540, r=14)
# Row No 22:
# circle 1: (x=708, y=578, r=12)
# Row No 23:
# circle 1: (x=466, y=580, r=14)
# circle 2: (x=646, y=580, r=14)
# circle 3: (x=770, y=580, r=14)
# circle 4: (x=832, y=580, r=14)
# circle 5: (x=892, y=580, r=14)
# Row No 24:
# circle 1: (x=218, y=582, r=14)
# circle 2: (x=280, y=582, r=14)
# circle 3: (x=342, y=582, r=14)
# circle 4: (x=404, y=582, r=14)
# Row No 25:
# circle 1: (x=708, y=622, r=14)
# circle 2: (x=770, y=622, r=14)
# Row No 26:
# circle 1: (x=340, y=624, r=14)
# circle 2: (x=404, y=624, r=14)
# circle 3: (x=466, y=624, r=14)
# circle 4: (x=646, y=624, r=14)
# circle 5: (x=832, y=624, r=14)
# circle 6: (x=894, y=624, r=14)
# Row No 27:
# circle 1: (x=216, y=626, r=14)
# circle 2: (x=278, y=626, r=14)
# Row No 28:
# circle 1: (x=646, y=666, r=12)
# circle 2: (x=708, y=666, r=14)
# circle 3: (x=772, y=666, r=14)
# Row No 29:
# circle 1: (x=214, y=668, r=14)
# circle 2: (x=278, y=668, r=14)
# circle 3: (x=340, y=668, r=14)
# circle 4: (x=402, y=668, r=12)
# circle 5: (x=466, y=668, r=12)
# circle 6: (x=834, y=668, r=14)
# circle 7: (x=896, y=668, r=13)
# Row No 30:
# circle 1: (x=646, y=710, r=14)
# circle 2: (x=710, y=710, r=14)
# circle 3: (x=772, y=710, r=12)
# Row No 31:
# circle 1: (x=212, y=712, r=13)
# circle 2: (x=274, y=712, r=12)
# circle 3: (x=338, y=712, r=13)
# circle 4: (x=402, y=712, r=12)
# circle 5: (x=464, y=712, r=12)
# circle 6: (x=836, y=712, r=14)
# circle 7: (x=898, y=712, r=13)
# Row No 32:
# circle 1: (x=648, y=754, r=13)
# circle 2: (x=710, y=754, r=14)
# circle 3: (x=774, y=754, r=13)
# Row No 33:
# circle 1: (x=274, y=756, r=12)
# circle 2: (x=340, y=756, r=14)
# circle 3: (x=402, y=756, r=14)
# circle 4: (x=466, y=756, r=12)
# circle 5: (x=838, y=756, r=14)
# circle 6: (x=900, y=756, r=14)
# Row No 34:
# circle 1: (x=210, y=758, r=12)
# Row No 35:
# circle 1: (x=466, y=800, r=12)
# circle 2: (x=648, y=800, r=12)
# circle 3: (x=712, y=800, r=12)
# circle 4: (x=774, y=800, r=12)
# circle 5: (x=838, y=800, r=12)
# circle 6: (x=902, y=800, r=12)
# Row No 36:
# circle 1: (x=210, y=802, r=12)
# circle 2: (x=274, y=802, r=13)
# circle 3: (x=338, y=802, r=13)
# circle 4: (x=402, y=802, r=13)
# Row No 37:
# circle 1: (x=710, y=844, r=14)
# Row No 38:
# circle 1: (x=402, y=846, r=12)
# circle 2: (x=466, y=846, r=12)
# circle 3: (x=648, y=846, r=13)
# circle 4: (x=776, y=846, r=12)
# circle 5: (x=840, y=846, r=12)
# circle 6: (x=904, y=846, r=14)
# Row No 39:
# circle 1: (x=208, y=848, r=14)
# circle 2: (x=274, y=848, r=13)
# circle 3: (x=336, y=848, r=14)
# Row No 40:
# circle 1: (x=648, y=890, r=13)
# circle 2: (x=712, y=890, r=12)
# circle 3: (x=776, y=890, r=12)
# Row No 41:
# circle 1: (x=274, y=892, r=12)
# circle 2: (x=336, y=892, r=14)
# circle 3: (x=402, y=892, r=13)
# circle 4: (x=466, y=892, r=13)
# circle 5: (x=840, y=892, r=13)
# circle 6: (x=908, y=892, r=14)
# Row No 42:
# circle 1: (x=210, y=894, r=12)
# Row No 43:
# circle 1: (x=714, y=936, r=12)
# circle 2: (x=776, y=936, r=12)
# Row No 44:
# circle 1: (x=210, y=938, r=12)
# circle 2: (x=272, y=938, r=12)
# circle 3: (x=336, y=938, r=14)
# circle 4: (x=402, y=938, r=13)
# circle 5: (x=466, y=938, r=12)
# circle 6: (x=648, y=938, r=13)
# circle 7: (x=840, y=938, r=13)
# circle 8: (x=906, y=938, r=14)
# Row No 45:
# circle 1: (x=778, y=980, r=14)
# Row No 46:
# circle 1: (x=274, y=982, r=12)
# circle 2: (x=338, y=982, r=14)
# circle 3: (x=402, y=982, r=14)
# circle 4: (x=466, y=982, r=13)
# circle 5: (x=648, y=982, r=14)
# circle 6: (x=712, y=982, r=14)
# circle 7: (x=844, y=982, r=13)
# circle 8: (x=908, y=982, r=14)
# Row No 47:
# circle 1: (x=208, y=984, r=13)
# Row No 48:
# circle 1: (x=464, y=1024, r=14)
# Row No 49:
# circle 1: (x=402, y=1026, r=14)
# circle 2: (x=650, y=1026, r=13)
# circle 3: (x=714, y=1026, r=13)
# circle 4: (x=910, y=1026, r=13)
# Row No 50:
# circle 1: (x=208, y=1028, r=12)
# circle 2: (x=272, y=1028, r=12)
# circle 3: (x=336, y=1028, r=12)
# circle 4: (x=780, y=1028, r=14)
# circle 5: (x=846, y=1028, r=14)
# Row No 51:
# circle 1: (x=648, y=1068, r=14)
# Row No 52:
# circle 1: (x=402, y=1070, r=14)
# circle 2: (x=466, y=1070, r=13)
# circle 3: (x=714, y=1070, r=13)
# circle 4: (x=780, y=1070, r=13)
# circle 5: (x=846, y=1070, r=13)
# circle 6: (x=908, y=1070, r=14)
# Row No 53:
# circle 1: (x=208, y=1072, r=14)
# circle 2: (x=334, y=1072, r=13)
# Row No 54:
# circle 1: (x=270, y=1074, r=14)
# Row No 55:
# circle 1: (x=650, y=1114, r=14)
# Row No 56:
# circle 1: (x=204, y=1116, r=14)
# circle 2: (x=270, y=1116, r=13)
# circle 3: (x=334, y=1116, r=14)
# circle 4: (x=400, y=1116, r=13)
# circle 5: (x=464, y=1116, r=13)
# circle 6: (x=716, y=1116, r=14)
# circle 7: (x=780, y=1116, r=13)
# circle 8: (x=846, y=1116, r=13)
# circle 9: (x=912, y=1116, r=14)
# Row No 57:
# circle 1: (x=334, y=1160, r=14)
# circle 2: (x=464, y=1160, r=14)
# circle 3: (x=716, y=1160, r=14)
# circle 4: (x=848, y=1160, r=14)
# Row No 58:
# circle 1: (x=204, y=1162, r=13)
# circle 2: (x=398, y=1162, r=14)
# circle 3: (x=650, y=1162, r=14)
# circle 4: (x=782, y=1162, r=13)
# circle 5: (x=912, y=1162, r=14)
# Row No 59:
# circle 1: (x=268, y=1164, r=14)
# Row No 60:
# circle 1: (x=464, y=1204, r=14)
# Row No 61:
# circle 1: (x=266, y=1206, r=14)
# circle 2: (x=652, y=1206, r=13)
# circle 3: (x=718, y=1206, r=13)
# circle 4: (x=782, y=1206, r=14)
# Row No 62:
# circle 1: (x=202, y=1208, r=13)
# circle 2: (x=332, y=1208, r=13)
# circle 3: (x=398, y=1208, r=14)
# Row No 63:
# circle 1: (x=850, y=1210, r=14)
# circle 2: (x=914, y=1210, r=14)
# Row No 64:
# circle 1: (x=268, y=1252, r=14)
# circle 2: (x=332, y=1252, r=14)
# circle 3: (x=396, y=1252, r=14)
# circle 4: (x=654, y=1252, r=14)
# circle 5: (x=716, y=1252, r=14)
# circle 6: (x=784, y=1252, r=14)
# Row No 65:
# circle 1: (x=200, y=1254, r=14)
# circle 2: (x=462, y=1254, r=14)
# circle 3: (x=850, y=1254, r=14)
# circle 4: (x=916, y=1254, r=13)
# Row No 66:
# circle 1: (x=462, y=1296, r=14)
# circle 2: (x=652, y=1296, r=14)
# Row No 67:
# circle 1: (x=200, y=1298, r=13)
# circle 2: (x=264, y=1298, r=14)
# circle 3: (x=332, y=1298, r=13)
# circle 4: (x=398, y=1298, r=13)
# circle 5: (x=718, y=1298, r=13)
# circle 6: (x=784, y=1298, r=14)
# circle 7: (x=918, y=1298, r=14)
# Row No 68:
# circle 1: (x=850, y=1300, r=14)
# Row No 69:
# circle 1: (x=462, y=1342, r=14)
# Row No 70:
# circle 1: (x=202, y=1344, r=14)
# circle 2: (x=652, y=1344, r=14)
# circle 3: (x=720, y=1344, r=14)
# circle 4: (x=784, y=1344, r=14)
# circle 5: (x=916, y=1344, r=14)
# Row No 71:
# circle 1: (x=264, y=1346, r=14)
# circle 2: (x=332, y=1346, r=14)
# circle 3: (x=398, y=1346, r=14)
# circle 4: (x=852, y=1346, r=13)
# C:\Users\User\AppData\Local\Temp\ipykernel_16536\1782284691.py:23: RuntimeWarning: overflow encountered in scalar subtract
#   if abs(row_y - y) < tolerance:

# %% [markdown]
# #### Using clustering method DBSCAN

# %%
import numpy as np
from sklearn.cluster import DBSCAN


# Function to group circles by rows using DBSCAN (y-coordinate clustering)
def group_by_row_dbscan(pixel_counts, eps=10):
    # Extract the y-coordinates of circles from the pixel_counts
    y_coords = np.array([[y] for (x, y, r, black_count, white_count) in pixel_counts])
    
    # Apply DBSCAN clustering based on y-coordinates
    clustering = DBSCAN(eps=eps, min_samples=1).fit(y_coords)
    
    # Get cluster labels
    labels = clustering.labels_

    # Group circles by the row labels
    rows = {}
    for label, circle_data in zip(labels, pixel_counts):
        if label not in rows:
            rows[label] = []
        rows[label].append(circle_data)

    sorted_rows = sorted(rows.values(), key=lambda row: np.mean([c[1] for c in row]))
    sorted_rows = [sorted(row, key=lambda c: c[0]) for row in sorted_rows]
    
    return sorted_rows

# %%
# Group the circles by rows using the group_by_row_dbscan function
grouped_rows_s = group_by_row_dbscan(pixel_counts_s, eps=10)

# Print the grouped results
for row_idx, row in enumerate(grouped_rows_s, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, black_count, white_count) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")
# Out:
# Row 1:
#   Circle 1: Coordinates = (102, 188), Black Pixels = 1868015, White Pixels = 1953
#   Circle 2: Coordinates = (172, 188), Black Pixels = 1868128, White Pixels = 1840
#   Circle 3: Coordinates = (234, 188), Black Pixels = 1869829, White Pixels = 139
#   Circle 4: Coordinates = (300, 188), Black Pixels = 1868069, White Pixels = 1899
#   Circle 5: Coordinates = (472, 190), Black Pixels = 1868025, White Pixels = 1943
#   Circle 6: Coordinates = (536, 188), Black Pixels = 1868248, White Pixels = 1720
#   Circle 7: Coordinates = (600, 188), Black Pixels = 1868114, White Pixels = 1854
#   Circle 8: Coordinates = (664, 188), Black Pixels = 1869947, White Pixels = 21
#   Circle 5: Coordinates = (528, 1418), Black Pixels = 1953232, White Pixels = 1968
#   Circle 6: Coordinates = (592, 1420), Black Pixels = 1953300, White Pixels = 1900
#   Circle 7: Coordinates = (664, 1422), Black Pixels = 1955118, White Pixels = 82
#   Circle 8: Coordinates = (728, 1420), Black Pixels = 1953257, White Pixels = 1943
#   Circle 9: Coordinates = (908, 1424), Black Pixels = 1953190, White Pixels = 2010
#   Circle 10: Coordinates = (976, 1424), Black Pixels = 1953240, White Pixels = 1960
#   Circle 11: Coordinates = (1046, 1426), Black Pixels = 1953115, White Pixels = 2085
# Row 18:
#   Circle 1: Coordinates = (144, 1502), Black Pixels = 1955158, White Pixels = 42
#   Circle 2: Coordinates = (212, 1504), Black Pixels = 1953377, White Pixels = 1823
#   Circle 3: Coordinates = (280, 1506), Black Pixels = 1953280, White Pixels = 1920
#   Circle 4: Coordinates = (344, 1506), Black Pixels = 1953304, White Pixels = 1896
#   Circle 5: Coordinates = (526, 1504), Black Pixels = 1953264, White Pixels = 1936
#   Circle 6: Coordinates = (596, 1506), Black Pixels = 1955061, White Pixels = 139
#   Circle 7: Coordinates = (662, 1508), Black Pixels = 1953221, White Pixels = 1979
#   Circle 8: Coordinates = (730, 1508), Black Pixels = 1953229, White Pixels = 1971

# %% [markdown]
# ### 5. Idendifying Marked and unmarked bubbles

# %%
def subtract_grouped_rows(grouped_rows_s, grouped_rows_t):
    """
    Subtract the black and white pixel values of grouped_rows_t from grouped_rows_s.

    Args:
        grouped_rows_s (list): List of grouped circles with pixel counts for the student's answer sheet.
        grouped_rows_t (list): List of grouped circles with pixel counts for the template.

    Returns:
        list: List of grouped circles with subtracted pixel counts.
    """
    subtracted_rows = []

    for row_s, row_t in zip(grouped_rows_s, grouped_rows_t):
        subtracted_row = []
        for (x_s, y_s, r_s, black_s, white_s), (x_t, y_t, r_t, black_t, white_t) in zip(row_s, row_t):
            subtracted_black = black_s - black_t
            subtracted_white = white_s - white_t
            subtracted_row.append((x_s, y_s, r_s, subtracted_black, subtracted_white))
        subtracted_rows.append(subtracted_row)

    return subtracted_rows

# Subtract the grouped rows
subtracted_grouped_rows = subtract_grouped_rows(grouped_rows_t, grouped_rows_s)

# Print the results
for row_idx, row in enumerate(subtracted_grouped_rows, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, subtracted_black, subtracted_white) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Subtracted Black Pixels = {subtracted_black}, Subtracted White Pixels = {subtracted_white}")
# Out:
# Row 1:
#   Circle 1: Coordinates = (146, 164), Subtracted Black Pixels = 8368, Subtracted White Pixels = -363
#   Circle 2: Coordinates = (208, 164), Subtracted Black Pixels = 8183, Subtracted White Pixels = -178
#   Circle 3: Coordinates = (268, 164), Subtracted Black Pixels = 6476, Subtracted White Pixels = 1529
#   Circle 4: Coordinates = (334, 162), Subtracted Black Pixels = 8344, Subtracted White Pixels = -339
#   Circle 5: Coordinates = (502, 160), Subtracted Black Pixels = 8219, Subtracted White Pixels = -214
#   Circle 6: Coordinates = (566, 160), Subtracted Black Pixels = 8129, Subtracted White Pixels = -124
#   Circle 7: Coordinates = (628, 158), Subtracted Black Pixels = 8162, Subtracted White Pixels = -157
#   Circle 8: Coordinates = (690, 158), Subtracted Black Pixels = 6349, Subtracted White Pixels = 1656
#   Circle 9: Coordinates = (858, 156), Subtracted Black Pixels = 8194, Subtracted White Pixels = -189
#   Circle 10: Coordinates = (922, 156), Subtracted Black Pixels = 8096, Subtracted White Pixels = -91
#   Circle 11: Coordinates = (984, 152), Subtracted Black Pixels = 6573, Subtracted White Pixels = 1432
#   Circle 12: Coordinates = (1048, 152), Subtracted Black Pixels = 8120, Subtracted White Pixels = -115
# Row 2:
#   Circle 1: Coordinates = (144, 244), Subtracted Black Pixels = 8246, Subtracted White Pixels = -241
#   Circle 2: Coordinates = (208, 242), Subtracted Black Pixels = 6416, Subtracted White Pixels = 1589
#   Circle 3: Coordinates = (270, 242), Subtracted Black Pixels = 8354, Subtracted White Pixels = -349
#   Circle 4: Coordinates = (332, 240), Subtracted Black Pixels = 8204, Subtracted White Pixels = -199
#   Circle 5: Coordinates = (502, 240), Subtracted Black Pixels = 8063, Subtracted White Pixels = -58
#   Circle 6: Coordinates = (566, 238), Subtracted Black Pixels = 8041, Subtracted White Pixels = -36
#   Circle 7: Coordinates = (628, 236), Subtracted Black Pixels = 8024, Subtracted White Pixels = -19
#   Circle 8: Coordinates = (690, 236), Subtracted Black Pixels = 6299, Subtracted White Pixels = 1706
#   Circle 9: Coordinates = (860, 236), Subtracted Black Pixels = 6683, Subtracted White Pixels = 1322
#   Circle 10: Coordinates = (922, 234), Subtracted Black Pixels = 7945, Subtracted White Pixels = 60
#   Circle 11: Coordinates = (986, 234), Subtracted Black Pixels = 8219, Subtracted White Pixels = -214
#   Circle 12: Coordinates = (1048, 232), Subtracted Black Pixels = 8089, Subtracted White Pixels = -84
# Row 3:
#   Circle 1: Coordinates = (142, 320), Subtracted Black Pixels = 8320, Subtracted White Pixels = -315
#   Circle 2: Coordinates = (204, 322), Subtracted Black Pixels = 8379, Subtracted White Pixels = -374
#   Circle 3: Coordinates = (266, 320), Subtracted Black Pixels = 8188, Subtracted White Pixels = -183
#   Circle 4: Coordinates = (332, 320), Subtracted Black Pixels = 6376, Subtracted White Pixels = 1629
#   Circle 5: Coordinates = (502, 318), Subtracted Black Pixels = 8125, Subtracted White Pixels = -120
#   Circle 6: Coordinates = (566, 318), Subtracted Black Pixels = 6568, Subtracted White Pixels = 1437
#   Circle 7: Coordinates = (628, 316), Subtracted Black Pixels = 8040, Subtracted White Pixels = -35
#   Circle 8: Coordinates = (692, 316), Subtracted Black Pixels = 8412, Subtracted White Pixels = -407
#   Circle 9: Coordinates = (860, 316), Subtracted Black Pixels = 8109, Subtracted White Pixels = -104
#   Circle 10: Coordinates = (926, 314), Subtracted Black Pixels = 8086, Subtracted White Pixels = -81
#   Circle 11: Coordinates = (988, 312), Subtracted Black Pixels = 8092, Subtracted White Pixels = -87
#   Circle 12: Coordinates = (1050, 312), Subtracted Black Pixels = 6490, Subtracted White Pixels = 1515
# Row 4:
#   Circle 1: Coordinates = (142, 402), Subtracted Black Pixels = 6322, Subtracted White Pixels = 1683
#   Circle 2: Coordinates = (204, 400), Subtracted Black Pixels = 8208, Subtracted White Pixels = -203
#   Circle 3: Coordinates = (268, 400), Subtracted Black Pixels = 8343, Subtracted White Pixels = -338
#   Circle 4: Coordinates = (332, 400), Subtracted Black Pixels = 8228, Subtracted White Pixels = -223
#   Circle 5: Coordinates = (504, 398), Subtracted Black Pixels = 8323, Subtracted White Pixels = -318
#   Circle 6: Coordinates = (566, 398), Subtracted Black Pixels = 6564, Subtracted White Pixels = 1441
#   Circle 7: Coordinates = (630, 398), Subtracted Black Pixels = 8328, Subtracted White Pixels = -323
#   Circle 8: Coordinates = (692, 396), Subtracted Black Pixels = 8169, Subtracted White Pixels = -164
#   Circle 9: Coordinates = (862, 394), Subtracted Black Pixels = 6495, Subtracted White Pixels = 1510
#   Circle 10: Coordinates = (926, 394), Subtracted Black Pixels = 8128, Subtracted White Pixels = -123
#   Circle 11: Coordinates = (988, 392), Subtracted Black Pixels = 8152, Subtracted White Pixels = -147
#   Circle 12: Coordinates = (1050, 392), Subtracted Black Pixels = 8111, Subtracted White Pixels = -106
# Row 5:
#   Circle 1: Coordinates = (140, 480), Subtracted Black Pixels = 6533, Subtracted White Pixels = 1472
#   Circle 2: Coordinates = (204, 480), Subtracted Black Pixels = 8254, Subtracted White Pixels = -249
#   Circle 3: Coordinates = (268, 480), Subtracted Black Pixels = 8353, Subtracted White Pixels = -348
#   Circle 4: Coordinates = (330, 480), Subtracted Black Pixels = 8159, Subtracted White Pixels = -154
#   Circle 5: Coordinates = (504, 478), Subtracted Black Pixels = 8148, Subtracted White Pixels = -143
#   Circle 6: Coordinates = (566, 478), Subtracted Black Pixels = 8328, Subtracted White Pixels = -323
#   Circle 7: Coordinates = (630, 478), Subtracted Black Pixels = 6511, Subtracted White Pixels = 1494
#   Circle 8: Coordinates = (692, 476), Subtracted Black Pixels = 8331, Subtracted White Pixels = -326
#   Circle 9: Coordinates = (864, 476), Subtracted Black Pixels = 8231, Subtracted White Pixels = -226
#   Circle 10: Coordinates = (928, 474), Subtracted Black Pixels = 6629, Subtracted White Pixels = 1376
#   Circle 11: Coordinates = (990, 474), Subtracted Black Pixels = 8144, Subtracted White Pixels = -139
#   Circle 12: Coordinates = (1054, 472), Subtracted Black Pixels = 8154, Subtracted White Pixels = -149
# Row 6:
#   Circle 1: Coordinates = (140, 562), Subtracted Black Pixels = 6276, Subtracted White Pixels = 1729
#   Circle 2: Coordinates = (204, 560), Subtracted Black Pixels = 8212, Subtracted White Pixels = -207
#   Circle 3: Coordinates = (266, 560), Subtracted Black Pixels = 8188, Subtracted White Pixels = -183
#   Circle 4: Coordinates = (330, 560), Subtracted Black Pixels = 8159, Subtracted White Pixels = -154
#   Circle 5: Coordinates = (504, 560), Subtracted Black Pixels = 6394, Subtracted White Pixels = 1611
#   Circle 6: Coordinates = (568, 558), Subtracted Black Pixels = 8245, Subtracted White Pixels = -240
#   Circle 7: Coordinates = (630, 560), Subtracted Black Pixels = 8324, Subtracted White Pixels = -319
#   Circle 8: Coordinates = (692, 560), Subtracted Black Pixels = 8254, Subtracted White Pixels = -249
#   Circle 9: Coordinates = (864, 556), Subtracted Black Pixels = 8140, Subtracted White Pixels = -135
#   Circle 10: Coordinates = (926, 556), Subtracted Black Pixels = 8269, Subtracted White Pixels = -264
#   Circle 11: Coordinates = (992, 554), Subtracted Black Pixels = 8320, Subtracted White Pixels = -315
#   Circle 12: Coordinates = (1054, 554), Subtracted Black Pixels = 6549, Subtracted White Pixels = 1456
# Row 7:
#   Circle 1: Coordinates = (138, 642), Subtracted Black Pixels = 8081, Subtracted White Pixels = -76
#   Circle 2: Coordinates = (206, 642), Subtracted Black Pixels = 8210, Subtracted White Pixels = -205
#   Circle 3: Coordinates = (268, 642), Subtracted Black Pixels = 6352, Subtracted White Pixels = 1653
#   Circle 4: Coordinates = (332, 642), Subtracted Black Pixels = 8213, Subtracted White Pixels = -208
#   Circle 5: Coordinates = (504, 640), Subtracted Black Pixels = 8197, Subtracted White Pixels = -192
#   Circle 6: Coordinates = (568, 640), Subtracted Black Pixels = 8238, Subtracted White Pixels = -233
#   Circle 7: Coordinates = (630, 640), Subtracted Black Pixels = 8218, Subtracted White Pixels = -213
#   Circle 8: Coordinates = (694, 640), Subtracted Black Pixels = 6527, Subtracted White Pixels = 1478
#   Circle 9: Coordinates = (862, 638), Subtracted Black Pixels = 6576, Subtracted White Pixels = 1429
#   Circle 10: Coordinates = (926, 638), Subtracted Black Pixels = 8218, Subtracted White Pixels = -213
#   Circle 11: Coordinates = (994, 636), Subtracted Black Pixels = 8137, Subtracted White Pixels = -132
#   Circle 12: Coordinates = (1056, 634), Subtracted Black Pixels = 8155, Subtracted White Pixels = -150
# Row 8:
#   Circle 1: Coordinates = (142, 726), Subtracted Black Pixels = 8141, Subtracted White Pixels = -136
#   Circle 2: Coordinates = (204, 724), Subtracted Black Pixels = 6413, Subtracted White Pixels = 1592
#   Circle 3: Coordinates = (268, 724), Subtracted Black Pixels = 8223, Subtracted White Pixels = -218
#   Circle 4: Coordinates = (334, 724), Subtracted Black Pixels = 8255, Subtracted White Pixels = -250
#   Circle 5: Coordinates = (504, 722), Subtracted Black Pixels = 8164, Subtracted White Pixels = -159
#   Circle 6: Coordinates = (570, 722), Subtracted Black Pixels = 6477, Subtracted White Pixels = 1528
#   Circle 7: Coordinates = (630, 722), Subtracted Black Pixels = 8115, Subtracted White Pixels = -110
#   Circle 8: Coordinates = (694, 720), Subtracted Black Pixels = 8239, Subtracted White Pixels = -234
#   Circle 9: Coordinates = (864, 718), Subtracted Black Pixels = 8125, Subtracted White Pixels = -120
#   Circle 10: Coordinates = (928, 718), Subtracted Black Pixels = 6598, Subtracted White Pixels = 1407
#   Circle 11: Coordinates = (992, 718), Subtracted Black Pixels = 8236, Subtracted White Pixels = -231
#   Circle 12: Coordinates = (1056, 716), Subtracted Black Pixels = 8176, Subtracted White Pixels = -171
# Row 9:
#   Circle 1: Coordinates = (142, 806), Subtracted Black Pixels = 8130, Subtracted White Pixels = -125
#   Circle 2: Coordinates = (204, 806), Subtracted Black Pixels = 8146, Subtracted White Pixels = -141
#   Circle 3: Coordinates = (272, 804), Subtracted Black Pixels = 6255, Subtracted White Pixels = 1750
#   Circle 4: Coordinates = (332, 804), Subtracted Black Pixels = 8097, Subtracted White Pixels = -92
#   Circle 5: Coordinates = (506, 804), Subtracted Black Pixels = 6524, Subtracted White Pixels = 1481
#   Circle 6: Coordinates = (570, 802), Subtracted Black Pixels = 8146, Subtracted White Pixels = -141
#   Circle 7: Coordinates = (632, 802), Subtracted Black Pixels = 8199, Subtracted White Pixels = -194
#   Circle 8: Coordinates = (694, 802), Subtracted Black Pixels = 8134, Subtracted White Pixels = -129
#   Circle 9: Coordinates = (864, 800), Subtracted Black Pixels = 6404, Subtracted White Pixels = 1601
#   Circle 10: Coordinates = (928, 798), Subtracted Black Pixels = 8190, Subtracted White Pixels = -185
#   Circle 11: Coordinates = (992, 798), Subtracted Black Pixels = 8230, Subtracted White Pixels = -225
#   Circle 12: Coordinates = (1058, 798), Subtracted Black Pixels = 8222, Subtracted White Pixels = -217
# Row 10:
#   Circle 1: Coordinates = (134, 890), Subtracted Black Pixels = 6220, Subtracted White Pixels = 1785
#   Circle 2: Coordinates = (200, 886), Subtracted Black Pixels = 8155, Subtracted White Pixels = -150
#   Circle 3: Coordinates = (264, 888), Subtracted Black Pixels = 8151, Subtracted White Pixels = -146
#   Circle 4: Coordinates = (334, 886), Subtracted Black Pixels = 8130, Subtracted White Pixels = -125
#   Circle 5: Coordinates = (506, 884), Subtracted Black Pixels = 8142, Subtracted White Pixels = -137
#   Circle 6: Coordinates = (570, 882), Subtracted Black Pixels = 8014, Subtracted White Pixels = -9
#   Circle 7: Coordinates = (632, 882), Subtracted Black Pixels = 6520, Subtracted White Pixels = 1485
#   Circle 8: Coordinates = (694, 884), Subtracted Black Pixels = 8085, Subtracted White Pixels = -80
#   Circle 9: Coordinates = (868, 882), Subtracted Black Pixels = 8111, Subtracted White Pixels = -106
#   Circle 10: Coordinates = (930, 882), Subtracted Black Pixels = 6460, Subtracted White Pixels = 1545
#   Circle 11: Coordinates = (996, 880), Subtracted Black Pixels = 8187, Subtracted White Pixels = -182
#   Circle 12: Coordinates = (1062, 882), Subtracted Black Pixels = 8183, Subtracted White Pixels = -178
# Row 11:
#   Circle 1: Coordinates = (134, 970), Subtracted Black Pixels = 8122, Subtracted White Pixels = -117
#   Circle 2: Coordinates = (198, 974), Subtracted Black Pixels = 8155, Subtracted White Pixels = -150
#   Circle 3: Coordinates = (266, 972), Subtracted Black Pixels = 8157, Subtracted White Pixels = -152
#   Circle 4: Coordinates = (332, 970), Subtracted Black Pixels = 6315, Subtracted White Pixels = 1690
#   Circle 5: Coordinates = (506, 966), Subtracted Black Pixels = 8224, Subtracted White Pixels = -219
#   Circle 6: Coordinates = (570, 966), Subtracted Black Pixels = 6453, Subtracted White Pixels = 1552
#   Circle 7: Coordinates = (632, 968), Subtracted Black Pixels = 8138, Subtracted White Pixels = -133
#   Circle 8: Coordinates = (694, 966), Subtracted Black Pixels = 8218, Subtracted White Pixels = -213
#   Circle 9: Coordinates = (870, 964), Subtracted Black Pixels = 8090, Subtracted White Pixels = -85
#   Circle 10: Coordinates = (932, 962), Subtracted Black Pixels = 6461, Subtracted White Pixels = 1544
#   Circle 11: Coordinates = (996, 962), Subtracted Black Pixels = 8163, Subtracted White Pixels = -158
#   Circle 12: Coordinates = (1058, 962), Subtracted Black Pixels = 8085, Subtracted White Pixels = -80
# Row 12:
#   Circle 1: Coordinates = (130, 1056), Subtracted Black Pixels = 8201, Subtracted White Pixels = -196
#   Circle 2: Coordinates = (194, 1056), Subtracted Black Pixels = 6335, Subtracted White Pixels = 1670
#   Circle 3: Coordinates = (260, 1054), Subtracted Black Pixels = 8118, Subtracted White Pixels = -113
#   Circle 4: Coordinates = (328, 1052), Subtracted Black Pixels = 8128, Subtracted White Pixels = -123
#   Circle 5: Coordinates = (504, 1050), Subtracted Black Pixels = 6404, Subtracted White Pixels = 1601
#   Circle 6: Coordinates = (568, 1048), Subtracted Black Pixels = 8170, Subtracted White Pixels = -165
#   Circle 7: Coordinates = (634, 1048), Subtracted Black Pixels = 8246, Subtracted White Pixels = -241
#   Circle 8: Coordinates = (698, 1048), Subtracted Black Pixels = 8251, Subtracted White Pixels = -246
#   Circle 9: Coordinates = (872, 1050), Subtracted Black Pixels = 8127, Subtracted White Pixels = -122
#   Circle 10: Coordinates = (934, 1046), Subtracted Black Pixels = 8236, Subtracted White Pixels = -231
#   Circle 11: Coordinates = (998, 1048), Subtracted Black Pixels = 6405, Subtracted White Pixels = 1600
#   Circle 12: Coordinates = (1062, 1046), Subtracted Black Pixels = 8140, Subtracted White Pixels = -135
# Row 13:
#   Circle 1: Coordinates = (130, 1140), Subtracted Black Pixels = 8015, Subtracted White Pixels = -10
#   Circle 2: Coordinates = (196, 1140), Subtracted Black Pixels = 8175, Subtracted White Pixels = -170
#   Circle 3: Coordinates = (260, 1140), Subtracted Black Pixels = 6333, Subtracted White Pixels = 1672
#   Circle 4: Coordinates = (328, 1138), Subtracted Black Pixels = 8190, Subtracted White Pixels = -185
#   Circle 5: Coordinates = (504, 1136), Subtracted Black Pixels = 8218, Subtracted White Pixels = -213
#   Circle 6: Coordinates = (570, 1136), Subtracted Black Pixels = 8219, Subtracted White Pixels = -214
#   Circle 7: Coordinates = (634, 1136), Subtracted Black Pixels = 6345, Subtracted White Pixels = 1660
#   Circle 8: Coordinates = (698, 1132), Subtracted Black Pixels = 8211, Subtracted White Pixels = -206
#   Circle 9: Coordinates = (870, 1130), Subtracted Black Pixels = 6480, Subtracted White Pixels = 1525
#   Circle 10: Coordinates = (934, 1130), Subtracted Black Pixels = 8254, Subtracted White Pixels = -249
#   Circle 11: Coordinates = (998, 1130), Subtracted Black Pixels = 8184, Subtracted White Pixels = -179
#   Circle 12: Coordinates = (1064, 1130), Subtracted Black Pixels = 8144, Subtracted White Pixels = -139
# Row 14:
#   Circle 1: Coordinates = (132, 1224), Subtracted Black Pixels = 8045, Subtracted White Pixels = -40
#   Circle 2: Coordinates = (200, 1224), Subtracted Black Pixels = 6383, Subtracted White Pixels = 1622
#   Circle 3: Coordinates = (262, 1224), Subtracted Black Pixels = 8271, Subtracted White Pixels = -266
#   Circle 4: Coordinates = (328, 1222), Subtracted Black Pixels = 8231, Subtracted White Pixels = -226
#   Circle 5: Coordinates = (502, 1220), Subtracted Black Pixels = 8110, Subtracted White Pixels = -105
#   Circle 6: Coordinates = (568, 1220), Subtracted Black Pixels = 6366, Subtracted White Pixels = 1639
#   Circle 7: Coordinates = (634, 1218), Subtracted Black Pixels = 8164, Subtracted White Pixels = -159
#   Circle 8: Coordinates = (700, 1216), Subtracted Black Pixels = 8160, Subtracted White Pixels = -155
#   Circle 9: Coordinates = (872, 1216), Subtracted Black Pixels = 8127, Subtracted White Pixels = -122
#   Circle 10: Coordinates = (936, 1216), Subtracted Black Pixels = 8204, Subtracted White Pixels = -199
#   Circle 11: Coordinates = (1002, 1214), Subtracted Black Pixels = 8102, Subtracted White Pixels = -97
#   Circle 12: Coordinates = (1066, 1214), Subtracted Black Pixels = 6418, Subtracted White Pixels = 1587
# Row 15:
#   Circle 1: Coordinates = (130, 1308), Subtracted Black Pixels = 6299, Subtracted White Pixels = 1706
#   Circle 2: Coordinates = (200, 1306), Subtracted Black Pixels = 8148, Subtracted White Pixels = -143
#   Circle 3: Coordinates = (262, 1306), Subtracted Black Pixels = 8172, Subtracted White Pixels = -167
#   Circle 4: Coordinates = (328, 1306), Subtracted Black Pixels = 8197, Subtracted White Pixels = -192
#   Circle 5: Coordinates = (504, 1304), Subtracted Black Pixels = 6297, Subtracted White Pixels = 1708
#   Circle 6: Coordinates = (570, 1304), Subtracted Black Pixels = 8166, Subtracted White Pixels = -161
#   Circle 7: Coordinates = (634, 1302), Subtracted Black Pixels = 8121, Subtracted White Pixels = -116
#   Circle 8: Coordinates = (698, 1304), Subtracted Black Pixels = 8114, Subtracted White Pixels = -109
#   Circle 9: Coordinates = (872, 1298), Subtracted Black Pixels = 8012, Subtracted White Pixels = -7
#   Circle 10: Coordinates = (936, 1302), Subtracted Black Pixels = 6407, Subtracted White Pixels = 1598
#   Circle 11: Coordinates = (1004, 1300), Subtracted Black Pixels = 8121, Subtracted White Pixels = -116
#   Circle 12: Coordinates = (1066, 1300), Subtracted Black Pixels = 8134, Subtracted White Pixels = -129
# Row 16:
#   Circle 1: Coordinates = (132, 1390), Subtracted Black Pixels = 8237, Subtracted White Pixels = -232
#   Circle 2: Coordinates = (196, 1390), Subtracted Black Pixels = 8169, Subtracted White Pixels = -164
#   Circle 3: Coordinates = (262, 1390), Subtracted Black Pixels = 8014, Subtracted White Pixels = -9
#   Circle 4: Coordinates = (330, 1392), Subtracted Black Pixels = 6338, Subtracted White Pixels = 1667
#   Circle 5: Coordinates = (502, 1392), Subtracted Black Pixels = 8118, Subtracted White Pixels = -113
#   Circle 6: Coordinates = (570, 1388), Subtracted Black Pixels = 8115, Subtracted White Pixels = -110
#   Circle 7: Coordinates = (634, 1388), Subtracted Black Pixels = 6282, Subtracted White Pixels = 1723
#   Circle 8: Coordinates = (700, 1386), Subtracted Black Pixels = 8079, Subtracted White Pixels = -74
#   Circle 9: Coordinates = (874, 1388), Subtracted Black Pixels = 8075, Subtracted White Pixels = -70
#   Circle 10: Coordinates = (940, 1384), Subtracted Black Pixels = 8098, Subtracted White Pixels = -93
#   Circle 11: Coordinates = (1004, 1386), Subtracted Black Pixels = 8101, Subtracted White Pixels = -96
#   Circle 12: Coordinates = (1070, 1384), Subtracted Black Pixels = 6306, Subtracted White Pixels = 1699
# Row 17:
#   Circle 1: Coordinates = (132, 1478), Subtracted Black Pixels = 6270, Subtracted White Pixels = 1735
#   Circle 2: Coordinates = (198, 1478), Subtracted Black Pixels = 8218, Subtracted White Pixels = -213
#   Circle 3: Coordinates = (262, 1474), Subtracted Black Pixels = 8072, Subtracted White Pixels = -67
#   Circle 4: Coordinates = (326, 1476), Subtracted Black Pixels = 8149, Subtracted White Pixels = -144
#   Circle 5: Coordinates = (506, 1474), Subtracted Black Pixels = 8132, Subtracted White Pixels = -127
#   Circle 6: Coordinates = (568, 1474), Subtracted Black Pixels = 6385, Subtracted White Pixels = 1620
#   Circle 7: Coordinates = (638, 1474), Subtracted Black Pixels = 8116, Subtracted White Pixels = -111
#   Circle 8: Coordinates = (698, 1474), Subtracted Black Pixels = 8137, Subtracted White Pixels = -132

# %%
subtract_grouped_rows_key = subtract_grouped_rows(grouped_rows_t,grouped_rows_k)
for row_idx, row in enumerate(subtract_grouped_rows_key, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, subtracted_black, subtracted_white) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Subtracted Black Pixels = {subtracted_black}, Subtracted White Pixels = {subtracted_white}")
# Out:
# Row 1:
#   Circle 1: Coordinates = (146, 164), Subtracted Black Pixels = -78636, Subtracted White Pixels = 1409
#   Circle 2: Coordinates = (208, 164), Subtracted Black Pixels = -78767, Subtracted White Pixels = 1540
#   Circle 3: Coordinates = (268, 164), Subtracted Black Pixels = -78757, Subtracted White Pixels = 1530
# Row 2:
#   Circle 1: Coordinates = (144, 244), Subtracted Black Pixels = -76859, Subtracted White Pixels = -368
#   Circle 2: Coordinates = (208, 242), Subtracted Black Pixels = -76842, Subtracted White Pixels = -385
#   Circle 3: Coordinates = (270, 242), Subtracted Black Pixels = -78755, Subtracted White Pixels = 1528
#   Circle 4: Coordinates = (332, 240), Subtracted Black Pixels = -77004, Subtracted White Pixels = -223
#   Circle 5: Coordinates = (502, 240), Subtracted Black Pixels = -77045, Subtracted White Pixels = -182
#   Circle 6: Coordinates = (566, 238), Subtracted Black Pixels = -78543, Subtracted White Pixels = 1316
#   Circle 7: Coordinates = (628, 236), Subtracted Black Pixels = -76917, Subtracted White Pixels = -310
#   Circle 8: Coordinates = (690, 236), Subtracted Black Pixels = -76940, Subtracted White Pixels = -287
#   Circle 9: Coordinates = (860, 236), Subtracted Black Pixels = -76783, Subtracted White Pixels = -444
#   Circle 10: Coordinates = (922, 234), Subtracted Black Pixels = -76915, Subtracted White Pixels = -312
#   Circle 11: Coordinates = (986, 234), Subtracted Black Pixels = -78698, Subtracted White Pixels = 1471
#   Circle 12: Coordinates = (1048, 232), Subtracted Black Pixels = -76844, Subtracted White Pixels = -383
# Row 3:
#   Circle 1: Coordinates = (142, 320), Subtracted Black Pixels = -76819, Subtracted White Pixels = -408
#   Circle 2: Coordinates = (204, 322), Subtracted Black Pixels = -78679, Subtracted White Pixels = 1452
#   Circle 3: Coordinates = (266, 320), Subtracted Black Pixels = -76881, Subtracted White Pixels = -346
#   Circle 4: Coordinates = (332, 320), Subtracted Black Pixels = -76916, Subtracted White Pixels = -311
#   Circle 5: Coordinates = (502, 318), Subtracted Black Pixels = -76930, Subtracted White Pixels = -297
#   Circle 6: Coordinates = (566, 318), Subtracted Black Pixels = -76780, Subtracted White Pixels = -447
#   Circle 7: Coordinates = (628, 316), Subtracted Black Pixels = -76948, Subtracted White Pixels = -279
#   Circle 8: Coordinates = (692, 316), Subtracted Black Pixels = -78665, Subtracted White Pixels = 1438
#   Circle 9: Coordinates = (860, 316), Subtracted Black Pixels = -76896, Subtracted White Pixels = -331
#   Circle 10: Coordinates = (926, 314), Subtracted Black Pixels = -76826, Subtracted White Pixels = -401
#   Circle 11: Coordinates = (988, 312), Subtracted Black Pixels = -76881, Subtracted White Pixels = -346
#   Circle 12: Coordinates = (1050, 312), Subtracted Black Pixels = -78781, Subtracted White Pixels = 1554
# Row 4:
#   Circle 1: Coordinates = (142, 402), Subtracted Black Pixels = -76925, Subtracted White Pixels = -302
#   Circle 2: Coordinates = (204, 400), Subtracted Black Pixels = -76925, Subtracted White Pixels = -302
#   Circle 3: Coordinates = (268, 400), Subtracted Black Pixels = -78682, Subtracted White Pixels = 1455
#   Circle 4: Coordinates = (332, 400), Subtracted Black Pixels = -76993, Subtracted White Pixels = -234
#   Circle 5: Coordinates = (504, 398), Subtracted Black Pixels = -78717, Subtracted White Pixels = 1490
#   Circle 6: Coordinates = (566, 398), Subtracted Black Pixels = -76809, Subtracted White Pixels = -418
#   Circle 7: Coordinates = (630, 398), Subtracted Black Pixels = -76778, Subtracted White Pixels = -449
#   Circle 8: Coordinates = (692, 396), Subtracted Black Pixels = -76929, Subtracted White Pixels = -298
#   Circle 9: Coordinates = (862, 394), Subtracted Black Pixels = -78719, Subtracted White Pixels = 1492
#   Circle 10: Coordinates = (926, 394), Subtracted Black Pixels = -76919, Subtracted White Pixels = -308
#   Circle 11: Coordinates = (988, 392), Subtracted Black Pixels = -77001, Subtracted White Pixels = -226
#   Circle 12: Coordinates = (1050, 392), Subtracted Black Pixels = -76833, Subtracted White Pixels = -394
# Row 5:
#   Circle 1: Coordinates = (140, 480), Subtracted Black Pixels = -78695, Subtracted White Pixels = 1468
#   Circle 2: Coordinates = (204, 480), Subtracted Black Pixels = -76879, Subtracted White Pixels = -348
#   Circle 3: Coordinates = (268, 480), Subtracted Black Pixels = -76763, Subtracted White Pixels = -464
#   Circle 4: Coordinates = (330, 480), Subtracted Black Pixels = -76901, Subtracted White Pixels = -326
#   Circle 5: Coordinates = (504, 478), Subtracted Black Pixels = -76877, Subtracted White Pixels = -350
#   Circle 6: Coordinates = (566, 478), Subtracted Black Pixels = -76896, Subtracted White Pixels = -331
#   Circle 7: Coordinates = (630, 478), Subtracted Black Pixels = -78643, Subtracted White Pixels = 1416
#   Circle 8: Coordinates = (692, 476), Subtracted Black Pixels = -76721, Subtracted White Pixels = -506
#   Circle 9: Coordinates = (864, 476), Subtracted Black Pixels = -76717, Subtracted White Pixels = -510
#   Circle 10: Coordinates = (928, 474), Subtracted Black Pixels = -78484, Subtracted White Pixels = 1257
#   Circle 11: Coordinates = (990, 474), Subtracted Black Pixels = -76823, Subtracted White Pixels = -404
#   Circle 12: Coordinates = (1054, 472), Subtracted Black Pixels = -76795, Subtracted White Pixels = -432
# Row 6:
#   Circle 1: Coordinates = (140, 562), Subtracted Black Pixels = -77069, Subtracted White Pixels = -158
#   Circle 2: Coordinates = (204, 560), Subtracted Black Pixels = -77021, Subtracted White Pixels = -206
#   Circle 3: Coordinates = (266, 560), Subtracted Black Pixels = -76975, Subtracted White Pixels = -252
#   Circle 4: Coordinates = (330, 560), Subtracted Black Pixels = -78886, Subtracted White Pixels = 1659
#   Circle 5: Coordinates = (504, 560), Subtracted Black Pixels = -76953, Subtracted White Pixels = -274
#   Circle 6: Coordinates = (568, 558), Subtracted Black Pixels = -76978, Subtracted White Pixels = -249
#   Circle 7: Coordinates = (630, 560), Subtracted Black Pixels = -76847, Subtracted White Pixels = -380
#   Circle 8: Coordinates = (692, 560), Subtracted Black Pixels = -78693, Subtracted White Pixels = 1466
#   Circle 9: Coordinates = (864, 556), Subtracted Black Pixels = -76911, Subtracted White Pixels = -316
#   Circle 10: Coordinates = (926, 556), Subtracted Black Pixels = -76824, Subtracted White Pixels = -403
#   Circle 11: Coordinates = (992, 554), Subtracted Black Pixels = -78740, Subtracted White Pixels = 1513
#   Circle 12: Coordinates = (1054, 554), Subtracted Black Pixels = -76891, Subtracted White Pixels = -336
# Row 7:
#   Circle 1: Coordinates = (138, 642), Subtracted Black Pixels = -78837, Subtracted White Pixels = 1610
#   Circle 2: Coordinates = (206, 642), Subtracted Black Pixels = -76896, Subtracted White Pixels = -331
#   Circle 3: Coordinates = (268, 642), Subtracted Black Pixels = -76986, Subtracted White Pixels = -241
#   Circle 4: Coordinates = (332, 642), Subtracted Black Pixels = -76927, Subtracted White Pixels = -300
#   Circle 5: Coordinates = (504, 640), Subtracted Black Pixels = -78580, Subtracted White Pixels = 1353
#   Circle 6: Coordinates = (568, 640), Subtracted Black Pixels = -76740, Subtracted White Pixels = -487
#   Circle 7: Coordinates = (630, 640), Subtracted Black Pixels = -76733, Subtracted White Pixels = -494
#   Circle 8: Coordinates = (694, 640), Subtracted Black Pixels = -76715, Subtracted White Pixels = -512
#   Circle 9: Coordinates = (862, 638), Subtracted Black Pixels = -76725, Subtracted White Pixels = -502
#   Circle 10: Coordinates = (926, 638), Subtracted Black Pixels = -78702, Subtracted White Pixels = 1475
#   Circle 11: Coordinates = (994, 636), Subtracted Black Pixels = -76894, Subtracted White Pixels = -333
#   Circle 12: Coordinates = (1056, 634), Subtracted Black Pixels = -76819, Subtracted White Pixels = -408
# Row 8:
#   Circle 1: Coordinates = (142, 726), Subtracted Black Pixels = -76890, Subtracted White Pixels = -337
#   Circle 2: Coordinates = (204, 724), Subtracted Black Pixels = -78779, Subtracted White Pixels = 1552
#   Circle 3: Coordinates = (268, 724), Subtracted Black Pixels = -76904, Subtracted White Pixels = -323
#   Circle 4: Coordinates = (334, 724), Subtracted Black Pixels = -76989, Subtracted White Pixels = -238
#   Circle 5: Coordinates = (504, 722), Subtracted Black Pixels = -76864, Subtracted White Pixels = -363
#   Circle 6: Coordinates = (570, 722), Subtracted Black Pixels = -76892, Subtracted White Pixels = -335
#   Circle 7: Coordinates = (630, 722), Subtracted Black Pixels = -78701, Subtracted White Pixels = 1474
#   Circle 8: Coordinates = (694, 720), Subtracted Black Pixels = -76794, Subtracted White Pixels = -433
#   Circle 9: Coordinates = (864, 718), Subtracted Black Pixels = -76942, Subtracted White Pixels = -285
#   Circle 10: Coordinates = (928, 718), Subtracted Black Pixels = -76732, Subtracted White Pixels = -495
#   Circle 11: Coordinates = (992, 718), Subtracted Black Pixels = -76910, Subtracted White Pixels = -317
# Row 9:
#   Circle 1: Coordinates = (142, 806), Subtracted Black Pixels = -77035, Subtracted White Pixels = -192
#   Circle 2: Coordinates = (204, 806), Subtracted Black Pixels = -78893, Subtracted White Pixels = 1666
#   Circle 3: Coordinates = (272, 804), Subtracted Black Pixels = -77022, Subtracted White Pixels = -205
#   Circle 4: Coordinates = (332, 804), Subtracted Black Pixels = -76983, Subtracted White Pixels = -244
#   Circle 5: Coordinates = (506, 804), Subtracted Black Pixels = -76790, Subtracted White Pixels = -437
#   Circle 6: Coordinates = (570, 802), Subtracted Black Pixels = -78662, Subtracted White Pixels = 1435
#   Circle 7: Coordinates = (632, 802), Subtracted Black Pixels = -76882, Subtracted White Pixels = -345
#   Circle 8: Coordinates = (694, 802), Subtracted Black Pixels = -76926, Subtracted White Pixels = -301
#   Circle 9: Coordinates = (864, 800), Subtracted Black Pixels = -76870, Subtracted White Pixels = -357
#   Circle 10: Coordinates = (928, 798), Subtracted Black Pixels = -76807, Subtracted White Pixels = -420
#   Circle 11: Coordinates = (992, 798), Subtracted Black Pixels = -76839, Subtracted White Pixels = -388
#   Circle 12: Coordinates = (1058, 798), Subtracted Black Pixels = -78807, Subtracted White Pixels = 1580
# Row 10:
#   Circle 1: Coordinates = (134, 890), Subtracted Black Pixels = -77038, Subtracted White Pixels = -189
#   Circle 2: Coordinates = (200, 886), Subtracted Black Pixels = -77056, Subtracted White Pixels = -171
#   Circle 3: Coordinates = (264, 888), Subtracted Black Pixels = -76995, Subtracted White Pixels = -232
#   Circle 4: Coordinates = (334, 886), Subtracted Black Pixels = -78681, Subtracted White Pixels = 1454
#   Circle 5: Coordinates = (506, 884), Subtracted Black Pixels = -77062, Subtracted White Pixels = -165
#   Circle 6: Coordinates = (570, 882), Subtracted Black Pixels = -78700, Subtracted White Pixels = 1473
#   Circle 7: Coordinates = (632, 882), Subtracted Black Pixels = -76918, Subtracted White Pixels = -309
#   Circle 8: Coordinates = (694, 884), Subtracted Black Pixels = -76896, Subtracted White Pixels = -331
#   Circle 9: Coordinates = (868, 882), Subtracted Black Pixels = -76928, Subtracted White Pixels = -299
#   Circle 10: Coordinates = (930, 882), Subtracted Black Pixels = -76864, Subtracted White Pixels = -363
#   Circle 11: Coordinates = (996, 880), Subtracted Black Pixels = -78846, Subtracted White Pixels = 1619
#   Circle 12: Coordinates = (1062, 882), Subtracted Black Pixels = -76897, Subtracted White Pixels = -330
# Row 11:
#   Circle 1: Coordinates = (134, 970), Subtracted Black Pixels = -77048, Subtracted White Pixels = -179
#   Circle 2: Coordinates = (198, 974), Subtracted Black Pixels = -77056, Subtracted White Pixels = -171
#   Circle 3: Coordinates = (266, 972), Subtracted Black Pixels = -78756, Subtracted White Pixels = 1529
#   Circle 4: Coordinates = (332, 970), Subtracted Black Pixels = -76943, Subtracted White Pixels = -284
#   Circle 5: Coordinates = (506, 966), Subtracted Black Pixels = -76972, Subtracted White Pixels = -255
#   Circle 6: Coordinates = (570, 966), Subtracted Black Pixels = -76889, Subtracted White Pixels = -338
#   Circle 7: Coordinates = (632, 968), Subtracted Black Pixels = -76995, Subtracted White Pixels = -232
#   Circle 8: Coordinates = (694, 966), Subtracted Black Pixels = -78741, Subtracted White Pixels = 1514
#   Circle 9: Coordinates = (870, 964), Subtracted Black Pixels = -76942, Subtracted White Pixels = -285
#   Circle 10: Coordinates = (932, 962), Subtracted Black Pixels = -76755, Subtracted White Pixels = -472
#   Circle 11: Coordinates = (996, 962), Subtracted Black Pixels = -76863, Subtracted White Pixels = -364
# Row 12:
#   Circle 1: Coordinates = (130, 1056), Subtracted Black Pixels = -76939, Subtracted White Pixels = -288
#   Circle 2: Coordinates = (194, 1056), Subtracted Black Pixels = -76967, Subtracted White Pixels = -260
#   Circle 3: Coordinates = (260, 1054), Subtracted Black Pixels = -78945, Subtracted White Pixels = 1718
#   Circle 4: Coordinates = (328, 1052), Subtracted Black Pixels = -76995, Subtracted White Pixels = -232
#   Circle 5: Coordinates = (504, 1050), Subtracted Black Pixels = -78742, Subtracted White Pixels = 1515
#   Circle 6: Coordinates = (568, 1048), Subtracted Black Pixels = -76952, Subtracted White Pixels = -275
#   Circle 7: Coordinates = (634, 1048), Subtracted Black Pixels = -76945, Subtracted White Pixels = -282
#   Circle 8: Coordinates = (698, 1048), Subtracted Black Pixels = -76832, Subtracted White Pixels = -395
#   Circle 9: Coordinates = (872, 1050), Subtracted Black Pixels = -78859, Subtracted White Pixels = 1632
#   Circle 10: Coordinates = (934, 1046), Subtracted Black Pixels = -76790, Subtracted White Pixels = -437
#   Circle 11: Coordinates = (998, 1048), Subtracted Black Pixels = -76863, Subtracted White Pixels = -364
#   Circle 12: Coordinates = (1062, 1046), Subtracted Black Pixels = -76920, Subtracted White Pixels = -307
# Row 13:
#   Circle 1: Coordinates = (130, 1140), Subtracted Black Pixels = -78892, Subtracted White Pixels = 1665
#   Circle 2: Coordinates = (196, 1140), Subtracted Black Pixels = -76998, Subtracted White Pixels = -229
#   Circle 3: Coordinates = (260, 1140), Subtracted Black Pixels = -76915, Subtracted White Pixels = -312
#   Circle 4: Coordinates = (328, 1138), Subtracted Black Pixels = -76875, Subtracted White Pixels = -352
#   Circle 5: Coordinates = (504, 1136), Subtracted Black Pixels = -76887, Subtracted White Pixels = -340
#   Circle 6: Coordinates = (570, 1136), Subtracted Black Pixels = -76861, Subtracted White Pixels = -366
#   Circle 7: Coordinates = (634, 1136), Subtracted Black Pixels = -78728, Subtracted White Pixels = 1501
#   Circle 8: Coordinates = (698, 1132), Subtracted Black Pixels = -76846, Subtracted White Pixels = -381
#   Circle 9: Coordinates = (870, 1130), Subtracted Black Pixels = -76893, Subtracted White Pixels = -334
#   Circle 10: Coordinates = (934, 1130), Subtracted Black Pixels = -76777, Subtracted White Pixels = -450
#   Circle 11: Coordinates = (998, 1130), Subtracted Black Pixels = -76816, Subtracted White Pixels = -411
#   Circle 12: Coordinates = (1064, 1130), Subtracted Black Pixels = -78816, Subtracted White Pixels = 1589
# Row 14:
#   Circle 1: Coordinates = (132, 1224), Subtracted Black Pixels = -78875, Subtracted White Pixels = 1648
#   Circle 2: Coordinates = (200, 1224), Subtracted Black Pixels = -76896, Subtracted White Pixels = -331
#   Circle 3: Coordinates = (262, 1224), Subtracted Black Pixels = -76851, Subtracted White Pixels = -376
#   Circle 4: Coordinates = (328, 1222), Subtracted Black Pixels = -76884, Subtracted White Pixels = -343
#   Circle 5: Coordinates = (502, 1220), Subtracted Black Pixels = -76996, Subtracted White Pixels = -231
#   Circle 6: Coordinates = (568, 1220), Subtracted Black Pixels = -78810, Subtracted White Pixels = 1583
#   Circle 7: Coordinates = (634, 1218), Subtracted Black Pixels = -76928, Subtracted White Pixels = -299
#   Circle 8: Coordinates = (700, 1216), Subtracted Black Pixels = -76916, Subtracted White Pixels = -311
#   Circle 9: Coordinates = (872, 1216), Subtracted Black Pixels = -78844, Subtracted White Pixels = 1617
#   Circle 10: Coordinates = (936, 1216), Subtracted Black Pixels = -76952, Subtracted White Pixels = -275
#   Circle 11: Coordinates = (1002, 1214), Subtracted Black Pixels = -76852, Subtracted White Pixels = -375
#   Circle 12: Coordinates = (1066, 1214), Subtracted Black Pixels = -76966, Subtracted White Pixels = -261
# Row 15:
#   Circle 1: Coordinates = (130, 1308), Subtracted Black Pixels = -78780, Subtracted White Pixels = 1553
#   Circle 2: Coordinates = (200, 1306), Subtracted Black Pixels = -77066, Subtracted White Pixels = -161
#   Circle 3: Coordinates = (262, 1306), Subtracted Black Pixels = -77051, Subtracted White Pixels = -176
#   Circle 4: Coordinates = (328, 1306), Subtracted Black Pixels = -76899, Subtracted White Pixels = -328
#   Circle 5: Coordinates = (504, 1304), Subtracted Black Pixels = -76959, Subtracted White Pixels = -268
#   Circle 6: Coordinates = (570, 1304), Subtracted Black Pixels = -76922, Subtracted White Pixels = -305
#   Circle 7: Coordinates = (634, 1302), Subtracted Black Pixels = -76922, Subtracted White Pixels = -305
#   Circle 8: Coordinates = (698, 1304), Subtracted Black Pixels = -78624, Subtracted White Pixels = 1397
#   Circle 9: Coordinates = (872, 1298), Subtracted Black Pixels = -76929, Subtracted White Pixels = -298
#   Circle 10: Coordinates = (936, 1302), Subtracted Black Pixels = -76908, Subtracted White Pixels = -319
#   Circle 11: Coordinates = (1004, 1300), Subtracted Black Pixels = -78922, Subtracted White Pixels = 1695
#   Circle 12: Coordinates = (1066, 1300), Subtracted Black Pixels = -76995, Subtracted White Pixels = -232
# Row 16:
#   Circle 1: Coordinates = (132, 1390), Subtracted Black Pixels = -77041, Subtracted White Pixels = -186
#   Circle 2: Coordinates = (196, 1390), Subtracted Black Pixels = -78857, Subtracted White Pixels = 1630
#   Circle 3: Coordinates = (262, 1390), Subtracted Black Pixels = -77063, Subtracted White Pixels = -164
#   Circle 4: Coordinates = (330, 1392), Subtracted Black Pixels = -76954, Subtracted White Pixels = -273
#   Circle 5: Coordinates = (502, 1392), Subtracted Black Pixels = -78786, Subtracted White Pixels = 1559
#   Circle 6: Coordinates = (570, 1388), Subtracted Black Pixels = -76954, Subtracted White Pixels = -273
#   Circle 7: Coordinates = (634, 1388), Subtracted Black Pixels = -76999, Subtracted White Pixels = -228
#   Circle 8: Coordinates = (700, 1386), Subtracted Black Pixels = -76953, Subtracted White Pixels = -274
#   Circle 9: Coordinates = (874, 1388), Subtracted Black Pixels = -76957, Subtracted White Pixels = -270
#   Circle 10: Coordinates = (940, 1384), Subtracted Black Pixels = -78817, Subtracted White Pixels = 1590
#   Circle 11: Coordinates = (1004, 1386), Subtracted Black Pixels = -76890, Subtracted White Pixels = -337
#   Circle 12: Coordinates = (1070, 1384), Subtracted Black Pixels = -76941, Subtracted White Pixels = -286
# Row 17:
#   Circle 1: Coordinates = (132, 1478), Subtracted Black Pixels = -77057, Subtracted White Pixels = -170
#   Circle 2: Coordinates = (198, 1478), Subtracted Black Pixels = -76976, Subtracted White Pixels = -251
#   Circle 3: Coordinates = (262, 1474), Subtracted Black Pixels = -77093, Subtracted White Pixels = -134
#   Circle 4: Coordinates = (326, 1476), Subtracted Black Pixels = -78842, Subtracted White Pixels = 1615
#   Circle 5: Coordinates = (506, 1474), Subtracted Black Pixels = -76956, Subtracted White Pixels = -271
#   Circle 6: Coordinates = (568, 1474), Subtracted Black Pixels = -76947, Subtracted White Pixels = -280
#   Circle 7: Coordinates = (638, 1474), Subtracted Black Pixels = -78839, Subtracted White Pixels = 1612
#   Circle 8: Coordinates = (698, 1474), Subtracted Black Pixels = -76924, Subtracted White Pixels = -303

# %%
import numpy as np

def detect_marked_and_unmarked_bubbles(subtracted_grouped_rows, num_options, deviation_threshold=50):
    """
    Detect marked and unmarked bubbles based on white pixel values and a deviation threshold.

    Args:
        subtracted_grouped_rows (list): List of grouped circles with subtracted pixel counts.
        num_options (int): The number of options per question.
        deviation_threshold (float): The threshold below which a question is considered unmarked.

    Returns:
        list: A 2D array where each element is:
              - 1 for the most deviated (marked) bubble.
              - 0 for unmarked bubbles.
    """
    marked_bubbles = []

    for row in subtracted_grouped_rows:
        for question_start in range(0, len(row), num_options):
            question_group = row[question_start:question_start + num_options]

            # Extract white pixel values for the current question
            white_pixel_values = [subtracted_white for (_, _, _, _, subtracted_white) in question_group]

            # Calculate the mean and standard deviation of the white pixel values
            mean_white = np.mean(white_pixel_values)
            std_dev_white = np.std(white_pixel_values)
            print(f"Mean: {mean_white}, Standard Deviation: {std_dev_white}")
            # If the standard deviation is less than the threshold, consider the question unmarked
            if std_dev_white < deviation_threshold:
                marked_bubbles.append([0] * num_options)  
            else:
                # Calculate absolute deviations from the mean
                deviations = [abs(white_value - mean_white) for white_value in white_pixel_values]

                # Create a 1D array for the question (options), initialized to zeros
                marked_question = np.zeros(num_options, dtype=int)

                # Find the index of the maximum deviation
                max_deviation_index = np.argmax(deviations)

                # Mark the option with the highest deviation as 1 (marked bubble)
                marked_question[max_deviation_index] = 1

                marked_bubbles.append(marked_question)

    return np.array(marked_bubbles)


  
answer_student = detect_marked_and_unmarked_bubbles(subtracted_grouped_rows, options)

# Print the marked bubbles in a readable format
for row_idx, row in enumerate(answer_student, start=1):
    print(f"Question {row_idx}: Marked Bubble = {row.tolist()}")
# Out:
# Mean: 87.0, Standard Deviation: 724.4537252302592
# Mean: 219.0, Standard Deviation: 719.2437695246306
# Mean: 658.5, Standard Deviation: 773.5
# Mean: 148.4, Standard Deviation: 726.3133208196032
# Mean: 606.6, Standard Deviation: 751.473113291487
# Mean: -149.0, Standard Deviation: 65.0
# Mean: 127.4, Standard Deviation: 756.2376875030759
# Mean: 162.0, Standard Deviation: 650.8456038109192
# Mean: 714.0, Standard Deviation: 801.0
# Mean: 120.2, Standard Deviation: 783.1417240831956
# Mean: 468.2, Standard Deviation: 825.4548806567201
# Mean: -126.5, Standard Deviation: 20.5
# Mean: 115.6, Standard Deviation: 682.2370848905827
# Mean: 399.0, Standard Deviation: 847.477197333356
# Mean: -144.0, Standard Deviation: 5.0
# Mean: 559.2, Standard Deviation: 907.8868651985225
# Mean: -241.4, Standard Deviation: 59.85515850785127
# Mean: 570.5, Standard Deviation: 885.5
# Mean: 194.4, Standard Deviation: 730.9420223246163
# Mean: 449.6, Standard Deviation: 819.8598904690972
# Mean: -141.0, Standard Deviation: 9.0
# Mean: 165.8, Standard Deviation: 714.2572085740543
# Mean: 494.2, Standard Deviation: 796.808734891881
# Mean: -201.0, Standard Deviation: 30.0
# Mean: 574.6, Standard Deviation: 854.2839340640792
# Mean: 190.4, Standard Deviation: 705.7369481612819
# Mean: -221.0, Standard Deviation: 4.0
# Mean: 245.4, Standard Deviation: 769.8479330361289
# Mean: 567.0, Standard Deviation: 774.9221896422893
# Mean: -180.0, Standard Deviation: 2.0
# Mean: 210.4, Standard Deviation: 740.5421257430261
# Mean: 533.0, Standard Deviation: 829.7563497798616
# Mean: -119.0, Standard Deviation: 39.0
# Mean: 567.8, Standard Deviation: 872.5171402327865
# Mean: -201.0, Standard Deviation: 49.11618877722497
# Mean: 732.5, Standard Deviation: 867.5
# Mean: 218.8, Standard Deviation: 730.0425741009904
# Mean: 503.2, Standard Deviation: 890.5511551842488
# Mean: -159.0, Standard Deviation: 20.0
# Mean: 197.0, Standard Deviation: 717.1186791598724
# Mean: 200.8, Standard Deviation: 719.514947725202
# Mean: 745.0, Standard Deviation: 842.0
# Mean: 582.4, Standard Deviation: 918.3630219036478
# Mean: 241.0, Standard Deviation: 680.3684296026676
# Mean: -122.5, Standard Deviation: 6.5
# Mean: 229.8, Standard Deviation: 722.2767890497381
# Mean: 275.2, Standard Deviation: 724.0412695420061
# Mean: 801.5, Standard Deviation: 897.5
# Mean: 236.8, Standard Deviation: 750.5433764946567
# Mean: 459.0, Standard Deviation: 820.9957368951436
# Question 1: Marked Bubble = [0, 0, 1, 0, 0]
# Question 2: Marked Bubble = [0, 0, 1, 0, 0]
# Question 3: Marked Bubble = [1, 0, 0, 0, 0]
# Question 4: Marked Bubble = [0, 1, 0, 0, 0]
# Question 5: Marked Bubble = [0, 0, 1, 0, 0]
# Question 6: Marked Bubble = [1, 0, 0, 0, 0]
# Question 7: Marked Bubble = [0, 0, 0, 1, 0]
# Question 8: Marked Bubble = [1, 0, 0, 0, 0]
# Question 9: Marked Bubble = [1, 0, 0, 0, 0]
# Question 10: Marked Bubble = [1, 0, 0, 0, 0]
# Question 11: Marked Bubble = [0, 0, 0, 1, 0]
# Question 12: Marked Bubble = [0, 0, 0, 0, 0]
# Question 13: Marked Bubble = [1, 0, 0, 0, 0]
# Question 14: Marked Bubble = [0, 1, 0, 0, 0]
# Question 15: Marked Bubble = [0, 0, 0, 0, 0]
# Question 16: Marked Bubble = [1, 0, 0, 0, 0]
# Question 17: Marked Bubble = [0, 0, 0, 1, 0]
# Question 18: Marked Bubble = [1, 0, 0, 0, 0]
# Question 19: Marked Bubble = [0, 0, 1, 0, 0]
# Question 20: Marked Bubble = [0, 0, 1, 0, 0]
# Question 21: Marked Bubble = [0, 0, 0, 0, 0]
# Question 22: Marked Bubble = [0, 1, 0, 0, 0]
# Question 23: Marked Bubble = [1, 0, 0, 0, 0]
# Question 24: Marked Bubble = [0, 0, 0, 0, 0]
# Question 25: Marked Bubble = [0, 0, 1, 0, 0]
# Question 26: Marked Bubble = [0, 0, 0, 1, 0]
# Question 27: Marked Bubble = [0, 0, 0, 0, 0]
# Question 28: Marked Bubble = [1, 0, 0, 0, 0]
# Question 29: Marked Bubble = [0, 0, 0, 0, 1]
# Question 30: Marked Bubble = [0, 0, 0, 0, 0]
# Question 31: Marked Bubble = [0, 0, 0, 1, 0]
# Question 32: Marked Bubble = [1, 0, 0, 0, 0]
# Question 33: Marked Bubble = [0, 0, 0, 0, 0]
# Question 34: Marked Bubble = [0, 1, 0, 0, 0]
# Question 35: Marked Bubble = [0, 0, 0, 0, 0]
# Question 36: Marked Bubble = [1, 0, 0, 0, 0]
# Question 37: Marked Bubble = [0, 0, 1, 0, 0]
# Question 38: Marked Bubble = [0, 1, 0, 0, 0]
# Question 39: Marked Bubble = [0, 0, 0, 0, 0]
# Question 40: Marked Bubble = [0, 1, 0, 0, 0]
# Question 41: Marked Bubble = [1, 0, 0, 0, 0]
# Question 42: Marked Bubble = [1, 0, 0, 0, 0]
# Question 43: Marked Bubble = [0, 0, 0, 0, 1]
# Question 44: Marked Bubble = [0, 0, 0, 0, 1]
# Question 45: Marked Bubble = [0, 0, 0, 0, 0]
# Question 46: Marked Bubble = [0, 0, 0, 1, 0]
# Question 47: Marked Bubble = [0, 1, 0, 0, 0]
# Question 48: Marked Bubble = [1, 0, 0, 0, 0]
# Question 49: Marked Bubble = [1, 0, 0, 0, 0]
# Question 50: Marked Bubble = [1, 0, 0, 0, 0]

# %%
answer_key = detect_marked_and_unmarked_bubbles(subtract_grouped_rows_key, options)
for row_idx, row in enumerate(answer_key, start=1):
    print(f"Question {row_idx}: Marked Bubble = {row.tolist()}")
# Out:
# Mean:
# Question 11: Marked Bubble = [1, 0, 0, 0, 0]
# Question 12: Marked Bubble = [0, 1, 0, 0, 0]
# Question 13: Marked Bubble = [0, 0, 0, 0, 0]
# Question 14: Marked Bubble = [0, 0, 0, 1, 0]
# Question 15: Marked Bubble = [0, 0, 1, 0, 0]
# Question 16: Marked Bubble = [1, 0, 0, 0, 0]
# Question 17: Marked Bubble = [1, 0, 0, 0, 0]
# Question 18: Marked Bubble = [0, 0, 0, 0, 1]
# Question 19: Marked Bubble = [0, 0, 0, 0, 0]
# Question 20: Marked Bubble = [0, 1, 0, 0, 0]
# Question 21: Marked Bubble = [0, 1, 0, 0, 0]
# Question 22: Marked Bubble = [0, 0, 0, 0, 0]
# Question 23: Marked Bubble = [0, 1, 0, 0, 0]
# Question 24: Marked Bubble = [1, 0, 0, 0, 0]
# Question 25: Marked Bubble = [1, 0, 0, 0, 0]
# Question 26: Marked Bubble = [0, 0, 0, 1, 0]
# Question 27: Marked Bubble = [1, 0, 0, 0, 0]
# Question 28: Marked Bubble = [1, 0, 0, 0, 0]
# Question 29: Marked Bubble = [0, 0, 1, 0, 0]
# Question 30: Marked Bubble = [0, 0, 1, 0, 0]
# Question 31: Marked Bubble = [0, 0, 0, 0, 0]
# Question 32: Marked Bubble = [0, 0, 1, 0, 0]
# Question 33: Marked Bubble = [0, 0, 0, 1, 0]
# Question 34: Marked Bubble = [0, 0, 0, 0, 0]
# Question 35: Marked Bubble = [1, 0, 0, 0, 0]
# Question 36: Marked Bubble = [0, 1, 0, 0, 0]
# Question 37: Marked Bubble = [1, 0, 0, 0, 0]
# Question 38: Marked Bubble = [1, 0, 0, 0, 0]
# Question 39: Marked Bubble = [0, 0, 0, 1, 0]
# Question 40: Marked Bubble = [1, 0, 0, 0, 0]
# Question 41: Marked Bubble = [1, 0, 0, 0, 0]
# Question 42: Marked Bubble = [0, 0, 1, 0, 0]
# Question 43: Marked Bubble = [1, 0, 0, 0, 0]
# Question 44: Marked Bubble = [0, 1, 0, 0, 0]
# Question 45: Marked Bubble = [0, 0, 0, 0, 1]
# Question 46: Marked Bubble = [0, 0, 0, 0, 0]
# Question 47: Marked Bubble = [0, 0, 0, 1, 0]
# Question 48: Marked Bubble = [0, 1, 0, 0, 0]

# %% [markdown]
# ### 6. Calculating score

# %%
def calculate_score(answer_key, answer_student):
    """
    Compare the student's answers with the answer key and calculate the score.

    Args:
        answer_key (np.ndarray): The correct answer key with marked bubbles (1 for correct option, 0 for others).
        answer_student (np.ndarray): The student's marked answers with bubbles (1 for marked option, 0 for others).

    Returns:
        int: The total score of the student.
        list: A list indicating correctness for each question (1 for correct, 0 for incorrect).
    """
    total_score = 0
    result_per_question = []

    for key, student in zip(answer_key, answer_student):
        if np.array_equal(key, student):
            total_score += 1
            result_per_question.append(1)  # Correct answer
        else:
            result_per_question.append(0)  # Incorrect answer

    return total_score, result_per_question


total_score, result_per_question = calculate_score(answer_key, answer_student)

# Print the final score and results
print(f"Total Score: {total_score}")
for idx, result in enumerate(result_per_question, start=1):
    status = "Correct" if result == 1 else "Incorrect"
    print(f"Question {idx}: {status}")
# Out:
# Total Score: 7
# Question 1: Incorrect
# Question 2: Correct
# Question 3: Correct
# Question 4: Incorrect
# Question 5: Incorrect
# Question 6: Incorrect
# Question 7: Incorrect
# Question 8: Incorrect
# Question 9: Incorrect
# Question 10: Correct
# Question 11: Incorrect
# Question 12: Incorrect
# Question 13: Incorrect
# Question 14: Incorrect
# Question 15: Incorrect
# Question 16: Correct
# Question 17: Incorrect
# Question 18: Incorrect
# Question 19: Incorrect
# Question 20: Incorrect
# Question 21: Incorrect
# Question 22: Incorrect
# Question 23: Incorrect
# Question 24: Incorrect
# Question 25: Incorrect
# Question 26: Correct
# Question 27: Incorrect
# Question 28: Correct
# Question 29: Incorrect
# Question 30: Incorrect
# Question 31: Incorrect
# Question 32: Incorrect
# Question 33: Incorrect
# Question 34: Incorrect
# Question 35: Incorrect
# Question 36: Incorrect
# Question 37: Incorrect
# Question 38: Incorrect
# Question 39: Incorrect
# Question 40: Incorrect
# Question 41: Correct
# Question 42: Incorrect
# Question 43: Incorrect
# Question 44: Incorrect
# Question 45: Incorrect
# Question 46: Incorrect
# Question 47: Incorrect
# Question 48: Incorrect

# %% [markdown]
# ### Group Circle by radius (extra verification step)

# %% [markdown]
# this can be used to verify that the detected circles are answer circles. Now we are not using this. we will use this after we finish the core of the function.

# %%
import cv2
import numpy as np
from collections import defaultdict

def group_circles_by_radius(circles, img, tolerance_percentage=20):
    """
    Groups circles based on their radius with a given tolerance percentage of the y-coordinate.
    
    Args:
        circles (array): List of detected circles [(x, y, r)].
        img (numpy array): The original image.
        tolerance_percentage (float): Tolerance as a percentage of the y-coordinate (default is 20%).
        
    Returns:
        dict: Groups of circles based on their radius.
    """
    radius_groups = defaultdict(list)
    
    # Iterate over the detected circles and group them by radius
    for circle in circles:
        x, y, r = circle[0], circle[1], circle[2]

        if not radius_groups:
            # If no groups exist yet, start a new group with the first circle
            radius_groups[r].append((x, y, r))
        else:
            matched_group = None
            for existing_radius in radius_groups.keys():
                diff = abs(int(r) - int(existing_radius))
                
                # Calculate tolerance based on the radius
                tol = (tolerance_percentage / 100.0) * existing_radius

                if diff <= tol:
                    matched_group = existing_radius
                    break

            if matched_group is not None:
                radius_groups[matched_group].append((x, y, r))
            else:
                radius_groups[r].append((x, y, r))

    # Print the radius groups for debugging
    for radius, grouped_circles in radius_groups.items():
        print(f"Radius: {radius}, Circles: {grouped_circles}")
        
    # Visualize each group of circles in separate images
    for radius, grouped_circles in radius_groups.items():
        img_copy = img.copy()  # Create a copy of the original image to visualize each group
        
        for x, y, r in grouped_circles:
            cv2.circle(img_copy, (x, y), r, (0, 255, 0), 2)  # Draw outer circle
            cv2.circle(img_copy, (x, y), 2, (0, 0, 255), 3)  # Draw center

        # Display the grouped circles in a separate window
        cv2.imshow(f'Circles with radius ~ {radius}', img_copy)
        cv2.waitKey(0)
    
    return radius_groups



# if detected_circles is not None:
#     detected_circles = np.uint16(np.around(detected_circles))

#     # Call the function with the detected circles and image
#     group_circles_by_radius(detected_circles[0, :], img, tolerance_percentage=20)

cv2.destroyAllWindows()

# %% [markdown]
# ## Contour Detection

# %% [markdown]
# ### test 1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Function to display images using matplotlib
def display_image(image, title="Image"):
    plt.figure(figsize=(8, 8))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis("off")
    plt.show()

def detectcontour(image):

    clone = image.copy()
    # Step 2: Convert to grayscale and blur
    gray_image = cv2.cvtColor(clone, cv2.COLOR_BGR2GRAY)
    blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

    # Step 3: Canny Edge Detection
    edges = cv2.Canny(blurred_image, 30, 150)


    # Step 4: Finding Contours
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Step 6: Filter contours based on area (size) to detect bubbles
    bubble_contours = []
    for contour in contours:
        area = cv2.contourArea(contour) 
        bubble_contours.append(contour)

    #  Draw the detected bubbles on the original image
    output_image = image.copy()
    cv2.drawContours(output_image, bubble_contours, -1, (0, 255, 0), 2)
    display_image(output_image, "Detected Bubbles")

image = cv2.imread('./Test/1_K.jpg')
detectcontour(image)

# %%
image = cv2.imread('withoutborder50.png')
detectcontour(image)

# %% [markdown]
# ### test 3

# %%
image = cv2.imread('sample50.jpg')
detectcontour(image)

# %% [markdown]
# ### test 4

# %%
image = cv2.imread('border50.png')
detectcontour(image)

# %% [markdown]
# ### method 2

# %%
import cv2
 
# read the image
image = cv2.imread('omr_test.png')
 
# B, G, R channel splitting
blue, green, red = cv2.split(image)
 
# detect contours using blue channel and without thresholding
contours1, hierarchy1 = cv2.findContours(image=blue, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)
 
# draw contours on the original image
image_contour_blue = image.copy()
cv2.drawContours(image=image_contour_blue, contours=contours1, contourIdx=-1, color=(0, 255, 0), thickness=2, lineType=cv2.LINE_AA)
# see the results
cv2.imshow('Contour detection using blue channels only', image_contour_blue)
cv2.waitKey(0)
cv2.destroyAllWindows()
 
# detect contours using green channel and without thresholding
contours2, hierarchy2 = cv2.findContours(image=green, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)
# draw contours on the original image
image_contour_green = image.copy()
cv2.drawContours(image=image_contour_green, contours=contours2, contourIdx=-1, color=(0, 255, 0), thickness=2, lineType=cv2.LINE_AA)
# see the results
cv2.imshow('Contour detection using green channels only', image_contour_green)
cv2.waitKey(0)
cv2.destroyAllWindows()
 
# detect contours using red channel and without thresholding
contours3, hierarchy3 = cv2.findContours(image=red, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)
# draw contours on the original image
image_contour_red = image.copy()
cv2.drawContours(image=image_contour_red, contours=contours3, contourIdx=-1, color=(0, 255, 0), thickness=2, lineType=cv2.LINE_AA)
# see the results
cv2.imshow('Contour detection using red channels only', image_contour_red)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image1 = cv2.imread('omr_test.png')
img_gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
 
ret, thresh1 = cv2.threshold(img_gray1, 150, 255, cv2.THRESH_BINARY)
contours2, hierarchy2 = cv2.findContours(thresh1, cv2.RETR_TREE,
                                               cv2.CHAIN_APPROX_SIMPLE)
image_copy2 = image1.copy()
cv2.drawContours(image_copy2, contours2, -1, (0, 255, 0), 2, cv2.LINE_AA)
cv2.imshow('SIMPLE Approximation contours', image_copy2)
cv2.waitKey(0)
image_copy3 = image1.copy()
for i, contour in enumerate(contours2): # loop over one contour area
   for j, contour_point in enumerate(contour): # loop over the points
       # draw a circle on the current contour coordinate
       cv2.circle(image_copy3, ((contour_point[0][0], contour_point[0][1])), 2, (0, 255, 0), 2, cv2.LINE_AA)
# see the results
cv2.imshow('CHAIN_APPROX_SIMPLE Point only', image_copy3)
cv2.waitKey(0)
#cv2.imwrite('contour_point_simple.jpg', image_copy3)
cv2.destroyAllWindows()
