# %% [markdown]
# ## Design Overview
#
# This workflow is designed for automated OMR (Optical Mark Recognition) processing using image analysis and statistical methods. The main phases are:
#
# 1. **Template Analysis (`detect_circles_template`)**
#     - Analyzes a clean template image to find optimal circle detection parameters (`a_t`, `b_t`).
#     - Statistically determines the most common bubble radius (`mode_radius`).
#
# 2. **Answer Sheet Processing (`detect_circles`)**
#     - Uses template-derived parameters as a starting point.
#     - Adapts detection with ±20% tolerance for real-world variations.
#     - Efficiently locates answer bubbles without exhaustive parameter search.
#
# 3. **Pixel Counting**
#     - Counts black and white pixels inside each detected bubble for template, student, and key images.
#
# 4. **Grouping Bubbles**
#     - Groups detected bubbles by rows using clustering (DBSCAN) or tolerance-based methods.
#
# 5. **Mark Detection**
#     - Compares student and template bubbles to identify marked/unmarked answers using statistical deviation.
#
# 6. **Scoring**
#     - Compares detected answers with the key and calculates the total score and per-question correctness.

# %% [markdown]
# ## Steps

# %% [markdown]
# ### 1. Preprocessing

# %%
import cv2
import numpy as np


def preprocess_image(image_path, blur_ksize=(5, 5)):
    """
    Preprocess the input image by converting it to grayscale and applying Gaussian blur and convert it to binary image.
    
    Args:
        image_path (str): Path to the input image.
        blur_ksize (tuple): Kernel size for the Gaussian blur (default is (5, 5)).
        
    Returns:
        gray_blurred (numpy array): Blurred grayscale version of the image.
        original_img (numpy array): Original color image.
        gray (numpy array): Grayscale version of the image.
        binary_img (numpy array): Binary version of the image
    """
    # Read the image.
    original_img = cv2.imread(image_path, cv2.IMREAD_COLOR)

    if original_img is None:
        raise ValueError(f"Image at {image_path} not found.")
    
    # Convert to grayscale.
    gray = cv2.cvtColor(original_img, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur.
    gray_blurred = cv2.GaussianBlur(gray, blur_ksize, 0)

    # Convert the original image to a binary image
    _, binary_img = cv2.threshold(gray_blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    return gray_blurred, original_img, gray, binary_img

# %%
# Preprocess the images
gray_blurred_s, original_img_s, gray_s, binary_img_s = preprocess_image('./Test/7_S.jpg')
gray_blurred_t, original_img_t, gray_t, binary_img_t = preprocess_image('./Test/7_T.jpg')
gray_blurred_k, original_img_k, gray_k, binary_img_k = preprocess_image('./Test/7_K.jpg')

questions = 40
options=4

# %% [markdown]
# ### 2. Circle Detection

# %%
from collections import Counter
def detect_circles_template(img, gray_blurred, questions, options):
    """
    Detect circles in the preprocessed grayscale image using the Hough Circle Transform.
    
    Args:
        img (numpy array): Original image for visualization.
        gray_blurred (numpy array): Blurred grayscale image.
        num_questions (int): Number of questions in the OMR.
        num_options (int): Number of options per question.
        dp (float): Inverse ratio of the accumulator resolution to the image resolution (default is 1).
        min_dist (int): Minimum distance between the centers of detected circles (default is 1).
        param1 (float): First method-specific parameter (gradient threshold for Canny edge detection).
        param2 (float): Second method-specific parameter (accumulator threshold for circle detection).
        min_radius_range (tuple): Tuple for minimum and maximum radius values for circle detection.
    
    Returns:
        detected_circles (numpy array): Array of detected circles, if found.
    """
    
    for b in range(15,5,-1): 
        for a in range(5,35):  
            detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, a, 
                            param1 = b,param2 = 3*b, minRadius = a//2, maxRadius = a) 
            if detected_circles is not None:
                detected_circles=np.uint16(np.around(detected_circles))
                print(f"circles:{detected_circles.shape[1]},a:{a},b:{b}")
                if detected_circles.shape[1]==questions*options:

                    radius_list = [pt[2] for pt in detected_circles[0, :]]
                    
                    # Find the most common radius
                    most_common_radius = Counter(radius_list).most_common(1)[0][0]
                    print(f"Most common radius: {most_common_radius}")



                    for pt in detected_circles[0, :]: 
                        x, y, r = pt[0], pt[1], pt[2] 

                        # Draw the circumference of the circle. 
                        cv2.circle(img, (x, y), r, (0, 255, 0), 3) 

                        # Draw a small circle (of radius 1) to show the center. 
                        cv2.circle(img, (x, y), 2, (0, 0, 255), 3) 
                    cv2.imwrite(f'./output/detected_circles_template.jpg', img)
                    cv2.imshow("Detected Circle", img) 
                    cv2.waitKey(0) 
                    return detected_circles, most_common_radius,a,b

    cv2.destroyAllWindows()
    return None

# %%
import math
def detect_circles(img, gray_blurred, questions, options, mode_radius, a_t, b_t):
    """
    Detect circles in the preprocessed grayscale image using the Hough Circle Transform.
    
    Args:
        img (numpy array): Original image for visualization.
        gray_blurred (numpy array): Blurred grayscale image.
        num_questions (int): Number of questions in the OMR.
        num_options (int): Number of options per question.
        dp (float): Inverse ratio of the accumulator resolution to the image resolution (default is 1).
        min_dist (int): Minimum distance between the centers of detected circles (default is 1).
        param1 (float): First method-specific parameter (gradient threshold for Canny edge detection).
        param2 (float): Second method-specific parameter (accumulator threshold for circle detection).
        min_radius_range (tuple): Tuple for minimum and maximum radius values for circle detection.
    
    Returns:
        detected_circles (numpy array): Array of detected circles, if found.
    """
    #b=b_t
    # a=math.ceil(mode_radius+mode_radius*0.20)

    upper_a = max(a_t, mode_radius)
    lower_a = min(a_t, mode_radius)
    upper_a_threshold = math.ceil(upper_a + upper_a * 0.20)
    lower_a_threshold = math.floor(lower_a - lower_a * 0.20)


    for b in range(b_t, b_t-10, -1):
        for a in range(upper_a_threshold, lower_a_threshold, -1):
                
            detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, a, 
                            param1 = b,param2 = 3*b, minRadius = a//2, maxRadius = a) 
            if detected_circles is not None:
                print(f"detect_circles: {detected_circles.shape[1]}, a: {a}, b: {b}")
                detected_circles=np.uint16(np.around(detected_circles))
                if detected_circles.shape[1]==questions*options:
                    for pt in detected_circles[0, :]: 
                        x, y, r = pt[0], pt[1], pt[2] 

                        cv2.circle(img, (x, y), r, (0, 255, 0), 3) 
                        cv2.circle(img, (x, y), 2, (0, 0, 255), 3) 
                    cv2.imshow("Detected Circle", img) 
                    cv2.imwrite(f'./output/detected_circles{a}b{b}.jpg', img)
                    cv2.waitKey(0) 
                    return detected_circles

    cv2.destroyAllWindows()
    return None

# %%
detected_circles_t,mode_radius,a_t,b_t = detect_circles_template(
    original_img_t, gray_blurred_t, 
    questions, options,
)
# Out:
# circles:81,a:15,b:15
# circles:125,a:16,b:15
# circles:142,a:17,b:15
# circles:157,a:18,b:15
# circles:157,a:19,b:15
# circles:156,a:20,b:15
# circles:157,a:21,b:15
# circles:157,a:22,b:15
# circles:157,a:23,b:15
# circles:158,a:24,b:15
# circles:158,a:25,b:15
# circles:155,a:26,b:15
# circles:154,a:27,b:15
# circles:157,a:28,b:15
# circles:158,a:29,b:15
# circles:158,a:30,b:15
# circles:159,a:31,b:15
# circles:149,a:32,b:15
# circles:147,a:33,b:15
# circles:137,a:34,b:15
# circles:98,a:15,b:14
# circles:141,a:16,b:14
# circles:150,a:17,b:14
# circles:159,a:18,b:14
# circles:159,a:19,b:14
# circles:159,a:20,b:14
# circles:159,a:21,b:14
# circles:160,a:22,b:14
# Most common radius: 14

# %%
detected_circles_s = detect_circles(
    original_img_s, gray_blurred_s, 
    questions, options, mode_radius, a_t, b_t
)

detected_circles_k = detect_circles(
    original_img_k, gray_blurred_k, 
    questions, options, mode_radius, a_t, b_t
)
# Out:
# detect_circles: 157, a: 27, b: 14
# detect_circles: 157, a: 26, b: 14
# detect_circles: 156, a: 25, b: 14
# detect_circles: 155, a: 24, b: 14
# detect_circles: 155, a: 23, b: 14
# detect_circles: 152, a: 22, b: 14
# detect_circles: 150, a: 21, b: 14
# detect_circles: 151, a: 20, b: 14
# detect_circles: 152, a: 19, b: 14
# detect_circles: 149, a: 18, b: 14
# detect_circles: 122, a: 17, b: 14
# detect_circles: 103, a: 16, b: 14
# detect_circles: 91, a: 15, b: 14
# detect_circles: 16, a: 14, b: 14
# detect_circles: 160, a: 27, b: 13
# detect_circles: 157, a: 27, b: 14
# detect_circles: 157, a: 26, b: 14
# detect_circles: 159, a: 25, b: 14
# detect_circles: 159, a: 24, b: 14
# detect_circles: 158, a: 23, b: 14
# detect_circles: 158, a: 22, b: 14
# detect_circles: 158, a: 21, b: 14
# detect_circles: 158, a: 20, b: 14
# detect_circles: 159, a: 19, b: 14
# detect_circles: 157, a: 18, b: 14
# detect_circles: 128, a: 17, b: 14
# detect_circles: 110, a: 16, b: 14
# detect_circles: 104, a: 15, b: 14
# detect_circles: 21, a: 14, b: 14
# detect_circles: 160, a: 27, b: 13

# %% [markdown]
# ### 3. Pixel counts

# %%
import cv2
import numpy as np

def count_black_and_white_pixels(img, circles):
    """
    Count black and white pixels in the detected circles.

    Parameters:
    - img: The binary image (where black indicates marked areas).
    - circles: List of detected circles in the format (x, y, r).

    Returns:
    - A list of tuples containing counts of (black_pixels, white_pixels) for each circle.
    """
    counts = []

    for (x, y, r) in circles:
        # Create a mask for the current circle
        mask = np.zeros_like(img, dtype=np.uint8)
        cv2.circle(mask, (x, y), r, (255), thickness=-1)  # Fill the circle in the mask

        # Apply the mask to get the pixel values within the circle
        masked_area = cv2.bitwise_and(img, mask)

        # Count black and white pixels
        black_pixels = np.sum(masked_area == 0)   # Count of black pixels (0)
        white_pixels = np.sum(masked_area == 255) # Count of white pixels (255)

        counts.append((x,y,r,black_pixels, white_pixels))

    return counts

# %%
circles_s = detected_circles_s[0, :]
circles_t = detected_circles_t[0, :]  
circles_k = detected_circles_k[0, :]

# Count black and white pixels in the detected circles
pixel_counts_s = count_black_and_white_pixels(binary_img_s, circles_s)
pixel_counts_t = count_black_and_white_pixels(binary_img_t, circles_t)
pixel_counts_k = count_black_and_white_pixels(binary_img_k, circles_k)

# Print the results
print("students answer sheet")
for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_s, start=1):
    print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")

print("template")
for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_t, start=1):
    print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")

print("key")
for idx, (x, y,r, black_count, white_count) in enumerate(pixel_counts_k, start=1):
    print(f"Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")


# Draw the circles on the binary image for visualization
# for (x, y, r) in circles_s:
#     cv2.circle(binary_img_s, (x, y), r, (127), 2)
# cv2.imshow("Detected Circles in Binary Image student", binary_img_s)
# cv2.waitKey(0)


# for (x, y, r) in circles_t:
#     cv2.circle(binary_img_t, (x, y), r, (127), 2)  
# cv2.imshow("Detected Circles in Binary Image template", binary_img_t)
# cv2.waitKey(0)

# for (x, y, r) in circles_k:
#     cv2.circle(binary_img_k, (x, y), r, (127), 2)
# cv2.imshow("Detected Circles in Binary Image key(scheme)", binary_img_k)
# cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# students answer sheet
# Circle 1: Coordinates = (1108, 738), Black Pixels = 1721669, White Pixels = 481
# Circle 2: Coordinates = (1046, 804), Black Pixels = 1722148, White Pixels = 2
# Circle 3: Coordinates = (984, 544), Black Pixels = 1721631, White Pixels = 519
# Circle 4: Coordinates = (230, 274), Black Pixels = 1722075, White Pixels = 75
# Circle 5: Coordinates = (1340, 228), Black Pixels = 1721644, White Pixels = 506
# Circle 6: Coordinates = (168, 206), Black Pixels = 1721412, White Pixels = 738
# Circle 7: Coordinates = (1108, 804), Black Pixels = 1721667, White Pixels = 483
# Circle 8: Coordinates = (730, 608), Black Pixels = 1722135, White Pixels = 15
# Circle 9: Coordinates = (348, 610), Black Pixels = 1721553, White Pixels = 597
# Circle 10: Coordinates = (612, 412), Black Pixels = 1721604, White Pixels = 546
# Circle 11: Coordinates = (730, 542), Black Pixels = 1721576, White Pixels = 574
# Circle 12: Coordinates = (1346, 544), Black Pixels = 1721696, White Pixels = 454
# Circle 13: Coordinates = (1342, 290), Black Pixels = 1721635, White Pixels = 515
# Circle 14: Coordinates = (1460, 418), Black Pixels = 1721672, White Pixels = 478
# Circle 15: Coordinates = (292, 274), Black Pixels = 1721560, White Pixels = 590
# Circle 16: Coordinates = (222, 542), Black Pixels = 1721448, White Pixels = 702
# Circle 17: Coordinates = (550, 346), Black Pixels = 1722113, White Pixels = 37
# Circle 18: Coordinates = (156, 812), Black Pixels = 1722138, White Pixels = 12
# Circle 19: Coordinates = (1458, 354), Black Pixels = 1721658, White Pixels = 492
# Circle 20: Coordinates = (1400, 354), Black Pixels = 1721675, White Pixels = 475
# Circle 21: Coordinates = (350, 542), Black Pixels = 1721602, White Pixels = 548
# Circle 22: Coordinates = (732, 412), Black Pixels = 1721594, White Pixels = 556
# Circle 23: Coordinates = (280, 816), Black Pixels = 1721474, White Pixels = 676
# Circle 24: Coordinates = (542, 808), Black Pixels = 1721584, White Pixels = 566
# Circle 25: Coordinates = (924, 738), Black Pixels = 1721628, White Pixels = 522
# Circle 26: Coordinates = (928, 214), Black Pixels = 1721611, White Pixels = 539
# Circle 27: Coordinates = (288, 408), Black Pixels = 1721566, White Pixels = 584
# Circle 28: Coordinates = (924, 806), Black Pixels = 1721613, White Pixels = 537
# Circle 29: Coordinates = (162, 474), Black Pixels = 1721596, White Pixels = 554
# Circle 30: Coordinates = (158, 676), Black Pixels = 1721432, White Pixels = 718
# Circle 31: Coordinates = (730, 676), Black Pixels = 1722138, White Pixels = 12
# Circle 32: Coordinates = (1044, 672), Black Pixels = 1722138, White Pixels = 12
# Circle 33: Coordinates = (1458, 228), Black Pixels = 1721671, White Pixels = 479
# Circle 34: Coordinates = (164, 406), Black Pixels = 1721593, White Pixels = 557
# Circle 35: Coordinates = (1344, 354), Black Pixels = 1721650, White Pixels = 500
# Circle 36: Coordinates = (1458, 292), Black Pixels = 1721699, White Pixels = 451
# Circle 37: Coordinates = (730, 742), Black Pixels = 1722135, White Pixels = 15
# Circle 38: Coordinates = (1284, 352), Black Pixels = 1722126, White Pixels = 24
# Circle 39: Coordinates = (232, 208), Black Pixels = 1722088, White Pixels = 62
# Circle 40: Coordinates = (924, 544), Black Pixels = 1721665, White Pixels = 485
# Circle 41: Coordinates = (672, 412), Black Pixels = 1722070, White Pixels = 80
# Circle 42: Coordinates = (608, 674), Black Pixels = 1721594, White Pixels = 556
# Circle 43: Coordinates = (346, 746), Black Pixels = 1722132, White Pixels = 18
# Circle 44: Coordinates = (728, 810), Black Pixels = 1722150, White Pixels = 0
# Circle 45: Coordinates = (986, 284), Black Pixels = 1722143, White Pixels = 7
# Circle 46: Coordinates = (1350, 738), Black Pixels = 1721681, White Pixels = 469
# Circle 47: Coordinates = (986, 804), Black Pixels = 1721684, White Pixels = 466
# Circle 48: Coordinates = (984, 478), Black Pixels = 1721703, White Pixels = 447
# Circle 49: Coordinates = (166, 340), Black Pixels = 1721597, White Pixels = 553
# Circle 50: Coordinates = (550, 280), Black Pixels = 1722112, White Pixels = 38
# Circle 51: Coordinates = (286, 474), Black Pixels = 1722099, White Pixels = 51
# Circle 52: Coordinates = (1048, 218), Black Pixels = 1721669, White Pixels = 481
# Circle 53: Coordinates = (674, 282), Black Pixels = 1721413, White Pixels = 737
# Circle 54: Coordinates = (280, 746), Black Pixels = 1721504, White Pixels = 646
# Circle 55: Coordinates = (550, 412), Black Pixels = 1721636, White Pixels = 514
# Circle 56: Coordinates = (548, 476), Black Pixels = 1721626, White Pixels = 524
# Circle 57: Coordinates = (1462, 544), Black Pixels = 1721697, White Pixels = 453
# Circle 58: Coordinates = (924, 674), Black Pixels = 1721623, White Pixels = 527
# Circle 59: Coordinates = (1106, 608), Black Pixels = 1722118, White Pixels = 32
# Circle 60: Coordinates = (606, 740), Black Pixels = 1721540, White Pixels = 610
# Circle 61: Coordinates = (666, 810), Black Pixels = 1721559, White Pixels = 591
# Circle 62: Coordinates = (1290, 610), Black Pixels = 1721627, White Pixels = 523
# Circle 63: Coordinates = (1108, 674), Black Pixels = 1721667, White Pixels = 483
# Circle 64: Coordinates = (1046, 738), Black Pixels = 1722136, White Pixels = 14
# Circle 65: Coordinates = (226, 408), Black Pixels = 1722066, White Pixels = 84
# Circle 66: Coordinates = (670, 542), Black Pixels = 1722091, White Pixels = 59
# Circle 67: Coordinates = (610, 608), Black Pixels = 1721591, White Pixels = 559
# Circle 68: Coordinates = (284, 610), Black Pixels = 1722097, White Pixels = 53
# Circle 69: Coordinates = (282, 678), Black Pixels = 1722138, White Pixels = 12
# Circle 70: Coordinates = (546, 674), Black Pixels = 1721568, White Pixels = 582
# Circle 71: Coordinates = (346, 678), Black Pixels = 1721576, White Pixels = 574
# Circle 72: Coordinates = (1106, 414), Black Pixels = 1721708, White Pixels = 442
# Circle 73: Coordinates = (984, 608), Black Pixels = 1721721, White Pixels = 429
# Circle 74: Coordinates = (544, 740), Black Pixels = 1721566, White Pixels = 584
# Circle 75: Coordinates = (352, 474), Black Pixels = 1721540, White Pixels = 610
# Circle 76: Coordinates = (1106, 544), Black Pixels = 1722104, White Pixels = 46
# Circle 77: Coordinates = (674, 216), Black Pixels = 1721444, White Pixels = 706
# Circle 78: Coordinates = (1346, 608), Black Pixels = 1721663, White Pixels = 487
# Circle 79: Coordinates = (1468, 800), Black Pixels = 1721710, White Pixels = 440
# Circle 80: Coordinates = (218, 678), Black Pixels = 1721650, White Pixels = 500
# Circle 81: Coordinates = (1400, 292), Black Pixels = 1721724, White Pixels = 426
# Circle 82: Coordinates = (358, 274), Black Pixels = 1721558, White Pixels = 592
# Circle 83: Coordinates = (290, 340), Black Pixels = 1721519, White Pixels = 631
# Circle 84: Coordinates = (926, 282), Black Pixels = 1721625, White Pixels = 525
# Circle 85: Coordinates = (1408, 738), Black Pixels = 1721685, White Pixels = 465
# Circle 86: Coordinates = (732, 478), Black Pixels = 1721624, White Pixels = 526
# Circle 87: Coordinates = (610, 542), Black Pixels = 1721676, White Pixels = 474
# Circle 88: Coordinates = (1464, 672), Black Pixels = 1721687, White Pixels = 463
# Circle 89: Coordinates = (672, 348), Black Pixels = 1721485, White Pixels = 665
# Circle 90: Coordinates = (986, 348), Black Pixels = 1721681, White Pixels = 469
# Circle 91: Coordinates = (1288, 674), Black Pixels = 1721673, White Pixels = 477
# Circle 92: Coordinates = (986, 738), Black Pixels = 1721693, White Pixels = 457
# Circle 93: Coordinates = (158, 610), Black Pixels = 1721593, White Pixels = 557
# Circle 94: Coordinates = (668, 676), Black Pixels = 1721645, White Pixels = 505
# Circle 95: Coordinates = (1046, 414), Black Pixels = 1721709, White Pixels = 441
# Circle 96: Coordinates = (354, 408), Black Pixels = 1721597, White Pixels = 553
# Circle 97: Coordinates = (160, 542), Black Pixels = 1721514, White Pixels = 636
# Circle 98: Coordinates = (218, 746), Black Pixels = 1721552, White Pixels = 598
# Circle 99: Coordinates = (732, 346), Black Pixels = 1721559, White Pixels = 591
# Circle 100: Coordinates = (220, 610), Black Pixels = 1721644, White Pixels = 506
# Circle 101: Coordinates = (546, 608), Black Pixels = 1721637, White Pixels = 513
# Circle 102: Coordinates = (294, 208), Black Pixels = 1721531, White Pixels = 619
# Circle 103: Coordinates = (924, 414), Black Pixels = 1722118, White Pixels = 32
# Circle 104: Coordinates = (1348, 674), Black Pixels = 1721701, White Pixels = 449
# Circle 105: Coordinates = (224, 474), Black Pixels = 1721540, White Pixels = 610
# Circle 106: Coordinates = (168, 274), Black Pixels = 1721589, White Pixels = 561
# Circle 107: Coordinates = (1046, 348), Black Pixels = 1721717, White Pixels = 433
# Circle 108: Coordinates = (1106, 284), Black Pixels = 1721732, White Pixels = 418
# Circle 109: Coordinates = (1106, 220), Black Pixels = 1721728, White Pixels = 422
# Circle 110: Coordinates = (924, 478), Black Pixels = 1722137, White Pixels = 13
# Circle 111: Coordinates = (1108, 350), Black Pixels = 1722135, White Pixels = 15
# Circle 112: Coordinates = (612, 478), Black Pixels = 1721631, White Pixels = 519
# Circle 113: Coordinates = (156, 744), Black Pixels = 1721602, White Pixels = 548
# Circle 114: Coordinates = (668, 610), Black Pixels = 1721633, White Pixels = 517
# Circle 115: Coordinates = (924, 608), Black Pixels = 1721646, White Pixels = 504
# Circle 116: Coordinates = (228, 340), Black Pixels = 1722131, White Pixels = 19
# Circle 117: Coordinates = (1286, 544), Black Pixels = 1721675, White Pixels = 475
# Circle 118: Coordinates = (614, 218), Black Pixels = 1721605, White Pixels = 545
# Circle 119: Coordinates = (734, 214), Black Pixels = 1721553, White Pixels = 597
# Circle 120: Coordinates = (984, 672), Black Pixels = 1721731, White Pixels = 419
# Circle 121: Coordinates = (1352, 804), Black Pixels = 1721704, White Pixels = 446
# Circle 122: Coordinates = (666, 742), Black Pixels = 1721641, White Pixels = 509
# Circle 123: Coordinates = (1292, 738), Black Pixels = 1721675, White Pixels = 475
# Circle 124: Coordinates = (1460, 480), Black Pixels = 1721725, White Pixels = 425
# Circle 125: Coordinates = (552, 216), Black Pixels = 1722112, White Pixels = 38
# Circle 126: Coordinates = (1294, 804), Black Pixels = 1722073, White Pixels = 77
# Circle 127: Coordinates = (1406, 672), Black Pixels = 1722146, White Pixels = 4
# Circle 128: Coordinates = (216, 814), Black Pixels = 1721511, White Pixels = 639
# Circle 129: Coordinates = (548, 542), Black Pixels = 1721631, White Pixels = 519
# Circle 130: Coordinates = (986, 414), Black Pixels = 1721711, White Pixels = 439
# Circle 131: Coordinates = (1048, 284), Black Pixels = 1721727, White Pixels = 423
# Circle 132: Coordinates = (1106, 478), Black Pixels = 1721718, White Pixels = 432
# Circle 133: Coordinates = (1404, 546), Black Pixels = 1722096, White Pixels = 54
# Circle 134: Coordinates = (1464, 736), Black Pixels = 1722149, White Pixels = 1
# Circle 135: Coordinates = (1046, 544), Black Pixels = 1721734, White Pixels = 416
# Circle 136: Coordinates = (614, 346), Black Pixels = 1721603, White Pixels = 547
# Circle 137: Coordinates = (360, 210), Black Pixels = 1721612, White Pixels = 538
# Circle 138: Coordinates = (614, 284), Black Pixels = 1721617, White Pixels = 533
# Circle 139: Coordinates = (732, 280), Black Pixels = 1721556, White Pixels = 594
# Circle 140: Coordinates = (926, 348), Black Pixels = 1721646, White Pixels = 504
# Circle 141: Coordinates = (1408, 802), Black Pixels = 1721723, White Pixels = 427
# Circle 142: Coordinates = (1044, 478), Black Pixels = 1721704, White Pixels = 446
# Circle 143: Coordinates = (1282, 288), Black Pixels = 1722121, White Pixels = 29
# Circle 144: Coordinates = (1344, 416), Black Pixels = 1722121, White Pixels = 29
# Circle 145: Coordinates = (1404, 480), Black Pixels = 1721704, White Pixels = 446
# Circle 146: Coordinates = (1344, 480), Black Pixels = 1722150, White Pixels = 0
# Circle 147: Coordinates = (1402, 416), Black Pixels = 1721707, White Pixels = 443
# Circle 148: Coordinates = (1404, 608), Black Pixels = 1722149, White Pixels = 1
# Circle 149: Coordinates = (1462, 608), Black Pixels = 1721714, White Pixels = 436
# Circle 150: Coordinates = (344, 814), Black Pixels = 1721565, White Pixels = 585
# Circle 151: Coordinates = (606, 808), Black Pixels = 1721555, White Pixels = 595
# Circle 152: Coordinates = (284, 540), Black Pixels = 1722140, White Pixels = 10
# Circle 153: Coordinates = (1288, 480), Black Pixels = 1721693, White Pixels = 457
# Circle 154: Coordinates = (354, 342), Black Pixels = 1721637, White Pixels = 513
# Circle 155: Coordinates = (1400, 228), Black Pixels = 1721706, White Pixels = 444
# Circle 156: Coordinates = (1282, 226), Black Pixels = 1722146, White Pixels = 4
# Circle 157: Coordinates = (986, 216), Black Pixels = 1722133, White Pixels = 17
# Circle 158: Coordinates = (1046, 608), Black Pixels = 1721726, White Pixels = 424
# Circle 159: Coordinates = (1286, 416), Black Pixels = 1721674, White Pixels = 476
# Circle 160: Coordinates = (672, 476), Black Pixels = 1722123, White Pixels = 27
# template
# Circle 1: Coordinates = (1354, 248), Black Pixels = 1776109, White Pixels = 509
# Circle 2: Coordinates = (272, 448), Black Pixels = 1776023, White Pixels = 595
# Circle 3: Coordinates = (1356, 576), Black Pixels = 1776136, White Pixels = 482
# Circle 4: Coordinates = (274, 788), Black Pixels = 1776018, White Pixels = 600
# Circle 5: Coordinates = (340, 788), Black Pixels = 1776057, White Pixels = 561
# Circle 6: Coordinates = (340, 584), Black Pixels = 1776033, White Pixels = 585
# Circle 7: Coordinates = (1046, 776), Black Pixels = 1776166, White Pixels = 452
# Circle 8: Coordinates = (208, 652), Black Pixels = 1776056, White Pixels = 562
# Circle 9: Coordinates = (1046, 446), Black Pixels = 1776164, White Pixels = 454
# Circle 10: Coordinates = (338, 516), Black Pixels = 1776024, White Pixels = 594
# Circle 11: Coordinates = (538, 580), Black Pixels = 1776026, White Pixels = 592
# Circle 12: Coordinates = (600, 248), Black Pixels = 1776067, White Pixels = 551
# Circle 13: Coordinates = (1108, 512), Black Pixels = 1776137, White Pixels = 481
# Circle 14: Coordinates = (144, 722), Black Pixels = 1775949, White Pixels = 669
# Circle 15: Coordinates = (602, 580), Black Pixels = 1776042, White Pixels = 576
# Circle 16: Coordinates = (276, 652), Black Pixels = 1776055, White Pixels = 563
# Circle 17: Coordinates = (984, 312), Black Pixels = 1776155, White Pixels = 463
# Circle 18: Coordinates = (274, 244), Black Pixels = 1776051, White Pixels = 567
# Circle 19: Coordinates = (922, 512), Black Pixels = 1776095, White Pixels = 523
# Circle 20: Coordinates = (1482, 774), Black Pixels = 1776155, White Pixels = 463
# Circle 21: Coordinates = (984, 710), Black Pixels = 1776188, White Pixels = 430
# Circle 22: Coordinates = (724, 850), Black Pixels = 1776052, White Pixels = 566
# Circle 23: Coordinates = (1108, 578), Black Pixels = 1776117, White Pixels = 501
# Circle 24: Coordinates = (724, 648), Black Pixels = 1776067, White Pixels = 551
# Circle 25: Coordinates = (272, 516), Black Pixels = 1776015, White Pixels = 603
# Circle 26: Coordinates = (340, 244), Black Pixels = 1776052, White Pixels = 566
# Circle 27: Coordinates = (148, 246), Black Pixels = 1775882, White Pixels = 736
# Circle 28: Coordinates = (1046, 312), Black Pixels = 1776142, White Pixels = 476
# Circle 29: Coordinates = (1476, 314), Black Pixels = 1776164, White Pixels = 454
# Circle 30: Coordinates = (538, 782), Black Pixels = 1776013, White Pixels = 605
# Circle 31: Coordinates = (602, 514), Black Pixels = 1776084, White Pixels = 534
# Circle 32: Coordinates = (1358, 774), Black Pixels = 1776168, White Pixels = 450
# Circle 33: Coordinates = (208, 448), Black Pixels = 1776010, White Pixels = 608
# Circle 34: Coordinates = (724, 446), Black Pixels = 1776061, White Pixels = 557
# Circle 35: Coordinates = (984, 512), Black Pixels = 1776165, White Pixels = 453
# Circle 36: Coordinates = (602, 712), Black Pixels = 1776111, White Pixels = 507
# Circle 37: Coordinates = (924, 242), Black Pixels = 1775992, White Pixels = 626
# Circle 38: Coordinates = (208, 858), Black Pixels = 1776020, White Pixels = 598
# Circle 39: Coordinates = (922, 776), Black Pixels = 1776117, White Pixels = 501
# Circle 40: Coordinates = (1110, 842), Black Pixels = 1776147, White Pixels = 471
# Circle 41: Coordinates = (1046, 708), Black Pixels = 1776165, White Pixels = 453
# Circle 42: Coordinates = (724, 312), Black Pixels = 1776112, White Pixels = 506
# Circle 43: Coordinates = (1108, 644), Black Pixels = 1776191, White Pixels = 427
# Circle 44: Coordinates = (538, 714), Black Pixels = 1775967, White Pixels = 651
# Circle 45: Coordinates = (1476, 510), Black Pixels = 1776153, White Pixels = 465
# Circle 46: Coordinates = (1298, 708), Black Pixels = 1776118, White Pixels = 500
# Circle 47: Coordinates = (1356, 378), Black Pixels = 1776144, White Pixels = 474
# Circle 48: Coordinates = (1422, 840), Black Pixels = 1776133, White Pixels = 485
# Circle 49: Coordinates = (984, 578), Black Pixels = 1776166, White Pixels = 452
# Circle 50: Coordinates = (208, 584), Black Pixels = 1776046, White Pixels = 572
# Circle 51: Coordinates = (1294, 314), Black Pixels = 1776078, White Pixels = 540
# Circle 52: Coordinates = (1046, 378), Black Pixels = 1776122, White Pixels = 496
# Circle 53: Coordinates = (340, 312), Black Pixels = 1776076, White Pixels = 542
# Circle 54: Coordinates = (724, 580), Black Pixels = 1776048, White Pixels = 570
# Circle 55: Coordinates = (662, 648), Black Pixels = 1775970, White Pixels = 648
# Circle 56: Coordinates = (1110, 378), Black Pixels = 1776159, White Pixels = 459
# Circle 57: Coordinates = (1476, 444), Black Pixels = 1776154, White Pixels = 464
# Circle 58: Coordinates = (274, 856), Black Pixels = 1776098, White Pixels = 520
# Circle 59: Coordinates = (602, 646), Black Pixels = 1776046, White Pixels = 572
# Circle 60: Coordinates = (338, 380), Black Pixels = 1776018, White Pixels = 600
# Circle 61: Coordinates = (1480, 706), Black Pixels = 1776141, White Pixels = 477
# Circle 62: Coordinates = (538, 514), Black Pixels = 1776030, White Pixels = 588
# Circle 63: Coordinates = (984, 644), Black Pixels = 1776205, White Pixels = 413
# Circle 64: Coordinates = (210, 790), Black Pixels = 1776000, White Pixels = 618
# Circle 65: Coordinates = (922, 446), Black Pixels = 1776106, White Pixels = 512
# Circle 66: Coordinates = (600, 314), Black Pixels = 1776142, White Pixels = 476
# Circle 67: Coordinates = (724, 714), Black Pixels = 1776047, White Pixels = 571
# Circle 68: Coordinates = (538, 848), Black Pixels = 1776044, White Pixels = 574
# Circle 69: Coordinates = (662, 580), Black Pixels = 1775943, White Pixels = 675
# Circle 70: Coordinates = (1108, 710), Black Pixels = 1776137, White Pixels = 481
# Circle 71: Coordinates = (1356, 314), Black Pixels = 1776099, White Pixels = 519
# Circle 72: Coordinates = (1356, 510), Black Pixels = 1776170, White Pixels = 448
# Circle 73: Coordinates = (724, 380), Black Pixels = 1776116, White Pixels = 502
# Circle 74: Coordinates = (1420, 774), Black Pixels = 1776177, White Pixels = 441
# Circle 75: Coordinates = (924, 310), Black Pixels = 1776071, White Pixels = 547
# Circle 76: Coordinates = (602, 382), Black Pixels = 1776063, White Pixels = 555
# Circle 77: Coordinates = (602, 448), Black Pixels = 1776088, White Pixels = 530
# Circle 78: Coordinates = (662, 246), Black Pixels = 1775955, White Pixels = 663
# Circle 79: Coordinates = (662, 514), Black Pixels = 1775982, White Pixels = 636
# Circle 80: Coordinates = (924, 844), Black Pixels = 1776087, White Pixels = 531
# Circle 81: Coordinates = (1478, 640), Black Pixels = 1776146, White Pixels = 472
# Circle 82: Coordinates = (600, 778), Black Pixels = 1775955, White Pixels = 663
# Circle 83: Coordinates = (662, 314), Black Pixels = 1775922, White Pixels = 696
# Circle 84: Coordinates = (340, 856), Black Pixels = 1776081, White Pixels = 537
# Circle 85: Coordinates = (984, 776), Black Pixels = 1776193, White Pixels = 425
# Circle 86: Coordinates = (1108, 446), Black Pixels = 1776167, White Pixels = 451
# Circle 87: Coordinates = (342, 720), Black Pixels = 1776072, White Pixels = 546
# Circle 88: Coordinates = (536, 246), Black Pixels = 1776008, White Pixels = 610
# Circle 89: Coordinates = (724, 782), Black Pixels = 1776105, White Pixels = 513
# Circle 90: Coordinates = (340, 448), Black Pixels = 1776099, White Pixels = 519
# Circle 91: Coordinates = (144, 654), Black Pixels = 1776016, White Pixels = 602
# Circle 92: Coordinates = (210, 380), Black Pixels = 1776018, White Pixels = 600
# Circle 93: Coordinates = (144, 790), Black Pixels = 1775934, White Pixels = 684
# Circle 94: Coordinates = (984, 842), Black Pixels = 1776170, White Pixels = 448
# Circle 95: Coordinates = (272, 380), Black Pixels = 1776025, White Pixels = 593
# Circle 96: Coordinates = (276, 720), Black Pixels = 1776062, White Pixels = 556
# Circle 97: Coordinates = (922, 578), Black Pixels = 1776107, White Pixels = 511
# Circle 98: Coordinates = (986, 244), Black Pixels = 1776190, White Pixels = 428
# Circle 99: Coordinates = (660, 850), Black Pixels = 1776021, White Pixels = 597
# Circle 100: Coordinates = (342, 652), Black Pixels = 1776104, White Pixels = 514
# Circle 101: Coordinates = (662, 446), Black Pixels = 1776002, White Pixels = 616
# Circle 102: Coordinates = (1044, 512), Black Pixels = 1776172, White Pixels = 446
# Circle 103: Coordinates = (1418, 642), Black Pixels = 1776164, White Pixels = 454
# Circle 104: Coordinates = (1108, 246), Black Pixels = 1776201, White Pixels = 417
# Circle 105: Coordinates = (210, 312), Black Pixels = 1775940, White Pixels = 678
# Circle 106: Coordinates = (1294, 378), Black Pixels = 1776070, White Pixels = 548
# Circle 107: Coordinates = (210, 244), Black Pixels = 1776113, White Pixels = 505
# Circle 108: Coordinates = (1294, 446), Black Pixels = 1776145, White Pixels = 473
# Circle 109: Coordinates = (1298, 842), Black Pixels = 1776126, White Pixels = 492
# Circle 110: Coordinates = (1108, 312), Black Pixels = 1776154, White Pixels = 464
# Circle 111: Coordinates = (1046, 244), Black Pixels = 1776199, White Pixels = 419
# Circle 112: Coordinates = (922, 380), Black Pixels = 1776129, White Pixels = 489
# Circle 113: Coordinates = (662, 380), Black Pixels = 1776082, White Pixels = 536
# Circle 114: Coordinates = (1294, 512), Black Pixels = 1776129, White Pixels = 489
# Circle 115: Coordinates = (724, 244), Black Pixels = 1776043, White Pixels = 575
# Circle 116: Coordinates = (144, 516), Black Pixels = 1776061, White Pixels = 557
# Circle 117: Coordinates = (724, 514), Black Pixels = 1776148, White Pixels = 470
# Circle 118: Coordinates = (1296, 644), Black Pixels = 1776157, White Pixels = 461
# Circle 119: Coordinates = (1476, 250), Black Pixels = 1776203, White Pixels = 415
# Circle 120: Coordinates = (1416, 576), Black Pixels = 1776161, White Pixels = 457
# Circle 121: Coordinates = (1416, 510), Black Pixels = 1776170, White Pixels = 448
# Circle 122: Coordinates = (538, 448), Black Pixels = 1776105, White Pixels = 513
# Circle 123: Coordinates = (1108, 776), Black Pixels = 1776200, White Pixels = 418
# Circle 124: Coordinates = (922, 644), Black Pixels = 1776117, White Pixels = 501
# Circle 125: Coordinates = (148, 312), Black Pixels = 1775787, White Pixels = 831
# Circle 126: Coordinates = (660, 782), Black Pixels = 1775960, White Pixels = 658
# Circle 127: Coordinates = (1484, 840), Black Pixels = 1776199, White Pixels = 419
# Circle 128: Coordinates = (1292, 248), Black Pixels = 1776113, White Pixels = 505
# Circle 129: Coordinates = (1416, 314), Black Pixels = 1776175, White Pixels = 443
# Circle 130: Coordinates = (1474, 576), Black Pixels = 1776175, White Pixels = 443
# Circle 131: Coordinates = (208, 516), Black Pixels = 1776010, White Pixels = 608
# Circle 132: Coordinates = (1044, 578), Black Pixels = 1776165, White Pixels = 453
# Circle 133: Coordinates = (1418, 708), Black Pixels = 1776172, White Pixels = 446
# Circle 134: Coordinates = (1416, 380), Black Pixels = 1776177, White Pixels = 441
# Circle 135: Coordinates = (146, 448), Black Pixels = 1776066, White Pixels = 552
# Circle 136: Coordinates = (984, 378), Black Pixels = 1776196, White Pixels = 422
# Circle 137: Coordinates = (142, 584), Black Pixels = 1775952, White Pixels = 666
# Circle 138: Coordinates = (1416, 444), Black Pixels = 1776199, White Pixels = 419
# Circle 139: Coordinates = (274, 584), Black Pixels = 1776074, White Pixels = 544
# Circle 140: Coordinates = (538, 380), Black Pixels = 1776110, White Pixels = 508
# Circle 141: Coordinates = (600, 848), Black Pixels = 1776163, White Pixels = 455
# Circle 142: Coordinates = (536, 312), Black Pixels = 1776024, White Pixels = 594
# Circle 143: Coordinates = (144, 858), Black Pixels = 1775993, White Pixels = 625
# Circle 144: Coordinates = (1360, 840), Black Pixels = 1776176, White Pixels = 442
# Circle 145: Coordinates = (1414, 248), Black Pixels = 1776189, White Pixels = 429
# Circle 146: Coordinates = (538, 648), Black Pixels = 1776114, White Pixels = 504
# Circle 147: Coordinates = (984, 446), Black Pixels = 1776185, White Pixels = 433
# Circle 148: Coordinates = (922, 710), Black Pixels = 1776124, White Pixels = 494
# Circle 149: Coordinates = (208, 720), Black Pixels = 1776124, White Pixels = 494
# Circle 150: Coordinates = (1476, 380), Black Pixels = 1776174, White Pixels = 444
# Circle 151: Coordinates = (660, 714), Black Pixels = 1775917, White Pixels = 701
# Circle 152: Coordinates = (1298, 776), Black Pixels = 1776151, White Pixels = 467
# Circle 153: Coordinates = (1358, 708), Black Pixels = 1776196, White Pixels = 422
# Circle 154: Coordinates = (1048, 840), Black Pixels = 1776122, White Pixels = 496
# Circle 155: Coordinates = (1296, 576), Black Pixels = 1776201, White Pixels = 417
# Circle 156: Coordinates = (274, 310), Black Pixels = 1776115, White Pixels = 503
# Circle 157: Coordinates = (1356, 642), Black Pixels = 1776186, White Pixels = 432
# Circle 158: Coordinates = (146, 380), Black Pixels = 1776076, White Pixels = 542
# Circle 159: Coordinates = (1356, 446), Black Pixels = 1776190, White Pixels = 428
# Circle 160: Coordinates = (1044, 644), Black Pixels = 1776213, White Pixels = 405
# key
# Circle 1: Coordinates = (664, 220), Black Pixels = 1712323, White Pixels = 747
# Circle 2: Coordinates = (284, 410), Black Pixels = 1712345, White Pixels = 725
# Circle 3: Coordinates = (724, 480), Black Pixels = 1712916, White Pixels = 154
# Circle 4: Coordinates = (288, 278), Black Pixels = 1712431, White Pixels = 639
# Circle 5: Coordinates = (538, 738), Black Pixels = 1712436, White Pixels = 634
# Circle 6: Coordinates = (976, 352), Black Pixels = 1712529, White Pixels = 541
# Circle 7: Coordinates = (914, 802), Black Pixels = 1713063, White Pixels = 7
# Circle 8: Coordinates = (1396, 356), Black Pixels = 1712561, White Pixels = 509
# Circle 9: Coordinates = (158, 542), Black Pixels = 1712446, White Pixels = 624
# Circle 10: Coordinates = (540, 544), Black Pixels = 1712455, White Pixels = 615
# Circle 11: Coordinates = (722, 610), Black Pixels = 1712987, White Pixels = 83
# Circle 12: Coordinates = (1336, 230), Black Pixels = 1712537, White Pixels = 533
# Circle 13: Coordinates = (1278, 548), Black Pixels = 1712540, White Pixels = 530
# Circle 14: Coordinates = (1454, 358), Black Pixels = 1712565, White Pixels = 505
# Circle 15: Coordinates = (284, 476), Black Pixels = 1712366, White Pixels = 704
# Circle 16: Coordinates = (1336, 676), Black Pixels = 1712590, White Pixels = 480
# Circle 17: Coordinates = (352, 216), Black Pixels = 1712540, White Pixels = 530
# Circle 18: Coordinates = (1096, 738), Black Pixels = 1712562, White Pixels = 508
# Circle 19: Coordinates = (1278, 356), Black Pixels = 1712446, White Pixels = 624
# Circle 20: Coordinates = (1396, 294), Black Pixels = 1712574, White Pixels = 496
# Circle 21: Coordinates = (1096, 802), Black Pixels = 1712573, White Pixels = 497
# Circle 22: Coordinates = (540, 608), Black Pixels = 1712489, White Pixels = 581
# Circle 23: Coordinates = (540, 414), Black Pixels = 1712993, White Pixels = 77
# Circle 24: Coordinates = (1396, 484), Black Pixels = 1712589, White Pixels = 481
# Circle 25: Coordinates = (156, 674), Black Pixels = 1712386, White Pixels = 684
# Circle 26: Coordinates = (222, 542), Black Pixels = 1712417, White Pixels = 653
# Circle 27: Coordinates = (220, 610), Black Pixels = 1712471, White Pixels = 599
# Circle 28: Coordinates = (280, 744), Black Pixels = 1712422, White Pixels = 648
# Circle 29: Coordinates = (216, 808), Black Pixels = 1712408, White Pixels = 662
# Circle 30: Coordinates = (218, 676), Black Pixels = 1712447, White Pixels = 623
# Circle 31: Coordinates = (1340, 804), Black Pixels = 1712549, White Pixels = 521
# Circle 32: Coordinates = (1394, 232), Black Pixels = 1712549, White Pixels = 521
# Circle 33: Coordinates = (280, 676), Black Pixels = 1712440, White Pixels = 630
# Circle 34: Coordinates = (660, 674), Black Pixels = 1712424, White Pixels = 646
# Circle 35: Coordinates = (664, 480), Black Pixels = 1712349, White Pixels = 721
# Circle 36: Coordinates = (722, 806), Black Pixels = 1713055, White Pixels = 15
# Circle 37: Coordinates = (664, 286), Black Pixels = 1712414, White Pixels = 656
# Circle 38: Coordinates = (158, 608), Black Pixels = 1712431, White Pixels = 639
# Circle 39: Coordinates = (1338, 420), Black Pixels = 1712501, White Pixels = 569
# Circle 40: Coordinates = (226, 212), Black Pixels = 1713011, White Pixels = 59
# Circle 41: Coordinates = (916, 416), Black Pixels = 1713063, White Pixels = 7
# Circle 42: Coordinates = (1336, 294), Black Pixels = 1713070, White Pixels = 0
# Circle 43: Coordinates = (604, 350), Black Pixels = 1713012, White Pixels = 58
# Circle 44: Coordinates = (1038, 288), Black Pixels = 1712508, White Pixels = 562
# Circle 45: Coordinates = (536, 804), Black Pixels = 1712494, White Pixels = 576
# Circle 46: Coordinates = (538, 674), Black Pixels = 1713055, White Pixels = 15
# Circle 47: Coordinates = (916, 352), Black Pixels = 1713053, White Pixels = 17
# Circle 48: Coordinates = (278, 810), Black Pixels = 1712472, White Pixels = 598
# Circle 49: Coordinates = (664, 414), Black Pixels = 1712326, White Pixels = 744
# Circle 50: Coordinates = (542, 282), Black Pixels = 1712459, White Pixels = 611
# Circle 51: Coordinates = (1396, 420), Black Pixels = 1712577, White Pixels = 493
# Circle 52: Coordinates = (974, 672), Black Pixels = 1712624, White Pixels = 446
# Circle 53: Coordinates = (162, 278), Black Pixels = 1712329, White Pixels = 741
# Circle 54: Coordinates = (286, 344), Black Pixels = 1712368, White Pixels = 702
# Circle 55: Coordinates = (724, 414), Black Pixels = 1712425, White Pixels = 645
# Circle 56: Coordinates = (282, 610), Black Pixels = 1712946, White Pixels = 124
# Circle 57: Coordinates = (224, 410), Black Pixels = 1712462, White Pixels = 608
# Circle 58: Coordinates = (348, 478), Black Pixels = 1712583, White Pixels = 487
# Circle 59: Coordinates = (1096, 610), Black Pixels = 1712563, White Pixels = 507
# Circle 60: Coordinates = (344, 676), Black Pixels = 1713047, White Pixels = 23
# Circle 61: Coordinates = (222, 476), Black Pixels = 1712430, White Pixels = 640
# Circle 62: Coordinates = (352, 280), Black Pixels = 1712501, White Pixels = 569
# Circle 63: Coordinates = (1394, 612), Black Pixels = 1713039, White Pixels = 31
# Circle 64: Coordinates = (914, 672), Black Pixels = 1713065, White Pixels = 5
# Circle 65: Coordinates = (1278, 612), Black Pixels = 1712548, White Pixels = 522
# Circle 66: Coordinates = (600, 738), Black Pixels = 1712478, White Pixels = 592
# Circle 67: Coordinates = (1454, 676), Black Pixels = 1712613, White Pixels = 457
# Circle 68: Coordinates = (914, 544), Black Pixels = 1712564, White Pixels = 506
# Circle 69: Coordinates = (602, 608), Black Pixels = 1712528, White Pixels = 542
# Circle 70: Coordinates = (1036, 418), Black Pixels = 1712605, White Pixels = 465
# Circle 71: Coordinates = (156, 742), Black Pixels = 1712334, White Pixels = 736
# Circle 72: Coordinates = (974, 738), Black Pixels = 1712595, White Pixels = 475
# Circle 73: Coordinates = (344, 744), Black Pixels = 1713035, White Pixels = 35
# Circle 74: Coordinates = (158, 476), Black Pixels = 1713056, White Pixels = 14
# Circle 75: Coordinates = (1098, 354), Black Pixels = 1712600, White Pixels = 470
# Circle 76: Coordinates = (604, 414), Black Pixels = 1712580, White Pixels = 490
# Circle 77: Coordinates = (1280, 804), Black Pixels = 1712531, White Pixels = 539
# Circle 78: Coordinates = (346, 544), Black Pixels = 1712444, White Pixels = 626
# Circle 79: Coordinates = (1278, 420), Black Pixels = 1713038, White Pixels = 32
# Circle 80: Coordinates = (162, 344), Black Pixels = 1712512, White Pixels = 558
# Circle 81: Coordinates = (542, 348), Black Pixels = 1712532, White Pixels = 538
# Circle 82: Coordinates = (1096, 418), Black Pixels = 1712606, White Pixels = 464
# Circle 83: Coordinates = (1452, 548), Black Pixels = 1712613, White Pixels = 457
# Circle 84: Coordinates = (600, 674), Black Pixels = 1712546, White Pixels = 524
# Circle 85: Coordinates = (602, 544), Black Pixels = 1712557, White Pixels = 513
# Circle 86: Coordinates = (1338, 484), Black Pixels = 1712579, White Pixels = 491
# Circle 87: Coordinates = (914, 736), Black Pixels = 1712590, White Pixels = 480
# Circle 88: Coordinates = (1400, 804), Black Pixels = 1712594, White Pixels = 476
# Circle 89: Coordinates = (604, 286), Black Pixels = 1712996, White Pixels = 74
# Circle 90: Coordinates = (1034, 738), Black Pixels = 1713066, White Pixels = 4
# Circle 91: Coordinates = (1034, 610), Black Pixels = 1712572, White Pixels = 498
# Circle 92: Coordinates = (156, 808), Black Pixels = 1713051, White Pixels = 19
# Circle 93: Coordinates = (978, 288), Black Pixels = 1713058, White Pixels = 12
# Circle 94: Coordinates = (1278, 740), Black Pixels = 1713069, White Pixels = 1
# Circle 95: Coordinates = (1394, 548), Black Pixels = 1713065, White Pixels = 5
# Circle 96: Coordinates = (660, 806), Black Pixels = 1712520, White Pixels = 550
# Circle 97: Coordinates = (1096, 674), Black Pixels = 1712566, White Pixels = 504
# Circle 98: Coordinates = (350, 346), Black Pixels = 1712579, White Pixels = 491
# Circle 99: Coordinates = (662, 544), Black Pixels = 1712541, White Pixels = 529
# Circle 100: Coordinates = (1038, 352), Black Pixels = 1712622, White Pixels = 448
# Circle 101: Coordinates = (598, 804), Black Pixels = 1712470, White Pixels = 600
# Circle 102: Coordinates = (1038, 224), Black Pixels = 1712581, White Pixels = 489
# Circle 103: Coordinates = (1338, 356), Black Pixels = 1713066, White Pixels = 4
# Circle 104: Coordinates = (1452, 612), Black Pixels = 1712602, White Pixels = 468
# Circle 105: Coordinates = (920, 220), Black Pixels = 1712521, White Pixels = 549
# Circle 106: Coordinates = (976, 418), Black Pixels = 1712600, White Pixels = 470
# Circle 107: Coordinates = (1096, 482), Black Pixels = 1712581, White Pixels = 489
# Circle 108: Coordinates = (918, 286), Black Pixels = 1712568, White Pixels = 502
# Circle 109: Coordinates = (162, 212), Black Pixels = 1712369, White Pixels = 701
# Circle 110: Coordinates = (722, 544), Black Pixels = 1712991, White Pixels = 79
# Circle 111: Coordinates = (974, 608), Black Pixels = 1712596, White Pixels = 474
# Circle 112: Coordinates = (974, 482), Black Pixels = 1712611, White Pixels = 459
# Circle 113: Coordinates = (1336, 548), Black Pixels = 1712568, White Pixels = 502
# Circle 114: Coordinates = (660, 740), Black Pixels = 1712568, White Pixels = 502
# Circle 115: Coordinates = (1094, 546), Black Pixels = 1712619, White Pixels = 451
# Circle 116: Coordinates = (1034, 546), Black Pixels = 1713039, White Pixels = 31
# Circle 117: Coordinates = (348, 412), Black Pixels = 1712527, White Pixels = 543
# Circle 118: Coordinates = (724, 350), Black Pixels = 1712491, White Pixels = 579
# Circle 119: Coordinates = (664, 350), Black Pixels = 1712518, White Pixels = 552
# Circle 120: Coordinates = (1278, 676), Black Pixels = 1713057, White Pixels = 13
# Circle 121: Coordinates = (1276, 292), Black Pixels = 1712514, White Pixels = 556
# Circle 122: Coordinates = (722, 674), Black Pixels = 1712563, White Pixels = 507
# Circle 123: Coordinates = (1454, 232), Black Pixels = 1712615, White Pixels = 455
# Circle 124: Coordinates = (1454, 294), Black Pixels = 1712624, White Pixels = 446
# Circle 125: Coordinates = (662, 610), Black Pixels = 1712576, White Pixels = 494
# Circle 126: Coordinates = (1398, 740), Black Pixels = 1712599, White Pixels = 471
# Circle 127: Coordinates = (1394, 674), Black Pixels = 1712632, White Pixels = 438
# Circle 128: Coordinates = (914, 608), Black Pixels = 1713060, White Pixels = 10
# Circle 129: Coordinates = (1338, 738), Black Pixels = 1712584, White Pixels = 486
# Circle 130: Coordinates = (1456, 740), Black Pixels = 1712573, White Pixels = 497
# Circle 131: Coordinates = (344, 610), Black Pixels = 1712598, White Pixels = 472
# Circle 132: Coordinates = (1098, 226), Black Pixels = 1712634, White Pixels = 436
# Circle 133: Coordinates = (1034, 674), Black Pixels = 1712619, White Pixels = 451
# Circle 134: Coordinates = (160, 410), Black Pixels = 1713040, White Pixels = 30
# Circle 135: Coordinates = (224, 346), Black Pixels = 1713036, White Pixels = 34
# Circle 136: Coordinates = (1454, 420), Black Pixels = 1712636, White Pixels = 434
# Circle 137: Coordinates = (1034, 482), Black Pixels = 1713065, White Pixels = 5
# Circle 138: Coordinates = (342, 810), Black Pixels = 1712500, White Pixels = 570
# Circle 139: Coordinates = (1098, 290), Black Pixels = 1712614, White Pixels = 456
# Circle 140: Coordinates = (1454, 484), Black Pixels = 1712619, White Pixels = 451
# Circle 141: Coordinates = (284, 542), Black Pixels = 1713013, White Pixels = 57
# Circle 142: Coordinates = (978, 224), Black Pixels = 1713055, White Pixels = 15
# Circle 143: Coordinates = (290, 214), Black Pixels = 1712571, White Pixels = 499
# Circle 144: Coordinates = (1034, 802), Black Pixels = 1712575, White Pixels = 495
# Circle 145: Coordinates = (724, 284), Black Pixels = 1712542, White Pixels = 528
# Circle 146: Coordinates = (726, 218), Black Pixels = 1712548, White Pixels = 522
# Circle 147: Coordinates = (914, 482), Black Pixels = 1712608, White Pixels = 462
# Circle 148: Coordinates = (974, 546), Black Pixels = 1712615, White Pixels = 455
# Circle 149: Coordinates = (542, 218), Black Pixels = 1713050, White Pixels = 20
# Circle 150: Coordinates = (604, 220), Black Pixels = 1712588, White Pixels = 482
# Circle 151: Coordinates = (1336, 612), Black Pixels = 1712680, White Pixels = 390
# Circle 152: Coordinates = (226, 280), Black Pixels = 1712941, White Pixels = 129
# Circle 153: Coordinates = (602, 478), Black Pixels = 1712632, White Pixels = 438
# Circle 154: Coordinates = (974, 802), Black Pixels = 1712604, White Pixels = 466
# Circle 155: Coordinates = (722, 740), Black Pixels = 1713068, White Pixels = 2
# Circle 156: Coordinates = (218, 742), Black Pixels = 1712551, White Pixels = 519
# Circle 157: Coordinates = (1458, 804), Black Pixels = 1713061, White Pixels = 9
# Circle 158: Coordinates = (1276, 482), Black Pixels = 1713064, White Pixels = 6
# Circle 159: Coordinates = (540, 478), Black Pixels = 1712532, White Pixels = 538
# Circle 160: Coordinates = (1276, 230), Black Pixels = 1713045, White Pixels = 25

# %% [markdown]
# ### additional

# %% [markdown]
# #### Pixel count list to json

# %%
# Convert the list to a JSON string
import json
input_list_as_int = [tuple(int(x) for x in tpl) for tpl in pixel_counts_t]
json_data = json.dumps(input_list_as_int, indent=4)

# %%
# Save the JSON string to a file
save_path = "./output/pixel_counts_template.json"
with open(save_path, "w") as file:
    file.write(json_data)

# %% [markdown]
# #### draw detected circles using pixel count

# %%
import cv2
import json
import numpy as np

def draw_detected_circles(image_path, pixel_count_json, output_path):
    """
    Draws detected circles on the given image based on pixel count data.
    
    Parameters:
    - image_path (str): Path to the original image.
    - pixel_count_json (str): Path to the JSON file containing circle coordinates and radius.
    - output_path (str): Path to save the output image with drawn circles.
    """
    # Load the image
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    if image is None:
        raise ValueError(f"Error: Unable to load image from {image_path}")
    
    # Load the JSON data
    with open(pixel_count_json, 'r') as file:
        circles = json.load(file)
    
    # Draw each circle
    for circle in circles:
        x, y, r, _, _ = circle  # Extract circle parameters
        cv2.circle(image, (x, y), r, (0, 255, 0), 2)  # Draw the circle
        cv2.circle(image, (x, y), 2, (0, 0, 255), 3)  # Mark the center
    
    # Save the image with drawn circles
    cv2.imwrite(output_path, image)
    print(f"Output image saved at {output_path}")

# Example usage:
draw_detected_circles("./Test/7_T.jpg", "./output/pixel_counts_template.json", "./output/detect_from_json.jpg")
# Out:
# Output image saved at ./output/detect_from_json.jpg

# %% [markdown]
# ### 4. Divide the circles by rows

# %% [markdown]
# #### method using tolerance

# %%
from collections import defaultdict
import numpy as np

def group_circles_by_rows(circles, percentage=0.5):
    # Sort circles by y-coordinate (vertical position)
    sorted_circles = sorted(circles, key=lambda x: x[1])

    # Calculate the average vertical distance between consecutive circles
    y_distances = [sorted_circles[i+1][1] - sorted_circles[i][1] for i in range(len(sorted_circles) - 1)]
    avg_distance = np.mean(y_distances)
    print(f"Average distance between circles: {avg_distance}")
    # Set the tolerance as a percentage of the average distance
    tolerance = percentage * avg_distance

    # Group circles into rows based on y-coordinate proximity
    grouped_by_rows = defaultdict(list)
    for circle in sorted_circles:
        x, y, r = circle[0], circle[1], circle[2]

        # Find the row where this circle belongs based on y-coordinate
        assigned = False
        for row_y in grouped_by_rows:
            if abs(row_y - y) < tolerance:
                grouped_by_rows[row_y].append((x, y, r))
                assigned = True
                break
        
        # If not assigned to any existing row, create a new row
        if not assigned:
            grouped_by_rows[y].append((x, y, r))

    # For each row, sort circles by x-coordinate (left to right)
    grouped_circles = []
    for row_y in sorted(grouped_by_rows.keys()):
        grouped_by_rows[row_y].sort(key=lambda c: c[0])  # Sort by x (horizontal position)
        grouped_circles.append(grouped_by_rows[row_y])

    return grouped_circles

# Example usage:
if pixel_counts is not None:
    #circles = detected_circles[0, :]  # Extract the circles from detected_circles
    
    # Group the circles by rows with a 50% tolerance of average row distance
    grouped_circles = group_circles_by_rows(pixel_counts, percentage=0.5)

    # For visualization
    question_num = 1
    for group in grouped_circles:
        print(f"Row No {question_num}:")
        for idx, (x, y, r) in enumerate(group, 1):
            print(f"circle {idx}: (x={x}, y={y}, r={r})")
            cv2.circle(original_img, (x, y), r, (0, 255, 0), 2)   # Draw the circle
            cv2.circle(original_img, (x, y), 2, (0, 0, 255), 3)   # Draw the center
        question_num += 1

    # Display the result
    cv2.imshow("Detected Circles", original_img)
    cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 41
#      38     return grouped_circles
#      40 # Example usage:
# ---> 41 if pixel_counts is not None:
#      42     #circles = detected_circles[0, :]  # Extract the circles from detected_circles
#      43
#      44     # Group the circles by rows with a 50% tolerance of average row distance
#      45     grouped_circles = group_circles_by_rows(pixel_counts, percentage=0.5)
#      47     # For visualization
#
# NameError: name 'pixel_counts' is not defined

# %% [markdown]
# #### Using clustering method DBSCAN

# %%
import numpy as np
from sklearn.cluster import DBSCAN


# Function to group circles by rows using DBSCAN (y-coordinate clustering)
def group_by_row_dbscan(pixel_counts, eps=10):
    # Extract the y-coordinates of circles from the pixel_counts
    y_coords = np.array([[y] for (x, y, r, black_count, white_count) in pixel_counts])
    
    # Apply DBSCAN clustering based on y-coordinates
    clustering = DBSCAN(eps=eps, min_samples=1).fit(y_coords)
    
    # Get cluster labels
    labels = clustering.labels_

    # Group circles by the row labels
    rows = {}
    for label, circle_data in zip(labels, pixel_counts):
        if label not in rows:
            rows[label] = []
        rows[label].append(circle_data)

    sorted_rows = sorted(rows.values(), key=lambda row: np.mean([c[1] for c in row]))
    sorted_rows = [sorted(row, key=lambda c: c[0]) for row in sorted_rows]
    
    return sorted_rows

# %%
# Group the circles by rows using the group_by_row_dbscan function
grouped_rows_s = group_by_row_dbscan(pixel_counts_s, eps=20)

# Print the grouped results
for row_idx, row in enumerate(grouped_rows_s, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, black_count, white_count) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")
# Out:
# Row 1:
#   Circle 1: Coordinates = (168, 206), Black Pixels = 1721412, White Pixels = 738
#   Circle 2: Coordinates = (232, 208), Black Pixels = 1722088, White Pixels = 62
#   Circle 3: Coordinates = (294, 208), Black Pixels = 1721531, White Pixels = 619
#   Circle 4: Coordinates = (360, 210), Black Pixels = 1721612, White Pixels = 538
#   Circle 5: Coordinates = (552, 216), Black Pixels = 1722112, White Pixels = 38
#   Circle 6: Coordinates = (614, 218), Black Pixels = 1721605, White Pixels = 545
#   Circle 7: Coordinates = (674, 216), Black Pixels = 1721444, White Pixels = 706
#   Circle 8: Coordinates = (734, 214), Black Pixels = 1721553, White Pixels = 597
#   Circle 9: Coordinates = (928, 214), Black Pixels = 1721611, White Pixels = 539
#   Circle 10: Coordinates = (986, 216), Black Pixels = 1722133, White Pixels = 17
#   Circle 11: Coordinates = (1048, 218), Black Pixels = 1721669, White Pixels = 481
#   Circle 12: Coordinates = (1106, 220), Black Pixels = 1721728, White Pixels = 422
#   Circle 13: Coordinates = (1282, 226), Black Pixels = 1722146, White Pixels = 4
#   Circle 14: Coordinates = (1340, 228), Black Pixels = 1721644, White Pixels = 506
#   Circle 15: Coordinates = (1400, 228), Black Pixels = 1721706, White Pixels = 444
#   Circle 16: Coordinates = (1458, 228), Black Pixels = 1721671, White Pixels = 479
# Row 2:
#   Circle 1: Coordinates = (168, 274), Black Pixels = 1721589, White Pixels = 561
#   Circle 2: Coordinates = (230, 274), Black Pixels = 1722075, White Pixels = 75
#   Circle 3: Coordinates = (292, 274), Black Pixels = 1721560, White Pixels = 590
#   Circle 4: Coordinates = (358, 274), Black Pixels = 1721558, White Pixels = 592
#   Circle 5: Coordinates = (550, 280), Black Pixels = 1722112, White Pixels = 38
#   Circle 6: Coordinates = (614, 284), Black Pixels = 1721617, White Pixels = 533
#   Circle 7: Coordinates = (674, 282), Black Pixels = 1721413, White Pixels = 737
#   Circle 8: Coordinates = (732, 280), Black Pixels = 1721556, White Pixels = 594
#   Circle 9: Coordinates = (926, 282), Black Pixels = 1721625, White Pixels = 525
#   Circle 10: Coordinates = (986, 284), Black Pixels = 1722143, White Pixels = 7
#   Circle 11: Coordinates = (1048, 284), Black Pixels = 1721727, White Pixels = 423
#   Circle 12: Coordinates = (1106, 284), Black Pixels = 1721732, White Pixels = 418
#   Circle 13: Coordinates = (1282, 288), Black Pixels = 1722121, White Pixels = 29
#   Circle 14: Coordinates = (1342, 290), Black Pixels = 1721635, White Pixels = 515
#   Circle 15: Coordinates = (1400, 292), Black Pixels = 1721724, White Pixels = 426
#   Circle 16: Coordinates = (1458, 292), Black Pixels = 1721699, White Pixels = 451
# Row 3:
#   Circle 1: Coordinates = (166, 340), Black Pixels = 1721597, White Pixels = 553
#   Circle 2: Coordinates = (228, 340), Black Pixels = 1722131, White Pixels = 19
#   Circle 3: Coordinates = (290, 340), Black Pixels = 1721519, White Pixels = 631
#   Circle 4: Coordinates = (354, 342), Black Pixels = 1721637, White Pixels = 513
#   Circle 5: Coordinates = (550, 346), Black Pixels = 1722113, White Pixels = 37
#   Circle 6: Coordinates = (614, 346), Black Pixels = 1721603, White Pixels = 547
#   Circle 7: Coordinates = (672, 348), Black Pixels = 1721485, White Pixels = 665
#   Circle 8: Coordinates = (732, 346), Black Pixels = 1721559, White Pixels = 591
#   Circle 9: Coordinates = (926, 348), Black Pixels = 1721646, White Pixels = 504
#   Circle 10: Coordinates = (986, 348), Black Pixels = 1721681, White Pixels = 469
#   Circle 11: Coordinates = (1046, 348), Black Pixels = 1721717, White Pixels = 433
#   Circle 12: Coordinates = (1108, 350), Black Pixels = 1722135, White Pixels = 15
#   Circle 13: Coordinates = (1284, 352), Black Pixels = 1722126, White Pixels = 24
#   Circle 14: Coordinates = (1344, 354), Black Pixels = 1721650, White Pixels = 500
#   Circle 15: Coordinates = (1400, 354), Black Pixels = 1721675, White Pixels = 475
#   Circle 16: Coordinates = (1458, 354), Black Pixels = 1721658, White Pixels = 492
# Row 4:
#   Circle 1: Coordinates = (164, 406), Black Pixels = 1721593, White Pixels = 557
#   Circle 2: Coordinates = (226, 408), Black Pixels = 1722066, White Pixels = 84
#   Circle 3: Coordinates = (288, 408), Black Pixels = 1721566, White Pixels = 584
#   Circle 4: Coordinates = (354, 408), Black Pixels = 1721597, White Pixels = 553
#   Circle 5: Coordinates = (550, 412), Black Pixels = 1721636, White Pixels = 514
#   Circle 6: Coordinates = (612, 412), Black Pixels = 1721604, White Pixels = 546
#   Circle 7: Coordinates = (672, 412), Black Pixels = 1722070, White Pixels = 80
#   Circle 8: Coordinates = (732, 412), Black Pixels = 1721594, White Pixels = 556
#   Circle 9: Coordinates = (924, 414), Black Pixels = 1722118, White Pixels = 32
#   Circle 10: Coordinates = (986, 414), Black Pixels = 1721711, White Pixels = 439
#   Circle 11: Coordinates = (1046, 414), Black Pixels = 1721709, White Pixels = 441
#   Circle 12: Coordinates = (1106, 414), Black Pixels = 1721708, White Pixels = 442
#   Circle 13: Coordinates = (1286, 416), Black Pixels = 1721674, White Pixels = 476
#   Circle 14: Coordinates = (1344, 416), Black Pixels = 1722121, White Pixels = 29
#   Circle 15: Coordinates = (1402, 416), Black Pixels = 1721707, White Pixels = 443
#   Circle 16: Coordinates = (1460, 418), Black Pixels = 1721672, White Pixels = 478
# Row 5:
#   Circle 1: Coordinates = (162, 474), Black Pixels = 1721596, White Pixels = 554
#   Circle 2: Coordinates = (224, 474), Black Pixels = 1721540, White Pixels = 610
#   Circle 3: Coordinates = (286, 474), Black Pixels = 1722099, White Pixels = 51
#   Circle 4: Coordinates = (352, 474), Black Pixels = 1721540, White Pixels = 610
#   Circle 5: Coordinates = (548, 476), Black Pixels = 1721626, White Pixels = 524
#   Circle 6: Coordinates = (612, 478), Black Pixels = 1721631, White Pixels = 519
#   Circle 7: Coordinates = (672, 476), Black Pixels = 1722123, White Pixels = 27
#   Circle 8: Coordinates = (732, 478), Black Pixels = 1721624, White Pixels = 526
#   Circle 9: Coordinates = (924, 478), Black Pixels = 1722137, White Pixels = 13
#   Circle 10: Coordinates = (984, 478), Black Pixels = 1721703, White Pixels = 447
#   Circle 11: Coordinates = (1044, 478), Black Pixels = 1721704, White Pixels = 446
#   Circle 12: Coordinates = (1106, 478), Black Pixels = 1721718, White Pixels = 432
#   Circle 13: Coordinates = (1288, 480), Black Pixels = 1721693, White Pixels = 457
#   Circle 14: Coordinates = (1344, 480), Black Pixels = 1722150, White Pixels = 0
#   Circle 15: Coordinates = (1404, 480), Black Pixels = 1721704, White Pixels = 446
#   Circle 16: Coordinates = (1460, 480), Black Pixels = 1721725, White Pixels = 425
# Row 6:
#   Circle 1: Coordinates = (160, 542), Black Pixels = 1721514, White Pixels = 636
#   Circle 2: Coordinates = (222, 542), Black Pixels = 1721448, White Pixels = 702
#   Circle 3: Coordinates = (284, 540), Black Pixels = 1722140, White Pixels = 10
#   Circle 4: Coordinates = (350, 542), Black Pixels = 1721602, White Pixels = 548
#   Circle 5: Coordinates = (548, 542), Black Pixels = 1721631, White Pixels = 519
#   Circle 6: Coordinates = (610, 542), Black Pixels = 1721676, White Pixels = 474
#   Circle 7: Coordinates = (670, 542), Black Pixels = 1722091, White Pixels = 59
#   Circle 8: Coordinates = (730, 542), Black Pixels = 1721576, White Pixels = 574
#   Circle 9: Coordinates = (924, 544), Black Pixels = 1721665, White Pixels = 485
#   Circle 10: Coordinates = (984, 544), Black Pixels = 1721631, White Pixels = 519
#   Circle 11: Coordinates = (1046, 544), Black Pixels = 1721734, White Pixels = 416
#   Circle 12: Coordinates = (1106, 544), Black Pixels = 1722104, White Pixels = 46
#   Circle 13: Coordinates = (1286, 544), Black Pixels = 1721675, White Pixels = 475
#   Circle 14: Coordinates = (1346, 544), Black Pixels = 1721696, White Pixels = 454
#   Circle 15: Coordinates = (1404, 546), Black Pixels = 1722096, White Pixels = 54
#   Circle 16: Coordinates = (1462, 544), Black Pixels = 1721697, White Pixels = 453
# Row 7:
#   Circle 1: Coordinates = (158, 610), Black Pixels = 1721593, White Pixels = 557
#   Circle 2: Coordinates = (220, 610), Black Pixels = 1721644, White Pixels = 506
#   Circle 3: Coordinates = (284, 610), Black Pixels = 1722097, White Pixels = 53
#   Circle 4: Coordinates = (348, 610), Black Pixels = 1721553, White Pixels = 597
#   Circle 5: Coordinates = (546, 608), Black Pixels = 1721637, White Pixels = 513
#   Circle 6: Coordinates = (610, 608), Black Pixels = 1721591, White Pixels = 559
#   Circle 7: Coordinates = (668, 610), Black Pixels = 1721633, White Pixels = 517
#   Circle 8: Coordinates = (730, 608), Black Pixels = 1722135, White Pixels = 15
#   Circle 9: Coordinates = (924, 608), Black Pixels = 1721646, White Pixels = 504
#   Circle 10: Coordinates = (984, 608), Black Pixels = 1721721, White Pixels = 429
#   Circle 11: Coordinates = (1046, 608), Black Pixels = 1721726, White Pixels = 424
#   Circle 12: Coordinates = (1106, 608), Black Pixels = 1722118, White Pixels = 32
#   Circle 13: Coordinates = (1290, 610), Black Pixels = 1721627, White Pixels = 523
#   Circle 14: Coordinates = (1346, 608), Black Pixels = 1721663, White Pixels = 487
#   Circle 15: Coordinates = (1404, 608), Black Pixels = 1722149, White Pixels = 1
#   Circle 16: Coordinates = (1462, 608), Black Pixels = 1721714, White Pixels = 436
# Row 8:
#   Circle 1: Coordinates = (158, 676), Black Pixels = 1721432, White Pixels = 718
#   Circle 2: Coordinates = (218, 678), Black Pixels = 1721650, White Pixels = 500
#   Circle 3: Coordinates = (282, 678), Black Pixels = 1722138, White Pixels = 12
#   Circle 4: Coordinates = (346, 678), Black Pixels = 1721576, White Pixels = 574
#   Circle 5: Coordinates = (546, 674), Black Pixels = 1721568, White Pixels = 582
#   Circle 6: Coordinates = (608, 674), Black Pixels = 1721594, White Pixels = 556
#   Circle 7: Coordinates = (668, 676), Black Pixels = 1721645, White Pixels = 505
#   Circle 8: Coordinates = (730, 676), Black Pixels = 1722138, White Pixels = 12
#   Circle 9: Coordinates = (924, 674), Black Pixels = 1721623, White Pixels = 527
#   Circle 10: Coordinates = (984, 672), Black Pixels = 1721731, White Pixels = 419
#   Circle 11: Coordinates = (1044, 672), Black Pixels = 1722138, White Pixels = 12
#   Circle 12: Coordinates = (1108, 674), Black Pixels = 1721667, White Pixels = 483
#   Circle 13: Coordinates = (1288, 674), Black Pixels = 1721673, White Pixels = 477
#   Circle 14: Coordinates = (1348, 674), Black Pixels = 1721701, White Pixels = 449
#   Circle 15: Coordinates = (1406, 672), Black Pixels = 1722146, White Pixels = 4
#   Circle 16: Coordinates = (1464, 672), Black Pixels = 1721687, White Pixels = 463
# Row 9:
#   Circle 1: Coordinates = (156, 744), Black Pixels = 1721602, White Pixels = 548
#   Circle 2: Coordinates = (218, 746), Black Pixels = 1721552, White Pixels = 598
#   Circle 3: Coordinates = (280, 746), Black Pixels = 1721504, White Pixels = 646
#   Circle 4: Coordinates = (346, 746), Black Pixels = 1722132, White Pixels = 18
#   Circle 5: Coordinates = (544, 740), Black Pixels = 1721566, White Pixels = 584
#   Circle 6: Coordinates = (606, 740), Black Pixels = 1721540, White Pixels = 610
#   Circle 7: Coordinates = (666, 742), Black Pixels = 1721641, White Pixels = 509
#   Circle 8: Coordinates = (730, 742), Black Pixels = 1722135, White Pixels = 15
#   Circle 9: Coordinates = (924, 738), Black Pixels = 1721628, White Pixels = 522
#   Circle 10: Coordinates = (986, 738), Black Pixels = 1721693, White Pixels = 457
#   Circle 11: Coordinates = (1046, 738), Black Pixels = 1722136, White Pixels = 14
#   Circle 12: Coordinates = (1108, 738), Black Pixels = 1721669, White Pixels = 481
#   Circle 13: Coordinates = (1292, 738), Black Pixels = 1721675, White Pixels = 475
#   Circle 14: Coordinates = (1350, 738), Black Pixels = 1721681, White Pixels = 469
#   Circle 15: Coordinates = (1408, 738), Black Pixels = 1721685, White Pixels = 465
#   Circle 16: Coordinates = (1464, 736), Black Pixels = 1722149, White Pixels = 1
# Row 10:
#   Circle 1: Coordinates = (156, 812), Black Pixels = 1722138, White Pixels = 12
#   Circle 2: Coordinates = (216, 814), Black Pixels = 1721511, White Pixels = 639
#   Circle 3: Coordinates = (280, 816), Black Pixels = 1721474, White Pixels = 676
#   Circle 4: Coordinates = (344, 814), Black Pixels = 1721565, White Pixels = 585
#   Circle 5: Coordinates = (542, 808), Black Pixels = 1721584, White Pixels = 566
#   Circle 6: Coordinates = (606, 808), Black Pixels = 1721555, White Pixels = 595
#   Circle 7: Coordinates = (666, 810), Black Pixels = 1721559, White Pixels = 591
#   Circle 8: Coordinates = (728, 810), Black Pixels = 1722150, White Pixels = 0
#   Circle 9: Coordinates = (924, 806), Black Pixels = 1721613, White Pixels = 537
#   Circle 10: Coordinates = (986, 804), Black Pixels = 1721684, White Pixels = 466
#   Circle 11: Coordinates = (1046, 804), Black Pixels = 1722148, White Pixels = 2
#   Circle 12: Coordinates = (1108, 804), Black Pixels = 1721667, White Pixels = 483
#   Circle 13: Coordinates = (1294, 804), Black Pixels = 1722073, White Pixels = 77
#   Circle 14: Coordinates = (1352, 804), Black Pixels = 1721704, White Pixels = 446
#   Circle 15: Coordinates = (1408, 802), Black Pixels = 1721723, White Pixels = 427
#   Circle 16: Coordinates = (1468, 800), Black Pixels = 1721710, White Pixels = 440

# %%
grouped_rows_t = group_by_row_dbscan(pixel_counts_t, eps=10)

# Print the grouped results
for row_idx, row in enumerate(grouped_rows_t, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, black_count, white_count) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")
# Out:
# Row 1:
#   Circle 1: Coordinates = (148, 246), Black Pixels = 1775882, White Pixels = 736
#   Circle 2: Coordinates = (210, 244), Black Pixels = 1776113, White Pixels = 505
#   Circle 3: Coordinates = (274, 244), Black Pixels = 1776051, White Pixels = 567
#   Circle 4: Coordinates = (340, 244), Black Pixels = 1776052, White Pixels = 566
#   Circle 5: Coordinates = (536, 246), Black Pixels = 1776008, White Pixels = 610
#   Circle 6: Coordinates = (600, 248), Black Pixels = 1776067, White Pixels = 551
#   Circle 7: Coordinates = (662, 246), Black Pixels = 1775955, White Pixels = 663
#   Circle 8: Coordinates = (724, 244), Black Pixels = 1776043, White Pixels = 575
#   Circle 9: Coordinates = (924, 242), Black Pixels = 1775992, White Pixels = 626
#   Circle 10: Coordinates = (986, 244), Black Pixels = 1776190, White Pixels = 428
#   Circle 11: Coordinates = (1046, 244), Black Pixels = 1776199, White Pixels = 419
#   Circle 12: Coordinates = (1108, 246), Black Pixels = 1776201, White Pixels = 417
#   Circle 13: Coordinates = (1292, 248), Black Pixels = 1776113, White Pixels = 505
#   Circle 14: Coordinates = (1354, 248), Black Pixels = 1776109, White Pixels = 509
#   Circle 15: Coordinates = (1414, 248), Black Pixels = 1776189, White Pixels = 429
#   Circle 16: Coordinates = (1476, 250), Black Pixels = 1776203, White Pixels = 415
# Row 2:
#   Circle 1: Coordinates = (148, 312), Black Pixels = 1775787, White Pixels = 831
#   Circle 2: Coordinates = (210, 312), Black Pixels = 1775940, White Pixels = 678
#   Circle 3: Coordinates = (274, 310), Black Pixels = 1776115, White Pixels = 503
#   Circle 4: Coordinates = (340, 312), Black Pixels = 1776076, White Pixels = 542
#   Circle 5: Coordinates = (536, 312), Black Pixels = 1776024, White Pixels = 594
#   Circle 6: Coordinates = (600, 314), Black Pixels = 1776142, White Pixels = 476
#   Circle 7: Coordinates = (662, 314), Black Pixels = 1775922, White Pixels = 696
#   Circle 8: Coordinates = (724, 312), Black Pixels = 1776112, White Pixels = 506
#   Circle 9: Coordinates = (924, 310), Black Pixels = 1776071, White Pixels = 547
#   Circle 10: Coordinates = (984, 312), Black Pixels = 1776155, White Pixels = 463
#   Circle 11: Coordinates = (1046, 312), Black Pixels = 1776142, White Pixels = 476
#   Circle 12: Coordinates = (1108, 312), Black Pixels = 1776154, White Pixels = 464
#   Circle 13: Coordinates = (1294, 314), Black Pixels = 1776078, White Pixels = 540
#   Circle 14: Coordinates = (1356, 314), Black Pixels = 1776099, White Pixels = 519
#   Circle 15: Coordinates = (1416, 314), Black Pixels = 1776175, White Pixels = 443
#   Circle 16: Coordinates = (1476, 314), Black Pixels = 1776164, White Pixels = 454
# Row 3:
#   Circle 1: Coordinates = (146, 380), Black Pixels = 1776076, White Pixels = 542
#   Circle 2: Coordinates = (210, 380), Black Pixels = 1776018, White Pixels = 600
#   Circle 3: Coordinates = (272, 380), Black Pixels = 1776025, White Pixels = 593
#   Circle 4: Coordinates = (338, 380), Black Pixels = 1776018, White Pixels = 600
#   Circle 5: Coordinates = (538, 380), Black Pixels = 1776110, White Pixels = 508
#   Circle 6: Coordinates = (602, 382), Black Pixels = 1776063, White Pixels = 555
#   Circle 7: Coordinates = (662, 380), Black Pixels = 1776082, White Pixels = 536
#   Circle 8: Coordinates = (724, 380), Black Pixels = 1776116, White Pixels = 502
#   Circle 9: Coordinates = (922, 380), Black Pixels = 1776129, White Pixels = 489
#   Circle 10: Coordinates = (984, 378), Black Pixels = 1776196, White Pixels = 422
#   Circle 11: Coordinates = (1046, 378), Black Pixels = 1776122, White Pixels = 496
#   Circle 12: Coordinates = (1110, 378), Black Pixels = 1776159, White Pixels = 459
#   Circle 13: Coordinates = (1294, 378), Black Pixels = 1776070, White Pixels = 548
#   Circle 14: Coordinates = (1356, 378), Black Pixels = 1776144, White Pixels = 474
#   Circle 15: Coordinates = (1416, 380), Black Pixels = 1776177, White Pixels = 441
#   Circle 16: Coordinates = (1476, 380), Black Pixels = 1776174, White Pixels = 444
# Row 4:
#   Circle 1: Coordinates = (146, 448), Black Pixels = 1776066, White Pixels = 552
#   Circle 2: Coordinates = (208, 448), Black Pixels = 1776010, White Pixels = 608
#   Circle 3: Coordinates = (272, 448), Black Pixels = 1776023, White Pixels = 595
#   Circle 4: Coordinates = (340, 448), Black Pixels = 1776099, White Pixels = 519
#   Circle 5: Coordinates = (538, 448), Black Pixels = 1776105, White Pixels = 513
#   Circle 6: Coordinates = (602, 448), Black Pixels = 1776088, White Pixels = 530
#   Circle 7: Coordinates = (662, 446), Black Pixels = 1776002, White Pixels = 616
#   Circle 8: Coordinates = (724, 446), Black Pixels = 1776061, White Pixels = 557
#   Circle 9: Coordinates = (922, 446), Black Pixels = 1776106, White Pixels = 512
#   Circle 10: Coordinates = (984, 446), Black Pixels = 1776185, White Pixels = 433
#   Circle 11: Coordinates = (1046, 446), Black Pixels = 1776164, White Pixels = 454
#   Circle 12: Coordinates = (1108, 446), Black Pixels = 1776167, White Pixels = 451
#   Circle 13: Coordinates = (1294, 446), Black Pixels = 1776145, White Pixels = 473
#   Circle 14: Coordinates = (1356, 446), Black Pixels = 1776190, White Pixels = 428
#   Circle 15: Coordinates = (1416, 444), Black Pixels = 1776199, White Pixels = 419
#   Circle 16: Coordinates = (1476, 444), Black Pixels = 1776154, White Pixels = 464
# Row 5:
#   Circle 1: Coordinates = (144, 516), Black Pixels = 1776061, White Pixels = 557
#   Circle 2: Coordinates = (208, 516), Black Pixels = 1776010, White Pixels = 608
#   Circle 3: Coordinates = (272, 516), Black Pixels = 1776015, White Pixels = 603
#   Circle 4: Coordinates = (338, 516), Black Pixels = 1776024, White Pixels = 594
#   Circle 5: Coordinates = (538, 514), Black Pixels = 1776030, White Pixels = 588
#   Circle 6: Coordinates = (602, 514), Black Pixels = 1776084, White Pixels = 534
#   Circle 7: Coordinates = (662, 514), Black Pixels = 1775982, White Pixels = 636
#   Circle 8: Coordinates = (724, 514), Black Pixels = 1776148, White Pixels = 470
#   Circle 9: Coordinates = (922, 512), Black Pixels = 1776095, White Pixels = 523
#   Circle 10: Coordinates = (984, 512), Black Pixels = 1776165, White Pixels = 453
#   Circle 11: Coordinates = (1044, 512), Black Pixels = 1776172, White Pixels = 446
#   Circle 12: Coordinates = (1108, 512), Black Pixels = 1776137, White Pixels = 481
#   Circle 13: Coordinates = (1294, 512), Black Pixels = 1776129, White Pixels = 489
#   Circle 14: Coordinates = (1356, 510), Black Pixels = 1776170, White Pixels = 448
#   Circle 15: Coordinates = (1416, 510), Black Pixels = 1776170, White Pixels = 448
#   Circle 16: Coordinates = (1476, 510), Black Pixels = 1776153, White Pixels = 465
# Row 6:
#   Circle 1: Coordinates = (142, 584), Black Pixels = 1775952, White Pixels = 666
#   Circle 2: Coordinates = (208, 584), Black Pixels = 1776046, White Pixels = 572
#   Circle 3: Coordinates = (274, 584), Black Pixels = 1776074, White Pixels = 544
#   Circle 4: Coordinates = (340, 584), Black Pixels = 1776033, White Pixels = 585
#   Circle 5: Coordinates = (538, 580), Black Pixels = 1776026, White Pixels = 592
#   Circle 6: Coordinates = (602, 580), Black Pixels = 1776042, White Pixels = 576
#   Circle 7: Coordinates = (662, 580), Black Pixels = 1775943, White Pixels = 675
#   Circle 8: Coordinates = (724, 580), Black Pixels = 1776048, White Pixels = 570
#   Circle 9: Coordinates = (922, 578), Black Pixels = 1776107, White Pixels = 511
#   Circle 10: Coordinates = (984, 578), Black Pixels = 1776166, White Pixels = 452
#   Circle 11: Coordinates = (1044, 578), Black Pixels = 1776165, White Pixels = 453
#   Circle 12: Coordinates = (1108, 578), Black Pixels = 1776117, White Pixels = 501
#   Circle 13: Coordinates = (1296, 576), Black Pixels = 1776201, White Pixels = 417
#   Circle 14: Coordinates = (1356, 576), Black Pixels = 1776136, White Pixels = 482
#   Circle 15: Coordinates = (1416, 576), Black Pixels = 1776161, White Pixels = 457
#   Circle 16: Coordinates = (1474, 576), Black Pixels = 1776175, White Pixels = 443
# Row 7:
#   Circle 1: Coordinates = (144, 654), Black Pixels = 1776016, White Pixels = 602
#   Circle 2: Coordinates = (208, 652), Black Pixels = 1776056, White Pixels = 562
#   Circle 3: Coordinates = (276, 652), Black Pixels = 1776055, White Pixels = 563
#   Circle 4: Coordinates = (342, 652), Black Pixels = 1776104, White Pixels = 514
#   Circle 5: Coordinates = (538, 648), Black Pixels = 1776114, White Pixels = 504
#   Circle 6: Coordinates = (602, 646), Black Pixels = 1776046, White Pixels = 572
#   Circle 7: Coordinates = (662, 648), Black Pixels = 1775970, White Pixels = 648
#   Circle 8: Coordinates = (724, 648), Black Pixels = 1776067, White Pixels = 551
#   Circle 9: Coordinates = (922, 644), Black Pixels = 1776117, White Pixels = 501
#   Circle 10: Coordinates = (984, 644), Black Pixels = 1776205, White Pixels = 413
#   Circle 11: Coordinates = (1044, 644), Black Pixels = 1776213, White Pixels = 405
#   Circle 12: Coordinates = (1108, 644), Black Pixels = 1776191, White Pixels = 427
#   Circle 13: Coordinates = (1296, 644), Black Pixels = 1776157, White Pixels = 461
#   Circle 14: Coordinates = (1356, 642), Black Pixels = 1776186, White Pixels = 432
#   Circle 15: Coordinates = (1418, 642), Black Pixels = 1776164, White Pixels = 454
#   Circle 16: Coordinates = (1478, 640), Black Pixels = 1776146, White Pixels = 472
# Row 8:
#   Circle 1: Coordinates = (144, 722), Black Pixels = 1775949, White Pixels = 669
#   Circle 2: Coordinates = (208, 720), Black Pixels = 1776124, White Pixels = 494
#   Circle 3: Coordinates = (276, 720), Black Pixels = 1776062, White Pixels = 556
#   Circle 4: Coordinates = (342, 720), Black Pixels = 1776072, White Pixels = 546
#   Circle 5: Coordinates = (538, 714), Black Pixels = 1775967, White Pixels = 651
#   Circle 6: Coordinates = (602, 712), Black Pixels = 1776111, White Pixels = 507
#   Circle 7: Coordinates = (660, 714), Black Pixels = 1775917, White Pixels = 701
#   Circle 8: Coordinates = (724, 714), Black Pixels = 1776047, White Pixels = 571
#   Circle 9: Coordinates = (922, 710), Black Pixels = 1776124, White Pixels = 494
#   Circle 10: Coordinates = (984, 710), Black Pixels = 1776188, White Pixels = 430
#   Circle 11: Coordinates = (1046, 708), Black Pixels = 1776165, White Pixels = 453
#   Circle 12: Coordinates = (1108, 710), Black Pixels = 1776137, White Pixels = 481
#   Circle 13: Coordinates = (1298, 708), Black Pixels = 1776118, White Pixels = 500
#   Circle 14: Coordinates = (1358, 708), Black Pixels = 1776196, White Pixels = 422
#   Circle 15: Coordinates = (1418, 708), Black Pixels = 1776172, White Pixels = 446
#   Circle 16: Coordinates = (1480, 706), Black Pixels = 1776141, White Pixels = 477
# Row 9:
#   Circle 1: Coordinates = (144, 790), Black Pixels = 1775934, White Pixels = 684
#   Circle 2: Coordinates = (210, 790), Black Pixels = 1776000, White Pixels = 618
#   Circle 3: Coordinates = (274, 788), Black Pixels = 1776018, White Pixels = 600
#   Circle 4: Coordinates = (340, 788), Black Pixels = 1776057, White Pixels = 561
#   Circle 5: Coordinates = (538, 782), Black Pixels = 1776013, White Pixels = 605
#   Circle 6: Coordinates = (600, 778), Black Pixels = 1775955, White Pixels = 663
#   Circle 7: Coordinates = (660, 782), Black Pixels = 1775960, White Pixels = 658
#   Circle 8: Coordinates = (724, 782), Black Pixels = 1776105, White Pixels = 513
#   Circle 9: Coordinates = (922, 776), Black Pixels = 1776117, White Pixels = 501
#   Circle 10: Coordinates = (984, 776), Black Pixels = 1776193, White Pixels = 425
#   Circle 11: Coordinates = (1046, 776), Black Pixels = 1776166, White Pixels = 452
#   Circle 12: Coordinates = (1108, 776), Black Pixels = 1776200, White Pixels = 418
#   Circle 13: Coordinates = (1298, 776), Black Pixels = 1776151, White Pixels = 467
#   Circle 14: Coordinates = (1358, 774), Black Pixels = 1776168, White Pixels = 450
#   Circle 15: Coordinates = (1420, 774), Black Pixels = 1776177, White Pixels = 441
#   Circle 16: Coordinates = (1482, 774), Black Pixels = 1776155, White Pixels = 463
# Row 10:
#   Circle 1: Coordinates = (144, 858), Black Pixels = 1775993, White Pixels = 625
#   Circle 2: Coordinates = (208, 858), Black Pixels = 1776020, White Pixels = 598
#   Circle 3: Coordinates = (274, 856), Black Pixels = 1776098, White Pixels = 520
#   Circle 4: Coordinates = (340, 856), Black Pixels = 1776081, White Pixels = 537
#   Circle 5: Coordinates = (538, 848), Black Pixels = 1776044, White Pixels = 574
#   Circle 6: Coordinates = (600, 848), Black Pixels = 1776163, White Pixels = 455
#   Circle 7: Coordinates = (660, 850), Black Pixels = 1776021, White Pixels = 597
#   Circle 8: Coordinates = (724, 850), Black Pixels = 1776052, White Pixels = 566
#   Circle 9: Coordinates = (924, 844), Black Pixels = 1776087, White Pixels = 531
#   Circle 10: Coordinates = (984, 842), Black Pixels = 1776170, White Pixels = 448
#   Circle 11: Coordinates = (1048, 840), Black Pixels = 1776122, White Pixels = 496
#   Circle 12: Coordinates = (1110, 842), Black Pixels = 1776147, White Pixels = 471
#   Circle 13: Coordinates = (1298, 842), Black Pixels = 1776126, White Pixels = 492
#   Circle 14: Coordinates = (1360, 840), Black Pixels = 1776176, White Pixels = 442
#   Circle 15: Coordinates = (1422, 840), Black Pixels = 1776133, White Pixels = 485
#   Circle 16: Coordinates = (1484, 840), Black Pixels = 1776199, White Pixels = 419

# %%
grouped_rows_k = group_by_row_dbscan(pixel_counts_k, eps=10)

# Print the grouped results
for row_idx, row in enumerate(grouped_rows_k, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, black_count, white_count) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Black Pixels = {black_count}, White Pixels = {white_count}")
# Out:
# Row 1:
#   Circle 1: Coordinates = (162, 212), Black Pixels = 1712369, White Pixels = 701
#   Circle 2: Coordinates = (226, 212), Black Pixels = 1713011, White Pixels = 59
#   Circle 3: Coordinates = (290, 214), Black Pixels = 1712571, White Pixels = 499
#   Circle 4: Coordinates = (352, 216), Black Pixels = 1712540, White Pixels = 530
#   Circle 5: Coordinates = (542, 218), Black Pixels = 1713050, White Pixels = 20
#   Circle 6: Coordinates = (604, 220), Black Pixels = 1712588, White Pixels = 482
#   Circle 7: Coordinates = (664, 220), Black Pixels = 1712323, White Pixels = 747
#   Circle 8: Coordinates = (726, 218), Black Pixels = 1712548, White Pixels = 522
#   Circle 9: Coordinates = (920, 220), Black Pixels = 1712521, White Pixels = 549
#   Circle 10: Coordinates = (978, 224), Black Pixels = 1713055, White Pixels = 15
#   Circle 11: Coordinates = (1038, 224), Black Pixels = 1712581, White Pixels = 489
#   Circle 12: Coordinates = (1098, 226), Black Pixels = 1712634, White Pixels = 436
#   Circle 13: Coordinates = (1276, 230), Black Pixels = 1713045, White Pixels = 25
#   Circle 14: Coordinates = (1336, 230), Black Pixels = 1712537, White Pixels = 533
#   Circle 15: Coordinates = (1394, 232), Black Pixels = 1712549, White Pixels = 521
#   Circle 16: Coordinates = (1454, 232), Black Pixels = 1712615, White Pixels = 455
# Row 2:
#   Circle 1: Coordinates = (162, 278), Black Pixels = 1712329, White Pixels = 741
#   Circle 2: Coordinates = (226, 280), Black Pixels = 1712941, White Pixels = 129
#   Circle 3: Coordinates = (288, 278), Black Pixels = 1712431, White Pixels = 639
#   Circle 4: Coordinates = (352, 280), Black Pixels = 1712501, White Pixels = 569
#   Circle 5: Coordinates = (542, 282), Black Pixels = 1712459, White Pixels = 611
#   Circle 6: Coordinates = (604, 286), Black Pixels = 1712996, White Pixels = 74
#   Circle 7: Coordinates = (664, 286), Black Pixels = 1712414, White Pixels = 656
#   Circle 8: Coordinates = (724, 284), Black Pixels = 1712542, White Pixels = 528
#   Circle 9: Coordinates = (918, 286), Black Pixels = 1712568, White Pixels = 502
#   Circle 10: Coordinates = (978, 288), Black Pixels = 1713058, White Pixels = 12
#   Circle 11: Coordinates = (1038, 288), Black Pixels = 1712508, White Pixels = 562
#   Circle 12: Coordinates = (1098, 290), Black Pixels = 1712614, White Pixels = 456
#   Circle 13: Coordinates = (1276, 292), Black Pixels = 1712514, White Pixels = 556
#   Circle 14: Coordinates = (1336, 294), Black Pixels = 1713070, White Pixels = 0
#   Circle 15: Coordinates = (1396, 294), Black Pixels = 1712574, White Pixels = 496
#   Circle 16: Coordinates = (1454, 294), Black Pixels = 1712624, White Pixels = 446
# Row 3:
#   Circle 1: Coordinates = (162, 344), Black Pixels = 1712512, White Pixels = 558
#   Circle 2: Coordinates = (224, 346), Black Pixels = 1713036, White Pixels = 34
#   Circle 3: Coordinates = (286, 344), Black Pixels = 1712368, White Pixels = 702
#   Circle 4: Coordinates = (350, 346), Black Pixels = 1712579, White Pixels = 491
#   Circle 5: Coordinates = (542, 348), Black Pixels = 1712532, White Pixels = 538
#   Circle 6: Coordinates = (604, 350), Black Pixels = 1713012, White Pixels = 58
#   Circle 7: Coordinates = (664, 350), Black Pixels = 1712518, White Pixels = 552
#   Circle 8: Coordinates = (724, 350), Black Pixels = 1712491, White Pixels = 579
#   Circle 9: Coordinates = (916, 352), Black Pixels = 1713053, White Pixels = 17
#   Circle 10: Coordinates = (976, 352), Black Pixels = 1712529, White Pixels = 541
#   Circle 11: Coordinates = (1038, 352), Black Pixels = 1712622, White Pixels = 448
#   Circle 12: Coordinates = (1098, 354), Black Pixels = 1712600, White Pixels = 470
#   Circle 13: Coordinates = (1278, 356), Black Pixels = 1712446, White Pixels = 624
#   Circle 14: Coordinates = (1338, 356), Black Pixels = 1713066, White Pixels = 4
#   Circle 15: Coordinates = (1396, 356), Black Pixels = 1712561, White Pixels = 509
#   Circle 16: Coordinates = (1454, 358), Black Pixels = 1712565, White Pixels = 505
# Row 4:
#   Circle 1: Coordinates = (160, 410), Black Pixels = 1713040, White Pixels = 30
#   Circle 2: Coordinates = (224, 410), Black Pixels = 1712462, White Pixels = 608
#   Circle 3: Coordinates = (284, 410), Black Pixels = 1712345, White Pixels = 725
#   Circle 4: Coordinates = (348, 412), Black Pixels = 1712527, White Pixels = 543
#   Circle 5: Coordinates = (540, 414), Black Pixels = 1712993, White Pixels = 77
#   Circle 6: Coordinates = (604, 414), Black Pixels = 1712580, White Pixels = 490
#   Circle 7: Coordinates = (664, 414), Black Pixels = 1712326, White Pixels = 744
#   Circle 8: Coordinates = (724, 414), Black Pixels = 1712425, White Pixels = 645
#   Circle 9: Coordinates = (916, 416), Black Pixels = 1713063, White Pixels = 7
#   Circle 10: Coordinates = (976, 418), Black Pixels = 1712600, White Pixels = 470
#   Circle 11: Coordinates = (1036, 418), Black Pixels = 1712605, White Pixels = 465
#   Circle 12: Coordinates = (1096, 418), Black Pixels = 1712606, White Pixels = 464
#   Circle 13: Coordinates = (1278, 420), Black Pixels = 1713038, White Pixels = 32
#   Circle 14: Coordinates = (1338, 420), Black Pixels = 1712501, White Pixels = 569
#   Circle 15: Coordinates = (1396, 420), Black Pixels = 1712577, White Pixels = 493
#   Circle 16: Coordinates = (1454, 420), Black Pixels = 1712636, White Pixels = 434
# Row 5:
#   Circle 1: Coordinates = (158, 476), Black Pixels = 1713056, White Pixels = 14
#   Circle 2: Coordinates = (222, 476), Black Pixels = 1712430, White Pixels = 640
#   Circle 3: Coordinates = (284, 476), Black Pixels = 1712366, White Pixels = 704
#   Circle 4: Coordinates = (348, 478), Black Pixels = 1712583, White Pixels = 487
#   Circle 5: Coordinates = (540, 478), Black Pixels = 1712532, White Pixels = 538
#   Circle 6: Coordinates = (602, 478), Black Pixels = 1712632, White Pixels = 438
#   Circle 7: Coordinates = (664, 480), Black Pixels = 1712349, White Pixels = 721
#   Circle 8: Coordinates = (724, 480), Black Pixels = 1712916, White Pixels = 154
#   Circle 9: Coordinates = (914, 482), Black Pixels = 1712608, White Pixels = 462
#   Circle 10: Coordinates = (974, 482), Black Pixels = 1712611, White Pixels = 459
#   Circle 11: Coordinates = (1034, 482), Black Pixels = 1713065, White Pixels = 5
#   Circle 12: Coordinates = (1096, 482), Black Pixels = 1712581, White Pixels = 489
#   Circle 13: Coordinates = (1276, 482), Black Pixels = 1713064, White Pixels = 6
#   Circle 14: Coordinates = (1338, 484), Black Pixels = 1712579, White Pixels = 491
#   Circle 15: Coordinates = (1396, 484), Black Pixels = 1712589, White Pixels = 481
#   Circle 16: Coordinates = (1454, 484), Black Pixels = 1712619, White Pixels = 451
# Row 6:
#   Circle 1: Coordinates = (158, 542), Black Pixels = 1712446, White Pixels = 624
#   Circle 2: Coordinates = (222, 542), Black Pixels = 1712417, White Pixels = 653
#   Circle 3: Coordinates = (284, 542), Black Pixels = 1713013, White Pixels = 57
#   Circle 4: Coordinates = (346, 544), Black Pixels = 1712444, White Pixels = 626
#   Circle 5: Coordinates = (540, 544), Black Pixels = 1712455, White Pixels = 615
#   Circle 6: Coordinates = (602, 544), Black Pixels = 1712557, White Pixels = 513
#   Circle 7: Coordinates = (662, 544), Black Pixels = 1712541, White Pixels = 529
#   Circle 8: Coordinates = (722, 544), Black Pixels = 1712991, White Pixels = 79
#   Circle 9: Coordinates = (914, 544), Black Pixels = 1712564, White Pixels = 506
#   Circle 10: Coordinates = (974, 546), Black Pixels = 1712615, White Pixels = 455
#   Circle 11: Coordinates = (1034, 546), Black Pixels = 1713039, White Pixels = 31
#   Circle 12: Coordinates = (1094, 546), Black Pixels = 1712619, White Pixels = 451
#   Circle 13: Coordinates = (1278, 548), Black Pixels = 1712540, White Pixels = 530
#   Circle 14: Coordinates = (1336, 548), Black Pixels = 1712568, White Pixels = 502
#   Circle 15: Coordinates = (1394, 548), Black Pixels = 1713065, White Pixels = 5
#   Circle 16: Coordinates = (1452, 548), Black Pixels = 1712613, White Pixels = 457
# Row 7:
#   Circle 1: Coordinates = (158, 608), Black Pixels = 1712431, White Pixels = 639
#   Circle 2: Coordinates = (220, 610), Black Pixels = 1712471, White Pixels = 599
#   Circle 3: Coordinates = (282, 610), Black Pixels = 1712946, White Pixels = 124
#   Circle 4: Coordinates = (344, 610), Black Pixels = 1712598, White Pixels = 472
#   Circle 5: Coordinates = (540, 608), Black Pixels = 1712489, White Pixels = 581
#   Circle 6: Coordinates = (602, 608), Black Pixels = 1712528, White Pixels = 542
#   Circle 7: Coordinates = (662, 610), Black Pixels = 1712576, White Pixels = 494
#   Circle 8: Coordinates = (722, 610), Black Pixels = 1712987, White Pixels = 83
#   Circle 9: Coordinates = (914, 608), Black Pixels = 1713060, White Pixels = 10
#   Circle 10: Coordinates = (974, 608), Black Pixels = 1712596, White Pixels = 474
#   Circle 11: Coordinates = (1034, 610), Black Pixels = 1712572, White Pixels = 498
#   Circle 12: Coordinates = (1096, 610), Black Pixels = 1712563, White Pixels = 507
#   Circle 13: Coordinates = (1278, 612), Black Pixels = 1712548, White Pixels = 522
#   Circle 14: Coordinates = (1336, 612), Black Pixels = 1712680, White Pixels = 390
#   Circle 15: Coordinates = (1394, 612), Black Pixels = 1713039, White Pixels = 31
#   Circle 16: Coordinates = (1452, 612), Black Pixels = 1712602, White Pixels = 468
# Row 8:
#   Circle 1: Coordinates = (156, 674), Black Pixels = 1712386, White Pixels = 684
#   Circle 2: Coordinates = (218, 676), Black Pixels = 1712447, White Pixels = 623
#   Circle 3: Coordinates = (280, 676), Black Pixels = 1712440, White Pixels = 630
#   Circle 4: Coordinates = (344, 676), Black Pixels = 1713047, White Pixels = 23
#   Circle 5: Coordinates = (538, 674), Black Pixels = 1713055, White Pixels = 15
#   Circle 6: Coordinates = (600, 674), Black Pixels = 1712546, White Pixels = 524
#   Circle 7: Coordinates = (660, 674), Black Pixels = 1712424, White Pixels = 646
#   Circle 8: Coordinates = (722, 674), Black Pixels = 1712563, White Pixels = 507
#   Circle 9: Coordinates = (914, 672), Black Pixels = 1713065, White Pixels = 5
#   Circle 10: Coordinates = (974, 672), Black Pixels = 1712624, White Pixels = 446
#   Circle 11: Coordinates = (1034, 674), Black Pixels = 1712619, White Pixels = 451
#   Circle 12: Coordinates = (1096, 674), Black Pixels = 1712566, White Pixels = 504
#   Circle 13: Coordinates = (1278, 676), Black Pixels = 1713057, White Pixels = 13
#   Circle 14: Coordinates = (1336, 676), Black Pixels = 1712590, White Pixels = 480
#   Circle 15: Coordinates = (1394, 674), Black Pixels = 1712632, White Pixels = 438
#   Circle 16: Coordinates = (1454, 676), Black Pixels = 1712613, White Pixels = 457
# Row 9:
#   Circle 1: Coordinates = (156, 742), Black Pixels = 1712334, White Pixels = 736
#   Circle 2: Coordinates = (218, 742), Black Pixels = 1712551, White Pixels = 519
#   Circle 3: Coordinates = (280, 744), Black Pixels = 1712422, White Pixels = 648
#   Circle 4: Coordinates = (344, 744), Black Pixels = 1713035, White Pixels = 35
#   Circle 5: Coordinates = (538, 738), Black Pixels = 1712436, White Pixels = 634
#   Circle 6: Coordinates = (600, 738), Black Pixels = 1712478, White Pixels = 592
#   Circle 7: Coordinates = (660, 740), Black Pixels = 1712568, White Pixels = 502
#   Circle 8: Coordinates = (722, 740), Black Pixels = 1713068, White Pixels = 2
#   Circle 9: Coordinates = (914, 736), Black Pixels = 1712590, White Pixels = 480
#   Circle 10: Coordinates = (974, 738), Black Pixels = 1712595, White Pixels = 475
#   Circle 11: Coordinates = (1034, 738), Black Pixels = 1713066, White Pixels = 4
#   Circle 12: Coordinates = (1096, 738), Black Pixels = 1712562, White Pixels = 508
#   Circle 13: Coordinates = (1278, 740), Black Pixels = 1713069, White Pixels = 1
#   Circle 14: Coordinates = (1338, 738), Black Pixels = 1712584, White Pixels = 486
#   Circle 15: Coordinates = (1398, 740), Black Pixels = 1712599, White Pixels = 471
#   Circle 16: Coordinates = (1456, 740), Black Pixels = 1712573, White Pixels = 497
# Row 10:
#   Circle 1: Coordinates = (156, 808), Black Pixels = 1713051, White Pixels = 19
#   Circle 2: Coordinates = (216, 808), Black Pixels = 1712408, White Pixels = 662
#   Circle 3: Coordinates = (278, 810), Black Pixels = 1712472, White Pixels = 598
#   Circle 4: Coordinates = (342, 810), Black Pixels = 1712500, White Pixels = 570
#   Circle 5: Coordinates = (536, 804), Black Pixels = 1712494, White Pixels = 576
#   Circle 6: Coordinates = (598, 804), Black Pixels = 1712470, White Pixels = 600
#   Circle 7: Coordinates = (660, 806), Black Pixels = 1712520, White Pixels = 550
#   Circle 8: Coordinates = (722, 806), Black Pixels = 1713055, White Pixels = 15
#   Circle 9: Coordinates = (914, 802), Black Pixels = 1713063, White Pixels = 7
#   Circle 10: Coordinates = (974, 802), Black Pixels = 1712604, White Pixels = 466
#   Circle 11: Coordinates = (1034, 802), Black Pixels = 1712575, White Pixels = 495
#   Circle 12: Coordinates = (1096, 802), Black Pixels = 1712573, White Pixels = 497
#   Circle 13: Coordinates = (1280, 804), Black Pixels = 1712531, White Pixels = 539
#   Circle 14: Coordinates = (1340, 804), Black Pixels = 1712549, White Pixels = 521
#   Circle 15: Coordinates = (1400, 804), Black Pixels = 1712594, White Pixels = 476
#   Circle 16: Coordinates = (1458, 804), Black Pixels = 1713061, White Pixels = 9

# %% [markdown]
# ### 5. Idendifying Marked and unmarked bubbles

# %%
def subtract_grouped_rows(grouped_rows_s, grouped_rows_t):
    """
    Subtract the black and white pixel values of grouped_rows_t from grouped_rows_s.

    Args:
        grouped_rows_s (list): List of grouped circles with pixel counts for the student's answer sheet.
        grouped_rows_t (list): List of grouped circles with pixel counts for the template.

    Returns:
        list: List of grouped circles with subtracted pixel counts.
    """
    subtracted_rows = []

    for row_s, row_t in zip(grouped_rows_s, grouped_rows_t):
        subtracted_row = []
        for (x_s, y_s, r_s, black_s, white_s), (x_t, y_t, r_t, black_t, white_t) in zip(row_s, row_t):
            subtracted_black = black_s - black_t
            subtracted_white = white_s - white_t
            subtracted_row.append((x_s, y_s, r_s, subtracted_black, subtracted_white))
        subtracted_rows.append(subtracted_row)

    return subtracted_rows

# Subtract the grouped rows
subtracted_grouped_rows = subtract_grouped_rows(grouped_rows_t, grouped_rows_s)

# Print the results
for row_idx, row in enumerate(subtracted_grouped_rows, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, subtracted_black, subtracted_white) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Subtracted Black Pixels = {subtracted_black}, Subtracted White Pixels = {subtracted_white}")
# Out:
# Row 1:
#   Circle 1: Coordinates = (148, 246), Subtracted Black Pixels = 54470, Subtracted White Pixels = -2
#   Circle 2: Coordinates = (210, 244), Subtracted Black Pixels = 54025, Subtracted White Pixels = 443
#   Circle 3: Coordinates = (274, 244), Subtracted Black Pixels = 54520, Subtracted White Pixels = -52
#   Circle 4: Coordinates = (340, 244), Subtracted Black Pixels = 54440, Subtracted White Pixels = 28
#   Circle 5: Coordinates = (536, 246), Subtracted Black Pixels = 53896, Subtracted White Pixels = 572
#   Circle 6: Coordinates = (600, 248), Subtracted Black Pixels = 54462, Subtracted White Pixels = 6
#   Circle 7: Coordinates = (662, 246), Subtracted Black Pixels = 54511, Subtracted White Pixels = -43
#   Circle 8: Coordinates = (724, 244), Subtracted Black Pixels = 54490, Subtracted White Pixels = -22
#   Circle 9: Coordinates = (924, 242), Subtracted Black Pixels = 54381, Subtracted White Pixels = 87
#   Circle 10: Coordinates = (986, 244), Subtracted Black Pixels = 54057, Subtracted White Pixels = 411
#   Circle 11: Coordinates = (1046, 244), Subtracted Black Pixels = 54530, Subtracted White Pixels = -62
#   Circle 12: Coordinates = (1108, 246), Subtracted Black Pixels = 54473, Subtracted White Pixels = -5
#   Circle 13: Coordinates = (1292, 248), Subtracted Black Pixels = 53967, Subtracted White Pixels = 501
#   Circle 14: Coordinates = (1354, 248), Subtracted Black Pixels = 54465, Subtracted White Pixels = 3
#   Circle 15: Coordinates = (1414, 248), Subtracted Black Pixels = 54483, Subtracted White Pixels = -15
#   Circle 16: Coordinates = (1476, 250), Subtracted Black Pixels = 54532, Subtracted White Pixels = -64
# Row 2:
#   Circle 1: Coordinates = (148, 312), Subtracted Black Pixels = 54198, Subtracted White Pixels = 270
#   Circle 2: Coordinates = (210, 312), Subtracted Black Pixels = 53865, Subtracted White Pixels = 603
#   Circle 3: Coordinates = (274, 310), Subtracted Black Pixels = 54555, Subtracted White Pixels = -87
#   Circle 4: Coordinates = (340, 312), Subtracted Black Pixels = 54518, Subtracted White Pixels = -50
#   Circle 5: Coordinates = (536, 312), Subtracted Black Pixels = 53912, Subtracted White Pixels = 556
#   Circle 6: Coordinates = (600, 314), Subtracted Black Pixels = 54525, Subtracted White Pixels = -57
#   Circle 7: Coordinates = (662, 314), Subtracted Black Pixels = 54509, Subtracted White Pixels = -41
#   Circle 8: Coordinates = (724, 312), Subtracted Black Pixels = 54556, Subtracted White Pixels = -88
#   Circle 9: Coordinates = (924, 310), Subtracted Black Pixels = 54446, Subtracted White Pixels = 22
#   Circle 10: Coordinates = (984, 312), Subtracted Black Pixels = 54012, Subtracted White Pixels = 456
#   Circle 11: Coordinates = (1046, 312), Subtracted Black Pixels = 54415, Subtracted White Pixels = 53
#   Circle 12: Coordinates = (1108, 312), Subtracted Black Pixels = 54422, Subtracted White Pixels = 46
#   Circle 13: Coordinates = (1294, 314), Subtracted Black Pixels = 53957, Subtracted White Pixels = 511
#   Circle 14: Coordinates = (1356, 314), Subtracted Black Pixels = 54464, Subtracted White Pixels = 4
#   Circle 15: Coordinates = (1416, 314), Subtracted Black Pixels = 54451, Subtracted White Pixels = 17
#   Circle 16: Coordinates = (1476, 314), Subtracted Black Pixels = 54465, Subtracted White Pixels = 3
# Row 3:
#   Circle 1: Coordinates = (146, 380), Subtracted Black Pixels = 54479, Subtracted White Pixels = -11
#   Circle 2: Coordinates = (210, 380), Subtracted Black Pixels = 53887, Subtracted White Pixels = 581
#   Circle 3: Coordinates = (272, 380), Subtracted Black Pixels = 54506, Subtracted White Pixels = -38
#   Circle 4: Coordinates = (338, 380), Subtracted Black Pixels = 54381, Subtracted White Pixels = 87
#   Circle 5: Coordinates = (538, 380), Subtracted Black Pixels = 53997, Subtracted White Pixels = 471
#   Circle 6: Coordinates = (602, 382), Subtracted Black Pixels = 54460, Subtracted White Pixels = 8
#   Circle 7: Coordinates = (662, 380), Subtracted Black Pixels = 54597, Subtracted White Pixels = -129
#   Circle 8: Coordinates = (724, 380), Subtracted Black Pixels = 54557, Subtracted White Pixels = -89
#   Circle 9: Coordinates = (922, 380), Subtracted Black Pixels = 54483, Subtracted White Pixels = -15
#   Circle 10: Coordinates = (984, 378), Subtracted Black Pixels = 54515, Subtracted White Pixels = -47
#   Circle 11: Coordinates = (1046, 378), Subtracted Black Pixels = 54405, Subtracted White Pixels = 63
#   Circle 12: Coordinates = (1110, 378), Subtracted Black Pixels = 54024, Subtracted White Pixels = 444
#   Circle 13: Coordinates = (1294, 378), Subtracted Black Pixels = 53944, Subtracted White Pixels = 524
#   Circle 14: Coordinates = (1356, 378), Subtracted Black Pixels = 54494, Subtracted White Pixels = -26
#   Circle 15: Coordinates = (1416, 380), Subtracted Black Pixels = 54502, Subtracted White Pixels = -34
#   Circle 16: Coordinates = (1476, 380), Subtracted Black Pixels = 54516, Subtracted White Pixels = -48
# Row 4:
#   Circle 1: Coordinates = (146, 448), Subtracted Black Pixels = 54473, Subtracted White Pixels = -5
#   Circle 2: Coordinates = (208, 448), Subtracted Black Pixels = 53944, Subtracted White Pixels = 524
#   Circle 3: Coordinates = (272, 448), Subtracted Black Pixels = 54457, Subtracted White Pixels = 11
#   Circle 4: Coordinates = (340, 448), Subtracted Black Pixels = 54502, Subtracted White Pixels = -34
#   Circle 5: Coordinates = (538, 448), Subtracted Black Pixels = 54469, Subtracted White Pixels = -1
#   Circle 6: Coordinates = (602, 448), Subtracted Black Pixels = 54484, Subtracted White Pixels = -16
#   Circle 7: Coordinates = (662, 446), Subtracted Black Pixels = 53932, Subtracted White Pixels = 536
#   Circle 8: Coordinates = (724, 446), Subtracted Black Pixels = 54467, Subtracted White Pixels = 1
#   Circle 9: Coordinates = (922, 446), Subtracted Black Pixels = 53988, Subtracted White Pixels = 480
#   Circle 10: Coordinates = (984, 446), Subtracted Black Pixels = 54474, Subtracted White Pixels = -6
#   Circle 11: Coordinates = (1046, 446), Subtracted Black Pixels = 54455, Subtracted White Pixels = 13
#   Circle 12: Coordinates = (1108, 446), Subtracted Black Pixels = 54459, Subtracted White Pixels = 9
#   Circle 13: Coordinates = (1294, 446), Subtracted Black Pixels = 54471, Subtracted White Pixels = -3
#   Circle 14: Coordinates = (1356, 446), Subtracted Black Pixels = 54069, Subtracted White Pixels = 399
#   Circle 15: Coordinates = (1416, 444), Subtracted Black Pixels = 54492, Subtracted White Pixels = -24
#   Circle 16: Coordinates = (1476, 444), Subtracted Black Pixels = 54482, Subtracted White Pixels = -14
# Row 5:
#   Circle 1: Coordinates = (144, 516), Subtracted Black Pixels = 54465, Subtracted White Pixels = 3
#   Circle 2: Coordinates = (208, 516), Subtracted Black Pixels = 54470, Subtracted White Pixels = -2
#   Circle 3: Coordinates = (272, 516), Subtracted Black Pixels = 53916, Subtracted White Pixels = 552
#   Circle 4: Coordinates = (338, 516), Subtracted Black Pixels = 54484, Subtracted White Pixels = -16
#   Circle 5: Coordinates = (538, 514), Subtracted Black Pixels = 54404, Subtracted White Pixels = 64
#   Circle 6: Coordinates = (602, 514), Subtracted Black Pixels = 54453, Subtracted White Pixels = 15
#   Circle 7: Coordinates = (662, 514), Subtracted Black Pixels = 53859, Subtracted White Pixels = 609
#   Circle 8: Coordinates = (724, 514), Subtracted Black Pixels = 54524, Subtracted White Pixels = -56
#   Circle 9: Coordinates = (922, 512), Subtracted Black Pixels = 53958, Subtracted White Pixels = 510
#   Circle 10: Coordinates = (984, 512), Subtracted Black Pixels = 54462, Subtracted White Pixels = 6
#   Circle 11: Coordinates = (1044, 512), Subtracted Black Pixels = 54468, Subtracted White Pixels = 0
#   Circle 12: Coordinates = (1108, 512), Subtracted Black Pixels = 54419, Subtracted White Pixels = 49
#   Circle 13: Coordinates = (1294, 512), Subtracted Black Pixels = 54436, Subtracted White Pixels = 32
#   Circle 14: Coordinates = (1356, 510), Subtracted Black Pixels = 54020, Subtracted White Pixels = 448
#   Circle 15: Coordinates = (1416, 510), Subtracted Black Pixels = 54466, Subtracted White Pixels = 2
#   Circle 16: Coordinates = (1476, 510), Subtracted Black Pixels = 54428, Subtracted White Pixels = 40
# Row 6:
#   Circle 1: Coordinates = (142, 584), Subtracted Black Pixels = 54438, Subtracted White Pixels = 30
#   Circle 2: Coordinates = (208, 584), Subtracted Black Pixels = 54598, Subtracted White Pixels = -130
#   Circle 3: Coordinates = (274, 584), Subtracted Black Pixels = 53934, Subtracted White Pixels = 534
#   Circle 4: Coordinates = (340, 584), Subtracted Black Pixels = 54431, Subtracted White Pixels = 37
#   Circle 5: Coordinates = (538, 580), Subtracted Black Pixels = 54395, Subtracted White Pixels = 73
#   Circle 6: Coordinates = (602, 580), Subtracted Black Pixels = 54366, Subtracted White Pixels = 102
#   Circle 7: Coordinates = (662, 580), Subtracted Black Pixels = 53852, Subtracted White Pixels = 616
#   Circle 8: Coordinates = (724, 580), Subtracted Black Pixels = 54472, Subtracted White Pixels = -4
#   Circle 9: Coordinates = (922, 578), Subtracted Black Pixels = 54442, Subtracted White Pixels = 26
#   Circle 10: Coordinates = (984, 578), Subtracted Black Pixels = 54535, Subtracted White Pixels = -67
#   Circle 11: Coordinates = (1044, 578), Subtracted Black Pixels = 54431, Subtracted White Pixels = 37
#   Circle 12: Coordinates = (1108, 578), Subtracted Black Pixels = 54013, Subtracted White Pixels = 455
#   Circle 13: Coordinates = (1296, 576), Subtracted Black Pixels = 54526, Subtracted White Pixels = -58
#   Circle 14: Coordinates = (1356, 576), Subtracted Black Pixels = 54440, Subtracted White Pixels = 28
#   Circle 15: Coordinates = (1416, 576), Subtracted Black Pixels = 54065, Subtracted White Pixels = 403
#   Circle 16: Coordinates = (1474, 576), Subtracted Black Pixels = 54478, Subtracted White Pixels = -10
# Row 7:
#   Circle 1: Coordinates = (144, 654), Subtracted Black Pixels = 54423, Subtracted White Pixels = 45
#   Circle 2: Coordinates = (208, 652), Subtracted Black Pixels = 54412, Subtracted White Pixels = 56
#   Circle 3: Coordinates = (276, 652), Subtracted Black Pixels = 53958, Subtracted White Pixels = 510
#   Circle 4: Coordinates = (342, 652), Subtracted Black Pixels = 54551, Subtracted White Pixels = -83
#   Circle 5: Coordinates = (538, 648), Subtracted Black Pixels = 54477, Subtracted White Pixels = -9
#   Circle 6: Coordinates = (602, 646), Subtracted Black Pixels = 54455, Subtracted White Pixels = 13
#   Circle 7: Coordinates = (662, 648), Subtracted Black Pixels = 54337, Subtracted White Pixels = 131
#   Circle 8: Coordinates = (724, 648), Subtracted Black Pixels = 53932, Subtracted White Pixels = 536
#   Circle 9: Coordinates = (922, 644), Subtracted Black Pixels = 54471, Subtracted White Pixels = -3
#   Circle 10: Coordinates = (984, 644), Subtracted Black Pixels = 54484, Subtracted White Pixels = -16
#   Circle 11: Coordinates = (1044, 644), Subtracted Black Pixels = 54487, Subtracted White Pixels = -19
#   Circle 12: Coordinates = (1108, 644), Subtracted Black Pixels = 54073, Subtracted White Pixels = 395
#   Circle 13: Coordinates = (1296, 644), Subtracted Black Pixels = 54530, Subtracted White Pixels = -62
#   Circle 14: Coordinates = (1356, 642), Subtracted Black Pixels = 54523, Subtracted White Pixels = -55
#   Circle 15: Coordinates = (1418, 642), Subtracted Black Pixels = 54015, Subtracted White Pixels = 453
#   Circle 16: Coordinates = (1478, 640), Subtracted Black Pixels = 54432, Subtracted White Pixels = 36
# Row 8:
#   Circle 1: Coordinates = (144, 722), Subtracted Black Pixels = 54517, Subtracted White Pixels = -49
#   Circle 2: Coordinates = (208, 720), Subtracted Black Pixels = 54474, Subtracted White Pixels = -6
#   Circle 3: Coordinates = (276, 720), Subtracted Black Pixels = 53924, Subtracted White Pixels = 544
#   Circle 4: Coordinates = (342, 720), Subtracted Black Pixels = 54496, Subtracted White Pixels = -28
#   Circle 5: Coordinates = (538, 714), Subtracted Black Pixels = 54399, Subtracted White Pixels = 69
#   Circle 6: Coordinates = (602, 712), Subtracted Black Pixels = 54517, Subtracted White Pixels = -49
#   Circle 7: Coordinates = (660, 714), Subtracted Black Pixels = 54272, Subtracted White Pixels = 196
#   Circle 8: Coordinates = (724, 714), Subtracted Black Pixels = 53909, Subtracted White Pixels = 559
#   Circle 9: Coordinates = (922, 710), Subtracted Black Pixels = 54501, Subtracted White Pixels = -33
#   Circle 10: Coordinates = (984, 710), Subtracted Black Pixels = 54457, Subtracted White Pixels = 11
#   Circle 11: Coordinates = (1046, 708), Subtracted Black Pixels = 54027, Subtracted White Pixels = 441
#   Circle 12: Coordinates = (1108, 710), Subtracted Black Pixels = 54470, Subtracted White Pixels = -2
#   Circle 13: Coordinates = (1298, 708), Subtracted Black Pixels = 54445, Subtracted White Pixels = 23
#   Circle 14: Coordinates = (1358, 708), Subtracted Black Pixels = 54495, Subtracted White Pixels = -27
#   Circle 15: Coordinates = (1418, 708), Subtracted Black Pixels = 54026, Subtracted White Pixels = 442
#   Circle 16: Coordinates = (1480, 706), Subtracted Black Pixels = 54454, Subtracted White Pixels = 14
# Row 9:
#   Circle 1: Coordinates = (144, 790), Subtracted Black Pixels = 54332, Subtracted White Pixels = 136
#   Circle 2: Coordinates = (210, 790), Subtracted Black Pixels = 54448, Subtracted White Pixels = 20
#   Circle 3: Coordinates = (274, 788), Subtracted Black Pixels = 54514, Subtracted White Pixels = -46
#   Circle 4: Coordinates = (340, 788), Subtracted Black Pixels = 53925, Subtracted White Pixels = 543
#   Circle 5: Coordinates = (538, 782), Subtracted Black Pixels = 54447, Subtracted White Pixels = 21
#   Circle 6: Coordinates = (600, 778), Subtracted Black Pixels = 54415, Subtracted White Pixels = 53
#   Circle 7: Coordinates = (660, 782), Subtracted Black Pixels = 54319, Subtracted White Pixels = 149
#   Circle 8: Coordinates = (724, 782), Subtracted Black Pixels = 53970, Subtracted White Pixels = 498
#   Circle 9: Coordinates = (922, 776), Subtracted Black Pixels = 54489, Subtracted White Pixels = -21
#   Circle 10: Coordinates = (984, 776), Subtracted Black Pixels = 54500, Subtracted White Pixels = -32
#   Circle 11: Coordinates = (1046, 776), Subtracted Black Pixels = 54030, Subtracted White Pixels = 438
#   Circle 12: Coordinates = (1108, 776), Subtracted Black Pixels = 54531, Subtracted White Pixels = -63
#   Circle 13: Coordinates = (1298, 776), Subtracted Black Pixels = 54476, Subtracted White Pixels = -8
#   Circle 14: Coordinates = (1358, 774), Subtracted Black Pixels = 54487, Subtracted White Pixels = -19
#   Circle 15: Coordinates = (1420, 774), Subtracted Black Pixels = 54492, Subtracted White Pixels = -24
#   Circle 16: Coordinates = (1482, 774), Subtracted Black Pixels = 54006, Subtracted White Pixels = 462
# Row 10:
#   Circle 1: Coordinates = (144, 858), Subtracted Black Pixels = 53855, Subtracted White Pixels = 613
#   Circle 2: Coordinates = (208, 858), Subtracted Black Pixels = 54509, Subtracted White Pixels = -41
#   Circle 3: Coordinates = (274, 856), Subtracted Black Pixels = 54624, Subtracted White Pixels = -156
#   Circle 4: Coordinates = (340, 856), Subtracted Black Pixels = 54516, Subtracted White Pixels = -48
#   Circle 5: Coordinates = (538, 848), Subtracted Black Pixels = 54460, Subtracted White Pixels = 8
#   Circle 6: Coordinates = (600, 848), Subtracted Black Pixels = 54608, Subtracted White Pixels = -140
#   Circle 7: Coordinates = (660, 850), Subtracted Black Pixels = 54462, Subtracted White Pixels = 6
#   Circle 8: Coordinates = (724, 850), Subtracted Black Pixels = 53902, Subtracted White Pixels = 566
#   Circle 9: Coordinates = (924, 844), Subtracted Black Pixels = 54474, Subtracted White Pixels = -6
#   Circle 10: Coordinates = (984, 842), Subtracted Black Pixels = 54486, Subtracted White Pixels = -18
#   Circle 11: Coordinates = (1048, 840), Subtracted Black Pixels = 53974, Subtracted White Pixels = 494
#   Circle 12: Coordinates = (1110, 842), Subtracted Black Pixels = 54480, Subtracted White Pixels = -12
#   Circle 13: Coordinates = (1298, 842), Subtracted Black Pixels = 54053, Subtracted White Pixels = 415
#   Circle 14: Coordinates = (1360, 840), Subtracted Black Pixels = 54472, Subtracted White Pixels = -4
#   Circle 15: Coordinates = (1422, 840), Subtracted Black Pixels = 54410, Subtracted White Pixels = 58
#   Circle 16: Coordinates = (1484, 840), Subtracted Black Pixels = 54489, Subtracted White Pixels = -21

# %%
subtract_grouped_rows_key = subtract_grouped_rows(grouped_rows_t,grouped_rows_k)
for row_idx, row in enumerate(subtract_grouped_rows_key, start=1):
    print(f"Row {row_idx}:")
    for idx, (x, y, r, subtracted_black, subtracted_white) in enumerate(row, start=1):
        print(f"  Circle {idx}: Coordinates = ({x}, {y}), Subtracted Black Pixels = {subtracted_black}, Subtracted White Pixels = {subtracted_white}")
# Out:
# Row 1:
#   Circle 1: Coordinates = (148, 246), Subtracted Black Pixels = 63513, Subtracted White Pixels = 35
#   Circle 2: Coordinates = (210, 244), Subtracted Black Pixels = 63102, Subtracted White Pixels = 446
#   Circle 3: Coordinates = (274, 244), Subtracted Black Pixels = 63480, Subtracted White Pixels = 68
#   Circle 4: Coordinates = (340, 244), Subtracted Black Pixels = 63512, Subtracted White Pixels = 36
#   Circle 5: Coordinates = (536, 246), Subtracted Black Pixels = 62958, Subtracted White Pixels = 590
#   Circle 6: Coordinates = (600, 248), Subtracted Black Pixels = 63479, Subtracted White Pixels = 69
#   Circle 7: Coordinates = (662, 246), Subtracted Black Pixels = 63632, Subtracted White Pixels = -84
#   Circle 8: Coordinates = (724, 244), Subtracted Black Pixels = 63495, Subtracted White Pixels = 53
#   Circle 9: Coordinates = (924, 242), Subtracted Black Pixels = 63471, Subtracted White Pixels = 77
#   Circle 10: Coordinates = (986, 244), Subtracted Black Pixels = 63135, Subtracted White Pixels = 413
#   Circle 11: Coordinates = (1046, 244), Subtracted Black Pixels = 63618, Subtracted White Pixels = -70
#   Circle 12: Coordinates = (1108, 246), Subtracted Black Pixels = 63567, Subtracted White Pixels = -19
#   Circle 13: Coordinates = (1292, 248), Subtracted Black Pixels = 63068, Subtracted White Pixels = 480
#   Circle 14: Coordinates = (1354, 248), Subtracted Black Pixels = 63572, Subtracted White Pixels = -24
#   Circle 15: Coordinates = (1414, 248), Subtracted Black Pixels = 63640, Subtracted White Pixels = -92
#   Circle 16: Coordinates = (1476, 250), Subtracted Black Pixels = 63588, Subtracted White Pixels = -40
# Row 2:
#   Circle 1: Coordinates = (148, 312), Subtracted Black Pixels = 63458, Subtracted White Pixels = 90
#   Circle 2: Coordinates = (210, 312), Subtracted Black Pixels = 62999, Subtracted White Pixels = 549
#   Circle 3: Coordinates = (274, 310), Subtracted Black Pixels = 63684, Subtracted White Pixels = -136
#   Circle 4: Coordinates = (340, 312), Subtracted Black Pixels = 63575, Subtracted White Pixels = -27
#   Circle 5: Coordinates = (536, 312), Subtracted Black Pixels = 63565, Subtracted White Pixels = -17
#   Circle 6: Coordinates = (600, 314), Subtracted Black Pixels = 63146, Subtracted White Pixels = 402
#   Circle 7: Coordinates = (662, 314), Subtracted Black Pixels = 63508, Subtracted White Pixels = 40
#   Circle 8: Coordinates = (724, 312), Subtracted Black Pixels = 63570, Subtracted White Pixels = -22
#   Circle 9: Coordinates = (924, 310), Subtracted Black Pixels = 63503, Subtracted White Pixels = 45
#   Circle 10: Coordinates = (984, 312), Subtracted Black Pixels = 63097, Subtracted White Pixels = 451
#   Circle 11: Coordinates = (1046, 312), Subtracted Black Pixels = 63634, Subtracted White Pixels = -86
#   Circle 12: Coordinates = (1108, 312), Subtracted Black Pixels = 63540, Subtracted White Pixels = 8
#   Circle 13: Coordinates = (1294, 314), Subtracted Black Pixels = 63564, Subtracted White Pixels = -16
#   Circle 14: Coordinates = (1356, 314), Subtracted Black Pixels = 63029, Subtracted White Pixels = 519
#   Circle 15: Coordinates = (1416, 314), Subtracted Black Pixels = 63601, Subtracted White Pixels = -53
#   Circle 16: Coordinates = (1476, 314), Subtracted Black Pixels = 63540, Subtracted White Pixels = 8
# Row 3:
#   Circle 1: Coordinates = (146, 380), Subtracted Black Pixels = 63564, Subtracted White Pixels = -16
#   Circle 2: Coordinates = (210, 380), Subtracted Black Pixels = 62982, Subtracted White Pixels = 566
#   Circle 3: Coordinates = (272, 380), Subtracted Black Pixels = 63657, Subtracted White Pixels = -109
#   Circle 4: Coordinates = (338, 380), Subtracted Black Pixels = 63439, Subtracted White Pixels = 109
#   Circle 5: Coordinates = (538, 380), Subtracted Black Pixels = 63578, Subtracted White Pixels = -30
#   Circle 6: Coordinates = (602, 382), Subtracted Black Pixels = 63051, Subtracted White Pixels = 497
#   Circle 7: Coordinates = (662, 380), Subtracted Black Pixels = 63564, Subtracted White Pixels = -16
#   Circle 8: Coordinates = (724, 380), Subtracted Black Pixels = 63625, Subtracted White Pixels = -77
#   Circle 9: Coordinates = (922, 380), Subtracted Black Pixels = 63076, Subtracted White Pixels = 472
#   Circle 10: Coordinates = (984, 378), Subtracted Black Pixels = 63667, Subtracted White Pixels = -119
#   Circle 11: Coordinates = (1046, 378), Subtracted Black Pixels = 63500, Subtracted White Pixels = 48
#   Circle 12: Coordinates = (1110, 378), Subtracted Black Pixels = 63559, Subtracted White Pixels = -11
#   Circle 13: Coordinates = (1294, 378), Subtracted Black Pixels = 63624, Subtracted White Pixels = -76
#   Circle 14: Coordinates = (1356, 378), Subtracted Black Pixels = 63078, Subtracted White Pixels = 470
#   Circle 15: Coordinates = (1416, 380), Subtracted Black Pixels = 63616, Subtracted White Pixels = -68
#   Circle 16: Coordinates = (1476, 380), Subtracted Black Pixels = 63609, Subtracted White Pixels = -61
# Row 4:
#   Circle 1: Coordinates = (146, 448), Subtracted Black Pixels = 63026, Subtracted White Pixels = 522
#   Circle 2: Coordinates = (208, 448), Subtracted Black Pixels = 63548, Subtracted White Pixels = 0
#   Circle 3: Coordinates = (272, 448), Subtracted Black Pixels = 63678, Subtracted White Pixels = -130
#   Circle 4: Coordinates = (340, 448), Subtracted Black Pixels = 63572, Subtracted White Pixels = -24
#   Circle 5: Coordinates = (538, 448), Subtracted Black Pixels = 63112, Subtracted White Pixels = 436
#   Circle 6: Coordinates = (602, 448), Subtracted Black Pixels = 63508, Subtracted White Pixels = 40
#   Circle 7: Coordinates = (662, 446), Subtracted Black Pixels = 63676, Subtracted White Pixels = -128
#   Circle 8: Coordinates = (724, 446), Subtracted Black Pixels = 63636, Subtracted White Pixels = -88
#   Circle 9: Coordinates = (922, 446), Subtracted Black Pixels = 63043, Subtracted White Pixels = 505
#   Circle 10: Coordinates = (984, 446), Subtracted Black Pixels = 63585, Subtracted White Pixels = -37
#   Circle 11: Coordinates = (1046, 446), Subtracted Black Pixels = 63559, Subtracted White Pixels = -11
#   Circle 12: Coordinates = (1108, 446), Subtracted Black Pixels = 63561, Subtracted White Pixels = -13
#   Circle 13: Coordinates = (1294, 446), Subtracted Black Pixels = 63107, Subtracted White Pixels = 441
#   Circle 14: Coordinates = (1356, 446), Subtracted Black Pixels = 63689, Subtracted White Pixels = -141
#   Circle 15: Coordinates = (1416, 444), Subtracted Black Pixels = 63622, Subtracted White Pixels = -74
#   Circle 16: Coordinates = (1476, 444), Subtracted Black Pixels = 63518, Subtracted White Pixels = 30
# Row 5:
#   Circle 1: Coordinates = (144, 516), Subtracted Black Pixels = 63005, Subtracted White Pixels = 543
#   Circle 2: Coordinates = (208, 516), Subtracted Black Pixels = 63580, Subtracted White Pixels = -32
#   Circle 3: Coordinates = (272, 516), Subtracted Black Pixels = 63649, Subtracted White Pixels = -101
#   Circle 4: Coordinates = (338, 516), Subtracted Black Pixels = 63441, Subtracted White Pixels = 107
#   Circle 5: Coordinates = (538, 514), Subtracted Black Pixels = 63498, Subtracted White Pixels = 50
#   Circle 6: Coordinates = (602, 514), Subtracted Black Pixels = 63452, Subtracted White Pixels = 96
#   Circle 7: Coordinates = (662, 514), Subtracted Black Pixels = 63633, Subtracted White Pixels = -85
#   Circle 8: Coordinates = (724, 514), Subtracted Black Pixels = 63232, Subtracted White Pixels = 316
#   Circle 9: Coordinates = (922, 512), Subtracted Black Pixels = 63487, Subtracted White Pixels = 61
#   Circle 10: Coordinates = (984, 512), Subtracted Black Pixels = 63554, Subtracted White Pixels = -6
#   Circle 11: Coordinates = (1044, 512), Subtracted Black Pixels = 63107, Subtracted White Pixels = 441
#   Circle 12: Coordinates = (1108, 512), Subtracted Black Pixels = 63556, Subtracted White Pixels = -8
#   Circle 13: Coordinates = (1294, 512), Subtracted Black Pixels = 63065, Subtracted White Pixels = 483
#   Circle 14: Coordinates = (1356, 510), Subtracted Black Pixels = 63591, Subtracted White Pixels = -43
#   Circle 15: Coordinates = (1416, 510), Subtracted Black Pixels = 63581, Subtracted White Pixels = -33
#   Circle 16: Coordinates = (1476, 510), Subtracted Black Pixels = 63534, Subtracted White Pixels = 14
# Row 6:
#   Circle 1: Coordinates = (142, 584), Subtracted Black Pixels = 63506, Subtracted White Pixels = 42
#   Circle 2: Coordinates = (208, 584), Subtracted Black Pixels = 63629, Subtracted White Pixels = -81
#   Circle 3: Coordinates = (274, 584), Subtracted Black Pixels = 63061, Subtracted White Pixels = 487
#   Circle 4: Coordinates = (340, 584), Subtracted Black Pixels = 63589, Subtracted White Pixels = -41
#   Circle 5: Coordinates = (538, 580), Subtracted Black Pixels = 63571, Subtracted White Pixels = -23
#   Circle 6: Coordinates = (602, 580), Subtracted Black Pixels = 63485, Subtracted White Pixels = 63
#   Circle 7: Coordinates = (662, 580), Subtracted Black Pixels = 63402, Subtracted White Pixels = 146
#   Circle 8: Coordinates = (724, 580), Subtracted Black Pixels = 63057, Subtracted White Pixels = 491
#   Circle 9: Coordinates = (922, 578), Subtracted Black Pixels = 63543, Subtracted White Pixels = 5
#   Circle 10: Coordinates = (984, 578), Subtracted Black Pixels = 63551, Subtracted White Pixels = -3
#   Circle 11: Coordinates = (1044, 578), Subtracted Black Pixels = 63126, Subtracted White Pixels = 422
#   Circle 12: Coordinates = (1108, 578), Subtracted Black Pixels = 63498, Subtracted White Pixels = 50
#   Circle 13: Coordinates = (1296, 576), Subtracted Black Pixels = 63661, Subtracted White Pixels = -113
#   Circle 14: Coordinates = (1356, 576), Subtracted Black Pixels = 63568, Subtracted White Pixels = -20
#   Circle 15: Coordinates = (1416, 576), Subtracted Black Pixels = 63096, Subtracted White Pixels = 452
#   Circle 16: Coordinates = (1474, 576), Subtracted Black Pixels = 63562, Subtracted White Pixels = -14
# Row 7:
#   Circle 1: Coordinates = (144, 654), Subtracted Black Pixels = 63585, Subtracted White Pixels = -37
#   Circle 2: Coordinates = (208, 652), Subtracted Black Pixels = 63585, Subtracted White Pixels = -37
#   Circle 3: Coordinates = (276, 652), Subtracted Black Pixels = 63109, Subtracted White Pixels = 439
#   Circle 4: Coordinates = (342, 652), Subtracted Black Pixels = 63506, Subtracted White Pixels = 42
#   Circle 5: Coordinates = (538, 648), Subtracted Black Pixels = 63625, Subtracted White Pixels = -77
#   Circle 6: Coordinates = (602, 646), Subtracted Black Pixels = 63518, Subtracted White Pixels = 30
#   Circle 7: Coordinates = (662, 648), Subtracted Black Pixels = 63394, Subtracted White Pixels = 154
#   Circle 8: Coordinates = (724, 648), Subtracted Black Pixels = 63080, Subtracted White Pixels = 468
#   Circle 9: Coordinates = (922, 644), Subtracted Black Pixels = 63057, Subtracted White Pixels = 491
#   Circle 10: Coordinates = (984, 644), Subtracted Black Pixels = 63609, Subtracted White Pixels = -61
#   Circle 11: Coordinates = (1044, 644), Subtracted Black Pixels = 63641, Subtracted White Pixels = -93
#   Circle 12: Coordinates = (1108, 644), Subtracted Black Pixels = 63628, Subtracted White Pixels = -80
#   Circle 13: Coordinates = (1296, 644), Subtracted Black Pixels = 63609, Subtracted White Pixels = -61
#   Circle 14: Coordinates = (1356, 642), Subtracted Black Pixels = 63506, Subtracted White Pixels = 42
#   Circle 15: Coordinates = (1418, 642), Subtracted Black Pixels = 63125, Subtracted White Pixels = 423
#   Circle 16: Coordinates = (1478, 640), Subtracted Black Pixels = 63544, Subtracted White Pixels = 4
# Row 8:
#   Circle 1: Coordinates = (144, 722), Subtracted Black Pixels = 63563, Subtracted White Pixels = -15
#   Circle 2: Coordinates = (208, 720), Subtracted Black Pixels = 63677, Subtracted White Pixels = -129
#   Circle 3: Coordinates = (276, 720), Subtracted Black Pixels = 63622, Subtracted White Pixels = -74
#   Circle 4: Coordinates = (342, 720), Subtracted Black Pixels = 63025, Subtracted White Pixels = 523
#   Circle 5: Coordinates = (538, 714), Subtracted Black Pixels = 62912, Subtracted White Pixels = 636
#   Circle 6: Coordinates = (602, 712), Subtracted Black Pixels = 63565, Subtracted White Pixels = -17
#   Circle 7: Coordinates = (660, 714), Subtracted Black Pixels = 63493, Subtracted White Pixels = 55
#   Circle 8: Coordinates = (724, 714), Subtracted Black Pixels = 63484, Subtracted White Pixels = 64
#   Circle 9: Coordinates = (922, 710), Subtracted Black Pixels = 63059, Subtracted White Pixels = 489
#   Circle 10: Coordinates = (984, 710), Subtracted Black Pixels = 63564, Subtracted White Pixels = -16
#   Circle 11: Coordinates = (1046, 708), Subtracted Black Pixels = 63546, Subtracted White Pixels = 2
#   Circle 12: Coordinates = (1108, 710), Subtracted Black Pixels = 63571, Subtracted White Pixels = -23
#   Circle 13: Coordinates = (1298, 708), Subtracted Black Pixels = 63061, Subtracted White Pixels = 487
#   Circle 14: Coordinates = (1358, 708), Subtracted Black Pixels = 63606, Subtracted White Pixels = -58
#   Circle 15: Coordinates = (1418, 708), Subtracted Black Pixels = 63540, Subtracted White Pixels = 8
#   Circle 16: Coordinates = (1480, 706), Subtracted Black Pixels = 63528, Subtracted White Pixels = 20
# Row 9:
#   Circle 1: Coordinates = (144, 790), Subtracted Black Pixels = 63600, Subtracted White Pixels = -52
#   Circle 2: Coordinates = (210, 790), Subtracted Black Pixels = 63449, Subtracted White Pixels = 99
#   Circle 3: Coordinates = (274, 788), Subtracted Black Pixels = 63596, Subtracted White Pixels = -48
#   Circle 4: Coordinates = (340, 788), Subtracted Black Pixels = 63022, Subtracted White Pixels = 526
#   Circle 5: Coordinates = (538, 782), Subtracted Black Pixels = 63577, Subtracted White Pixels = -29
#   Circle 6: Coordinates = (600, 778), Subtracted Black Pixels = 63477, Subtracted White Pixels = 71
#   Circle 7: Coordinates = (660, 782), Subtracted Black Pixels = 63392, Subtracted White Pixels = 156
#   Circle 8: Coordinates = (724, 782), Subtracted Black Pixels = 63037, Subtracted White Pixels = 511
#   Circle 9: Coordinates = (922, 776), Subtracted Black Pixels = 63527, Subtracted White Pixels = 21
#   Circle 10: Coordinates = (984, 776), Subtracted Black Pixels = 63598, Subtracted White Pixels = -50
#   Circle 11: Coordinates = (1046, 776), Subtracted Black Pixels = 63100, Subtracted White Pixels = 448
#   Circle 12: Coordinates = (1108, 776), Subtracted Black Pixels = 63638, Subtracted White Pixels = -90
#   Circle 13: Coordinates = (1298, 776), Subtracted Black Pixels = 63082, Subtracted White Pixels = 466
#   Circle 14: Coordinates = (1358, 774), Subtracted Black Pixels = 63584, Subtracted White Pixels = -36
#   Circle 15: Coordinates = (1420, 774), Subtracted Black Pixels = 63578, Subtracted White Pixels = -30
#   Circle 16: Coordinates = (1482, 774), Subtracted Black Pixels = 63582, Subtracted White Pixels = -34
# Row 10:
#   Circle 1: Coordinates = (144, 858), Subtracted Black Pixels = 62942, Subtracted White Pixels = 606
#   Circle 2: Coordinates = (208, 858), Subtracted Black Pixels = 63612, Subtracted White Pixels = -64
#   Circle 3: Coordinates = (274, 856), Subtracted Black Pixels = 63626, Subtracted White Pixels = -78
#   Circle 4: Coordinates = (340, 856), Subtracted Black Pixels = 63581, Subtracted White Pixels = -33
#   Circle 5: Coordinates = (538, 848), Subtracted Black Pixels = 63550, Subtracted White Pixels = -2
#   Circle 6: Coordinates = (600, 848), Subtracted Black Pixels = 63693, Subtracted White Pixels = -145
#   Circle 7: Coordinates = (660, 850), Subtracted Black Pixels = 63501, Subtracted White Pixels = 47
#   Circle 8: Coordinates = (724, 850), Subtracted Black Pixels = 62997, Subtracted White Pixels = 551
#   Circle 9: Coordinates = (924, 844), Subtracted Black Pixels = 63024, Subtracted White Pixels = 524
#   Circle 10: Coordinates = (984, 842), Subtracted Black Pixels = 63566, Subtracted White Pixels = -18
#   Circle 11: Coordinates = (1048, 840), Subtracted Black Pixels = 63547, Subtracted White Pixels = 1
#   Circle 12: Coordinates = (1110, 842), Subtracted Black Pixels = 63574, Subtracted White Pixels = -26
#   Circle 13: Coordinates = (1298, 842), Subtracted Black Pixels = 63595, Subtracted White Pixels = -47
#   Circle 14: Coordinates = (1360, 840), Subtracted Black Pixels = 63627, Subtracted White Pixels = -79
#   Circle 15: Coordinates = (1422, 840), Subtracted Black Pixels = 63539, Subtracted White Pixels = 9
#   Circle 16: Coordinates = (1484, 840), Subtracted Black Pixels = 63138, Subtracted White Pixels = 410

# %%
def detect_marked_and_unmarked_bubbles(subtracted_grouped_rows, num_options, deviation_threshold=50):
    """
    Detect marked and unmarked bubbles based on white pixel values and a deviation threshold.

    Args:
        subtracted_grouped_rows (list): List of grouped circles with subtracted pixel counts.
        num_options (int): The number of options per question.
        deviation_threshold (float): The threshold below which a question is considered unmarked.

    Returns:
        list: A 2D array where each element is:
              - 1 for the most deviated (marked) bubble.
              - 0 for unmarked bubbles.
    """
    marked_bubbles = []

    for row in subtracted_grouped_rows:
        for question_start in range(0, len(row), num_options):
            question_group = row[question_start:question_start + num_options]

            # Extract white pixel values for the current question
            white_pixel_values = [subtracted_white for (_, _, _, _, subtracted_white) in question_group]

            # Calculate the mean and standard deviation of the white pixel values
            mean_white = np.mean(white_pixel_values)
            std_dev_white = np.std(white_pixel_values)
            print(f"Mean: {mean_white}, Standard Deviation: {std_dev_white}")
            # If the standard deviation is less than the threshold, consider the question unmarked
            if std_dev_white < deviation_threshold:
                marked_bubbles.append([0] * num_options)  
            else:
                # Calculate absolute deviations from the mean
                deviations = [abs(white_value - mean_white) for white_value in white_pixel_values]

                # Create a 1D array for the question (options), initialized to zeros
                marked_question = np.zeros(num_options, dtype=int)

                # Find the index of the maximum deviation
                max_deviation_index = np.argmax(deviations)

                # Mark the option with the highest deviation as 1 (marked bubble)
                marked_question[max_deviation_index] = 1

                marked_bubbles.append(marked_question)

    return np.array(marked_bubbles)


answer_student = detect_marked_and_unmarked_bubbles(subtracted_grouped_rows, options)

# Print the marked bubbles in a readable format
for row_idx, row in enumerate(answer_student, start=1):
    print(f"Question {row_idx}: Marked Bubble = {row.tolist()}")
# Out:
# Mean: 104.25, Standard Deviation: 197.65421194601444
# Mean: 128.25, Standard Deviation: 256.78821526697834
# Mean: 107.75, Standard Deviation: 182.97455424183985
# Mean: 106.25, Standard Deviation: 229.224098863972
# Mean: 184.0, Standard Deviation: 278.90589810902173
# Mean: 92.5, Standard Deviation: 268.134760894592
# Mean: 144.25, Standard Deviation: 180.35572488834393
# Mean: 133.75, Standard Deviation: 217.87539443452536
# Mean: 154.75, Standard Deviation: 250.45196645265136
# Mean: 65.25, Standard Deviation: 239.49778182688874
# Mean: 111.25, Standard Deviation: 196.2350312762734
# Mean: 104.0, Standard Deviation: 242.61492122291241
# Mean: 124.0, Standard Deviation: 231.50269976827485
# Mean: 130.0, Standard Deviation: 234.49626862702954
# Mean: 124.0, Standard Deviation: 205.6586978466994
# Mean: 89.5, Standard Deviation: 178.8442059447272
# Mean: 134.25, Standard Deviation: 241.28859794859764
# Mean: 158.0, Standard Deviation: 263.8569688297052
# Mean: 141.25, Standard Deviation: 213.7350871990839
# Mean: 130.5, Standard Deviation: 183.85524197041542
# Mean: 117.75, Standard Deviation: 249.43172913645128
# Mean: 196.75, Standard Deviation: 245.13401946690306
# Mean: 112.75, Standard Deviation: 201.6858634113953
# Mean: 90.75, Standard Deviation: 182.8351374873003
# Mean: 132.0, Standard Deviation: 224.97444299297644
# Mean: 167.75, Standard Deviation: 219.17273439002398
# Mean: 89.25, Standard Deviation: 176.62725582423568
# Mean: 93.0, Standard Deviation: 211.4107376648594
# Mean: 115.25, Standard Deviation: 248.005418287585
# Mean: 193.75, Standard Deviation: 227.98177010454148
# Mean: 104.25, Standard Deviation: 195.07867002827348
# Mean: 113.0, Standard Deviation: 190.8808528899638
# Mean: 163.25, Standard Deviation: 228.72404224304887
# Mean: 180.25, Standard Deviation: 189.40350445543504
# Mean: 80.5, Standard Deviation: 206.97644793550788
# Mean: 102.75, Standard Deviation: 207.49382520933003
# Mean: 92.0, Standard Deviation: 304.2342847214955
# Mean: 110.0, Standard Deviation: 270.0259246813165
# Mean: 114.5, Standard Deviation: 219.14549961155944
# Mean: 112.0, Standard Deviation: 177.39081148695385
# Question 1: Marked Bubble = [0, 1, 0, 0]
# Question 2: Marked Bubble = [1, 0, 0, 0]
# Question 3: Marked Bubble = [0, 1, 0, 0]
# Question 4: Marked Bubble = [1, 0, 0, 0]
# Question 5: Marked Bubble = [0, 1, 0, 0]
# Question 6: Marked Bubble = [1, 0, 0, 0]
# Question 7: Marked Bubble = [0, 1, 0, 0]
# Question 8: Marked Bubble = [1, 0, 0, 0]
# Question 9: Marked Bubble = [0, 1, 0, 0]
# Question 10: Marked Bubble = [1, 0, 0, 0]
# Question 11: Marked Bubble = [0, 0, 0, 1]
# Question 12: Marked Bubble = [1, 0, 0, 0]
# Question 13: Marked Bubble = [0, 1, 0, 0]
# Question 14: Marked Bubble = [0, 0, 1, 0]
# Question 15: Marked Bubble = [1, 0, 0, 0]
# Question 16: Marked Bubble = [0, 1, 0, 0]
# Question 17: Marked Bubble = [0, 0, 1, 0]
# Question 18: Marked Bubble = [0, 0, 1, 0]
# Question 19: Marked Bubble = [1, 0, 0, 0]
# Question 20: Marked Bubble = [0, 1, 0, 0]
# Question 21: Marked Bubble = [0, 0, 1, 0]
# Question 22: Marked Bubble = [0, 0, 1, 0]
# Question 23: Marked Bubble = [0, 0, 0, 1]
# Question 24: Marked Bubble = [0, 0, 1, 0]
# Question 25: Marked Bubble = [0, 0, 1, 0]
# Question 26: Marked Bubble = [0, 0, 0, 1]
# Question 27: Marked Bubble = [0, 0, 0, 1]
# Question 28: Marked Bubble = [0, 0, 1, 0]
# Question 29: Marked Bubble = [0, 0, 1, 0]
# Question 30: Marked Bubble = [0, 0, 0, 1]
# Question 31: Marked Bubble = [0, 0, 1, 0]
# Question 32: Marked Bubble = [0, 0, 1, 0]
# Question 33: Marked Bubble = [0, 0, 0, 1]
# Question 34: Marked Bubble = [0, 0, 0, 1]
# Question 35: Marked Bubble = [0, 0, 1, 0]
# Question 36: Marked Bubble = [0, 0, 0, 1]
# Question 37: Marked Bubble = [1, 0, 0, 0]
# Question 38: Marked Bubble = [0, 0, 0, 1]
# Question 39: Marked Bubble = [0, 0, 1, 0]
# Question 40: Marked Bubble = [1, 0, 0, 0]

# %%
answer_key = detect_marked_and_unmarked_bubbles(subtract_grouped_rows_key, options)
for row_idx, row in enumerate(answer_key, start=1):
    print(f"Question {row_idx}: Marked Bubble = {row.tolist()}")
# Out:
# Mean: 146.25, Standard Deviation: 173.56897044114768
# Mean: 157.0, Standard Deviation: 256.9678968275999
# Mean: 100.25, Standard Deviation: 188.12147006655036
# Mean: 81.0, Standard Deviation: 231.73044685582428
# Mean: 119.0, Standard Deviation: 260.80740020175807
# Mean: 100.75, Standard Deviation: 175.62370995967487
# Mean: 104.5, Standard Deviation: 205.67267684357103
# Mean: 114.5, Standard Deviation: 234.54690362484004
# Mean: 137.5, Standard Deviation: 259.20503467332577
# Mean: 93.5, Standard Deviation: 234.05394677296087
# Mean: 97.5, Standard Deviation: 224.35741574550192
# Mean: 66.25, Standard Deviation: 233.1655795781187
# Mean: 92.0, Standard Deviation: 253.03359460751452
# Mean: 65.0, Standard Deviation: 223.0044842598462
# Mean: 111.0, Standard Deviation: 227.705950734714
# Mean: 64.0, Standard Deviation: 226.02765317544666
# Mean: 129.25, Standard Deviation: 250.35012981822078
# Mean: 94.25, Standard Deviation: 144.2781601629297
# Mean: 122.0, Standard Deviation: 186.25654350921474
# Mean: 105.25, Standard Deviation: 219.15334243401355
# Mean: 101.75, Standard Deviation: 226.80539565892167
# Mean: 169.25, Standard Deviation: 195.13633054867051
# Mean: 118.5, Standard Deviation: 176.38664915463414
# Mean: 76.25, Standard Deviation: 220.46130612876266
# Mean: 101.75, Standard Deviation: 197.3643521510407
# Mean: 143.75, Standard Deviation: 204.27478429801363
# Mean: 64.25, Standard Deviation: 246.64688828363515
# Mean: 102.0, Standard Deviation: 188.95369803208405
# Mean: 76.25, Standard Deviation: 261.0626122216661
# Mean: 184.5, Standard Deviation: 262.5571366388657
# Mean: 113.0, Standard Deviation: 217.27517115400002
# Mean: 114.25, Standard Deviation: 217.24683541998948
# Mean: 131.25, Standard Deviation: 235.89126202553584
# Mean: 177.25, Standard Deviation: 203.51213108805086
# Mean: 82.25, Standard Deviation: 214.8748182081837
# Mean: 91.5, Standard Deviation: 216.22846713603647
# Mean: 107.75, Standard Deviation: 288.1252982644877
# Mean: 112.75, Standard Deviation: 262.67315717446274
# Mean: 120.25, Standard Deviation: 233.31135313138964
# Mean: 73.25, Standard Deviation: 196.95732405777653
# Question 1: Marked Bubble = [0, 1, 0, 0]
# Question 2: Marked Bubble = [1, 0, 0, 0]
# Question 3: Marked Bubble = [0, 1, 0, 0]
# Question 4: Marked Bubble = [1, 0, 0, 0]
# Question 5: Marked Bubble = [0, 1, 0, 0]
# Question 6: Marked Bubble = [0, 1, 0, 0]
# Question 7: Marked Bubble = [0, 1, 0, 0]
# Question 8: Marked Bubble = [0, 1, 0, 0]
# Question 9: Marked Bubble = [0, 1, 0, 0]
# Question 10: Marked Bubble = [0, 1, 0, 0]
# Question 11: Marked Bubble = [1, 0, 0, 0]
# Question 12: Marked Bubble = [0, 1, 0, 0]
# Question 13: Marked Bubble = [1, 0, 0, 0]
# Question 14: Marked Bubble = [1, 0, 0, 0]
# Question 15: Marked Bubble = [1, 0, 0, 0]
# Question 16: Marked Bubble = [1, 0, 0, 0]
# Question 17: Marked Bubble = [1, 0, 0, 0]
# Question 18: Marked Bubble = [0, 0, 0, 1]
# Question 19: Marked Bubble = [0, 0, 1, 0]
# Question 20: Marked Bubble = [1, 0, 0, 0]
# Question 21: Marked Bubble = [0, 0, 1, 0]
# Question 22: Marked Bubble = [0, 0, 0, 1]
# Question 23: Marked Bubble = [0, 0, 1, 0]
# Question 24: Marked Bubble = [0, 0, 1, 0]
# Question 25: Marked Bubble = [0, 0, 1, 0]
# Question 26: Marked Bubble = [0, 0, 0, 1]
# Question 27: Marked Bubble = [1, 0, 0, 0]
# Question 28: Marked Bubble = [0, 0, 1, 0]
# Question 29: Marked Bubble = [0, 0, 0, 1]
# Question 30: Marked Bubble = [1, 0, 0, 0]
# Question 31: Marked Bubble = [1, 0, 0, 0]
# Question 32: Marked Bubble = [1, 0, 0, 0]
# Question 33: Marked Bubble = [0, 0, 0, 1]
# Question 34: Marked Bubble = [0, 0, 0, 1]
# Question 35: Marked Bubble = [0, 0, 1, 0]
# Question 36: Marked Bubble = [1, 0, 0, 0]
# Question 37: Marked Bubble = [1, 0, 0, 0]
# Question 38: Marked Bubble = [0, 0, 0, 1]
# Question 39: Marked Bubble = [1, 0, 0, 0]
# Question 40: Marked Bubble = [0, 0, 0, 1]

# %% [markdown]
# ### 6. Calculating score

# %%
def calculate_score(answer_key, answer_student):
    """
    Compare the student's answers with the answer key and calculate the score.

    Args:
        answer_key (np.ndarray): The correct answer key with marked bubbles (1 for correct option, 0 for others).
        answer_student (np.ndarray): The student's marked answers with bubbles (1 for marked option, 0 for others).

    Returns:
        int: The total score of the student.
        list: A list indicating correctness for each question (1 for correct, 0 for incorrect).
    """
    total_score = 0
    result_per_question = []

    for key, student in zip(answer_key, answer_student):
        if np.array_equal(key, student):
            total_score += 1
            result_per_question.append(1)  # Correct answer
        else:
            result_per_question.append(0)  # Incorrect answer

    return total_score, result_per_question


total_score, result_per_question = calculate_score(answer_key, answer_student)

# Print the final score and results
print(f"Total Score: {total_score}")
for idx, result in enumerate(result_per_question, start=1):
    status = "Correct" if result == 1 else "Incorrect"
    print(f"Question {idx}: {status}")
# Out:
# Total Score: 18
# Question 1: Correct
# Question 2: Correct
# Question 3: Correct
# Question 4: Correct
# Question 5: Correct
# Question 6: Incorrect
# Question 7: Correct
# Question 8: Incorrect
# Question 9: Correct
# Question 10: Incorrect
# Question 11: Incorrect
# Question 12: Incorrect
# Question 13: Incorrect
# Question 14: Incorrect
# Question 15: Correct
# Question 16: Incorrect
# Question 17: Incorrect
# Question 18: Incorrect
# Question 19: Incorrect
# Question 20: Incorrect
# Question 21: Correct
# Question 22: Incorrect
# Question 23: Incorrect
# Question 24: Correct
# Question 25: Correct
# Question 26: Correct
# Question 27: Incorrect
# Question 28: Correct
# Question 29: Incorrect
# Question 30: Incorrect
# Question 31: Incorrect
# Question 32: Incorrect
# Question 33: Correct
# Question 34: Correct
# Question 35: Correct
# Question 36: Incorrect
# Question 37: Correct
# Question 38: Correct
# Question 39: Incorrect
# Question 40: Incorrect

# %% [markdown]
# ## extra verification step

# %% [markdown]
# ### Group Circle by radius

# %% [markdown]
# this can be used to verify that the detected circles are answer circles. Now we are not using this. we will use this after we finish the core of the function.

# %%
import cv2
import numpy as np
from collections import defaultdict

def group_circles_by_radius(circles, img, tolerance_percentage=20):
    """
    Groups circles based on their radius with a given tolerance percentage of the y-coordinate.
    
    Args:
        circles (array): List of detected circles [(x, y, r)].
        img (numpy array): The original image.
        tolerance_percentage (float): Tolerance as a percentage of the y-coordinate (default is 20%).
        
    Returns:
        dict: Groups of circles based on their radius.
    """
    radius_groups = defaultdict(list)
    
    # Iterate over the detected circles and group them by radius
    for circle in circles:
        x, y, r = circle[0], circle[1], circle[2]

        if not radius_groups:
            # If no groups exist yet, start a new group with the first circle
            radius_groups[r].append((x, y, r))
        else:
            matched_group = None
            for existing_radius in radius_groups.keys():
                diff = abs(int(r) - int(existing_radius))
                
                # Calculate tolerance based on the radius
                tol = (tolerance_percentage / 100.0) * existing_radius

                if diff <= tol:
                    matched_group = existing_radius
                    break

            if matched_group is not None:
                radius_groups[matched_group].append((x, y, r))
            else:
                radius_groups[r].append((x, y, r))

    # Print the radius groups for debugging
    for radius, grouped_circles in radius_groups.items():
        print(f"Radius: {radius}, Circles: {grouped_circles}")
        
    # Visualize each group of circles in separate images
    for radius, grouped_circles in radius_groups.items():
        img_copy = img.copy()  # Create a copy of the original image to visualize each group
        
        for x, y, r in grouped_circles:
            cv2.circle(img_copy, (x, y), r, (0, 255, 0), 2)  # Draw outer circle
            cv2.circle(img_copy, (x, y), 2, (0, 0, 255), 3)  # Draw center

        # Display the grouped circles in a separate window
        cv2.imshow(f'Circles with radius ~ {radius}', img_copy)
        cv2.waitKey(0)
    
    return radius_groups



# if detected_circles is not None:
#     detected_circles = np.uint16(np.around(detected_circles))

#     # Call the function with the detected circles and image
#     group_circles_by_radius(detected_circles[0, :], img, tolerance_percentage=20)

cv2.destroyAllWindows()
